# %%
import os
import pandas

# %%
print(os.getcwd())
metadata_file = "../OspC_typing/longread_metadata_v3.csv"
metadata = pandas.read_csv(metadata_file)
metadata.shape
# Out:
# /Users/mf019/bioinformatics/longread_GWAS/notebooks/data_wranglin
# (379, 11)

# %%
metadata.fillna("unknown", inplace=True)

# %%
metadata
# Out:
#              Isolate MLST RST_Type   Source Origin Location skin/blood_pairs  \
# 0    5A18NP1-JBb08-A    1  unknown  culture     US       NY          unknown
# 1             UNY147   34      3.0  unknown     US       NY          unknown
# 2    5A18NP1-JBb08-C    1  unknown  culture     US       NY          unknown
# 3    5A18NP1-JBb08-B    1  unknown  culture     US       NY          unknown
# 4    5A18NP1-JBb08-E    1  unknown  culture     US       NY          unknown
# ..               ...  ...      ...      ...    ...      ...              ...
# 374              K60    1      1.0  unknown     US       RI          unknown
# 375              K82    3      2.0  unknown     US       RI          unknown
# 376              K11    3      2.0  unknown     US       CT          unknown
# 377              K59    3      2.0  unknown     US       RI          unknown
# 378              K69    1      1.0  unknown     US       CT          unknown
#
# ...
