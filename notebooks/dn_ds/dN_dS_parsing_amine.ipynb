# %%
import pandas
import os
import glob
from collections import defaultdict

# %%
def parse_lines(lines, i, y):
    line_x = lines[i+1].strip()
    log_l_x = line_x.split(',')[0].split('=')[1]
    aicc_x = line_x.split(',')[1].split('=')[1].split("(")[0]
    line_y = lines[i+y].strip()
    dnds_y = line_y.split('=')[1]
    return log_l_x.strip(), aicc_x.strip(), dnds_y.strip()

def process_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    gene = os.path.basename(file_path).split('.')[0]
    new_line = defaultdict()
    new_line["gene"] = gene
    a_gtr = None
    b_gtr = None
    c_gtr = None
    a_cod = None
    b_cod = None
    c_cod = None
    p_value_line = None
    gtr_string = 'Obtaining the global omega estimate based on relative GTR branch lengths and nucleotide substitution biases'
    dn_ds_string = 'Improving branch lengths, nucleotide substitution biases, and global dN/dS ratios under a full codon model'
    p_value_string = 'Branch-site unrestricted statistical test of episodic diversification'
    dnds_string = 'Diversifying selection'

    i = 0
    while i < len(lines):
        line = lines[i].strip()
        if line.startswith('#'):
            if gtr_string in line:
                a_gtr,b_gtr,c_gtr = parse_lines(lines, i, 3)
                #print(a_gtr,b_gtr,c_gtr)
                new_line["gtr_log_l"] = a_gtr
                new_line["gtr_aicc"] = b_gtr
                new_line["gtr_dnds"] = c_gtr
            elif dn_ds_string in line:
                a_cod, b_cod, c_cod = parse_lines(lines, i, 2)
                #print(a_cod,b_cod,c_cod)
                new_line["codon_log_l"] = a_cod
                new_line["codon_aicc"] = b_cod
                new_line["codon_dnds"] = c_cod
            elif p_value_string in line:
                p_value_line = lines[i+1].strip()
                p_val = p_value_line.split('=')[1].split('*')[0].strip()
                #print(p_val)
                new_line["p_val"] = p_val
        elif dnds_string in line:
            print(line)
            dnds_val = line.split('|')[2].strip()
            dnds_proportion = line.split('|')[3].strip()
            dnds_note = str(line.split('|')[4].strip())
            print(dnds_val, dnds_proportion, dnds_note)
            new_line['dNdS'] = dnds_val
            new_line['dNdS_proportion'] = dnds_proportion
            new_line['dNdS_note'] = dnds_note
        i += 1
    return new_line

# %%
dir_of_results = 'results'
results_files = glob.glob(f'{dir_of_results}/*.txt')

# %%
col_names = ["gene","gtr_log_l","gtr_aicc","gtr_dnds","codon_log_l","codon_aicc","codon_dnds","p_val", "dNdS", "dNdS_proportion", "dNdS_note"]
rows = []
for infile in results_files:
    print(infile)
    new_line = process_file(infile)
    rows.append(new_line)

results_df = pandas.DataFrame(rows, columns=col_names)
results_df.reset_index(drop=True)
# Out:
# results/GC_00000978-busted.txt
# |      Diversifying selection       |    297.825    |    6.495    |                                   |
# 297.825 6.495
# |      Diversifying selection       |    16.010     |   35.858    |                                   |
# 16.010 35.858
# results/GC_00000294-busted.txt
# |      Diversifying selection       |     4.701     |    0.000    |       Not supported by data       |
# 4.701 0.000 Not supported by data
# results/GC_00000594-busted.txt
# |      Diversifying selection       |    170.614    |   19.191    |                                   |
# 170.614 19.191
# results/GC_00000480-busted.txt
# results/GC_00000839-busted.txt
# |      Diversifying selection       |  150880.454   |    7.666    |                                   |
# 150880.454 7.666
# |      Diversifying selection       |     1.168     |    0.000    |       Not supported by data       |
# 1.168 0.000 Not supported by data
# results/GC_00001136-busted.txt
# results/GC_00000157-busted.txt
# |      Diversifying selection       |     2.054     |    0.000    |       Not supported by data       |
# 2.054 0.000 Not supported by data
# results/GC_00000160-busted.txt
# |      Diversifying selection       |     1.197     |    0.000    |       Not supported by data       |
# 1.197 0.000 Not supported by data
# results/GC_00000602-busted.txt
# results/GC_00001022-busted.txt
# results/GC_00000721-busted.txt
# results/GC_00000716-busted.txt
# |      Diversifying selection       |     6.854     |    0.000    |       Not supported by data       |
# 6.854 0.000 Not supported by data
# results/GC_00000209-busted.txt
# |      Diversifying selection       |     3.339     |    0.000    |       Not supported by data       |
# 3.339 0.000 Not supported by data
# results/GC_00001015-busted.txt
# |      Diversifying selection       |     1.293     |    0.000    |       Not supported by data       |
# 1.293 0.000 Not supported by data
# results/GC_00000348-busted.txt
# |      Diversifying selection       |     3.860     |    0.244    |                                   |
# 3.860 0.244
# results/GC_00000657-busted.txt
# |      Diversifying selection       |     6.160     |    0.000    |       Not supported by data       |
# 6.160 0.000 Not supported by data
# results/GC_00000660-busted.txt
# |      Diversifying selection       |     6.137     |    0.000    |       Not supported by data       |
# 6.137 0.000 Not supported by data
# results/GC_00001163-busted.txt
# results/GC_00000893-busted.txt
# |      Diversifying selection       |     2.718     |    0.000    |       Not supported by data       |
# 2.718 0.000 Not supported by data
# results/GC_00000743-busted.txt
# results/GC_00000509-busted.txt
# |      Diversifying selection       |     1.002     |    0.000    |       Not supported by data       |
# 1.002 0.000 Not supported by data
# results/GC_00000987-busted.txt
# results/GC_00000774-busted.txt
# |      Diversifying selection       |    196.746    |   32.073    |                                   |
# 196.746 32.073
# results/GC_00000847-busted.txt
# |      Diversifying selection       |     1.007     |    0.000    |       Not supported by data       |
# 1.007 0.000 Not supported by data
# results/GC_00001180-busted.txt
# |      Diversifying selection       |     1.991     |    2.354    |                                   |
# 1.991 2.354
# results/GC_00000683-busted.txt
# |      Diversifying selection       |     1.007     |    0.000    |       Not supported by data       |
# 1.007 0.000 Not supported by data
# results/GC_00000870-busted.txt
# |      Diversifying selection       |     5.796     |    0.000    |       Not supported by data       |
# 5.796 0.000 Not supported by data
# results/GC_00000953-busted.txt
# |      Diversifying selection       |     1.095     |    0.000    |       Not supported by data       |
# 1.095 0.000 Not supported by data
# results/GC_00000964-busted.txt
# |      Diversifying selection       |     3.129     |    0.000    |       Not supported by data       |
# 3.129 0.000 Not supported by data
# results/GC_00000797-busted.txt
# results/GC_00000288-busted.txt
# |      Diversifying selection       |     4.268     |    0.000    |       Not supported by data       |
# 4.268 0.000 Not supported by data
# results/GC_00000825-busted.txt
# |      Diversifying selection       |     1.024     |    0.000    |       Not supported by data       |
# 1.024 0.000 Not supported by data
# results/GC_00000183-busted.txt
# |      Diversifying selection       |     1.199     |    0.000    |       Not supported by data       |
# 1.199 0.000 Not supported by data
# results/GC_00000812-busted.txt
# results/GC_00000931-busted.txt
# results/GC_00000906-busted.txt
# |      Diversifying selection       |     2.204     |    0.000    |       Not supported by data       |
# 2.204 0.000 Not supported by data
# results/GC_00000588-busted.txt
# results/GC_00000215-busted.txt
# |      Diversifying selection       |     3.023     |    0.000    |       Not supported by data       |
# 3.023 0.000 Not supported by data
# results/GC_00001009-busted.txt
# results/GC_00000577-busted.txt
# |      Diversifying selection       |     2.741     |   10.582    |                                   |
# 2.741 10.582
# results/GC_00000540-busted.txt
# |      Diversifying selection       |     4.499     |    0.000    |       Not supported by data       |
# 4.499 0.000 Not supported by data
# results/GC_00000222-busted.txt
# |      Diversifying selection       |     3.681     |    0.000    |       Not supported by data       |
# 3.681 0.000 Not supported by data
# results/GC_00000463-busted.txt
# |      Diversifying selection       |     1.158     |    0.000    |       Not supported by data       |
# 1.158 0.000 Not supported by data
# results/GC_00000301-busted.txt
# results/GC_00000336-busted.txt
# |      Diversifying selection       |     1.085     |    0.000    |       Not supported by data       |
# 1.085 0.000 Not supported by data
# results/GC_00000629-busted.txt
# |      Diversifying selection       |     3.543     |    0.000    |       Not supported by data       |
# 3.543 0.000 Not supported by data
# results/GC_00000454-busted.txt
# |      Diversifying selection       |    381.043    |    1.651    |                                   |
# 381.043 1.651
# results/GC_00001216-busted.txt
# |      Diversifying selection       |    30.058     |   100.000   |                                   |
# 30.058 100.000
# results/GC_00000515-busted.txt
# |      Diversifying selection       |    189.368    |    1.707    |                                   |
# 189.368 1.707
# results/GC_00000768-busted.txt
# |      Diversifying selection       |     1.250     |    0.000    |       Not supported by data       |
# 1.250 0.000 Not supported by data
# results/GC_00000277-busted.txt
# |      Diversifying selection       |     1.397     |    0.000    |       Not supported by data       |
# 1.397 0.000 Not supported by data
# results/GC_00000240-busted.txt
# |      Diversifying selection       |     2.167     |    0.000    |       Not supported by data       |
# 2.167 0.000 Not supported by data
# results/GC_00000522-busted.txt
# |      Diversifying selection       |     1.695     |    0.000    |       Not supported by data       |
# 1.695 0.000 Not supported by data
# results/GC_00001221-busted.txt
# |      Diversifying selection       |     4.018     |    0.114    |                                   |
# 4.018 0.114
# results/GC_00000363-busted.txt
# results/GC_00000401-busted.txt
# |      Diversifying selection       |     3.453     |    0.000    |       Not supported by data       |
# 3.453 0.000 Not supported by data
# results/GC_00000436-busted.txt
# results/GC_00001148-busted.txt
# results/GC_00000354-busted.txt
# |      Diversifying selection       |   2157.931    |    1.414    |                                   |
# 2157.931 1.414
# results/GC_00000427-busted.txt
# |      Diversifying selection       |     1.988     |    0.000    |       Not supported by data       |
# 1.988 0.000 Not supported by data
# results/GC_00000345-busted.txt
# |      Diversifying selection       |     2.840     |    0.000    |       Not supported by data       |
# 2.840 0.000 Not supported by data
# results/GC_00001159-busted.txt
# results/GC_00000372-busted.txt
# |      Diversifying selection       |     1.985     |    0.000    |       Not supported by data       |
# 1.985 0.000 Not supported by data
# results/GC_00000410-busted.txt
# results/GC_00000251-busted.txt
# |      Diversifying selection       |    785.670    |    0.185    |                                   |
# 785.670 0.185
# results/GC_00001230-busted.txt
# |      Diversifying selection       |     4.513     |    0.091    |                                   |
# 4.513 0.091
# results/GC_00000533-busted.txt
# |      Diversifying selection       |     1.002     |    0.000    |       Not supported by data       |
# 1.002 0.000 Not supported by data
# results/GC_00000504-busted.txt
# |      Diversifying selection       |     3.407     |    0.000    |       Not supported by data       |
# 3.407 0.000 Not supported by data
# results/GC_00001207-busted.txt
# |      Diversifying selection       |     7.613     |    0.004    |       Not supported by data       |
# 7.613 0.004 Not supported by data
# results/GC_00000266-busted.txt
# |      Diversifying selection       |   40639.678   |    0.609    |                                   |
# 40639.678 0.609
# results/GC_00000779-busted.txt
# results/GC_00000327-busted.txt
# results/GC_00000445-busted.txt
# results/GC_00000472-busted.txt
# |      Diversifying selection       |     4.422     |    1.227    |                                   |
# 4.422 1.227
# results/GC_00000310-busted.txt
# |      Diversifying selection       |     2.625     |    0.000    |       Not supported by data       |
# 2.625 0.000 Not supported by data
# results/GC_00000551-busted.txt
# |      Diversifying selection       |     2.214     |    0.000    |       Not supported by data       |
# 2.214 0.000 Not supported by data
# results/GC_00000233-busted.txt
# |      Diversifying selection       |     2.150     |    0.000    |       Not supported by data       |
# 2.150 0.000 Not supported by data
# results/GC_00001018-busted.txt
# |      Diversifying selection       |     8.486     |   23.234    |                                   |
# 8.486 23.234
# results/GC_00000204-busted.txt
# results/GC_00000566-busted.txt
# results/GC_00000917-busted.txt
# |      Diversifying selection       |     1.483     |    7.227    |                                   |
# 1.483 7.227
# results/GC_00000599-busted.txt
# |      Diversifying selection       |     5.470     |    0.000    |       Not supported by data       |
# 5.470 0.000 Not supported by data
# results/GC_00000920-busted.txt
# results/busted_pval.txt
# results/GC_00000803-busted.txt
# |      Diversifying selection       |     2.772     |    0.000    |       Not supported by data       |
# 2.772 0.000 Not supported by data
# results/GC_00000192-busted.txt
# |      Diversifying selection       |     3.828     |    0.000    |       Not supported by data       |
# 3.828 0.000 Not supported by data
# results/GC_00000834-busted.txt
# results/GC_00000975-busted.txt
# |      Diversifying selection       |     3.887     |    0.000    |       Not supported by data       |
# 3.887 0.000 Not supported by data
# results/GC_00000299-busted.txt
# results/GC_00000692-busted.txt
# |      Diversifying selection       |     3.993     |    0.000    |       Not supported by data       |
# 3.993 0.000 Not supported by data
# results/GC_00001191-busted.txt
# |      Diversifying selection       |     2.732     |    6.640    |                                   |
# 2.732 6.640
# results/GC_00000856-busted.txt
# results/GC_00000518-busted.txt
# results/GC_00000996-busted.txt
# |      Diversifying selection       |9999999171.5...|   23.074    |                                   |
# 9999999171.5... 23.074
# results/GC_00000765-busted.txt
# |      Diversifying selection       |     1.003     |    0.000    |       Not supported by data       |
# 1.003 0.000 Not supported by data
# results/GC_00001066-busted.txt
# |      Diversifying selection       |     4.497     |    0.000    |       Not supported by data       |
# 4.497 0.000 Not supported by data
# results/GC_00001172-busted.txt
# |      Diversifying selection       |9999999171.5...|    3.045    |                                   |
# 9999999171.5... 3.045
# |      Diversifying selection       |    569.347    |    6.375    |                                   |
# 569.347 6.375
# results/GC_00000671-busted.txt
# results/GC_00000882-busted.txt
# |      Diversifying selection       |     5.285     |    0.000    |       Not supported by data       |
# 5.285 0.000 Not supported by data
# results/GC_00000646-busted.txt
# |      Diversifying selection       |     3.179     |    0.000    |       Not supported by data       |
# 3.179 0.000 Not supported by data
# results/GC_00000359-busted.txt
# results/GC_00001145-busted.txt
# |      Diversifying selection       |     2.328     |    0.000    |       Not supported by data       |
# 2.328 0.000 Not supported by data
# results/GC_00001004-busted.txt
# results/GC_00000218-busted.txt
# results/GC_00000707-busted.txt
# results/GC_00000730-busted.txt
# |      Diversifying selection       |     3.714     |    0.000    |       Not supported by data       |
# 3.714 0.000 Not supported by data
# results/GC_00001033-busted.txt
# |      Diversifying selection       |    212.982    |   10.308    |                                   |
# 212.982 10.308
# results/GC_00000171-busted.txt
# |      Diversifying selection       |     2.488     |    0.000    |       Not supported by data       |
# 2.488 0.000 Not supported by data
# results/GC_00000613-busted.txt
# results/GC_00000624-busted.txt
# |      Diversifying selection       |     3.759     |    0.000    |       Not supported by data       |
# 3.759 0.000 Not supported by data
# results/GC_00000459-busted.txt
# results/GC_00000828-busted.txt
# |      Diversifying selection       |    460.695    |    0.617    |                                   |
# 460.695 0.617
# results/GC_00000491-busted.txt
# |      Diversifying selection       |     1.613     |    0.000    |       Not supported by data       |
# 1.613 0.000 Not supported by data
# results/GC_00000585-busted.txt
# |      Diversifying selection       |     5.477     |    0.000    |       Not supported by data       |
# 5.477 0.000 Not supported by data
# results/GC_00000391-busted.txt
# |      Diversifying selection       |     2.179     |   21.739    |                                   |
# 2.179 21.739
# results/GC_00000969-busted.txt
# |      Diversifying selection       |     2.376     |    6.758    |                                   |
# 2.376 6.758
# results/GC_00000285-busted.txt
# |      Diversifying selection       |9999999171.5...|   41.932    |                                   |
# 9999999171.5... 41.932
# |      Diversifying selection       |     1.644     |   100.000   |                                   |
# 1.644 100.000
# results/GC_00001099-busted.txt
# |      Diversifying selection       |     2.437     |   100.000   |                                   |
# 2.437 100.000
# results/GC_00000831-busted.txt
# |      Diversifying selection       |     1.185     |    0.000    |       Not supported by data       |
# 1.185 0.000 Not supported by data
# results/GC_00000197-busted.txt
# |      Diversifying selection       |     3.827     |    0.000    |       Not supported by data       |
# 3.827 0.000 Not supported by data
# results/GC_00000488-busted.txt
# |      Diversifying selection       |     3.853     |    0.000    |       Not supported by data       |
# 3.853 0.000 Not supported by data
# results/GC_00000806-busted.txt
# |      Diversifying selection       |    29.104     |    1.640    |                                   |
# 29.104 1.640
# results/GC_00000912-busted.txt
# |      Diversifying selection       |     1.002     |    0.000    |       Not supported by data       |
# 1.002 0.000 Not supported by data
# results/GC_00000853-busted.txt
# results/GC_00000388-busted.txt
# |      Diversifying selection       |     3.807     |    0.000    |       Not supported by data       |
# 3.807 0.000 Not supported by data
# results/GC_00001194-busted.txt
# |      Diversifying selection       |     3.143     |    0.000    |       Not supported by data       |
# 3.143 0.000 Not supported by data
# results/GC_00000697-busted.txt
# results/GC_00000864-busted.txt
# results/GC_00000970-busted.txt
# |      Diversifying selection       |     3.719     |    0.000    |       Not supported by data       |
# 3.719 0.000 Not supported by data
# results/GC_00001202-busted.txt
# results/GC_00000501-busted.txt
# |      Diversifying selection       |9999999171.5...|    0.061    |                                   |
# 9999999171.5... 0.061
# results/GC_00000263-busted.txt
# |      Diversifying selection       |     8.910     |    2.292    |                                   |
# 8.910 2.292
# results/GC_00000254-busted.txt
# results/GC_00001048-busted.txt
# results/GC_00000536-busted.txt
# |      Diversifying selection       |    18.266     |   100.000   |                                   |
# 18.266 100.000
# results/GC_00000377-busted.txt
# |      Diversifying selection       |     2.852     |    0.000    |       Not supported by data       |
# 2.852 0.000 Not supported by data
# results/GC_00000668-busted.txt
# results/GC_00000415-busted.txt
# results/GC_00000422-busted.txt
# results/GC_00000340-busted.txt
# |      Diversifying selection       |    40.240     |    1.691    |                                   |
# 40.240 1.691
# results/GC_00000201-busted.txt
# |      Diversifying selection       |     3.152     |    0.000    |       Not supported by data       |
# 3.152 0.000 Not supported by data
# results/GC_00000563-busted.txt
# |      Diversifying selection       |    873.419    |    1.443    |                                   |
# 873.419 1.443
# results/GC_00000554-busted.txt
# results/GC_00000729-busted.txt
# |      Diversifying selection       |     6.369     |    0.000    |       Not supported by data       |
# 6.369 0.000 Not supported by data
# results/GC_00000236-busted.txt
# results/GC_00000168-busted.txt
# |      Diversifying selection       |     3.150     |    0.000    |       Not supported by data       |
# 3.150 0.000 Not supported by data
# results/GC_00000477-busted.txt
# |      Diversifying selection       |    572.628    |    0.369    |                                   |
# 572.628 0.369
# results/GC_00000315-busted.txt
# results/GC_00000322-busted.txt
# |      Diversifying selection       |    583.729    |    2.519    |                                   |
# 583.729 2.519
# results/GC_00000440-busted.txt
# results/GC_00000580-busted.txt
# results/GC_00000939-busted.txt
# |      Diversifying selection       |     1.324     |    0.000    |       Not supported by data       |
# 1.324 0.000 Not supported by data
# results/GC_00000494-busted.txt
# |      Diversifying selection       |     3.978     |    1.222    |                                   |
# 3.978 1.222
# results/GC_00000280-busted.txt
# |      Diversifying selection       |    11.431     |    2.917    |                                   |
# 11.431 2.917
# results/GC_00000394-busted.txt
# results/GC_00000878-busted.txt
# |      Diversifying selection       |     2.659     |    0.000    |       Not supported by data       |
# 2.659 0.000 Not supported by data
# results/GC_00000643-busted.txt
# results/GC_00000674-busted.txt
# results/GC_00001177-busted.txt
# |      Diversifying selection       |     1.172     |    0.000    |       Not supported by data       |
# 1.172 0.000 Not supported by data
# results/GC_00000887-busted.txt
# |      Diversifying selection       |     5.974     |    0.000    |       Not supported by data       |
# 5.974 0.000 Not supported by data
# results/GC_00000409-busted.txt
# |      Diversifying selection       |     2.101     |    0.000    |       Not supported by data       |
# 2.101 0.000 Not supported by data
# results/GC_00000757-busted.txt
# |      Diversifying selection       |     2.195     |    0.000    |       Not supported by data       |
# 2.195 0.000 Not supported by data
# results/GC_00000248-busted.txt
# |      Diversifying selection       |     1.006     |    0.000    |       Not supported by data       |
# 1.006 0.000 Not supported by data
# results/GC_00001054-busted.txt
# |      Diversifying selection       |     8.670     |    0.000    |       Not supported by data       |
# 8.670 0.000 Not supported by data
# results/GC_00000993-busted.txt
# |      Diversifying selection       |   13305.669   |    4.656    |                                   |
# 13305.669 4.656
# results/GC_00001063-busted.txt
# results/GC_00000760-busted.txt
# |      Diversifying selection       |     1.213     |    0.000    |       Not supported by data       |
# 1.213 0.000 Not supported by data
# results/GC_00000621-busted.txt
# |      Diversifying selection       |    93.699     |    1.863    |                                   |
# 93.699 1.863
# results/GC_00001122-busted.txt
# |      Diversifying selection       |    56.998     |   100.000   |                                   |
# 56.998 100.000
# results/GC_00000174-busted.txt
# results/GC_00001115-busted.txt
# |      Diversifying selection       |  866907.556   |   47.192    |                                   |
# 866907.556 47.192
# results/GC_00000309-busted.txt
# |      Diversifying selection       |     5.526     |    0.000    |       Not supported by data       |
# 5.526 0.000 Not supported by data
# results/GC_00000616-busted.txt
# results/GC_00000548-busted.txt
# results/GC_00001036-busted.txt
# results/GC_00000735-busted.txt
# results/GC_00000702-busted.txt
# |      Diversifying selection       |    194.454    |    3.412    |                                   |
# 194.454 3.412
# |      Diversifying selection       |     1.001     |   16.954    |       Collapsed rate class        |
# 1.001 16.954 Collapsed rate class
# results/GC_00001001-busted.txt
# |      Diversifying selection       |  130735.645   |    0.035    |                                   |
# 130735.645 0.035
# results/GC_00001010-busted.txt
# |      Diversifying selection       |    148.499    |   100.000   |                                   |
# 148.499 100.000
# |      Diversifying selection       |    50.108     |   100.000   |                                   |
# 50.108 100.000
# results/GC_00000713-busted.txt
# |      Diversifying selection       |     3.130     |    0.000    |       Not supported by data       |
# 3.130 0.000 Not supported by data
# results/GC_00000559-busted.txt
# |      Diversifying selection       |     5.409     |    1.942    |                                   |
# 5.409 1.942
# results/GC_00001027-busted.txt
# |      Diversifying selection       |9999999171.5...|    3.579    |                                   |
# 9999999171.5... 3.579
# |      Diversifying selection       |     1.168     |    0.000    |       Not supported by data       |
# 1.168 0.000 Not supported by data
# results/GC_00000165-busted.txt
# |      Diversifying selection       |     3.754     |    0.000    |       Not supported by data       |
# 3.754 0.000 Not supported by data
# results/GC_00000607-busted.txt
# results/GC_00000318-busted.txt
# results/GC_00001104-busted.txt
# |      Diversifying selection       |     4.777     |   26.416    |                                   |
# 4.777 26.416
# results/GC_00000630-busted.txt
# |      Diversifying selection       |     4.072     |    0.000    |       Not supported by data       |
# 4.072 0.000 Not supported by data
# results/GC_00000152-busted.txt
# |      Diversifying selection       |     2.279     |    0.000    |       Not supported by data       |
# 2.279 0.000 Not supported by data
# results/GC_00000982-busted.txt
# |      Diversifying selection       |    13.635     |    5.836    |                                   |
# 13.635 5.836
# results/GC_00000771-busted.txt
# results/GC_00001072-busted.txt
# |      Diversifying selection       |   1310.652    |    0.156    |                                   |
# 1310.652 0.156
# results/GC_00001045-busted.txt
# results/GC_00000259-busted.txt
# results/GC_00000746-busted.txt
# results/GC_00001166-busted.txt
# |      Diversifying selection       |9999999171.5...|   20.934    |                                   |
# 9999999171.5... 20.934
# |      Diversifying selection       |    29.633     |   100.000   |                                   |
# 29.633 100.000
# results/GC_00000665-busted.txt
# |      Diversifying selection       |     4.655     |    0.000    |       Not supported by data       |
# 4.655 0.000 Not supported by data
# results/GC_00000418-busted.txt
# results/GC_00001151-busted.txt
# |      Diversifying selection       |     5.323     |    2.689    |                                   |
# 5.323 2.689
# results/GC_00000385-busted.txt
# results/GC_00000869-busted.txt
# results/GC_00000291-busted.txt
# |      Diversifying selection       |     3.332     |    0.000    |       Not supported by data       |
# 3.332 0.000 Not supported by data
# results/GC_00000485-busted.txt
# results/GC_00000928-busted.txt
# results/GC_00000591-busted.txt
# |      Diversifying selection       |     4.525     |    0.000    |       Not supported by data       |
# 4.525 0.000 Not supported by data
# results/GC_00000333-busted.txt
# results/GC_00000451-busted.txt
# results/GC_00000466-busted.txt
# |      Diversifying selection       |     1.148     |    0.000    |       Not supported by data       |
# 1.148 0.000 Not supported by data
# results/GC_00000179-busted.txt
# |      Diversifying selection       |     3.905     |    0.000    |       Not supported by data       |
# 3.905 0.000 Not supported by data
# results/GC_00000304-busted.txt
# |      Diversifying selection       |     3.912     |    0.000    |       Not supported by data       |
# 3.912 0.000 Not supported by data
# results/GC_00000545-busted.txt
# results/GC_00000227-busted.txt
# results/GC_00000738-busted.txt
# |      Diversifying selection       |     5.306     |    0.000    |       Not supported by data       |
# 5.306 0.000 Not supported by data
# results/GC_00000210-busted.txt
# |      Diversifying selection       |     3.444     |    0.000    |       Not supported by data       |
# 3.444 0.000 Not supported by data
# results/GC_00000572-busted.txt
# |      Diversifying selection       |     6.361     |    0.000    |       Not supported by data       |
# 6.361 0.000 Not supported by data
# results/GC_00000433-busted.txt
# |      Diversifying selection       |     4.009     |    0.000    |       Not supported by data       |
# 4.009 0.000 Not supported by data
# results/GC_00000351-busted.txt
# results/GC_00000679-busted.txt
# results/GC_00000366-busted.txt
# results/GC_00000404-busted.txt
# |      Diversifying selection       |    289.057    |   21.028    |                                   |
# 289.057 21.028
# results/GC_00001059-busted.txt
# |      Diversifying selection       |     3.143     |    0.000    |       Not supported by data       |
# 3.143 0.000 Not supported by data
# results/GC_00000245-busted.txt
# |      Diversifying selection       |     6.399     |    0.000    |       Not supported by data       |
# 6.399 0.000 Not supported by data
# results/GC_00000527-busted.txt
# results/GC_00000510-busted.txt
# |      Diversifying selection       |   2015.946    |    1.168    |                                   |
# 2015.946 1.168
# results/GC_00001213-busted.txt
# |      Diversifying selection       |    10.858     |    2.328    |                                   |
# 10.858 2.328
# results/GC_00000272-busted.txt
# |      Diversifying selection       |   10206.875   |    0.480    |                                   |
# 10206.875 0.480
# results/GC_00000792-busted.txt
# results/GC_00000956-busted.txt
# results/GC_00000686-busted.txt
# |      Diversifying selection       |     6.251     |    0.000    |       Not supported by data       |
# 6.251 0.000 Not supported by data
# results/GC_00001185-busted.txt
# |      Diversifying selection       |     6.984     |    0.000    |       Not supported by data       |
# 6.984 0.000 Not supported by data
# results/GC_00000399-busted.txt
# results/GC_00000875-busted.txt
# |      Diversifying selection       |    10.493     |    0.000    |       Not supported by data       |
# 10.493 0.000 Not supported by data
# results/GC_00000842-busted.txt
# results/GC_00000903-busted.txt
# |      Diversifying selection       |     1.003     |    0.000    |       Not supported by data       |
# 1.003 0.000 Not supported by data
# results/GC_00000934-busted.txt
# results/GC_00000499-busted.txt
# |      Diversifying selection       |9999999171.5...|    0.216    |                                   |
# 9999999171.5... 0.216
# results/GC_00000817-busted.txt
# results/GC_00000186-busted.txt
# |      Diversifying selection       |     3.091     |    0.000    |       Not supported by data       |
# 3.091 0.000 Not supported by data
# results/GC_00000820-busted.txt
# results/GC_00000872-busted.txt
# results/GC_00000681-busted.txt
# results/GC_00001182-busted.txt
# |      Diversifying selection       |     5.641     |    0.151    |                                   |
# 5.641 0.151
# results/GC_00000845-busted.txt
# |      Diversifying selection       |     5.829     |    0.000    |       Not supported by data       |
# 5.829 0.000 Not supported by data
# results/GC_00000795-busted.txt
# |      Diversifying selection       |     1.554     |    0.000    |       Not supported by data       |
# 1.554 0.000 Not supported by data
# results/GC_00000966-busted.txt
# |      Diversifying selection       |     4.085     |    0.683    |                                   |
# 4.085 0.683
# results/GC_00000810-busted.txt
# |      Diversifying selection       |     4.944     |    0.000    |       Not supported by data       |
# 4.944 0.000 Not supported by data
# results/GC_00000181-busted.txt
# |      Diversifying selection       |     4.057     |    0.000    |       Not supported by data       |
# 4.057 0.000 Not supported by data
# results/GC_00000220-busted.txt
# |      Diversifying selection       |     1.949     |    0.000    |       Not supported by data       |
# 1.949 0.000 Not supported by data
# results/GC_00000542-busted.txt
# |      Diversifying selection       |     1.806     |    0.000    |       Not supported by data       |
# 1.806 0.000 Not supported by data
# results/GC_00000575-busted.txt
# |      Diversifying selection       |     1.466     |    0.000    |       Not supported by data       |
# 1.466 0.000 Not supported by data
# results/GC_00000708-busted.txt
# results/GC_00000217-busted.txt
# |      Diversifying selection       |     3.532     |    0.000    |       Not supported by data       |
# 3.532 0.000 Not supported by data
# results/GC_00000456-busted.txt
# |      Diversifying selection       |     1.132     |    0.000    |       Not supported by data       |
# 1.132 0.000 Not supported by data
# results/GC_00001128-busted.txt
# |      Diversifying selection       |     6.927     |    0.000    |       Not supported by data       |
# 6.927 0.000 Not supported by data
# results/GC_00000334-busted.txt
# |      Diversifying selection       |     5.896     |    0.000    |       Not supported by data       |
# 5.896 0.000 Not supported by data
# results/GC_00000303-busted.txt
# |      Diversifying selection       |    667.322    |    7.983    |                                   |
# 667.322 7.983
# results/GC_00000461-busted.txt
# |      Diversifying selection       |    427.135    |   14.575    |                                   |
# 427.135 14.575
# results/GC_00000520-busted.txt
# |      Diversifying selection       |     5.232     |    0.000    |       Not supported by data       |
# 5.232 0.000 Not supported by data
# results/GC_00000242-busted.txt
# |      Diversifying selection       |  635276.515   |    0.137    |                                   |
# 635276.515 0.137
# results/GC_00000275-busted.txt
# |      Diversifying selection       |   2953.730    |    0.729    |                                   |
# 2953.730 0.729
# results/GC_00001069-busted.txt
# results/GC_00000517-busted.txt
# |      Diversifying selection       |     3.081     |    0.000    |       Not supported by data       |
# 3.081 0.000 Not supported by data
# results/GC_00000999-busted.txt
# |      Diversifying selection       |    26.411     |    3.742    |                                   |
# 26.411 3.742
# results/GC_00001214-busted.txt
# |      Diversifying selection       |    615.534    |    5.855    |                                   |
# 615.534 5.855
# results/GC_00000356-busted.txt
# results/GC_00000649-busted.txt
# |      Diversifying selection       |     2.252     |    0.000    |       Not supported by data       |
# 2.252 0.000 Not supported by data
# results/GC_00000434-busted.txt
# results/GC_00000403-busted.txt
# results/GC_00000361-busted.txt
# |      Diversifying selection       |     3.402     |    0.000    |       Not supported by data       |
# 3.402 0.000 Not supported by data
# results/GC_00000789-busted.txt
# |      Diversifying selection       |    142.321    |    0.329    |                                   |
# 142.321 0.329
# results/GC_00000296-busted.txt
# |      Diversifying selection       |   3114.674    |    4.576    |                                   |
# 3114.674 4.576
# results/GC_00000859-busted.txt
# |      Diversifying selection       |    171.304    |    0.961    |                                   |
# 171.304 0.961
# results/GC_00000382-busted.txt
# |      Diversifying selection       |    273.053    |    1.416    |                                   |
# 273.053 1.416
# results/GC_00000596-busted.txt
# results/GC_00000482-busted.txt
# results/GC_00000600-busted.txt
# |      Diversifying selection       |     5.855     |    0.000    |       Not supported by data       |
# 5.855 0.000 Not supported by data
# results/GC_00000162-busted.txt
# |      Diversifying selection       |     3.095     |    0.000    |       Not supported by data       |
# 3.095 0.000 Not supported by data
# results/GC_00000155-busted.txt
# |      Diversifying selection       |     2.621     |    0.000    |       Not supported by data       |
# 2.621 0.000 Not supported by data
# results/GC_00001134-busted.txt
# |      Diversifying selection       |     1.408     |    0.000    |       Not supported by data       |
# 1.408 0.000 Not supported by data
# results/GC_00000328-busted.txt
# |      Diversifying selection       |     3.111     |    0.000    |       Not supported by data       |
# 3.111 0.000 Not supported by data
# results/GC_00000637-busted.txt
# results/GC_00000569-busted.txt
# results/GC_00001017-busted.txt
# results/GC_00000714-busted.txt
# |      Diversifying selection       |     4.847     |    0.000    |       Not supported by data       |
# 4.847 0.000 Not supported by data
# results/GC_00000723-busted.txt
# results/GC_00001020-busted.txt
# results/GC_00000891-busted.txt
# results/GC_00001161-busted.txt
# |      Diversifying selection       |    16.060     |    0.000    |       Not supported by data       |
# 16.060 0.000 Not supported by data
# results/GC_00000662-busted.txt
# results/GC_00000655-busted.txt
# |      Diversifying selection       |     4.862     |    0.000    |       Not supported by data       |
# 4.862 0.000 Not supported by data
# results/GC_00000428-busted.txt
# |      Diversifying selection       |     1.890     |    0.000    |       Not supported by data       |
# 1.890 0.000 Not supported by data
# results/GC_00000776-busted.txt
# |      Diversifying selection       |     4.416     |    0.000    |       Not supported by data       |
# 4.416 0.000 Not supported by data
# results/GC_00000269-busted.txt
# |      Diversifying selection       |    12.299     |   100.000   |                                   |
# 12.299 100.000
# results/GC_00001075-busted.txt
# results/GC_00001208-busted.txt
# |      Diversifying selection       |    13.512     |   10.022    |                                   |
# 13.512 10.022
# results/GC_00000985-busted.txt
# results/GC_00001042-busted.txt
# |      Diversifying selection       |     5.881     |   41.946    |                                   |
# 5.881 41.946
# |      Diversifying selection       |     1.386     |   100.000   |                                   |
# 1.386 100.000
# results/GC_00000741-busted.txt
# results/GC_00000750-busted.txt
# |      Diversifying selection       |     1.569     |    0.000    |       Not supported by data       |
# 1.569 0.000 Not supported by data
# results/GC_00001053-busted.txt
# |      Diversifying selection       |     3.990     |    0.000    |       Not supported by data       |
# 3.990 0.000 Not supported by data
# results/GC_00000278-busted.txt
# |      Diversifying selection       |9999999171.5...|   32.423    |                                   |
# 9999999171.5... 32.423
# results/GC_00000767-busted.txt
# |      Diversifying selection       |     3.974     |    0.000    |       Not supported by data       |
# 3.974 0.000 Not supported by data
# results/GC_00000994-busted.txt
# |      Diversifying selection       |    36.922     |    0.561    |                                   |
# 36.922 0.561
# |      Diversifying selection       |     1.080     |   12.332    |                                   |
# 1.080 12.332
# |      Diversifying selection       |     1.081     |   12.322    |                                   |
# 1.081 12.322
# |      Diversifying selection       |     1.079     |   12.327    |                                   |
# 1.079 12.327
# |      Diversifying selection       |     1.066     |   12.357    |                                   |
# 1.066 12.357
# |      Diversifying selection       |     1.074     |   12.329    |                                   |
# 1.074 12.329
# |      Diversifying selection       |     1.074     |   12.326    |                                   |
# 1.074 12.326
# results/GC_00001219-busted.txt
# |      Diversifying selection       |     7.131     |   12.006    |                                   |
# 7.131 12.006
# results/GC_00001147-busted.txt
# |      Diversifying selection       |    67.236     |   100.000   |                                   |
# 67.236 100.000
# results/GC_00000644-busted.txt
# results/GC_00000439-busted.txt
# |      Diversifying selection       |     3.213     |    0.000    |       Not supported by data       |
# 3.213 0.000 Not supported by data
# results/GC_00000880-busted.txt
# |      Diversifying selection       |     4.732     |    0.000    |       Not supported by data       |
# 4.732 0.000 Not supported by data
# results/GC_00000673-busted.txt
# |      Diversifying selection       |    89.751     |   20.479    |                                   |
# 89.751 20.479
# results/GC_00001170-busted.txt
# |      Diversifying selection       |    11.880     |    0.085    |                                   |
# 11.880 0.085
# results/GC_00001031-busted.txt
# |      Diversifying selection       |     2.289     |    0.000    |       Not supported by data       |
# 2.289 0.000 Not supported by data
# results/GC_00000732-busted.txt
# results/GC_00000578-busted.txt
# |      Diversifying selection       |     1.001     |    0.000    |       Not supported by data       |
# 1.001 0.000 Not supported by data
# results/GC_00000705-busted.txt
# |      Diversifying selection       |     5.264     |    0.000    |       Not supported by data       |
# 5.264 0.000 Not supported by data
# results/GC_00001006-busted.txt
# results/GC_00000626-busted.txt
# results/GC_00000339-busted.txt
# |      Diversifying selection       |    598.358    |    5.889    |                                   |
# 598.358 5.889
# results/GC_00001125-busted.txt
# results/GC_00000611-busted.txt
# |      Diversifying selection       |     1.114     |    0.000    |       Not supported by data       |
# 1.114 0.000 Not supported by data
# results/GC_00000173-busted.txt
# |      Diversifying selection       |     2.837     |    0.000    |       Not supported by data       |
# 2.837 0.000 Not supported by data
# results/GC_00000493-busted.txt
# |      Diversifying selection       |    27.427     |   100.000   |                                   |
# 27.427 100.000
# results/GC_00000587-busted.txt
# |      Diversifying selection       |    352.357    |    1.891    |                                   |
# 352.357 1.891
# results/GC_00000393-busted.txt
# results/GC_00000848-busted.txt
# results/GC_00000287-busted.txt
# |      Diversifying selection       |     4.296     |    0.000    |       Not supported by data       |
# 4.296 0.000 Not supported by data
# results/GC_00000798-busted.txt
# results/GC_00000412-busted.txt
# |      Diversifying selection       |     1.923     |    0.000    |       Not supported by data       |
# 1.923 0.000 Not supported by data
# results/GC_00000370-busted.txt
# results/GC_00000658-busted.txt
# |      Diversifying selection       |     2.328     |    0.000    |       Not supported by data       |
# 2.328 0.000 Not supported by data
# results/GC_00000347-busted.txt
# |      Diversifying selection       |     3.685     |    0.000    |       Not supported by data       |
# 3.685 0.000 Not supported by data
# results/GC_00000425-busted.txt
# |      Diversifying selection       |     1.368     |    0.000    |       Not supported by data       |
# 1.368 0.000 Not supported by data
# results/GC_00000264-busted.txt
# |      Diversifying selection       |     4.108     |    0.000    |       Not supported by data       |
# 4.108 0.000 Not supported by data
# results/GC_00001205-busted.txt
# |      Diversifying selection       |     6.282     |    6.556    |                                   |
# 6.282 6.556
# results/GC_00000506-busted.txt
# results/GC_00000988-busted.txt
# |      Diversifying selection       |     2.107     |    0.000    |       Not supported by data       |
# 2.107 0.000 Not supported by data
# results/GC_00000531-busted.txt
# |      Diversifying selection       |    467.244    |    2.880    |                                   |
# 467.244 2.880
# results/GC_00001232-busted.txt
# |      Diversifying selection       |     6.486     |   12.448    |                                   |
# 6.486 12.448
# results/GC_00000253-busted.txt
# results/GC_00000312-busted.txt
# |      Diversifying selection       |     1.478     |   15.131    |                                   |
# 1.478 15.131
# results/GC_00000470-busted.txt
# |      Diversifying selection       |    654.530    |    1.414    |                                   |
# 654.530 1.414
# results/GC_00000447-busted.txt
# |      Diversifying selection       |     1.648     |    0.000    |       Not supported by data       |
# 1.648 0.000 Not supported by data
# results/GC_00000158-busted.txt
# |      Diversifying selection       |     2.896     |    0.000    |       Not supported by data       |
# 2.896 0.000 Not supported by data
# results/GC_00000325-busted.txt
# results/GC_00001139-busted.txt
# results/GC_00000564-busted.txt
# |      Diversifying selection       |     6.729     |   11.446    |                                   |
# 6.729 11.446
# results/GC_00000206-busted.txt
# |      Diversifying selection       |     3.192     |    0.000    |       Not supported by data       |
# 3.192 0.000 Not supported by data
# results/GC_00000719-busted.txt
# results/GC_00000231-busted.txt
# |      Diversifying selection       |     1.438     |    0.000    |       Not supported by data       |
# 1.438 0.000 Not supported by data
# results/GC_00000553-busted.txt
# results/GC_00000922-busted.txt
# |      Diversifying selection       |     2.250     |    0.000    |       Not supported by data       |
# 2.250 0.000 Not supported by data
# results/GC_00000915-busted.txt
# results/GC_00000836-busted.txt
# results/GC_00000190-busted.txt
# |      Diversifying selection       |     1.190     |    0.000    |       Not supported by data       |
# 1.190 0.000 Not supported by data
# results/GC_00000784-busted.txt
# |      Diversifying selection       |     2.340     |    0.000    |       Not supported by data       |
# 2.340 0.000 Not supported by data
# results/GC_00000977-busted.txt
# |      Diversifying selection       |    53.990     |    3.734    |                                   |
# 53.990 3.734
# results/GC_00000854-busted.txt
# |      Diversifying selection       |     1.004     |    0.000    |       Not supported by data       |
# 1.004 0.000 Not supported by data
# results/GC_00001193-busted.txt
# |      Diversifying selection       |     4.098     |    0.000    |       Not supported by data       |
# 4.098 0.000 Not supported by data
# results/GC_00000690-busted.txt
# results/GC_00000582-busted.txt
# |      Diversifying selection       |     3.627     |    0.000    |       Not supported by data       |
# 3.627 0.000 Not supported by data
# results/GC_00000189-busted.txt
# |      Diversifying selection       |     1.936     |    0.000    |       Not supported by data       |
# 1.936 0.000 Not supported by data
# results/GC_00000496-busted.txt
# |      Diversifying selection       |    17.813     |    8.420    |                                   |
# 17.813 8.420
# results/GC_00000818-busted.txt
# results/GC_00000959-busted.txt
# |      Diversifying selection       |     2.229     |    0.000    |       Not supported by data       |
# 2.229 0.000 Not supported by data
# results/GC_00000282-busted.txt
# |      Diversifying selection       |    358.182    |    8.709    |                                   |
# 358.182 8.709
# |      Diversifying selection       |     1.168     |    0.000    |       Not supported by data       |
# 1.168 0.000 Not supported by data
# results/GC_00000396-busted.txt
# |      Diversifying selection       |     6.183     |    0.000    |       Not supported by data       |
# 6.183 0.000 Not supported by data
# results/GC_00000689-busted.txt
# results/GC_00000885-busted.txt
# |      Diversifying selection       |    516.631    |    4.635    |                                   |
# 516.631 4.635
# results/GC_00001175-busted.txt
# |      Diversifying selection       |     4.667     |    0.010    |                                   |
# 4.667 0.010
# results/GC_00000369-busted.txt
# results/GC_00000676-busted.txt
# results/GC_00000641-busted.txt
# results/GC_00001142-busted.txt
# |      Diversifying selection       |     3.880     |    0.000    |       Not supported by data       |
# 3.880 0.000 Not supported by data
# results/GC_00000762-busted.txt
# |      Diversifying selection       |     3.937     |    0.000    |       Not supported by data       |
# 3.937 0.000 Not supported by data
# results/GC_00001061-busted.txt
# |      Diversifying selection       |     4.111     |    0.000    |       Not supported by data       |
# 4.111 0.000 Not supported by data
# results/GC_00000991-busted.txt
# |      Diversifying selection       |     3.873     |    0.000    |       Not supported by data       |
# 3.873 0.000 Not supported by data
# results/GC_00000528-busted.txt
# results/GC_00000755-busted.txt
# results/GC_00000614-busted.txt
# |      Diversifying selection       |     1.732     |    0.000    |       Not supported by data       |
# 1.732 0.000 Not supported by data
# results/GC_00000176-busted.txt
# |      Diversifying selection       |     3.361     |    0.000    |       Not supported by data       |
# 3.361 0.000 Not supported by data
# results/GC_00000469-busted.txt
# |      Diversifying selection       |     5.572     |    0.000    |       Not supported by data       |
# 5.572 0.000 Not supported by data
# results/GC_00001120-busted.txt
# |      Diversifying selection       |     1.031     |    0.000    |       Not supported by data       |
# 1.031 0.000 Not supported by data
# results/GC_00000623-busted.txt
# |      Diversifying selection       |     5.832     |    0.000    |       Not supported by data       |
# 5.832 0.000 Not supported by data
# results/GC_00001003-busted.txt
# results/GC_00000700-busted.txt
# results/GC_00000228-busted.txt
# |      Diversifying selection       |   2432.633    |    0.999    |                                   |
# 2432.633 0.999
# results/GC_00000804-busted.txt
# |      Diversifying selection       |     4.443     |    0.000    |       Not supported by data       |
# 4.443 0.000 Not supported by data
# results/GC_00000195-busted.txt
# |      Diversifying selection       |     3.264     |    0.000    |       Not supported by data       |
# 3.264 0.000 Not supported by data
# results/GC_00000833-busted.txt
# |      Diversifying selection       |     2.416     |    0.000    |       Not supported by data       |
# 2.416 0.000 Not supported by data
# results/GC_00000910-busted.txt
# results/GC_00000927-busted.txt
# |      Diversifying selection       |     1.001     |    0.000    |       Not supported by data       |
# 1.001 0.000 Not supported by data
# results/GC_00000866-busted.txt
# |      Diversifying selection       |     4.607     |    0.000    |       Not supported by data       |
# 4.607 0.000 Not supported by data
# results/GC_00000695-busted.txt
# |      Diversifying selection       |    10.737     |    1.327    |                                   |
# 10.737 1.327
# ...
# 3.376 0.000 Not supported by data
# results/GC_00000666-busted.txt
# |      Diversifying selection       |    14.225     |    0.828    |                                   |
# 14.225 0.828
# results/GC_00000895-busted.txt
# |      Diversifying selection       |     7.392     |    0.000    |       Not supported by data       |
# 7.392 0.000 Not supported by data
# results/GC_00000543-busted.txt
# |      Diversifying selection       |     3.509     |    0.000    |       Not supported by data       |
# 3.509 0.000 Not supported by data
# results/GC_00000221-busted.txt
# |      Diversifying selection       |     3.966     |    0.245    |                                   |
# 3.966 0.245
# results/GC_00000216-busted.txt
# |      Diversifying selection       |     4.209     |    0.000    |       Not supported by data       |
# 4.209 0.000 Not supported by data
# results/GC_00000709-busted.txt
# |      Diversifying selection       |     3.979     |    0.000    |       Not supported by data       |
# 3.979 0.000 Not supported by data
# results/GC_00000574-busted.txt
# results/GC_00000335-busted.txt
# |      Diversifying selection       |     1.304     |    2.093    |                                   |
# 1.304 2.093
# results/GC_00000457-busted.txt
# |      Diversifying selection       |     3.838     |    0.000    |       Not supported by data       |
# 3.838 0.000 Not supported by data
# results/GC_00000460-busted.txt
# |      Diversifying selection       |     3.902     |    0.000    |       Not supported by data       |
# 3.902 0.000 Not supported by data
# results/GC_00000302-busted.txt
# |      Diversifying selection       |     3.943     |    0.000    |       Not supported by data       |
# 3.943 0.000 Not supported by data
# results/GC_00000243-busted.txt
# results/GC_00000521-busted.txt
# results/GC_00001222-busted.txt
# |      Diversifying selection       |    45.710     |    0.000    |       Not supported by data       |
# 45.710 0.000 Not supported by data
# results/GC_00001215-busted.txt
# |      Diversifying selection       |     1.349     |    0.401    |                                   |
# 1.349 0.401
# results/GC_00000516-busted.txt
# |      Diversifying selection       |  144290.783   |    0.578    |                                   |
# 144290.783 0.578
# results/GC_00000998-busted.txt
# results/GC_00000274-busted.txt
# |      Diversifying selection       |     2.886     |    0.000    |       Not supported by data       |
# 2.886 0.000 Not supported by data
# results/GC_00000435-busted.txt
# results/GC_00000648-busted.txt
# |      Diversifying selection       |    372.953    |   20.157    |                                   |
# 372.953 20.157
# results/GC_00000357-busted.txt
# results/GC_00000360-busted.txt
# |      Diversifying selection       |     3.910     |    0.000    |       Not supported by data       |
# 3.910 0.000 Not supported by data
# results/GC_00000402-busted.txt
# |      Diversifying selection       |     4.257     |    0.000    |       Not supported by data       |
# 4.257 0.000 Not supported by data
# results/GC_00000680-busted.txt
# results/GC_00000873-busted.txt
# |      Diversifying selection       |     1.618     |    0.000    |       Not supported by data       |
# 1.618 0.000 Not supported by data
# results/GC_00000844-busted.txt
# results/GC_00000967-busted.txt
# |      Diversifying selection       |     3.899     |    0.000    |       Not supported by data       |
# 3.899 0.000 Not supported by data
# results/GC_00000794-busted.txt
# |      Diversifying selection       |     4.958     |    0.000    |       Not supported by data       |
# 4.958 0.000 Not supported by data
# results/GC_00000950-busted.txt
# |      Diversifying selection       |    170.611    |    0.630    |                                   |
# 170.611 0.630
# results/GC_00000180-busted.txt
# |      Diversifying selection       |     4.076     |    0.000    |       Not supported by data       |
# 4.076 0.000 Not supported by data
# results/GC_00000811-busted.txt
# results/GC_00000826-busted.txt
# results/GC_00000905-busted.txt
# |      Diversifying selection       |     3.553     |    0.000    |       Not supported by data       |
# 3.553 0.000 Not supported by data
# results/GC_00000163-busted.txt
# |      Diversifying selection       |     3.167     |    0.000    |       Not supported by data       |
# 3.167 0.000 Not supported by data
# results/GC_00000601-busted.txt
# |      Diversifying selection       |     2.562     |    0.000    |       Not supported by data       |
# 2.562 0.000 Not supported by data
# results/GC_00000636-busted.txt
# |      Diversifying selection       |     5.127     |    0.000    |       Not supported by data       |
# 5.127 0.000 Not supported by data
# results/GC_00000329-busted.txt
# results/GC_00000154-busted.txt
# results/GC_00000715-busted.txt
# results/GC_00001016-busted.txt
# |      Diversifying selection       |    55.951     |   100.000   |                                   |
# 55.951 100.000
# results/GC_00000568-busted.txt
# |      Diversifying selection       |   8324.922    |    0.102    |                                   |
# 8324.922 0.102
# results/GC_00001021-busted.txt
# results/GC_00000722-busted.txt
# results/GC_00000663-busted.txt
# results/GC_00001160-busted.txt
# |      Diversifying selection       |     1.518     |   100.000   |                                   |
# 1.518 100.000
# results/GC_00000890-busted.txt
# |      Diversifying selection       |     1.529     |    0.000    |       Not supported by data       |
# 1.529 0.000 Not supported by data
# results/GC_00000429-busted.txt
# |      Diversifying selection       |     2.160     |    0.000    |       Not supported by data       |
# 2.160 0.000 Not supported by data
# results/GC_00001157-busted.txt
# |      Diversifying selection       |     4.464     |    0.000    |       Not supported by data       |
# 4.464 0.000 Not supported by data
# results/GC_00000654-busted.txt
# results/GC_00000984-busted.txt
# |      Diversifying selection       |     1.398     |    9.677    |                                   |
# 1.398 9.677
# |      Diversifying selection       |     1.038     |   16.226    |                                   |
# 1.038 16.226
# results/GC_00001209-busted.txt
# |      Diversifying selection       |     4.791     |    0.894    |                                   |
# 4.791 0.894
# results/GC_00001074-busted.txt
# |      Diversifying selection       |     4.466     |    0.000    |       Not supported by data       |
# 4.466 0.000 Not supported by data
# results/GC_00000268-busted.txt
# |      Diversifying selection       |     3.414     |    0.000    |       Not supported by data       |
# 3.414 0.000 Not supported by data
# results/GC_00000777-busted.txt
# results/GC_00000740-busted.txt
# |      Diversifying selection       |     4.068     |    0.000    |       Not supported by data       |
# 4.068 0.000 Not supported by data
# results/GC_00001043-busted.txt
# |      Diversifying selection       |     1.008     |    0.000    |       Not supported by data       |
# 1.008 0.000 Not supported by data
# results/GC_00000297-busted.txt
# |      Diversifying selection       |    15.950     |    3.211    |                                   |
# 15.950 3.211
# results/GC_00000788-busted.txt
# |      Diversifying selection       |     2.061     |    0.000    |       Not supported by data       |
# 2.061 0.000 Not supported by data
# results/GC_00000383-busted.txt
# results/GC_00000919-busted.txt
# results/GC_00000597-busted.txt
# |      Diversifying selection       |     2.544     |    0.000    |       Not supported by data       |
# 2.544 0.000 Not supported by data
# results/GC_00000483-busted.txt
# |      Diversifying selection       |     4.183     |    0.000    |       Not supported by data       |
# 4.183 0.000 Not supported by data
# results/GC_00000492-busted.txt
# |      Diversifying selection       |     5.050     |    0.000    |       Not supported by data       |
# 5.050 0.000 Not supported by data
# results/GC_00000908-busted.txt
# results/GC_00000586-busted.txt
# |      Diversifying selection       |     2.197     |    0.000    |       Not supported by data       |
# 2.197 0.000 Not supported by data
# results/GC_00000392-busted.txt
# |      Diversifying selection       |    47.384     |    0.978    |                                   |
# 47.384 0.978
# results/GC_00000799-busted.txt
# |      Diversifying selection       |     1.678     |   15.804    |                                   |
# 1.678 15.804
# results/GC_00000286-busted.txt
# |      Diversifying selection       |    38.310     |    3.784    |                                   |
# 38.310 3.784
# results/GC_00001052-busted.txt
# |      Diversifying selection       |    16.440     |    0.902    |                                   |
# 16.440 0.902
# results/GC_00000751-busted.txt
# results/GC_00001218-busted.txt
# |      Diversifying selection       |     3.596     |   18.350    |                                   |
# 3.596 18.350
# results/GC_00000995-busted.txt
# |      Diversifying selection       |     1.002     |    0.000    |       Not supported by data       |
# 1.002 0.000 Not supported by data
# results/GC_00000766-busted.txt
# results/GC_00000279-busted.txt
# |      Diversifying selection       |    367.336    |    0.344    |                                   |
# 367.336 0.344
# results/GC_00001065-busted.txt
# results/GC_00000438-busted.txt
# results/GC_00000645-busted.txt
# results/GC_00001171-busted.txt
# |      Diversifying selection       |    295.977    |   100.000   |                                   |
# 295.977 100.000
# results/GC_00000672-busted.txt
# |      Diversifying selection       |     5.747     |    0.000    |       Not supported by data       |
# 5.747 0.000 Not supported by data
# results/GC_00000881-busted.txt
# |      Diversifying selection       |9999999171.5...|   38.565    |                                   |
# 9999999171.5... 38.565
# results/GC_00001030-busted.txt
# results/GC_00001007-busted.txt
# |      Diversifying selection       |     4.010     |    0.000    |       Not supported by data       |
# 4.010 0.000 Not supported by data
# results/GC_00000704-busted.txt
# |      Diversifying selection       |     2.927     |    0.000    |       Not supported by data       |
# 2.927 0.000 Not supported by data
# results/GC_00000579-busted.txt
# |      Diversifying selection       |    228.150    |   75.294    |                                   |
# 228.150 75.294
# results/GC_00000338-busted.txt
# |      Diversifying selection       |     2.863     |    0.000    |       Not supported by data       |
# 2.863 0.000 Not supported by data
# results/GC_00000627-busted.txt
# |      Diversifying selection       |     2.880     |    0.000    |       Not supported by data       |
# 2.880 0.000 Not supported by data
# results/GC_00000172-busted.txt
# |      Diversifying selection       |     2.155     |    0.000    |       Not supported by data       |
# 2.155 0.000 Not supported by data
# results/GC_00000610-busted.txt
# results/GC_00000923-busted.txt
# results/GC_00000837-busted.txt
# results/GC_00000800-busted.txt
# results/GC_00000191-busted.txt
# |      Diversifying selection       |     3.480     |    0.000    |       Not supported by data       |
# 3.480 0.000 Not supported by data
# results/GC_00000976-busted.txt
# |      Diversifying selection       |     3.612     |    0.000    |       Not supported by data       |
# 3.612 0.000 Not supported by data
# results/GC_00001086-busted.txt
# |      Diversifying selection       |     3.238     |    0.000    |       Not supported by data       |
# 3.238 0.000 Not supported by data
# results/GC_00000785-busted.txt
# |      Diversifying selection       |     4.858     |    0.000    |       Not supported by data       |
# 4.858 0.000 Not supported by data
# results/GC_00000855-busted.txt
# |      Diversifying selection       |     3.923     |    0.000    |       Not supported by data       |
# 3.923 0.000 Not supported by data
# results/GC_00000691-busted.txt
# |      Diversifying selection       |     2.281     |    0.000    |       Not supported by data       |
# 2.281 0.000 Not supported by data
# results/GC_00001192-busted.txt
# |      Diversifying selection       |     5.226     |    7.221    |                                   |
# 5.226 7.221
# results/GC_00000862-busted.txt
# |      Diversifying selection       |     1.005     |    0.000    |       Not supported by data       |
# 1.005 0.000 Not supported by data
# results/GC_00000371-busted.txt
# results/GC_00000413-busted.txt
# results/GC_00000424-busted.txt
# |      Diversifying selection       |   1835.947    |    1.212    |                                   |
# 1835.947 1.212
# results/GC_00000346-busted.txt
# |      Diversifying selection       |     2.839     |    0.000    |       Not supported by data       |
# 2.839 0.000 Not supported by data
# results/GC_00000659-busted.txt
# results/GC_00000507-busted.txt
# results/GC_00000989-busted.txt
# results/GC_00000265-busted.txt
# |      Diversifying selection       |    57.041     |    0.084    |                                   |
# 57.041 0.084
# results/GC_00000252-busted.txt
# |      Diversifying selection       |     5.274     |    6.167    |                                   |
# 5.274 6.167
# results/GC_00000530-busted.txt
# results/GC_00000471-busted.txt
# |      Diversifying selection       |     2.052     |   100.000   |                                   |
# 2.052 100.000
# results/GC_00000313-busted.txt
# |      Diversifying selection       |     1.290     |    0.000    |       Not supported by data       |
# 1.290 0.000 Not supported by data
# results/GC_00000324-busted.txt
# |      Diversifying selection       |   1298.596    |    0.090    |                                   |
# 1298.596 0.090
# results/GC_00000159-busted.txt
# |      Diversifying selection       |     3.926     |    0.000    |       Not supported by data       |
# 3.926 0.000 Not supported by data
# results/GC_00000446-busted.txt
# results/GC_00000718-busted.txt
# results/GC_00000207-busted.txt
# |      Diversifying selection       |     4.093     |    0.191    |                                   |
# 4.093 0.191
# results/GC_00000565-busted.txt
# |      Diversifying selection       |     1.614     |    0.000    |       Not supported by data       |
# 1.614 0.000 Not supported by data
# results/GC_00000230-busted.txt
# |      Diversifying selection       |    389.328    |    2.368    |                                   |
# 389.328 2.368
#                    gene gtr_log_l gtr_aicc gtr_dnds codon_log_l codon_aicc  \
# 0    GC_00000978-busted  -2346.93  4830.55   0.1721    -1243.69    2624.06
# 1    GC_00000294-busted  -2249.55  4642.11   0.0855     -854.63    1852.25
# 2    GC_00000594-busted   -770.73  1678.79  18.8942     -770.73    1678.79
# 3    GC_00000480-busted       NaN      NaN      NaN         NaN        NaN
# 4    GC_00000839-busted  -2381.19  4909.45   0.6832    -2084.15    4315.37
# ..                  ...       ...      ...      ...         ...        ...
# 922  GC_00000446-busted       NaN      NaN      NaN         NaN        NaN
# 923  GC_00000718-busted       NaN      NaN      NaN         NaN        NaN
# 924  GC_00000207-busted   -285.21   700.56   0.0092     -285.21     700.56
# 925  GC_00000565-busted  -1617.59  3388.83   0.0715     -775.32    1704.29
# 926  GC_00000230-busted   -886.57  1914.84   0.0571     -486.66    1115.02
#
#     codon_dnds   p_val     dNdS dNdS_proportion              dNdS_note
# 0       0.0426  0.2867   16.010          35.858
# 1       0.0955  0.5000    4.701           0.000  Not supported by data
# 2      18.8942  0.1216  170.614          19.191
# 3          NaN     NaN      NaN             NaN                    NaN
# 4       0.4432  0.5000    1.168           0.000  Not supported by data
# ..         ...     ...      ...             ...                    ...
# 922        NaN     NaN      NaN             NaN                    NaN
# 923        NaN     NaN      NaN             NaN                    NaN
# 924     0.0088  0.5000    4.093           0.191
# 925     0.1604  0.5000    1.614           0.000  Not supported by data
# 926     0.0568  0.1959  389.328           2.368
#
# [927 rows x 11 columns]

# %%
results_df.to_csv('results_dNdS_busted_amine_v2.csv', index=False)
