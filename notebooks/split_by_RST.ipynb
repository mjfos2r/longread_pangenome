# %%
import pandas

# %%
metadata_file = '/Users/mf019/bioinformatics/longread_GWAS/notebooks/metadata/cleaned_metadata/longread_metadata_v8.csv'
metadata = pandas.read_csv(metadata_file)

# %%
metadata
# Out:
#      Isolate Original_Name Origin Location Disseminated skin/blood_pairs  \
# 0      ESI26      B1904/13     EU       SI            L              NaN
# 1     ESI26H  EU57_B190413     EU       SI            L              NaN
# 2     UCT109           K69     US       CT            L              NaN
# 3    UCT109H           K69     US       CT            L              NaN
# 4     UCT110           K70     US       CT            D              NaN
# ..       ...           ...    ...      ...          ...              ...
# 107  UWI248P         MC105     US       WI            L              NaN
# 108   UWI263         MC123     US       WI           ND              NaN
# 109  UWI263P         MC123     US       WI           ND              NaN
# 110   UWI283         MC149     US       WI            L              NaN
# 111  UWI283P         MC149     US       WI            L              NaN
#
#      Severity    method   MLST  RST_Type Source OspC_Type AT_type
# 0         NaN  illumina   20.0       1.0   Skin         R     AT7
# 1         NaN    Hybrid   20.0       1.0   Skin         M     AT7
# 2        mild  illumina    1.0       1.0   Skin         A     AT1
# 3        mild    Hybrid    1.0       1.0   Skin         A     AT1
# 4    moderate  illumina    3.0       2.0   Skin         K    AT11
# ..        ...       ...    ...       ...    ...       ...     ...
# 107       NaN    pacbio   32.0       2.0   Skin         H     AT8
# 108       NaN  illumina   29.0       2.0   Skin         L    AT10
# 109       NaN    pacbio   29.0       2.0   Skin         L    AT10
# 110       NaN  illumina  221.0       3.0   Skin         O     AT3
# 111       NaN    pacbio  221.0       3.0   Skin         O     AT3
#
# [112 rows x 13 columns]

# %%
# group by RST type then dump each group to a list of isolate names. store that list in the list of lists.
rst_type_lists = metadata.groupby('RST_Type').apply(lambda x: x['Isolate'].values.tolist()).tolist()

# ok now let's check on the contents of each list
for i, rst_list in enumerate(rst_type_lists):
    print(f"RST Type {i+1}: {rst_list}")
# Out:
# RST Type 1: ['ESI26', 'ESI26H', 'UCT109', 'UCT109H', 'UCT29', 'UCT29H', 'UCT31', 'UCT31H', 'UCT96', 'UCT96H', 'UNY1032P', 'URI101', 'URI101H', 'URI102', 'URI102H', 'URI107', 'URI107H', 'URI111', 'URI111H', 'URI120', 'URI120H', 'URI39', 'URI39H', 'URI40', 'URI40H', 'URI41', 'URI41H', 'URI42', 'URI42H', 'URI87', 'URI87H', 'URI89', 'URI89H', 'URI91', 'URI91H', 'URI93', 'URI93H']
# RST Type 2: ['UCT110', 'UCT110H', 'UCT113', 'UCT113H', 'UCT30', 'UCT30H', 'UCT32', 'UCT32H', 'UCT92', 'UCT92H', 'UNY1038P', 'UNY1090P', 'UNY149', 'UNY149P', 'UNY208', 'UNY208P', 'UNY990P', 'URI103', 'URI103H', 'URI112', 'URI112H', 'URI117', 'URI117H', 'URI118', 'URI118H', 'URI33', 'URI33H', 'URI44', 'URI44H', 'URI46', 'URI46H', 'URI47', 'URI47H', 'URI48', 'URI48H', 'URI86', 'URI86H', 'URI88', 'URI88H', 'UWI247', 'UWI247P', 'UWI248', 'UWI248P', 'UWI263', 'UWI263P']
# RST Type 3: ['UCT35', 'UCT35H', 'UCT50', 'UCT50H', 'UNY1083P', 'UNY1085P', 'UNY1128P', 'UNY169', 'UNY169P', 'UNY172', 'UNY172P', 'UNY193', 'UNY193P', 'UNY203', 'UNY203P', 'URI34', 'URI34H', 'URI36', 'URI36H', 'URI56', 'URI56H', 'UWI283', 'UWI283P']
# /var/folders/59/fs0fxd1x1wx1j_stw1ccjbcr0000gp/T/ipykernel_53009/3735468237.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   rst_type_lists = metadata.groupby('RST_Type').apply(lambda x: x['Isolate'].values.tolist()).tolist()

# %%
import os
import glob
import shutil
import datetime as dt

# get cwd and print to console
cwd = os.getcwd()
print(cwd)

sequencing_methods = ['shortread', 'longread']
rst_types = ['RST1', 'RST2', 'RST3']

# lets make sure there are directories for each sequencing method and within those, directories for each RST type
for rst_type in rst_types:
    for seq_method in sequencing_methods:
        # make the directories
        os.makedirs(f"{cwd}/{seq_method}/{rst_type}", exist_ok=True)
        print(f"{cwd}/{seq_method}/{rst_type}")

# now let's check on our annotations to make sure we've got em all! (and put em in a list for handy dandy access :)
list_of_annotations = glob.glob(pathname=f"{cwd}/*/annotation/*.gff3")

# now let's set the lists by hand to make it easier to move to remote machine :) (they're dicts but I need the keys to direct the files to the right place)
RST1 = {
    'RST1': [
          'ESI26', 'ESI26H',  'UCT109',  'UCT109H',   'UCT29',  'UCT29H',   'UCT31',
         'UCT31H',  'UCT96',  'UCT96H', 'UNY1032P',  'URI101', 'URI101H',  'URI102',
        'URI102H', 'URI107', 'URI107H',   'URI111', 'URI111H',  'URI120', 'URI120H',
          'URI39', 'URI39H',   'URI40',   'URI40H',   'URI41',  'URI41H',   'URI42',
         'URI42H',  'URI87',  'URI87H',    'URI89',  'URI89H',   'URI91',  'URI91H',
          'URI93', 'URI93H']
    }
RST2 = {
    'RST2': [
        'UCT110', 'UCT110H',  'UCT113',  'UCT113H',    'UCT30',  'UCT30H',   'UCT32',
        'UCT32H',   'UCT92',  'UCT92H', 'UNY1038P', 'UNY1090P',  'UNY149', 'UNY149P',
        'UNY208', 'UNY208P', 'UNY990P',   'URI103',  'URI103H',  'URI112', 'URI112H',
        'URI117', 'URI117H',  'URI118',  'URI118H',    'URI33',  'URI33H',   'URI44',
        'URI44H',   'URI46',  'URI46H',    'URI47',   'URI47H',   'URI48',  'URI48H',
         'URI86',  'URI86H',   'URI88',   'URI88H',   'UWI247', 'UWI247P',  'UWI248',
        'UWI248P', 'UWI263', 'UWI263P']
    }
RST3 = {
    'RST3': [
          'UCT35',  'UCT35H',  'UCT50',   'UCT50H', 'UNY1083P', 'UNY1085P', 'UNY1128P',
         'UNY169', 'UNY169P', 'UNY172',  'UNY172P',   'UNY193',  'UNY193P',   'UNY203',
        'UNY203P',   'URI34', 'URI34H',    'URI36',   'URI36H',    'URI56',   'URI56H',
         'UWI283', 'UWI283P']
    }
# pile em up
list_of_lists = [RST1, RST2, RST3]
# now let's actually move em. we'll just print the paths for now
for type in list_of_lists:
    for rst, assemblies in type.items():
        for assembly in assemblies:
            if assembly.endswith(('H', 'P')):
                # set path to longread annotation
                gff_path = f"{cwd}/longread/annotation/{assembly}.gff3"
                if os.path.isfile(gff_path):
                    print(f'{assembly}.gff3 exists. running command:')
                    print(f'os.copy(f"{cwd}/longread/annotation/{assembly}.gff3", f"{cwd}/longread/{rst}/{assembly}.gff3")')
                    # move this to the longread directory
                    shutil.copy(f"{cwd}/longread/annotation/{assembly}.gff3", f"{cwd}/longread/{rst}/{assembly}.gff3")
                else:
                    print(f'{assembly}.gff3 does not exist. skipping.')
            else:
                # set path to shortread annotation
                gff_path = f"{cwd}/shortread/annotation/{assembly}.gff3"
                if os.path.isfile(gff_path):
                    print(f'{assembly}.gff3 exists. running command:')
                    print(f'os.copy(f"{cwd}/shortread/annotation/{assembly}.gff3", f"{cwd}/shortread/{rst}/{assembly}.gff3")')
                    # move this to the shortread directory
                    shutil.copy(f"{cwd}/shortread/annotation/{assembly}.gff3", f"{cwd}/shortread/{rst}/{assembly}.gff3")
                else:
                    print(f'{assembly}.gff3 does not exist. skipping.')
print('done!')

for rst in rst_types:
    num_source = len(list_of_lists[rst_types.index(rst)][rst])
    num_destination = len(os.listdir(f"{cwd}/longread/{rst}")) + len(os.listdir(f"{cwd}/shortread/{rst}"))
    print(f'{rst} in source: {num_source}')
    print(f'{rst} in destination: {num_destination}')
    if num_source == num_destination:
        print(f'{rst} is good to go!')
    else:
        print(f'{rst}: UH OH SPAGHETTIO. something went wrong! check the output above to see what is missing.')

print('done!')
print(dt.datetime.now())
# Out:
# RST1: ESI26, Short-read
# RST1: ESI26H, Long-read
# RST1: UCT109, Short-read
# RST1: UCT109H, Long-read
# RST1: UCT29, Short-read
# RST1: UCT29H, Long-read
# RST1: UCT31, Short-read
# RST1: UCT31H, Long-read
# RST1: UCT96, Short-read
# RST1: UCT96H, Long-read
# RST1: UNY1032P, Long-read
# RST1: URI101, Short-read
# RST1: URI101H, Long-read
# RST1: URI102, Short-read
# RST1: URI102H, Long-read
# RST1: URI107, Short-read
# RST1: URI107H, Long-read
# RST1: URI111, Short-read
# RST1: URI111H, Long-read
# RST1: URI120, Short-read
# RST1: URI120H, Long-read
# RST1: URI39, Short-read
# RST1: URI39H, Long-read
# RST1: URI40, Short-read
# RST1: URI40H, Long-read
# RST1: URI41, Short-read
# RST1: URI41H, Long-read
# RST1: URI42, Short-read
# RST1: URI42H, Long-read
# RST1: URI87, Short-read
# RST1: URI87H, Long-read
# RST1: URI89, Short-read
# RST1: URI89H, Long-read
# RST1: URI91, Short-read
# RST1: URI91H, Long-read
# RST1: URI93, Short-read
# RST1: URI93H, Long-read
# RST2: UCT110, Short-read
# RST2: UCT110H, Long-read
# RST2: UCT113, Short-read
# RST2: UCT113H, Long-read
# RST2: UCT30, Short-read
# RST2: UCT30H, Long-read
# RST2: UCT32, Short-read
# RST2: UCT32H, Long-read
# RST2: UCT92, Short-read
# RST2: UCT92H, Long-read
# RST2: UNY1038P, Long-read
# RST2: UNY1090P, Long-read
# RST2: UNY149, Short-read
# RST2: UNY149P, Long-read
# RST2: UNY208, Short-read
# RST2: UNY208P, Long-read
# RST2: UNY990P, Long-read
# RST2: URI103, Short-read
# RST2: URI103H, Long-read
# RST2: URI112, Short-read
# RST2: URI112H, Long-read
# RST2: URI117, Short-read
# RST2: URI117H, Long-read
# RST2: URI118, Short-read
# RST2: URI118H, Long-read
# RST2: URI33, Short-read
# RST2: URI33H, Long-read
# RST2: URI44, Short-read
# RST2: URI44H, Long-read
# RST2: URI46, Short-read
# RST2: URI46H, Long-read
# RST2: URI47, Short-read
# RST2: URI47H, Long-read
# RST2: URI48, Short-read
# RST2: URI48H, Long-read
# RST2: URI86, Short-read
# RST2: URI86H, Long-read
# RST2: URI88, Short-read
# RST2: URI88H, Long-read
# RST2: UWI247, Short-read
# RST2: UWI247P, Long-read
# RST2: UWI248, Short-read
# RST2: UWI248P, Long-read
# RST2: UWI263, Short-read
# RST2: UWI263P, Long-read
# RST3: UCT35, Short-read
# RST3: UCT35H, Long-read
# RST3: UCT50, Short-read
# RST3: UCT50H, Long-read
# RST3: UNY1083P, Long-read
# RST3: UNY1085P, Long-read
# RST3: UNY1128P, Long-read
# RST3: UNY169, Short-read
# RST3: UNY169P, Long-read
# RST3: UNY172, Short-read
# RST3: UNY172P, Long-read
# RST3: UNY193, Short-read
# RST3: UNY193P, Long-read
# RST3: UNY203, Short-read
# RST3: UNY203P, Long-read
# RST3: URI34, Short-read
# RST3: URI34H, Long-read
# RST3: URI36, Short-read
# RST3: URI36H, Long-read
# RST3: URI56, Short-read
# RST3: URI56H, Long-read
# RST3: UWI283, Short-read
# RST3: UWI283P, Long-read
