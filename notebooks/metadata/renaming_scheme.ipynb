# %%
# Ok so we need to finish renaming the assemblies.
# I completely missed the renaming key table.
# downloaded it here, it is 3 columns and will be used to create a lookup dictionary

import pandas
import numpy as np

# %%
scheme_key = pandas.read_csv('old_lymeseq_tables/LymeSeq_SampleTrack-RenamingSchemeKey.csv')
scheme_key.shape
# Out:
# (387, 11)

# %%
scheme_key
# Out:
#     Original Rename_A  Unnamed: 2 Rename_A1 Unnamed: 4  Unnamed: 5 Rename_A2  \
# 0         N2      UM1         NaN        N2       UM1a         NaN        N2
# 1         N4      UM2         NaN       NaN       UM1b         NaN        N4
# 2         N7      UM3         NaN        N4       UM2a         NaN        N7
# 3         N9      UM4         NaN       NaN       UM2b         NaN        N9
# 4        N11      UM5         NaN        N7       UM3a         NaN       N11
# ..       ...      ...         ...       ...        ...         ...       ...
# 382      NaN      NaN         NaN     MC140      UW361         NaN       NaN
# 383      NaN      NaN         NaN     MC143      UW362         NaN       NaN
# 384      NaN      NaN         NaN     MC145      UW363         NaN       NaN
# 385      NaN      NaN         NaN     MC148      UW364         NaN       NaN
# 386      NaN      NaN         NaN     MC149      UW365         NaN       NaN
#
#     Unnamed: 7  Unnamed: 8 Rename_A3 Unnamed: 10
# 0          UM1         NaN        N2         UM1
# 1          UM2         NaN        N4         UM2
# 2          UM3         NaN        N7         UM3
# 3          UM4         NaN        N9         UM4
# 4          UM5         NaN       N11         UM5
# ..         ...         ...       ...         ...
# 382        NaN         NaN     MC140       UW380
# 383        NaN         NaN     MC143       UW381
# 384        NaN         NaN     MC145       UW382
# 385        NaN         NaN     MC148       UW383
# 386        NaN         NaN     MC149       UW384
#
# [387 rows x 11 columns]

# %%
final_scheme_key = scheme_key[['Rename_A3', 'Unnamed: 10']]
final_scheme_key = final_scheme_key.rename(columns={'Rename_A3': 'Original', 'Unnamed: 10': 'Renamed'})
#final_scheme_key.to_csv('final_scheme_key_v1.csv', index=False)

# %%
metadata = pandas.read_csv('wrangled/longread_metadata_v5.csv')
print(metadata.head())
# Out:
#            Isolate MLST  RST_Type   Source Origin Location skin/blood_pairs  \
# 0  5A18NP1-JBb08-A    1       NaN  culture     US       NY              NaN
# 1           UNY147   34       3.0      NaN     US       NY              NaN
# 2  5A18NP1-JBb08-C    1       NaN  culture     US       NY              NaN
# 3  5A18NP1-JBb08-B    1       NaN  culture     US       NY              NaN
# 4  5A18NP1-JBb08-E    1       NaN  culture     US       NY              NaN
#
#   Disseminated    method OspC_Type AT_type
# 0          NaN  nanopore         A     AT1
# 1            L  illumina         J     NaN
# 2          NaN  nanopore         A     AT1
# 3          NaN  nanopore         A     AT1
# 4          NaN  nanopore         A     AT1

# %%
list_of_countries = metadata['Origin'].unique()
list_of_locations = metadata['Location'].unique()
list_of_countries = np.delete(list_of_countries, 2)
list_of_locations = np.delete(list_of_locations, 3)
print(*enumerate(list_of_countries))
print(*enumerate(list_of_locations))
list_of_locations = np.append(list_of_locations, ['MA', 'SI'])
# Out:
# (0, 'US') (1, 'EU') (2, 'NY')
# (0, 'NY') (1, 'WI') (2, 'Slovenia') (3, 'RI') (4, 'CT') (5, 'Nantucket') (6, 'Nantuchet')

# %%
list_of_names = final_scheme_key['Renamed']
#print(list_of_names)
list_of_assemblies = metadata['Isolate']
#print(list_of_assemblies)

for asm in list_of_assemblies:
    if "_" in asm:
        print(asm)
# Out:
# BG001_C7
# EU57_B190413
# N40_HP
# BL082_H1
# BL091_B31E2_erpP
# EU51_B192411
# EU14_B89613

# %%
dirty_names = []
import re
highest_ids = {}

for name in list_of_assemblies:
    if not any(location in name for location in list_of_locations):
        dirty_names.append(name)
for location in list_of_locations:
    max_id = 0
    for name in list_of_assemblies:
        #print(name)
        if location not in name:
            continue
        else:
            id_number = name[3:]
            #print(name,location,id_number)
            if id_number.isnumeric():
                id_number = int(id_number)
            else:
                id_number = re.sub(r'\D', '', id_number)
                id_number = int(id_number)
            if id_number > max_id:
                max_id = id_number
        highest_ids[location] = max_id

print(highest_ids)
# Out:
# {'NY': 218, 'WI': 283, 'RI': 219, 'CT': 121, 'MA': 127, 'SI': 323}

# %%
metadata[metadata['Location'] == 'Nantucket']
# Out:
#     Isolate MLST  RST_Type Source Origin   Location skin/blood_pairs  \
# 133    UMA3    3       2.0    NaN     US  Nantucket              NaN
# 206   UMA14    1       1.0    NaN     US  Nantucket              NaN
# 274    UMA5   36       2.0    NaN     US  Nantucket              NaN
# 281    UMA1    3       2.0    NaN     US  Nantucket              NaN
# 293    UMA7   36       2.0    NaN     US  Nantucket              NaN
# 300   UMA15    3       2.0    NaN     US  Nantucket              NaN
# 308    UMA4    3       2.0    NaN     US  Nantucket              NaN
# 323   UMA16   59       1.0    NaN     US  Nantucket              NaN
# 329  UMA127   11       3.0    NaN     US  Nantucket              NaN
# 335    UMA9    1       1.0    NaN     US  Nantucket              NaN
# 337   UMA11   38       3.0    NaN     US  Nantucket              NaN
# 339   UMA12    1       1.0    NaN     US  Nantucket              NaN
# 346    UMA8    1       1.0    NaN     US  Nantucket              NaN
# 348   UMA13   59       1.0    NaN     US  Nantucket              NaN
# 349    UMA2    8       2.0    NaN     US  Nantucket              NaN
#
#     Disseminated    method OspC_Type AT_type
# 133            L  illumina         K    AT11
# 206            L  illumina         A     AT1
# 274            L  illumina         N    AT13
# 281            L  illumina         K    AT11
# 293            L  illumina         N    AT13
# 300            L  illumina         K    AT11
# 308            L  illumina         K    AT11
# 323            L  illumina         B     AT2
# 329            L  illumina         C     NaN
# 335            L  illumina         A     NaN
# 337            L  illumina         D     NaN
# 339            L  illumina         A     AT1
# 346            D  illumina         A     AT1
# 348            L  illumina         B     NaN
# 349            L  illumina         F     AT6

# %%
location_counts = metadata['Location'].value_counts()
print(location_counts)

metadata['newname'] = metadata['Isolate'].apply(lambda x: scheme_key[x] if x in dirty_names else '')
metadata[metadata['newname'] != '']
# Out:
# NY           109
# RI           102
# WI            66
# Slovenia      36
# CT            36
# Nantucket     15
# Nantuchet      1
# Name: Location, dtype: int64
