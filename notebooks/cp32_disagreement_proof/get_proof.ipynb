# %%
import pandas as pd

# %%
best_hits = '/Users/mf019/bioinformatics/longread_pangenome/plasmid_id/output/best_matches_v9_1kb.tsv'

# %%
pids = pd.read_csv(best_hits, sep='\t')

# %%
pids.head()
# Out:
#     name     method                              contig  contig_len  \
# 0  URI47  shortread  NODE_1_length_463767_cov_77.611941      463767
# 1  URI47  shortread  NODE_2_length_221463_cov_78.896272      221463
# 2  URI47  shortread  NODE_3_length_213568_cov_76.158203      213568
# 3  URI47  shortread  NODE_4_length_53880_cov_109.176347       53880
# 4  URI47  shortread  NODE_5_length_39870_cov_168.736612       39870
#
#   wp_alignment_id         pf_alignment_id wp_plasmid_name pf_plasmid_name  \
# 0      CP124080.1  B379_chromosome_ParA_4      chromosome      chromosome
# 1      CP124080.1  B379_chromosome_ParA_2      chromosome      chromosome
# 2      CP094579.1                       0      chromosome               0
# 3      CP124079.1                B31_lp54            lp54            lp54
# 4      CP094594.1                B31_lp36            lp36            lp36
#
#      best_hit
# 0  chromosome
# 1  chromosome
# 2  chromosome
# 3        lp54
# 4        lp36

# %%
lr_pids = pids[pids['method']=='longread' & pids['contig_len'] > 2500]
sr_pids = pids[pids['method']=='shortread' & pids['contig_len'] > 2500]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/roperator.py:54, in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# ...

# %%
#lr_cp32s = lr_pids[lr_pids['best_hit'].str.contains('cp32')]
lr_cp32s = lr_pids[lr_pids['best_hit'] != 'NaN']

# %%
lr_cp32s
# Out:
#          name    method        contig  contig_len wp_alignment_id  \
# 256    URI47H  longread  contig000001      921203      CP124080.1
# 257    URI47H  longread  contig000002       83849      CP094592.1
# 258    URI47H  longread  contig000003       53886      CP124079.1
# 259    URI47H  longread  contig000004       52987      CP002308.1
# 260    URI47H  longread  contig000005       30859      CP094604.1
# ...       ...       ...           ...         ...             ...
# 16824  URI93H  longread  contig000025         160               0
# 16825  URI93H  longread  contig000026         151               0
# 16826  URI93H  longread  contig000027         148               0
# 16827  URI93H  longread  contig000028         119               0
# 16828  URI93H  longread  contig000029         101               0
#
#               pf_alignment_id wp_plasmid_name pf_plasmid_name    best_hit
# 256    B379_chromosome_ParA_2      chromosome      chromosome  chromosome
# ...
