# %%
import os
import pandas

# %%
table50 = pandas.read_csv('tables/gene_homology_50percent_v1.tsv', sep='\t')
table100= pandas.read_csv('tables/gene_homology_100percent_v1.tsv', sep='\t')
tableall = pandas.read_csv('gene_homology_full_v1.tsv', sep='\t')

# %%
table50[table50['asm1_id'] == 'ESI26H_contig000001']
# Out:
#                     asm1_id asm1_locus_tag  \
# 1089    ESI26H_contig000001   DMPBEC_04255
# 16225   ESI26H_contig000001   DMPBEC_00005
# 16226   ESI26H_contig000001   DMPBEC_00020
# 16227   ESI26H_contig000001   DMPBEC_00040
# 16228   ESI26H_contig000001   DMPBEC_00045
# ...                     ...            ...
# 829002  ESI26H_contig000001   DMPBEC_04215
# 829003  ESI26H_contig000001   DMPBEC_04235
# 829004  ESI26H_contig000001   DMPBEC_04240
# 829005  ESI26H_contig000001   DMPBEC_04245
# 829006  ESI26H_contig000001   DMPBEC_04255
#
#                                              asm1_product    asm1_coords  \
# 1089    Type I restriction enzyme R N terminus family ...  908187-908922
# 16225                     Uncharacterized protein BB_0001        103-667
# 16226                                  Phosphomannomutase      3385-5179
# 16227                            diadenylate cyclase CdaA      8417-9188
# 16228         YbbR-like domain-containing protein BB-0009     9192-10197
# ...

# %%
table100[table100['asm1_id'] == 'ESI26H_contig000001']
# Out:
#                     asm1_id asm1_locus_tag  \
# 4678    ESI26H_contig000001   DMPBEC_00040
# 4679    ESI26H_contig000001   DMPBEC_00045
# 4680    ESI26H_contig000001   DMPBEC_00050
# 4681    ESI26H_contig000001   DMPBEC_00055
# 4682    ESI26H_contig000001   DMPBEC_00065
# ...                     ...            ...
# 246671  ESI26H_contig000001   DMPBEC_04075
# 246672  ESI26H_contig000001   DMPBEC_04110
# 246673  ESI26H_contig000001   DMPBEC_04145
# 246674  ESI26H_contig000001   DMPBEC_04175
# 246675  ESI26H_contig000001   DMPBEC_04235
#
#                                              asm1_product    asm1_coords  \
# 4678                             diadenylate cyclase CdaA      8417-9188
# 4679          YbbR-like domain-containing protein BB-0009     9192-10197
# 4680                 Holo-[acyl-carrier-protein] synthase    10193-10568
# 4681                      Uncharacterized protein BB_0011    10571-11411
# 4682                      Uncharacterized protein BB_0013    12144-12744
# ...

# %%
raw_matrix = 'matrices/matrix/shared_gene_matrix_100percent_v1.tsv'
matrix100df = pandas.read_csv(raw_matrix, sep='\t')
m100_np = matrix100df.to_numpy()

# %%
m100_np.shape
# Out:
# (1049, 1050)

# %%
len(tableall['asm1_id'].unique())
# Out:
# The history saving thread hit an unexpected error (OperationalError('unable to open database file')).History will not be written to the database.
# 1350

# %%
tableall
# Out:
#                       asm1_id asm1_locus_tag  \
# 0         URI86H_contig000033            NaN
# 1        URI120H_contig000068            NaN
# 2        URI117H_contig000032            NaN
# 3         UNY169P_B348_lp28-2   JFIHAH_05715
# 4         UNY169P_B348_lp28-2   JFIHAH_05720
# ...                       ...            ...
# 1514990   URI91H_contig000018            NaN
# 1514991  URI117H_contig000031            NaN
# 1514992   URI33H_contig000001   FLFPPO_01225
# 1514993   URI33H_contig000001   FLFPPO_01840
# 1514994   URI33H_contig000001   FLFPPO_02145
#
#                                               asm1_product    asm1_coords  \
# 0                                                      NaN            0-0
# 1                                                      NaN            0-0
# 2                                                      NaN            0-0
# 3                                  Borrelia family protein      5518-6091
# ...
