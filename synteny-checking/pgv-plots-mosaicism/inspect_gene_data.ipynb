# %%
import pandas as pd
import numpy as np
from collections import defaultdict

def identify_discordant_blocks(data, threshold=4):
    # Read the CSV data
    df = pd.read_csv(data)

    print(f"Total rows: {len(df)}")
    print(f"Unique assemblies: {df['assembly'].nunique()}")
    print(f"Unique genes: {df['gene'].nunique()}")

    # Identify replicon columns
    replicon_columns = df.columns[6:-2].tolist()

    # Function to get the replicons for each gene (allowing multiple)
    def get_gene_replicons(row):
        return [col for col in replicon_columns if row[col] > 0]

    # Apply the function to each row
    df['gene_replicons'] = df.apply(get_gene_replicons, axis=1)

    # Group by gene and assembly, and get the replicons for each
    gene_assembly_replicons = df.groupby(['gene', 'assembly'])['gene_replicons'].first()

    print(f"Shape of gene_assembly_replicons: {gene_assembly_replicons.shape}")

    # Identify discordant genes
    discordant_genes = []
    for gene in df['gene'].unique():
        try:
            replicon_sets = gene_assembly_replicons[gene].apply(set)
            if len(set.union(*replicon_sets)) > 1:
                discordant_genes.append(gene)
        except KeyError as e:
            print(f"KeyError for gene {gene}: {str(e)}")

    print(f"Number of discordant genes: {len(discordant_genes)}")

    # Filter the dataframe for discordant genes
    discordant_df = df[df['gene'].isin(discordant_genes)]

    # Group discordant genes into blocks
    blocks = defaultdict(lambda: defaultdict(set))
    current_block = []
    prev_pos = None
    prev_assembly = None

    for _, row in discordant_df.sort_values(['assembly', 'pos']).iterrows():
        if prev_assembly != row['assembly'] or (prev_pos is not None and row['pos'] - prev_pos > 1):
            if current_block:
                block_key = tuple(current_block)
                for gene in current_block:
                    try:
                        blocks[block_key][row['assembly']].update(gene_assembly_replicons[gene, row['assembly']])
                    except KeyError as e:
                        print(f"KeyError in block creation: {str(e)}")
                        print(f"Gene: {gene}, Assembly: {row['assembly']}")
            current_block = []
        current_block.append(row['gene'])
        blocks[tuple(current_block)][row['assembly']].update(row['gene_replicons'])
        prev_pos = row['pos']
        prev_assembly = row['assembly']

    # Prepare output
    results = []
    for block, assembly_replicons in blocks.items():
        all_replicons = set.union(*assembly_replicons.values())
        main_replicon = max(all_replicons, key=lambda r: sum(r in replicons for replicons in assembly_replicons.values()))

        discordant_assemblies = [
            assembly for assembly, replicons in assembly_replicons.items()
            if main_replicon not in replicons
        ]

        if len(discordant_assemblies) <= threshold:
            results.append({
                'block': block,
                'main_replicon': main_replicon,
                'all_assemblies': list(assembly_replicons.keys()),
                'discordant_assemblies': discordant_assemblies,
                'all_replicons': list(all_replicons),
                'discordant_replicons': list(all_replicons - {main_replicon})
            })

    print(f"Number of discordant blocks found: {len(results)}")
    return results

# %%
infile = 'GeneTree_Ordered_50.csv'
gtree = pd.read_csv(infile)

# %%
def chaos_block_finder(df, best_replicon, target_blocks=None):
    chaos = df[(df["best_replicon"]==best_replicon)&(df["replicon_name"]!=best_replicon)].copy()

    if target_blocks is not None:
        if isinstance(target_blocks, list):
            chaos = chaos[chaos["replicon_name"].isin(target_blocks)]
        else:
            raise ValueError('Target blocks must be formatted as a list, e.g. ["plasmid1", "plasmid2"]')
        for t in target_blocks:
            chaos_t = chaos[chaos["replicon_name"]==t].copy()
            print(f"********************{t}********************")
            print(f"Mosaic Assemblies: {chaos_t['assembly'].unique()}")
            print(f"Mosaic Genes: {chaos_t['gene'].unique()}\n")

    print(f"**********Overall Mosaicism in {best_replicon}**********")
    print(f"Mosaic Assemblies: {chaos['assembly'].unique()}")
    print(f"Mosaic Replicons: {chaos['replicon_name'].unique()}")
    print(f"Mosaic Genes: {chaos['gene'].unique()}")
    return chaos

# %%
lp28_4_df = chaos_block_finder(gtree, "lp28-4", ['lp36','lp38','lp28-2','cp32-10','lp28-1'])
# Out:
# ********************lp36********************
# Mosaic Assemblies: ['UCT109H' 'UCT31H' 'UCT96H' 'URI101H' 'URI102H' 'URI107H' 'URI111H'
#  'URI120H' 'URI39H' 'URI40H' 'URI41H' 'URI42H' 'URI87H' 'URI89H' 'URI91H'
#  'URI93H']
# Mosaic Genes: ['P12 family lipoprotein']
#
# ********************lp38********************
# Mosaic Assemblies: ['UCT29H']
# Mosaic Genes: ['P12 family lipoprotein']
#
# ********************lp28-2********************
# Mosaic Assemblies: ['URI102H' 'UCT109H']
# Mosaic Genes: ['Borrelia ORF-A' 'group_1798' 'group_1250' 'Transposase'
#  'Blasticidin-S acetyltransferase' 'BBC01' 'group_1795' 'group_1794'
#  'group_1793' 'group_862'
#  'Borrelia burgdorferi virulent strain associated lipoprotein'
#  'group_1796' 'group_1249' 'group_3525' 'Surface antigen'
#  'chromosome replication/partitioning protein']
#
# ********************cp32-10********************
# Mosaic Assemblies: ['URI42H']
# Mosaic Genes: ['Borrelia ORF-A' 'group_1798' 'group_1250' 'Transposase'
#  'Blasticidin-S acetyltransferase' 'BBC01' 'group_1795' 'group_1794'
#  'group_1793' 'Transporter, major facilitator family' 'group_862'
#  'Borrelia burgdorferi virulent strain associated lipoprotein'
#  'group_1796' 'group_1249'
#  'Borrelia virulent strain associated lipoprotein' 'group_3525'
#  'Surface antigen' 'chromosome replication/partitioning protein']
#
# ********************lp28-1********************
# Mosaic Assemblies: ['UCT35H' 'UNY203P' 'URI88H']
# Mosaic Genes: ['group_1251']
#
# **********Overall Mosaicism in lp28-4**********
# Mosaic Assemblies: ['UCT109H' 'UCT29H' 'UCT31H' 'UCT96H' 'URI101H' 'URI102H' 'URI107H'
#  'URI111H' 'URI120H' 'URI39H' 'URI40H' 'URI41H' 'URI42H' 'URI87H' 'URI89H'
#  'URI91H' 'URI93H' 'UCT35H' 'UNY203P' 'URI88H']
# Mosaic Replicons: ['lp36' 'lp38' 'lp28-2' 'cp32-10' 'lp28-1']
# Mosaic Genes: ['P12 family lipoprotein' 'Borrelia ORF-A' 'group_1798' 'group_1250'
#  'Transposase' 'Blasticidin-S acetyltransferase' 'BBC01' 'group_1795'
#  'group_1794' 'group_1793' 'Transporter, major facilitator family'
#  'group_862' 'Borrelia burgdorferi virulent strain associated lipoprotein'
#  'group_1796' 'group_1249'
#  'Borrelia virulent strain associated lipoprotein' 'group_3525'
#  'Surface antigen' 'chromosome replication/partitioning protein'
#  'group_1251']

# %%
cp32_1_df = chaos_block_finder(gtree, "cp32-1")
# Out:
# **********Overall Mosaicism in cp32-1**********
# Mosaic Assemblies: []
# Mosaic Replicons: []
# Mosaic Genes: []

# %%
# Usage
discordant_blocks = identify_discordant_blocks(infile)

# Print results
for i, block in enumerate(discordant_blocks, 1):
    print(f"Discordant Block {i}:")
    print(f"Genes: {', '.join(block['block'])}")
    print(f"Main Replicon: {block['main_replicon']}")
    print(f"All Assemblies: {', '.join(block['all_assemblies'])}")
    print(f"Discordant Assemblies: {', '.join(block['discordant_assemblies'])}")
    print(f"All Replicons: {', '.join(block['all_replicons'])}")
    print(f"Discordant Replicons: {', '.join(block['discordant_replicons'])}")
    print(f"Number of Assemblies: {len(block['all_assemblies'])}")
    print(f"Number of Discordant Assemblies: {len(block['discordant_assemblies'])}")
    print()

# %%
for block in discordant_blocks:
    print(block)
# Out:
# {'block': ('group_431',), 'main_replicon': 'cp32-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT29H', 'UCT31H', 'UCT50H', 'UCT96H', 'UNY172P', 'UNY203P', 'URI101H', 'URI107H', 'URI111H', 'URI120H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI86H', 'URI87H', 'URI89H', 'URI91H', 'URI93H', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-3', 'cp32-10', 'cp32-9', 'cp32-4', 'cp32-1', 'Unclassified', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-9', 'cp32-4', 'cp32-1', 'Unclassified', 'cp32-11']}
# {'block': ('Borrelia ORF-A',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'cp32-10', 'lp28-2'], 'discordant_replicons': ['cp32-10', 'lp28-2']}
# {'block': ('group_1798',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'cp32-10', 'lp28-2'], 'discordant_replicons': ['cp32-10', 'lp28-2']}
# {'block': ('group_1250',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'cp32-10', 'lp28-2'], 'discordant_replicons': ['cp32-10', 'lp28-2']}
# {'block': ('group_478',), 'main_replicon': 'cp32-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT29H', 'UCT31H', 'UCT50H', 'UCT96H', 'UNY172P', 'UNY203P', 'URI101H', 'URI107H', 'URI111H', 'URI120H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI86H', 'URI89H', 'URI93H', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-3', 'cp32-10', 'cp32-9', 'cp32-4', 'cp32-1', 'cp32-8', 'Unclassified'], 'discordant_replicons': ['cp32-10', 'cp32-9', 'cp32-4', 'cp32-1', 'cp32-8', 'Unclassified']}
# {'block': ('group_3568',), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp17'], 'discordant_replicons': ['lp17']}
# {'block': ('Transposase',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'cp32-10', 'lp28-2'], 'discordant_replicons': ['cp32-10', 'lp28-2']}
# {'block': ('Uncharacterized lipoprotein BBD10',), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp17'], 'discordant_replicons': ['lp17']}
# {'block': ('group_1243',), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp38', 'lp21', 'lp36'], 'discordant_replicons': ['lp38', 'lp36', 'lp21']}
# {'block': ('Uncharacterized protein BBD11',), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp17'], 'discordant_replicons': ['lp17']}
# {'block': ('Blasticidin-S acetyltransferase',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'cp32-10', 'lp28-2'], 'discordant_replicons': ['cp32-10', 'lp28-2']}
# {'block': ('Lipoprotein',), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp38', 'lp21', 'lp36', 'lp28-1'], 'discordant_replicons': ['lp28-1', 'lp38', 'lp36', 'lp21']}
# {'block': ('Lipoprotein', 'Lipoprotein'), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT110H', 'UCT113H', 'UCT30H', 'UCT92H', 'UNY149P', 'UNY208P', 'URI103H', 'URI112H', 'URI117H', 'URI118H', 'URI34H', 'URI44H', 'URI46H', 'URI47H', 'URI86H', 'UWI247P', 'UWI248P', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp38', 'lp21', 'lp36', 'lp28-1'], 'discordant_replicons': ['lp28-1', 'lp38', 'lp36', 'lp21']}
# {'block': ('Homing endonuclease LAGLIDADG domain-containing protein',), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp17'], 'discordant_replicons': ['lp17']}
# {'block': ('sIMPL',), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp38', 'lp21', 'lp36', 'lp28-1'], 'discordant_replicons': ['lp28-1', 'lp38', 'lp36', 'lp21']}
# {'block': ('BBD14-like protein',), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT29H', 'UCT31H', 'UCT50H', 'UCT96H', 'UNY169P', 'UNY172P', 'URI101H', 'URI102H', 'URI107H', 'URI111H', 'URI120H', 'URI33H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI48H', 'URI56H', 'URI87H', 'URI89H', 'URI91H', 'URI93H', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp17'], 'discordant_replicons': ['lp17']}
# {'block': ('group_350',), 'main_replicon': 'cp32-7', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT29H', 'UCT31H', 'UCT32H', 'UCT92H', 'UCT96H', 'UNY149P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI118H', 'URI120H', 'URI34H', 'URI36H', 'URI40H', 'URI42H', 'URI47H', 'URI87H', 'URI93H', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-5', 'cp32-1', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-11', 'cp32-5', 'cp32-6', 'cp32-1']}
# {'block': ('group_657',), 'main_replicon': 'cp32-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT29H', 'UCT31H', 'UCT35H', 'UNY169P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI107H', 'URI111H', 'URI120H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI56H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-3', 'cp32-10', 'cp32-5', 'cp32-4', 'cp32-8', 'Unclassified', 'cp32-11', 'cp32-9', 'cp32-13', 'cp32-1', 'cp32-6'], 'discordant_replicons': ['cp32-10', 'cp32-9', 'cp32-5', 'cp32-4', 'cp32-13', 'cp32-1', 'cp32-8', 'cp32-6', 'Unclassified', 'cp32-11']}
# {'block': ('DUF759 domain-containing protein',), 'main_replicon': 'cp32-7', 'all_assemblies': ['ESI26H', 'UCT29H', 'UCT30H', 'UCT32H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY193P', 'UNY203P', 'URI101H', 'URI118H', 'URI120H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI47H', 'URI87H', 'URI89H', 'UWI248P', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-10', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('Putative antigen, P35',), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp38', 'lp21', 'lp36', 'lp28-1'], 'discordant_replicons': ['lp28-1', 'lp38', 'lp36', 'lp21']}
# {'block': ('Putative antigen, P35', 'Putative antigen, P35'), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UNY169P', 'UNY193P', 'UNY208P', 'URI117H', 'URI118H', 'URI34H', 'URI47H', 'UWI247P', 'UWI248P', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp38', 'lp21', 'lp36', 'lp28-1'], 'discordant_replicons': ['lp28-1', 'lp38', 'lp36', 'lp21']}
# {'block': ('Uncharacterized membrane protein BB_D15',), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp17'], 'discordant_replicons': ['lp17']}
# {'block': ('group_756',), 'main_replicon': 'cp32-7', 'all_assemblies': ['ESI26H', 'UCT110H', 'UCT30H', 'UCT32H', 'UCT96H', 'UNY149P', 'URI103H', 'URI112H', 'URI118H', 'URI36H', 'URI44H', 'URI46H', 'URI47H', 'URI86H', 'UWI247P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-9', 'cp32-5', 'cp32-4', 'cp32-1', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-9', 'cp32-5', 'cp32-4', 'cp32-1', 'cp32-6', 'cp32-11']}
# {'block': ('group_745',), 'main_replicon': 'cp32-7', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT29H', 'UCT31H', 'UNY172P', 'URI101H', 'URI102H', 'URI111H', 'URI120H', 'URI33H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI48H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-10', 'cp32-5', 'cp32-4', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-5', 'cp32-4', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('ade',), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp38', 'lp21', 'lp36', 'lp28-1'], 'discordant_replicons': ['lp28-1', 'lp38', 'lp36', 'lp21']}
# {'block': ('group_162',), 'main_replicon': 'cp32-12', 'all_assemblies': ['ESI26H', 'UCT29H', 'UCT30H', 'UCT32H', 'UCT92H', 'UNY149P', 'UNY193P', 'UNY203P', 'URI101H', 'URI103H', 'URI118H', 'URI120H', 'URI34H', 'URI46H', 'URI47H', 'URI86H', 'URI87H', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-7', 'cp32-5', 'cp32-1', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-7', 'cp32-5', 'cp32-1', 'cp32-6', 'cp32-11']}
# {'block': ('BBC01',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'cp32-10', 'lp28-2'], 'discordant_replicons': ['cp32-10', 'lp28-2']}
# {'block': ('Uncharacterized protein BBD18',), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp17'], 'discordant_replicons': ['lp17']}
# {'block': ('rdgC',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT29H', 'UCT31H', 'UCT50H', 'UCT96H', 'UNY169P', 'UNY172P', 'UNY193P', 'URI101H', 'URI102H', 'URI107H', 'URI111H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI48H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'lp56', 'lp28-7', 'lp28-2', 'lp28-9'], 'discordant_replicons': ['lp28-9', 'lp28-7', 'lp56', 'lp28-2']}
# {'block': ('group_3828',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT29H', 'UCT31H', 'UCT50H', 'UCT96H', 'UNY169P', 'UNY172P', 'UNY193P', 'URI101H', 'URI102H', 'URI107H', 'URI111H', 'URI120H', 'URI33H', 'URI34H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI48H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'lp28-7', 'lp28-2', 'lp28-9'], 'discordant_replicons': ['lp28-9', 'lp28-7', 'lp28-2']}
# {'block': ('group_1795',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'cp32-10', 'lp28-2'], 'discordant_replicons': ['cp32-10', 'lp28-2']}
# {'block': ('group_1233',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT29H', 'UCT31H', 'UCT50H', 'UCT96H', 'UNY169P', 'UNY172P', 'UNY193P', 'URI101H', 'URI102H', 'URI107H', 'URI111H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI48H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'lp56', 'lp28-7', 'lp28-2', 'lp28-9'], 'discordant_replicons': ['lp28-9', 'lp28-7', 'lp56', 'lp28-2']}
# {'block': ('group_1794',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'cp32-10', 'lp28-2'], 'discordant_replicons': ['cp32-10', 'lp28-2']}
# {'block': ('group_1457',), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp38', 'lp21', 'lp36', 'lp28-1'], 'discordant_replicons': ['lp28-1', 'lp38', 'lp36', 'lp21']}
# {'block': ('group_1793',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'cp32-10', 'lp28-2'], 'discordant_replicons': ['cp32-10', 'lp28-2']}
# {'block': ('group_3291',), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp17'], 'discordant_replicons': ['lp17']}
# {'block': ('group_1742',), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp38', 'lp21', 'lp36', 'lp28-1'], 'discordant_replicons': ['lp28-1', 'lp38', 'lp36', 'lp21']}
# {'block': ('DUF226 domain-containing protein',), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp38', 'lp21', 'lp36', 'lp28-1'], 'discordant_replicons': ['lp28-1', 'lp38', 'lp36', 'lp21']}
# {'block': ('Borrelia family protein PFam57/62',), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp38', 'lp21', 'lp36', 'lp28-1'], 'discordant_replicons': ['lp28-1', 'lp38', 'lp36', 'lp21']}
# {'block': ('Transporter, major facilitator family',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT110H', 'UCT113H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI101H', 'URI103H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI88H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'cp32-10'], 'discordant_replicons': ['cp32-10']}
# {'block': ('group_1739',), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp38', 'lp21', 'lp36', 'lp28-1'], 'discordant_replicons': ['lp28-1', 'lp38', 'lp36', 'lp21']}
# {'block': ('group_862',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'cp32-10', 'lp28-2'], 'discordant_replicons': ['cp32-10', 'lp28-2']}
# {'block': ('ORF09/2-9 ORF7',), 'main_replicon': 'cp32-7', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT29H', 'UCT31H', 'UNY193P', 'URI101H', 'URI102H', 'URI107H', 'URI111H', 'URI120H', 'URI33H', 'URI39H', 'URI40H', 'URI42H', 'URI87H', 'URI89H', 'URI91H', 'URI93H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-10', 'cp32-5', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-5', 'cp32-10', 'cp32-6', 'cp32-11']}
# {'block': ('group_1445',), 'main_replicon': 'cp32-7', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT92H', 'UNY149P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-3', 'cp32-5', 'cp32-4'], 'discordant_replicons': ['cp32-5', 'cp32-3', 'cp32-4']}
# {'block': ('group_1738',), 'main_replicon': 'lp38', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT29H', 'UCT31H', 'UCT35H', 'UCT50H', 'UCT96H', 'UNY169P', 'UNY193P', 'UNY203P', 'URI101H', 'URI102H', 'URI107H', 'URI111H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI48H', 'URI56H', 'URI87H', 'URI89H', 'URI91H', 'URI93H'], 'discordant_assemblies': [], 'all_replicons': ['lp38', 'lp36', 'lp28-1'], 'discordant_replicons': ['lp36', 'lp28-1']}
# {'block': ('Borrelia family protein',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'lp28-3', 'lp21'], 'discordant_replicons': ['lp28-3', 'lp21']}
# {'block': ('DUF244 domain-containing protein',), 'main_replicon': 'cp32-12', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT29H', 'UCT31H', 'UCT50H', 'UNY169P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI86H', 'URI87H', 'URI89H', 'URI91H', 'URI93H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-5', 'cp32-7'], 'discordant_replicons': ['cp32-7', 'cp32-5']}
# {'block': ('group_1242',), 'main_replicon': 'lp38', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT29H', 'UCT31H', 'UCT35H', 'UCT50H', 'UCT96H', 'UNY169P', 'UNY193P', 'UNY203P', 'URI101H', 'URI102H', 'URI107H', 'URI111H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI48H', 'URI56H', 'URI87H', 'URI89H', 'URI91H', 'URI93H'], 'discordant_assemblies': [], 'all_replicons': ['lp38', 'lp36', 'lp28-1'], 'discordant_replicons': ['lp36', 'lp28-1']}
# {'block': ('group_1242', 'group_699'), 'main_replicon': 'lp38', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT29H', 'UCT31H', 'UCT35H', 'UCT96H', 'UNY193P', 'UNY203P', 'URI101H', 'URI102H', 'URI107H', 'URI111H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI48H', 'URI56H', 'URI87H', 'URI89H', 'URI91H', 'URI93H'], 'discordant_assemblies': [], 'all_replicons': ['lp38', 'lp36', 'lp28-1'], 'discordant_replicons': ['lp36', 'lp28-1']}
# {'block': ('group_1465',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'lp28-3', 'lp21'], 'discordant_replicons': ['lp28-3', 'lp21']}
# {'block': ('Borrelia burgdorferi virulent strain associated lipoprotein',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'cp32-10', 'lp28-2'], 'discordant_replicons': ['cp32-10', 'lp28-2']}
# {'block': ('Borrelia burgdorferi virulent strain associated lipoprotein', 'group_1796'), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'cp32-10', 'lp28-2'], 'discordant_replicons': ['cp32-10', 'lp28-2']}
# {'block': ('group_261',), 'main_replicon': 'cp32-9', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT29H', 'UCT31H', 'UCT50H', 'UCT92H', 'UNY149P', 'UNY169P', 'UNY172P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI117H', 'URI120H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI47H', 'URI87H', 'URI89H', 'URI91H', 'URI93H', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-9', 'cp32-8'], 'discordant_replicons': ['cp32-8']}
# {'block': ('group_1249',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'cp32-10', 'lp28-2'], 'discordant_replicons': ['cp32-10', 'lp28-2']}
# {'block': ('fibronectin-binding protein',), 'main_replicon': 'lp28-3', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp38', 'lp21', 'lp36', 'lp28-1'], 'discordant_replicons': ['lp28-1', 'lp38', 'lp36', 'lp21']}
# {'block': ('group_1459',), 'main_replicon': 'cp32-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY193P', 'UNY203P', 'URI101H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'UWI247P', 'UWI248P', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-4', 'cp32-6', 'Unclassified'], 'discordant_replicons': ['Unclassified', 'cp32-6']}
# {'block': ('group_1460',), 'main_replicon': 'cp32-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY193P', 'UNY203P', 'URI101H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'UWI247P', 'UWI248P', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-4', 'cp32-6', 'Unclassified'], 'discordant_replicons': ['Unclassified', 'cp32-6']}
# {'block': ('group_3525',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'cp32-10', 'lp28-2'], 'discordant_replicons': ['cp32-10', 'lp28-2']}
# {'block': ('KID repeat family protein',), 'main_replicon': 'cp32-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY193P', 'UNY203P', 'URI101H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'UWI247P', 'UWI248P', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-4', 'cp32-6'], 'discordant_replicons': ['cp32-6']}
# {'block': ('Surface antigen',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'cp32-10', 'lp28-2'], 'discordant_replicons': ['cp32-10', 'lp28-2']}
# {'block': ('group_604',), 'main_replicon': 'cp32-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT29H', 'UCT31H', 'UCT92H', 'UCT96H', 'UNY149P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI117H', 'URI120H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI47H', 'URI48H', 'URI87H', 'URI89H', 'URI91H', 'URI93H', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-4', 'cp32-10', 'cp32-9'], 'discordant_replicons': ['cp32-10', 'cp32-9']}
# {'block': ('chromosome replication/partitioning protein',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI56H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'cp32-10', 'lp28-2'], 'discordant_replicons': ['cp32-10', 'lp28-2']}
# {'block': ('group_1251',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT110H', 'UCT30H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI103H', 'URI112H', 'URI117H', 'URI118H', 'URI34H', 'URI44H', 'URI46H', 'URI47H', 'URI86H', 'URI88H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'lp28-1', 'Unclassified'], 'discordant_replicons': ['Unclassified', 'lp28-1']}
# {'block': ('group_1467',), 'main_replicon': 'lp28-4', 'all_assemblies': ['ESI26H', 'UCT110H', 'UCT113H', 'UCT30H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI103H', 'URI112H', 'URI117H', 'URI118H', 'URI33H', 'URI34H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI86H', 'URI88H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'Unclassified'], 'discordant_replicons': ['Unclassified']}
# {'block': ('group_1467', 'group_1101'), 'main_replicon': 'lp38', 'all_assemblies': ['ESI26H', 'UCT109H', 'UCT113H', 'UCT29H', 'UCT35H', 'UCT50H', 'UCT92H', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY203P', 'URI33H', 'URI34H', 'URI36H', 'URI48H', 'URI56H'], 'discordant_assemblies': ['UCT92H', 'UNY172P'], 'all_replicons': ['lp28-4', 'lp38', 'lp36', 'lp28-1', 'Unclassified'], 'discordant_replicons': ['lp28-4', 'Unclassified', 'lp36', 'lp28-1']}
# {'block': ('group_1483',), 'main_replicon': 'lp28-4', 'all_assemblies': ['UCT109H', 'UCT110H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI120H', 'URI33H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'lp25', 'lp28-8', 'lp28-2', 'lp17'], 'discordant_replicons': ['lp25', 'lp28-2', 'lp28-8', 'lp17']}
# {'block': ('P12 family lipoprotein',), 'main_replicon': 'lp28-4', 'all_assemblies': ['UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI36H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'lp38', 'lp36'], 'discordant_replicons': ['lp38', 'lp36']}
# {'block': ('cdsC',), 'main_replicon': 'lp28-3', 'all_assemblies': ['UCT109H', 'UCT29H', 'UCT31H', 'URI101H', 'URI107H', 'URI111H', 'URI120H', 'URI33H', 'URI41H', 'URI42H', 'URI48H', 'URI89H', 'URI91H', 'URI93H'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp25', 'lp17'], 'discordant_replicons': ['lp25', 'lp17']}
# {'block': ('cdsC', 'cdsC'), 'main_replicon': 'lp28-3', 'all_assemblies': ['UCT109H', 'UCT29H', 'UCT31H', 'URI101H', 'URI107H', 'URI33H', 'URI41H', 'URI42H', 'URI48H', 'URI89H', 'URI91H', 'URI93H'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp25', 'lp17'], 'discordant_replicons': ['lp25', 'lp17']}
# {'block': ('putative helicase',), 'main_replicon': 'lp28-4', 'all_assemblies': ['UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT50H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI120H', 'URI33H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'lp25', 'lp28-8', 'lp28-2', 'lp17'], 'discordant_replicons': ['lp25', 'lp28-2', 'lp28-8', 'lp17']}
# {'block': ('group_776',), 'main_replicon': 'lp28-4', 'all_assemblies': ['UCT109H', 'UCT110H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY193P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI120H', 'URI33H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'lp25', 'lp28-8', 'lp28-2', 'lp17'], 'discordant_replicons': ['lp25', 'lp28-2', 'lp28-8', 'lp17']}
# {'block': ('transposase',), 'main_replicon': 'lp28-4', 'all_assemblies': ['UCT109H', 'UCT110H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT35H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY169P', 'UNY172P', 'UNY208P', 'URI101H', 'URI102H', 'URI107H', 'URI111H', 'URI120H', 'URI33H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI47H', 'URI48H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'lp25', 'lp28-8', 'lp28-2', 'lp17'], 'discordant_replicons': ['lp25', 'lp28-2', 'lp28-8', 'lp17']}
# {'block': ('yeeA',), 'main_replicon': 'lp28-4', 'all_assemblies': ['UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT92H', 'UNY149P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI118H', 'URI120H', 'URI33H', 'URI34H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'lp28-3', 'lp21'], 'discordant_replicons': ['lp28-3', 'lp21']}
# {'block': ('group_3163',), 'main_replicon': 'cp32-7', 'all_assemblies': ['UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT32H', 'UCT92H', 'UNY149P', 'UNY203P', 'UNY208P', 'URI102H', 'URI103H', 'URI107H', 'URI112H', 'URI33H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI48H', 'URI86H', 'URI87H', 'URI88H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-10', 'cp32-9', 'cp32-5', 'cp32-4', 'cp32-6'], 'discordant_replicons': ['cp32-10', 'cp32-9', 'cp32-5', 'cp32-4', 'cp32-6']}
# {'block': ('group_316',), 'main_replicon': 'cp32-12', 'all_assemblies': ['UCT109H', 'UCT29H', 'UCT32H', 'UCT92H', 'UCT96H', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI120H', 'URI34H', 'URI40H', 'URI42H', 'URI46H', 'URI87H', 'URI89H', 'URI93H', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-10', 'cp32-13', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-13', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('group_1977',), 'main_replicon': 'lp28-4', 'all_assemblies': ['UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY172P', 'UNY193P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI118H', 'URI120H', 'URI34H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'lp28-3', 'lp21', 'chromosome'], 'discordant_replicons': ['chromosome', 'lp28-3', 'lp21']}
# {'block': ('Phage tail tape measure protein',), 'main_replicon': 'cp32-3', 'all_assemblies': ['UCT109H', 'UCT113H', 'UCT29H', 'UCT31H', 'UCT35H', 'UCT50H', 'UCT96H', 'UNY169P', 'UNY203P', 'UNY208P', 'URI101H', 'URI102H', 'URI107H', 'URI111H', 'URI117H', 'URI120H', 'URI33H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI56H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI248P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-3', 'cp32-10', 'cp32-9', 'cp32-13', 'cp32-4', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-9', 'cp32-13', 'cp32-4', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('group_1295',), 'main_replicon': 'lp28-4', 'all_assemblies': ['UCT109H', 'UCT110H', 'UCT113H', 'UCT29H', 'UCT30H', 'UCT31H', 'UCT32H', 'UCT35H', 'UCT92H', 'UCT96H', 'UNY149P', 'UNY172P', 'UNY208P', 'URI101H', 'URI102H', 'URI103H', 'URI107H', 'URI111H', 'URI112H', 'URI117H', 'URI120H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI44H', 'URI46H', 'URI47H', 'URI86H', 'URI87H', 'URI88H', 'URI89H', 'URI91H', 'URI93H', 'UWI247P', 'UWI248P', 'UWI263P', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-4', 'lp25', 'lp17'], 'discordant_replicons': ['lp25', 'lp17']}
# ...
# {'block': ('group_316', 'group_316', 'group_316'), 'main_replicon': 'cp32-12', 'all_assemblies': ['UCT96H', 'URI120H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-10', 'cp32-13', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-13', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('group_350', 'group_350'), 'main_replicon': 'cp32-7', 'all_assemblies': ['UCT96H', 'URI120H', 'URI36H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-5', 'cp32-1', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-11', 'cp32-5', 'cp32-6', 'cp32-1']}
# {'block': ('Lipoprotein', 'Lipoprotein', 'Lipoprotein'), 'main_replicon': 'lp28-3', 'all_assemblies': ['UNY149P', 'UNY208P', 'URI117H', 'URI118H', 'URI47H', 'UWI247P', 'UWI248P', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp38', 'lp21', 'lp36', 'lp28-1'], 'discordant_replicons': ['lp28-1', 'lp38', 'lp36', 'lp21']}
# {'block': ('Phage tail sheath protein', 'Phage tail sheath protein'), 'main_replicon': 'cp32-12', 'all_assemblies': ['UNY193P', 'URI118H', 'URI39H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-7', 'cp32-3', 'cp32-5', 'cp32-4', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-7', 'cp32-3', 'cp32-5', 'cp32-4', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('group_344', 'group_344'), 'main_replicon': 'cp32-12', 'all_assemblies': ['UNY193P', 'UNY203P', 'UNY208P', 'URI56H', 'URI88H', 'UWI248P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-7', 'cp32-3', 'cp32-10', 'cp32-5', 'cp32-4', 'cp32-8', 'Unclassified', 'cp32-11', 'cp32-13'], 'discordant_replicons': ['cp32-7', 'cp32-3', 'cp32-10', 'cp32-5', 'cp32-4', 'cp32-13', 'cp32-8', 'Unclassified', 'cp32-11']}
# {'block': ('group_162', 'group_162', 'group_165'), 'main_replicon': 'cp32-12', 'all_assemblies': ['UNY193P', 'URI103H', 'URI46H', 'URI86H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-7', 'cp32-3', 'cp32-10', 'cp32-5', 'cp32-8', 'cp32-11', 'cp32-1', 'cp32-6'], 'discordant_replicons': ['cp32-7', 'cp32-3', 'cp32-10', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('group_162', 'group_162', 'group_165', 'group_165'), 'main_replicon': 'cp32-12', 'all_assemblies': ['UNY193P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-7', 'cp32-3', 'cp32-10', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-7', 'cp32-3', 'cp32-10', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('DUF759 domain-containing protein', 'DUF759 domain-containing protein'), 'main_replicon': 'cp32-7', 'all_assemblies': ['UNY203P', 'URI120H', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-10', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('DUF759 domain-containing protein', 'DUF759 domain-containing protein', 'DUF759 domain-containing protein'), 'main_replicon': 'cp32-7', 'all_assemblies': ['UNY203P', 'URI120H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-10', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('DUF244 domain-containing protein', 'ORF25'), 'main_replicon': 'cp32-12', 'all_assemblies': ['URI103H', 'URI112H', 'URI117H', 'URI118H', 'URI44H', 'URI46H', 'URI47H', 'URI86H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-7', 'cp32-3', 'cp32-9', 'cp32-13', 'cp32-5'], 'discordant_replicons': ['cp32-7', 'cp32-3', 'cp32-9', 'cp32-13', 'cp32-5']}
# {'block': ('group_478', 'group_478'), 'main_replicon': 'cp32-3', 'all_assemblies': ['URI111H', 'URI39H', 'URI40H', 'URI42H', 'URI89H', 'URI93H', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-3', 'cp32-10', 'cp32-9', 'cp32-4', 'cp32-1', 'cp32-8', 'Unclassified'], 'discordant_replicons': ['cp32-10', 'cp32-9', 'cp32-4', 'cp32-1', 'cp32-8', 'Unclassified']}
# {'block': ('DUF792 domain-containing protein', 'DUF792 domain-containing protein'), 'main_replicon': 'cp32-7', 'all_assemblies': ['URI111H', 'URI91H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-3', 'cp32-10', 'cp32-9', 'cp32-13', 'cp32-4', 'cp32-1', 'cp32-8', 'cp32-6'], 'discordant_replicons': ['cp32-3', 'cp32-10', 'cp32-9', 'cp32-13', 'cp32-4', 'cp32-1', 'cp32-8', 'cp32-6']}
# {'block': ('DUF792 domain-containing protein', 'DUF792 domain-containing protein', 'group_756'), 'main_replicon': 'cp32-7', 'all_assemblies': ['URI111H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-5', 'cp32-4', 'cp32-11', 'cp32-1', 'cp32-6', 'cp32-9'], 'discordant_replicons': ['cp32-9', 'cp32-5', 'cp32-4', 'cp32-1', 'cp32-6', 'cp32-11']}
# {'block': ('DUF792 domain-containing protein', 'DUF792 domain-containing protein', 'group_756', 'group_756'), 'main_replicon': 'cp32-7', 'all_assemblies': ['URI111H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-3', 'cp32-10', 'cp32-9', 'cp32-5', 'cp32-4', 'cp32-13', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-3', 'cp32-10', 'cp32-9', 'cp32-5', 'cp32-4', 'cp32-13', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('DUF1073 domain-containing protein', 'DUF1073 domain-containing protein'), 'main_replicon': 'cp32-7', 'all_assemblies': ['URI111H', 'URI112H', 'URI117H', 'URI39H', 'URI40H', 'URI41H', 'URI42H', 'URI48H', 'URI87H', 'URI89H', 'URI91H', 'UWI247P', 'UWI248P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-10', 'cp32-5', 'cp32-1', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-5', 'cp32-1', 'cp32-6', 'cp32-11']}
# {'block': ('DUF244 domain-containing protein', 'ORF25', 'ORF25'), 'main_replicon': 'cp32-12', 'all_assemblies': ['URI112H', 'URI118H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-7', 'cp32-3', 'cp32-9', 'cp32-13', 'cp32-5'], 'discordant_replicons': ['cp32-7', 'cp32-3', 'cp32-9', 'cp32-13', 'cp32-5']}
# {'block': ('insQ', 'group_223'), 'main_replicon': 'lp28-5', 'all_assemblies': ['URI112H', 'UWI248P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp28-5', 'lp21', 'lp36', 'lp28-1', 'chromosome'], 'discordant_replicons': ['lp28-3', 'lp21', 'lp36', 'lp28-1', 'chromosome']}
# {'block': ('group_3290',), 'main_replicon': 'lp28-3', 'all_assemblies': ['URI118H'], 'discordant_assemblies': [], 'all_replicons': ['lp28-3', 'lp17'], 'discordant_replicons': ['lp17']}
# {'block': ('group_316', 'group_316', 'group_316', 'group_316'), 'main_replicon': 'cp32-12', 'all_assemblies': ['URI120H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-10', 'cp32-13', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-13', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('group_316', 'group_316', 'group_316', 'group_316', 'group_316'), 'main_replicon': 'cp32-12', 'all_assemblies': ['URI120H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-10', 'cp32-13', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-13', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('group_350', 'group_350', 'group_350'), 'main_replicon': 'cp32-7', 'all_assemblies': ['URI120H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-5', 'cp32-1', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-11', 'cp32-5', 'cp32-6', 'cp32-1']}
# {'block': ('group_350', 'group_350', 'group_350', 'group_350'), 'main_replicon': 'cp32-7', 'all_assemblies': ['URI120H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-5', 'cp32-1', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-11', 'cp32-5', 'cp32-6', 'cp32-1']}
# {'block': ('group_162', 'group_165'), 'main_replicon': 'cp32-12', 'all_assemblies': ['URI120H', 'URI87H', 'UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-7', 'cp32-3', 'cp32-10', 'cp32-5', 'cp32-8', 'cp32-11', 'cp32-1', 'cp32-6'], 'discordant_replicons': ['cp32-7', 'cp32-3', 'cp32-10', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('group_162', 'group_165', 'group_165'), 'main_replicon': 'cp32-12', 'all_assemblies': ['URI120H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-5', 'cp32-3', 'cp32-10', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-3', 'cp32-10', 'cp32-5', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('group_162', 'group_165', 'group_165', 'group_165'), 'main_replicon': 'cp32-12', 'all_assemblies': ['URI120H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-5', 'cp32-3', 'cp32-10', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-3', 'cp32-10', 'cp32-5', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('group_162', 'group_165', 'group_165', 'group_165', 'group_165'), 'main_replicon': 'cp32-12', 'all_assemblies': ['URI120H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-7', 'cp32-3', 'cp32-10', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-7', 'cp32-3', 'cp32-10', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('group_431', 'group_431'), 'main_replicon': 'cp32-3', 'all_assemblies': ['URI36H', 'URI39H', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-3', 'cp32-10', 'cp32-9', 'cp32-4', 'cp32-1', 'Unclassified', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-9', 'cp32-4', 'cp32-1', 'Unclassified', 'cp32-11']}
# {'block': ('DUF1073 domain-containing protein', 'DUF1073 domain-containing protein', 'DUF1073 domain-containing protein'), 'main_replicon': 'cp32-7', 'all_assemblies': ['URI39H', 'URI41H', 'URI91H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-10', 'cp32-5', 'cp32-1', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-5', 'cp32-1', 'cp32-6', 'cp32-11']}
# {'block': ('group_478', 'group_478', 'group_478'), 'main_replicon': 'cp32-3', 'all_assemblies': ['URI40H', 'URI42H', 'UWI283P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-3', 'cp32-10', 'cp32-9', 'cp32-4', 'cp32-1', 'cp32-8', 'Unclassified'], 'discordant_replicons': ['cp32-10', 'cp32-9', 'cp32-4', 'cp32-1', 'cp32-8', 'Unclassified']}
# {'block': ('group_478', 'group_478', 'group_478', 'group_478'), 'main_replicon': 'cp32-3', 'all_assemblies': ['URI40H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-3', 'cp32-10', 'cp32-4', 'cp32-1', 'cp32-8', 'Unclassified', 'cp32-9'], 'discordant_replicons': ['cp32-10', 'cp32-9', 'cp32-4', 'cp32-1', 'cp32-8', 'Unclassified']}
# {'block': ('DUF1073 domain-containing protein', 'DUF1073 domain-containing protein', 'DUF1073 domain-containing protein', 'DUF1073 domain-containing protein'), 'main_replicon': 'cp32-7', 'all_assemblies': ['URI41H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-5', 'cp32-10', 'cp32-1', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-5', 'cp32-1', 'cp32-6', 'cp32-11']}
# {'block': ('group_165', 'group_165'), 'main_replicon': 'cp32-12', 'all_assemblies': ['URI44H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-5', 'cp32-3', 'cp32-10', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-3', 'cp32-10', 'cp32-5', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('group_165', 'group_165', 'group_165'), 'main_replicon': 'cp32-12', 'all_assemblies': ['URI44H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-5', 'cp32-3', 'cp32-10', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-3', 'cp32-10', 'cp32-5', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('DUF1322 domain-containing protein', 'DUF1322 domain-containing protein', 'DUF1322 domain-containing protein', 'DUF1322 domain-containing protein'), 'main_replicon': 'cp32-12', 'all_assemblies': ['URI47H', 'URI88H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-7', 'cp32-3', 'cp32-10', 'cp32-5', 'cp32-4', 'cp32-8', 'Unclassified', 'cp32-11', 'cp32-13', 'cp32-6'], 'discordant_replicons': ['cp32-7', 'cp32-3', 'cp32-10', 'cp32-5', 'cp32-4', 'cp32-13', 'cp32-8', 'cp32-6', 'Unclassified', 'cp32-11']}
# {'block': ('group_745', 'group_745', 'group_745'), 'main_replicon': 'cp32-7', 'all_assemblies': ['URI48H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-5', 'cp32-4', 'cp32-10', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-5', 'cp32-4', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('Phage tail tape measure protein', 'Phage tail tape measure protein'), 'main_replicon': 'cp32-3', 'all_assemblies': ['URI56H', 'URI87H', 'URI91H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-3', 'cp32-10', 'cp32-9', 'cp32-13', 'cp32-4', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-9', 'cp32-13', 'cp32-4', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('group_657', 'group_657', 'group_657'), 'main_replicon': 'cp32-3', 'all_assemblies': ['URI91H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-3', 'cp32-10', 'cp32-9', 'cp32-13', 'cp32-4', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'Unclassified', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-9', 'cp32-13', 'cp32-4', 'cp32-5', 'cp32-1', 'cp32-8', 'cp32-6', 'Unclassified', 'cp32-11']}
# {'block': ('Phage tail tape measure protein', 'Phage tail tape measure protein', 'Phage tail tape measure protein'), 'main_replicon': 'cp32-3', 'all_assemblies': ['URI91H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-3', 'cp32-10', 'cp32-9', 'cp32-13', 'cp32-4', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-9', 'cp32-13', 'cp32-4', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('Phage tail tape measure protein', 'Phage tail tape measure protein', 'Phage tail tape measure protein', 'Phage tail tape measure protein'), 'main_replicon': 'cp32-3', 'all_assemblies': ['URI91H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-3', 'cp32-10', 'cp32-9', 'cp32-13', 'cp32-4', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-9', 'cp32-13', 'cp32-4', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('DUF792 domain-containing protein', 'DUF792 domain-containing protein', 'DUF792 domain-containing protein'), 'main_replicon': 'cp32-7', 'all_assemblies': ['URI91H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-3', 'cp32-10', 'cp32-9', 'cp32-13', 'cp32-4', 'cp32-1', 'cp32-8', 'cp32-6'], 'discordant_replicons': ['cp32-3', 'cp32-10', 'cp32-9', 'cp32-13', 'cp32-4', 'cp32-1', 'cp32-8', 'cp32-6']}
# {'block': ('DUF792 domain-containing protein', 'DUF792 domain-containing protein', 'DUF792 domain-containing protein', 'group_756'), 'main_replicon': 'cp32-7', 'all_assemblies': ['URI91H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-7', 'cp32-3', 'cp32-10', 'cp32-9', 'cp32-5', 'cp32-4', 'cp32-13', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-3', 'cp32-10', 'cp32-9', 'cp32-5', 'cp32-4', 'cp32-13', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('group_3126', 'group_3126', 'group_3126'), 'main_replicon': 'cp32-3', 'all_assemblies': ['URI91H'], 'discordant_assemblies': [], 'all_replicons': ['cp32-3', 'cp32-10', 'cp32-13', 'cp32-4', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11'], 'discordant_replicons': ['cp32-10', 'cp32-13', 'cp32-4', 'cp32-1', 'cp32-8', 'cp32-6', 'cp32-11']}
# {'block': ('insQ', 'group_223', 'group_223'), 'main_replicon': 'lp28-1', 'all_assemblies': ['UWI248P'], 'discordant_assemblies': [], 'all_replicons': ['lp28-1', 'lp28-3', 'lp36', 'lp28-5', 'chromosome', 'lp21'], 'discordant_replicons': ['lp28-3', 'lp21', 'lp28-5', 'lp36', 'chromosome']}
# {'block': ('ORF25', 'ORF25', 'ORF25'), 'main_replicon': 'cp32-12', 'all_assemblies': ['UWI263P'], 'discordant_assemblies': [], 'all_replicons': ['cp32-12', 'cp32-13', 'cp32-3', 'cp32-9'], 'discordant_replicons': ['cp32-13', 'cp32-3', 'cp32-9']}

# %%
def diagnose_csv(file_path):
    df = pd.read_csv(file_path)

    print(f"Total rows: {len(df)}")
    print(f"Total columns: {len(df.columns)}")
    print("\nColumn names:")
    print(df.columns.tolist())

    print("\nFirst 5 rows:")
    print(df.head())

    print("\nData types:")
    print(df.dtypes)

    print("\nUnique values in key columns:")
    for col in ['assembly', 'gene', 'replicon_name', 'best_replicon']:
        if col in df.columns:
            print(f"{col}: {df[col].nunique()}")

    replicon_columns = df.columns[6:-2].tolist()  # Assuming the last two columns are 'lipo' and 'surface_lipo'
    non_zero_counts = (df[replicon_columns] > 0).sum()
    print("\nNon-zero counts in replicon columns:")
    print(non_zero_counts)

    multiple_non_zero = (df[replicon_columns] > 0).sum(axis=1) > 1
    print(f"\nRows with multiple non-zero replicon values: {multiple_non_zero.sum()}")

    if multiple_non_zero.sum() > 0:
        print("\nSample row with multiple non-zero replicon values:")
        print(df[multiple_non_zero].iloc[0])

    gene_replicon_counts = df.groupby(['gene', 'best_replicon']).size().unstack(fill_value=0)
    discordant_genes = gene_replicon_counts[gene_replicon_counts.gt(0).sum(axis=1) > 1]
    print(f"\nNumber of discordant genes: {len(discordant_genes)}")

    if len(discordant_genes) > 0:
        print("\nSample discordant gene:")
        sample_gene = discordant_genes.index[0]
        print(df[df['gene'] == sample_gene])

# %%
def analyze_replicon_discrepancies(file_path, threshold=4):
    # Read the CSV file
    df = pd.read_csv(file_path)

    print("Data shape:", df.shape)
    print("Columns:", df.columns.tolist())

    # Identify discrepancies
    df['is_discrepant'] = df['replicon_name'] != df['best_replicon']

    # Group by gene and summarize discrepancies and non-discrepancies
    gene_summary = df.groupby('gene').agg({
        'is_discrepant': ['sum', 'size'],
        'assembly': lambda x: [list(x[df.loc[x.index, 'is_discrepant']]),
                               list(x[~df.loc[x.index, 'is_discrepant']])],
        'replicon_name': lambda x: [list(x[df.loc[x.index, 'is_discrepant']]),
                                    list(set(x[~df.loc[x.index, 'is_discrepant']]))],
        'best_replicon': 'first'
    })

    # Flatten the column names
    gene_summary.columns = ['discrepant_count', 'total_assemblies', 'assemblies', 'replicons', 'best_replicon']
    gene_summary['non_discrepant_count'] = gene_summary['total_assemblies'] - gene_summary['discrepant_count']

    # Split the lists
    gene_summary['discrepant_assemblies'] = gene_summary['assemblies'].str[0]
    gene_summary['non_discrepant_assemblies'] = gene_summary['assemblies'].str[1]
    gene_summary['discrepant_replicons'] = gene_summary['replicons'].str[0]
    gene_summary['non_discrepant_replicons'] = gene_summary['replicons'].str[1]
    gene_summary.drop(columns=['assemblies', 'replicons'], inplace=True)

    # Filter based on threshold
    results = gene_summary[
        (gene_summary['discrepant_count'] > 0) &
        (gene_summary['discrepant_count'] <= threshold)
    ].reset_index()

    return results

discrepancies = analyze_replicon_discrepancies(infile)

print("\nDetailed Replicon Location Analysis:")
if not discrepancies.empty:
    for _, disc in discrepancies.iterrows():
        print(f"\nGene: {disc['gene']}")
        print(f"Best Replicon: {disc['best_replicon']}")
        print(f"Total assemblies: {disc['total_assemblies']}")
        print(f"Number of discrepant assemblies: {disc['discrepant_count']}")
        print(f"Discrepant assemblies: {', '.join(disc['discrepant_assemblies'])}")
        print(f"Replicons in discrepant assemblies: {', '.join(disc['discrepant_replicons'])}")
        print(f"Number of non-discrepant assemblies: {disc['non_discrepant_count']}")
        print(f"Non-discrepant assemblies: {', '.join(disc['non_discrepant_assemblies'])}")
        print(f"Replicons in non-discrepant assemblies: {', '.join(disc['non_discrepant_replicons'])}")
else:
    print("No discrepancies found matching the current criteria.")

# Summary statistics
print("\nSummary Statistics:")
total_genes = len(gene_summary)
genes_with_discrepancies = len(discrepancies)
print(f"Total number of genes analyzed: {total_genes}")
print(f"Number of genes with discrepancies: {genes_with_discrepancies}")
print(f"Percentage of genes with discrepancies: {(genes_with_discrepancies / total_genes) * 100:.2f}%")

# Check for potential singletons
singletons = discrepancies[discrepancies['total_assemblies'] == 1]
if not singletons.empty:
    print(f"\nWarning: {len(singletons)} gene(s) appear to be singletons and are marked as discrepant:")
    for _, singleton in singletons.iterrows():
        print(f"Gene: {singleton['gene']}, Assembly: {singleton['discrepant_assemblies'][0]}")
# Out:
# Data shape: (49718, 46)
# Columns: ['assembly', 'gene', 'replicon_name', 'color', 'best_replicon', 'pos', 'Unclassified', 'chromosome', 'cp26', 'cp32-1', 'cp32-10', 'cp32-11', 'cp32-12', 'cp32-13', 'cp32-2', 'cp32-3', 'cp32-4', 'cp32-5', 'cp32-6', 'cp32-7', 'cp32-8', 'cp32-9', 'cp32-9-4', 'cp9', 'cp9-3', 'lp17', 'lp21', 'lp21-cp9', 'lp25', 'lp28-1', 'lp28-11', 'lp28-2', 'lp28-3', 'lp28-4', 'lp28-5', 'lp28-6', 'lp28-7', 'lp28-8', 'lp28-9', 'lp36', 'lp38', 'lp5', 'lp54', 'lp56', 'lipo', 'surface_lipo']
#
# Detailed Replicon Location Analysis:
#
# Gene: 2-9-5 36K minus strand ORF
# Best Replicon: cp32-3
# Total assemblies: 25
# Number of discrepant assemblies: 4
# Discrepant assemblies: URI33H, URI48H, URI111H, URI41H
# Replicons in discrepant assemblies: cp32-8, cp32-8, cp32-10, cp32-10
# Number of non-discrepant assemblies: 21
# Non-discrepant assemblies: UWI283P, URI93H, URI36H, URI56H, UNY172P, UCT29H, UCT109H, UCT31H, UCT96H, URI101H, URI102H, URI107H, URI39H, URI40H, URI42H, URI87H, URI89H, URI91H, UWI247P, URI120H, UWI248P
# Replicons in non-discrepant assemblies: cp32-3
#
# Gene: Antigen, P35, putative
# Best Replicon: lp28-3
# Total assemblies: 47
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT35H, URI112H, URI86H
# Replicons in discrepant assemblies: lp28-4, lp21, lp28-4
# Number of non-discrepant assemblies: 44
# Non-discrepant assemblies: UCT109H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, UNY203P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI111H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI42H, URI44H, URI46H, URI47H, URI48H, URI56H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp28-3
#
# Gene: BBC01
# Best Replicon: lp28-4
# Total assemblies: 48
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT109H, URI102H, URI42H
# Replicons in discrepant assemblies: lp28-2, lp28-2, cp32-10
# Number of non-discrepant assemblies: 45
# Non-discrepant assemblies: UCT31H, ESI26H, UCT110H, UCT113H, UCT29H, UCT30H, UCT32H, UCT35H, UCT50H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, UNY208P, URI101H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp28-4
#
# Gene: BBD14-like protein
# Best Replicon: lp17
# Total assemblies: 26
# Number of discrepant assemblies: 2
# Discrepant assemblies: URI41H, URI93H
# Replicons in discrepant assemblies: lp28-3, lp28-3
# Number of non-discrepant assemblies: 24
# Non-discrepant assemblies: ESI26H, UCT109H, UCT29H, UCT31H, UCT50H, UCT96H, UNY169P, UNY172P, URI101H, URI102H, URI107H, URI111H, URI120H, URI39H, URI40H, URI42H, URI87H, URI89H, URI91H, URI33H, URI36H, URI48H, URI56H, UWI283P
# Replicons in non-discrepant assemblies: lp17
#
# Gene: Blasticidin-S acetyltransferase
# Best Replicon: lp28-4
# Total assemblies: 48
# Number of discrepant assemblies: 3
# Discrepant assemblies: URI42H, UCT109H, URI102H
# Replicons in discrepant assemblies: cp32-10, lp28-2, lp28-2
# Number of non-discrepant assemblies: 45
# Non-discrepant assemblies: UWI247P, UCT50H, ESI26H, URI118H, URI93H, UNY208P, URI103H, URI86H, URI39H, URI88H, UCT31H, UNY169P, URI117H, URI91H, UNY172P, URI101H, UNY149P, UWI283P, URI111H, URI40H, URI56H, URI41H, URI87H, URI89H, UWI263P, UCT29H, UCT35H, URI36H, URI44H, URI46H, UWI248P, UCT110H, URI107H, UCT30H, UCT32H, UCT92H, URI112H, URI33H, URI47H, UCT113H, UCT96H, URI120H, UNY193P, URI34H, URI48H
# Replicons in non-discrepant assemblies: lp28-4
#
# Gene: Borrelia ORF-A
# Best Replicon: lp28-4
# Total assemblies: 44
# Number of discrepant assemblies: 3
# Discrepant assemblies: URI102H, UCT109H, URI42H
# Replicons in discrepant assemblies: lp28-2, lp28-2, cp32-10
# Number of non-discrepant assemblies: 41
# Non-discrepant assemblies: ESI26H, UCT110H, UCT30H, UCT32H, UCT35H, UCT50H, UCT92H, UNY149P, UNY169P, UNY172P, UNY208P, URI103H, URI112H, URI117H, URI118H, URI44H, URI46H, URI47H, URI86H, URI88H, UWI247P, UWI248P, UWI263P, UWI283P, URI33H, URI48H, UCT29H, UCT31H, URI101H, URI107H, URI111H, URI120H, URI39H, URI40H, URI41H, URI87H, URI89H, URI91H, URI93H, UCT96H, URI34H
# Replicons in non-discrepant assemblies: lp28-4
#
# Gene: Borrelia ORF-A superfamily
# Best Replicon: lp28-1
# Total assemblies: 36
# Number of discrepant assemblies: 2
# Discrepant assemblies: UCT30H, URI88H
# Replicons in discrepant assemblies: lp28-5, lp28-7
# Number of non-discrepant assemblies: 34
# Non-discrepant assemblies: UCT109H, UCT29H, UCT31H, UCT96H, URI101H, URI102H, URI107H, URI111H, URI120H, URI39H, URI40H, URI41H, URI42H, URI87H, URI89H, URI91H, URI93H, UCT110H, UCT113H, UCT32H, UCT92H, UNY149P, UNY208P, URI103H, URI112H, URI117H, URI118H, URI44H, URI46H, URI47H, URI86H, UWI247P, UWI248P, UWI263P
# Replicons in non-discrepant assemblies: lp28-1
#
# Gene: Borrelia burgdorferi virulent strain associated lipoprotein
# Best Replicon: lp28-4
# Total assemblies: 48
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT109H, URI102H, URI42H
# Replicons in discrepant assemblies: lp28-2, lp28-2, cp32-10
# Number of non-discrepant assemblies: 45
# Non-discrepant assemblies: ESI26H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT35H, UCT50H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, UNY208P, URI101H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp28-4
#
# Gene: Borrelia family protein
# Best Replicon: lp28-3
# Total assemblies: 48
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT35H, URI112H, URI86H
# Replicons in discrepant assemblies: lp28-4, lp21, lp28-4
# Number of non-discrepant assemblies: 45
# Non-discrepant assemblies: ESI26H, UCT109H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, UNY203P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI111H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI42H, URI44H, URI46H, URI47H, URI48H, URI56H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp28-3
#
# Gene: Borrelia virulent strain associated lipoprotein
# Best Replicon: lp28-4
# Total assemblies: 37
# Number of discrepant assemblies: 1
# Discrepant assemblies: URI42H
# Replicons in discrepant assemblies: cp32-10
# Number of non-discrepant assemblies: 36
# Non-discrepant assemblies: UNY172P, UCT96H, UCT110H, UCT113H, UCT30H, UCT32H, UCT50H, UCT92H, UNY149P, UNY169P, UNY208P, URI103H, URI112H, URI117H, URI118H, URI44H, URI46H, URI47H, URI86H, URI88H, UWI247P, UWI248P, UWI263P, UWI283P, UCT31H, URI101H, URI111H, URI120H, URI36H, URI39H, URI56H, UCT35H, UNY193P, URI34H, URI33H, URI48H
# Replicons in non-discrepant assemblies: lp28-4
#
# Gene: DUF244 domain-containing protein
# Best Replicon: cp32-7
# Total assemblies: 26
# Number of discrepant assemblies: 2
# Discrepant assemblies: ESI26H, UCT50H
# Replicons in discrepant assemblies: cp32-5, cp32-12
# Number of non-discrepant assemblies: 24
# Non-discrepant assemblies: URI93H, UNY169P, URI103H, URI112H, URI117H, URI118H, URI44H, URI46H, URI47H, URI86H, UCT109H, URI42H, URI87H, URI41H, URI89H, URI91H, UCT29H, UCT31H, URI101H, URI102H, URI107H, URI111H, URI39H, URI40H
# Replicons in non-discrepant assemblies: cp32-7
#
# Gene: Homing endonuclease LAGLIDADG domain-containing protein
# Best Replicon: lp17
# Total assemblies: 49
# Number of discrepant assemblies: 2
# Discrepant assemblies: URI41H, URI93H
# Replicons in discrepant assemblies: lp28-3, lp28-3
# Number of non-discrepant assemblies: 47
# Non-discrepant assemblies: ESI26H, UCT109H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT35H, UCT50H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, UNY203P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI42H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, URI87H, URI88H, URI89H, URI91H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp17
#
# Gene: KID repeat family protein
# Best Replicon: cp32-6
# Total assemblies: 40
# Number of discrepant assemblies: 1
# Discrepant assemblies: UCT35H
# Replicons in discrepant assemblies: cp32-4
# Number of non-discrepant assemblies: 39
# Non-discrepant assemblies: ESI26H, UCT109H, UCT29H, UCT31H, UCT32H, UCT92H, UCT96H, UNY149P, UNY193P, UNY203P, URI101H, URI103H, URI107H, URI111H, URI112H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI42H, URI44H, URI46H, URI47H, URI48H, URI56H, URI87H, URI88H, URI89H, URI91H, UWI247P, UWI248P, UWI263P, UCT110H, UCT30H, URI86H
# Replicons in non-discrepant assemblies: cp32-6
#
# Gene: Outer surface protein
# Best Replicon: lp54
# Total assemblies: 48
# Number of discrepant assemblies: 1
# Discrepant assemblies: URI117H
# Replicons in discrepant assemblies: Unclassified
# Number of non-discrepant assemblies: 47
# Non-discrepant assemblies: UCT109H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT35H, UCT50H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, UNY203P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI111H, URI112H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI42H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp54
#
# Gene: Surface antigen
# Best Replicon: lp28-4
# Total assemblies: 47
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT109H, URI102H, URI42H
# Replicons in discrepant assemblies: lp28-2, lp28-2, cp32-10
# Number of non-discrepant assemblies: 44
# Non-discrepant assemblies: URI39H, ESI26H, UCT110H, UCT113H, UCT30H, UCT32H, UCT35H, UCT50H, UCT92H, UNY149P, UNY169P, UNY172P, UNY208P, URI103H, URI112H, URI117H, URI118H, URI44H, URI46H, URI47H, URI86H, URI88H, UWI247P, UWI248P, UWI263P, UWI283P, UCT96H, URI33H, URI48H, UCT29H, UCT31H, UNY193P, URI101H, URI107H, URI111H, URI34H, URI36H, URI40H, URI41H, URI87H, URI89H, URI91H, URI93H, URI120H
# Replicons in non-discrepant assemblies: lp28-4
#
# Gene: Transporter, major facilitator family
# Best Replicon: lp28-4
# Total assemblies: 38
# Number of discrepant assemblies: 1
# Discrepant assemblies: URI42H
# Replicons in discrepant assemblies: cp32-10
# Number of non-discrepant assemblies: 37
# Non-discrepant assemblies: URI56H, UCT32H, ESI26H, UCT110H, UCT113H, UCT30H, UCT31H, UCT35H, UCT50H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, UNY208P, URI101H, URI103H, URI111H, URI112H, URI117H, URI118H, URI120H, URI33H, URI34H, URI39H, URI44H, URI46H, URI47H, URI48H, URI86H, URI88H, UWI247P, UWI248P, UWI263P, UWI283P, URI36H
# Replicons in non-discrepant assemblies: lp28-4
#
# Gene: Transposase
# Best Replicon: lp28-4
# Total assemblies: 48
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT109H, URI102H, URI42H
# Replicons in discrepant assemblies: lp28-2, lp28-2, cp32-10
# Number of non-discrepant assemblies: 45
# Non-discrepant assemblies: ESI26H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT35H, UCT50H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, UNY208P, URI101H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp28-4
#
# Gene: Tyr recombinase domain-containing protein
# Best Replicon: cp32-7
# Total assemblies: 25
# Number of discrepant assemblies: 1
# Discrepant assemblies: URI120H
# Replicons in discrepant assemblies: cp32-10
# Number of non-discrepant assemblies: 24
# Non-discrepant assemblies: URI47H, UCT110H, UCT109H, UCT30H, UCT32H, UCT92H, URI102H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI39H, URI40H, URI41H, URI42H, URI44H, URI46H, URI86H, URI87H, URI89H, URI91H, URI93H
# Replicons in non-discrepant assemblies: cp32-7
#
# Gene: Uncharacterized lipoprotein BBD10
# Best Replicon: lp17
# Total assemblies: 49
# Number of discrepant assemblies: 2
# Discrepant assemblies: URI41H, URI93H
# Replicons in discrepant assemblies: lp28-3, lp28-3
# Number of non-discrepant assemblies: 47
# Non-discrepant assemblies: ESI26H, UCT109H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT35H, UCT50H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, UNY203P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI42H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, URI87H, URI88H, URI89H, URI91H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp17
#
# Gene: Uncharacterized membrane protein BB_D15
# Best Replicon: lp17
# Total assemblies: 49
# Number of discrepant assemblies: 2
# Discrepant assemblies: URI41H, URI93H
# Replicons in discrepant assemblies: lp28-3, lp28-3
# Number of non-discrepant assemblies: 47
# Non-discrepant assemblies: ESI26H, UCT109H, UCT29H, UCT31H, UCT96H, URI101H, URI102H, URI107H, URI111H, URI120H, URI39H, URI40H, URI42H, URI87H, URI89H, URI91H, URI36H, URI56H, UCT110H, UCT113H, UCT30H, UCT32H, UCT92H, UNY149P, UNY208P, URI103H, URI112H, URI117H, URI118H, URI33H, URI44H, URI46H, URI47H, URI48H, URI86H, URI88H, UWI247P, UWI248P, UWI263P, UCT35H, UNY193P, UNY203P, URI34H, UCT50H, UNY169P, UNY172P, UWI283P
# Replicons in non-discrepant assemblies: lp17
#
# Gene: Uncharacterized protein BBD11
# Best Replicon: lp17
# Total assemblies: 49
# Number of discrepant assemblies: 2
# Discrepant assemblies: URI41H, URI93H
# Replicons in discrepant assemblies: lp28-3, lp28-3
# Number of non-discrepant assemblies: 47
# Non-discrepant assemblies: ESI26H, UCT110H, UCT113H, UCT30H, UCT32H, UCT50H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY208P, URI103H, URI112H, URI117H, URI118H, URI33H, URI36H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, URI88H, UWI247P, UWI248P, UWI263P, UWI283P, UCT109H, UCT29H, UCT31H, UCT35H, UNY193P, UNY203P, URI101H, URI102H, URI107H, URI111H, URI120H, URI34H, URI39H, URI40H, URI42H, URI87H, URI89H, URI91H
# Replicons in non-discrepant assemblies: lp17
#
# Gene: Uncharacterized protein BBD18
# Best Replicon: lp17
# Total assemblies: 49
# Number of discrepant assemblies: 2
# Discrepant assemblies: URI41H, URI93H
# Replicons in discrepant assemblies: lp28-3, lp28-3
# Number of non-discrepant assemblies: 47
# Non-discrepant assemblies: ESI26H, UCT109H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT35H, UCT50H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, UNY203P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI42H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, URI87H, URI88H, URI89H, URI91H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp17
#
# Gene: Uncharacterized protein BBD22
# Best Replicon: lp17
# Total assemblies: 37
# Number of discrepant assemblies: 1
# Discrepant assemblies: URI93H
# Replicons in discrepant assemblies: lp28-3
# Number of non-discrepant assemblies: 36
# Non-discrepant assemblies: URI47H, URI117H, UCT109H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT35H, UCT92H, UCT96H, UNY149P, UNY203P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI111H, URI112H, URI118H, URI120H, URI39H, URI40H, URI42H, URI44H, URI46H, URI86H, URI87H, URI88H, URI89H, URI91H, UWI247P, UWI248P, UWI263P
# Replicons in non-discrepant assemblies: lp17
#
# Gene: adeC
# Best Replicon: lp28-3
# Total assemblies: 47
# Number of discrepant assemblies: 3
# Discrepant assemblies: URI112H, URI86H, UCT35H
# Replicons in discrepant assemblies: lp21, lp28-4, lp28-4
# Number of non-discrepant assemblies: 44
# Non-discrepant assemblies: UCT109H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT92H, UCT96H, UNY149P, UNY172P, UNY193P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI111H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI42H, URI44H, URI46H, URI47H, URI48H, URI56H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P, UNY203P, UNY169P
# Replicons in non-discrepant assemblies: lp28-3
#
# Gene: chromosome replication/partitioning protein
# Best Replicon: lp28-4
# Total assemblies: 48
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT109H, URI102H, URI42H
# Replicons in discrepant assemblies: lp28-2, lp28-2, cp32-10
# Number of non-discrepant assemblies: 45
# Non-discrepant assemblies: ESI26H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT35H, UCT50H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY208P, URI101H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI33H, URI39H, URI40H, URI41H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P, URI36H, UNY193P, URI34H
# Replicons in non-discrepant assemblies: lp28-4
#
# Gene: group_1101
# Best Replicon: lp36
# Total assemblies: 29
# Number of discrepant assemblies: 2
# Discrepant assemblies: UCT29H, UCT35H
# Replicons in discrepant assemblies: lp38, lp28-1
# Number of non-discrepant assemblies: 27
# Non-discrepant assemblies: URI102H, ESI26H, UCT109H, UCT113H, UCT31H, UCT96H, UNY193P, UNY203P, URI101H, URI107H, URI111H, URI120H, URI33H, URI34H, URI39H, URI40H, URI41H, URI42H, URI48H, URI87H, URI89H, URI91H, URI93H, UCT50H, UNY169P, URI36H, URI56H
# Replicons in non-discrepant assemblies: lp36
#
# Gene: group_1133
# Best Replicon: cp32-3
# Total assemblies: 39
# Number of discrepant assemblies: 2
# Discrepant assemblies: URI111H, URI41H
# Replicons in discrepant assemblies: cp32-10, cp32-10
# Number of non-discrepant assemblies: 37
# Non-discrepant assemblies: UCT109H, UCT110H, UCT29H, UCT30H, UCT31H, UCT32H, UCT92H, UCT96H, UNY149P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI112H, URI118H, URI120H, URI36H, URI39H, URI40H, URI42H, URI44H, URI46H, URI47H, URI56H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P, UCT35H, URI117H, UNY172P
# Replicons in non-discrepant assemblies: cp32-3
#
# Gene: group_1143
# Best Replicon: lp28-3
# Total assemblies: 47
# Number of discrepant assemblies: 3
# Discrepant assemblies: URI112H, URI86H, UCT35H
# Replicons in discrepant assemblies: lp21, lp28-4, lp28-4
# Number of non-discrepant assemblies: 44
# Non-discrepant assemblies: UCT109H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT92H, UCT96H, UNY149P, UNY193P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI111H, URI117H, URI118H, URI120H, URI34H, URI39H, URI40H, URI41H, URI42H, URI44H, URI46H, URI47H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI263P, UNY172P, URI33H, URI48H, UWI283P, UNY169P, UNY203P, URI36H, URI56H, UWI247P, UWI248P
# Replicons in non-discrepant assemblies: lp28-3
#
# Gene: group_1144
# Best Replicon: lp28-3
# Total assemblies: 47
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT35H, URI112H, URI86H
# Replicons in discrepant assemblies: lp28-4, lp21, lp28-4
# Number of non-discrepant assemblies: 44
# Non-discrepant assemblies: UCT109H, UCT110H, UCT29H, UCT30H, UCT31H, UCT32H, UCT92H, UCT96H, UNY149P, UNY193P, UNY203P, URI101H, URI102H, URI103H, URI107H, URI111H, URI117H, URI118H, URI120H, URI33H, URI34H, URI39H, URI40H, URI41H, URI42H, URI44H, URI46H, URI47H, URI48H, URI87H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UCT113H, UNY208P, URI88H, UWI263P, UNY169P, UNY172P, UWI283P, URI36H, URI56H
# Replicons in non-discrepant assemblies: lp28-3
#
# Gene: group_1191
# Best Replicon: lp28-3
# Total assemblies: 45
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT35H, URI112H, URI86H
# Replicons in discrepant assemblies: lp28-4, lp21, lp28-4
# Number of non-discrepant assemblies: 42
# Non-discrepant assemblies: UNY172P, UWI283P, UNY193P, UCT109H, UCT29H, UCT31H, UCT96H, UNY203P, URI101H, URI102H, URI107H, URI111H, URI120H, URI33H, URI34H, URI39H, URI40H, URI41H, URI42H, URI48H, URI87H, URI89H, URI91H, URI93H, UWI263P, UNY208P, UCT113H, URI88H, UWI247P, UWI248P, URI118H, UCT110H, UCT30H, UCT32H, UCT92H, UNY149P, UNY169P, URI103H, URI117H, URI44H, URI46H, URI47H
# Replicons in non-discrepant assemblies: lp28-3
#
# Gene: group_1242
# Best Replicon: lp36
# Total assemblies: 28
# Number of discrepant assemblies: 2
# Discrepant assemblies: UCT29H, UCT35H
# Replicons in discrepant assemblies: lp38, lp28-1
# Number of non-discrepant assemblies: 26
# Non-discrepant assemblies: ESI26H, UCT109H, UCT31H, URI101H, URI102H, URI107H, URI111H, URI120H, URI39H, URI40H, URI41H, URI42H, URI87H, URI89H, URI91H, URI93H, UCT96H, UNY193P, UNY203P, URI33H, URI34H, URI36H, URI48H, URI56H, UCT50H, UNY169P
# Replicons in non-discrepant assemblies: lp36
#
# Gene: group_1249
# Best Replicon: lp28-4
# Total assemblies: 48
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT109H, URI102H, URI42H
# Replicons in discrepant assemblies: lp28-2, lp28-2, cp32-10
# Number of non-discrepant assemblies: 45
# Non-discrepant assemblies: ESI26H, UCT110H, UCT29H, UCT30H, UCT31H, UCT32H, UCT35H, UCT50H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, URI101H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI34H, URI36H, URI39H, URI40H, URI41H, URI44H, URI46H, URI47H, URI56H, URI86H, URI87H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P, UCT113H, UNY208P, URI88H, URI33H, URI48H
# Replicons in non-discrepant assemblies: lp28-4
#
# Gene: group_1250
# Best Replicon: lp28-4
# Total assemblies: 48
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT109H, URI102H, URI42H
# Replicons in discrepant assemblies: lp28-2, lp28-2, cp32-10
# Number of non-discrepant assemblies: 45
# Non-discrepant assemblies: ESI26H, UCT110H, UCT29H, UCT30H, UCT31H, UCT32H, UCT35H, UCT50H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, URI101H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI33H, URI34H, URI39H, URI40H, URI41H, URI44H, URI46H, URI47H, URI48H, URI86H, URI87H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P, UCT113H, UNY208P, URI88H, URI36H, URI56H
# Replicons in non-discrepant assemblies: lp28-4
#
# Gene: group_1279
# Best Replicon: cp32-10
# Total assemblies: 26
# Number of discrepant assemblies: 2
# Discrepant assemblies: URI89H, UCT113H
# Replicons in discrepant assemblies: cp32-6, Unclassified
# Number of non-discrepant assemblies: 24
# Non-discrepant assemblies: UCT109H, UCT29H, UCT31H, UCT50H, UNY169P, UNY193P, UNY203P, URI101H, URI102H, URI107H, URI111H, URI120H, URI33H, URI34H, URI39H, URI40H, URI41H, URI42H, URI48H, URI87H, URI91H, URI93H, UWI263P, UCT35H
# Replicons in non-discrepant assemblies: cp32-10
#
# Gene: group_1286
# Best Replicon: lp28-1
# Total assemblies: 37
# Number of discrepant assemblies: 2
# Discrepant assemblies: UCT30H, URI88H
# Replicons in discrepant assemblies: lp28-5, lp28-7
# Number of non-discrepant assemblies: 35
# Non-discrepant assemblies: UCT109H, UCT29H, UCT31H, UCT96H, URI101H, URI102H, URI107H, URI111H, URI120H, URI39H, URI40H, URI41H, URI42H, URI87H, URI89H, URI91H, URI93H, UCT110H, UCT113H, UCT32H, UCT92H, UNY149P, UNY208P, URI103H, URI112H, URI117H, URI118H, URI44H, URI46H, URI47H, URI86H, UWI247P, UWI248P, UWI263P, URI36H
# Replicons in non-discrepant assemblies: lp28-1
#
# Gene: group_1300
# Best Replicon: lp54
# Total assemblies: 31
# Number of discrepant assemblies: 1
# Discrepant assemblies: URI117H
# Replicons in discrepant assemblies: Unclassified
# Number of non-discrepant assemblies: 30
# Non-discrepant assemblies: UCT110H, UCT30H, UCT32H, UCT35H, UCT50H, UCT92H, UNY149P, UNY169P, UNY193P, UNY203P, URI103H, URI112H, URI118H, URI33H, URI34H, URI36H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, UWI248P, UWI283P, UCT113H, UNY172P, UNY208P, URI88H, UWI247P, UWI263P
# Replicons in non-discrepant assemblies: lp54
#
# Gene: group_1459
# Best Replicon: cp32-6
# Total assemblies: 42
# Number of discrepant assemblies: 2
# Discrepant assemblies: UCT35H, UCT113H
# Replicons in discrepant assemblies: cp32-4, Unclassified
# Number of non-discrepant assemblies: 40
# Non-discrepant assemblies: ESI26H, UCT109H, UCT110H, UCT29H, UCT30H, UCT31H, UCT32H, UCT92H, UCT96H, UNY149P, UNY193P, UNY203P, URI101H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI42H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, URI87H, URI88H, URI89H, URI91H, UWI247P, UWI248P, UWI263P
# Replicons in non-discrepant assemblies: cp32-6
#
# Gene: group_1460
# Best Replicon: cp32-6
# Total assemblies: 42
# Number of discrepant assemblies: 2
# Discrepant assemblies: UCT35H, UCT113H
# Replicons in discrepant assemblies: cp32-4, Unclassified
# Number of non-discrepant assemblies: 40
# Non-discrepant assemblies: ESI26H, UCT109H, UCT110H, UCT29H, UCT30H, UCT31H, UCT32H, UCT92H, UCT96H, UNY149P, UNY193P, UNY203P, URI101H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI42H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, URI87H, URI88H, URI89H, URI91H, UWI247P, UWI248P, UWI263P
# Replicons in non-discrepant assemblies: cp32-6
#
# Gene: group_1465
# Best Replicon: lp28-3
# Total assemblies: 48
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT35H, URI112H, URI86H
# Replicons in discrepant assemblies: lp28-4, lp21, lp28-4
# Number of non-discrepant assemblies: 45
# Non-discrepant assemblies: ESI26H, UCT109H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, UNY203P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI111H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI42H, URI44H, URI46H, URI47H, URI48H, URI56H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp28-3
#
# Gene: group_1467
# Best Replicon: lp28-4
# Total assemblies: 29
# Number of discrepant assemblies: 1
# Discrepant assemblies: UCT113H
# Replicons in discrepant assemblies: Unclassified
# Number of non-discrepant assemblies: 28
# Non-discrepant assemblies: ESI26H, UCT110H, UCT30H, UCT32H, UCT35H, UCT92H, UNY149P, URI103H, URI112H, URI117H, URI118H, URI33H, URI44H, URI46H, URI47H, URI48H, URI86H, UWI247P, UWI248P, UWI263P, UCT50H, UNY169P, UNY172P, UNY193P, UNY208P, URI34H, URI88H, UWI283P
# Replicons in non-discrepant assemblies: lp28-4
#
# Gene: group_1505
# Best Replicon: cp32-10
# Total assemblies: 25
# Number of discrepant assemblies: 1
# Discrepant assemblies: URI89H
# Replicons in discrepant assemblies: cp32-6
# Number of non-discrepant assemblies: 24
# Non-discrepant assemblies: UCT109H, UCT29H, UCT31H, UCT35H, UCT50H, UNY169P, UNY203P, URI101H, URI102H, URI107H, URI111H, URI120H, URI33H, URI34H, URI39H, URI40H, URI41H, URI42H, URI48H, URI87H, URI91H, URI93H, UWI263P, UNY193P
# Replicons in non-discrepant assemblies: cp32-10
#
# Gene: group_1520
# Best Replicon: lp28-1
# Total assemblies: 37
# Number of discrepant assemblies: 2
# Discrepant assemblies: UCT30H, URI88H
# Replicons in discrepant assemblies: lp28-5, lp28-7
# Number of non-discrepant assemblies: 35
# Non-discrepant assemblies: UCT109H, UCT110H, UCT113H, UCT29H, UCT31H, UCT32H, UCT92H, UCT96H, UNY149P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI39H, URI40H, URI41H, URI42H, URI44H, URI46H, URI47H, URI86H, URI87H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, URI36H
# Replicons in non-discrepant assemblies: lp28-1
#
# Gene: group_1547
# Best Replicon: lp28-3
# Total assemblies: 40
# Number of discrepant assemblies: 3
# Discrepant assemblies: URI112H, UCT35H, URI86H
# Replicons in discrepant assemblies: lp21, lp28-4, lp28-4
# Number of non-discrepant assemblies: 37
# Non-discrepant assemblies: UCT110H, UCT30H, UCT32H, UNY149P, URI103H, URI117H, URI118H, URI44H, URI46H, URI47H, UCT96H, UCT109H, UCT113H, UCT29H, UCT31H, UCT92H, UNY193P, UNY203P, UNY208P, URI101H, URI102H, URI107H, URI111H, URI120H, URI34H, URI39H, URI40H, URI41H, URI42H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P
# Replicons in non-discrepant assemblies: lp28-3
#
# Gene: group_1738
# Best Replicon: lp36
# Total assemblies: 28
# Number of discrepant assemblies: 2
# Discrepant assemblies: UCT29H, UCT35H
# Replicons in discrepant assemblies: lp38, lp28-1
# Number of non-discrepant assemblies: 26
# Non-discrepant assemblies: ESI26H, UCT109H, UCT31H, UCT50H, UCT96H, UNY169P, UNY193P, UNY203P, URI101H, URI102H, URI107H, URI111H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI42H, URI48H, URI56H, URI87H, URI89H, URI91H, URI93H
# Replicons in non-discrepant assemblies: lp36
#
# Gene: group_1793
# Best Replicon: lp28-4
# Total assemblies: 48
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT109H, URI102H, URI42H
# Replicons in discrepant assemblies: lp28-2, lp28-2, cp32-10
# Number of non-discrepant assemblies: 45
# Non-discrepant assemblies: ESI26H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT35H, UCT50H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, UNY208P, URI101H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp28-4
#
# Gene: group_1794
# Best Replicon: lp28-4
# Total assemblies: 48
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT109H, URI102H, URI42H
# Replicons in discrepant assemblies: lp28-2, lp28-2, cp32-10
# Number of non-discrepant assemblies: 45
# Non-discrepant assemblies: ESI26H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT35H, UCT50H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, UNY208P, URI101H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp28-4
#
# Gene: group_1795
# Best Replicon: lp28-4
# Total assemblies: 48
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT109H, URI102H, URI42H
# Replicons in discrepant assemblies: lp28-2, lp28-2, cp32-10
# Number of non-discrepant assemblies: 45
# Non-discrepant assemblies: ESI26H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT35H, UCT50H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, UNY208P, URI101H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp28-4
#
# Gene: group_1796
# Best Replicon: lp28-4
# Total assemblies: 48
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT109H, URI102H, URI42H
# Replicons in discrepant assemblies: lp28-2, lp28-2, cp32-10
# Number of non-discrepant assemblies: 45
# Non-discrepant assemblies: ESI26H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT35H, UCT50H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, UNY208P, URI101H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp28-4
#
# Gene: group_1798
# Best Replicon: lp28-4
# Total assemblies: 48
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT109H, URI102H, URI42H
# Replicons in discrepant assemblies: lp28-2, lp28-2, cp32-10
# Number of non-discrepant assemblies: 45
# Non-discrepant assemblies: ESI26H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT35H, UCT50H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, UNY208P, URI101H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp28-4
#
# Gene: group_1933
# Best Replicon: lp28-1
# Total assemblies: 37
# Number of discrepant assemblies: 2
# Discrepant assemblies: UCT30H, URI88H
# Replicons in discrepant assemblies: lp28-5, lp28-7
# Number of non-discrepant assemblies: 35
# Non-discrepant assemblies: UCT109H, UCT110H, UCT113H, UCT29H, UCT31H, UCT32H, UCT92H, UCT96H, UNY149P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI36H, URI39H, URI40H, URI41H, URI42H, URI44H, URI46H, URI47H, URI86H, URI87H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P
# Replicons in non-discrepant assemblies: lp28-1
#
# Gene: group_1972
# Best Replicon: cp32-3
# Total assemblies: 38
# Number of discrepant assemblies: 2
# Discrepant assemblies: URI111H, URI41H
# Replicons in discrepant assemblies: cp32-10, cp32-10
# Number of non-discrepant assemblies: 36
# Non-discrepant assemblies: UCT109H, UCT110H, UCT29H, UCT30H, UCT31H, UCT32H, UCT92H, UCT96H, UNY149P, UNY172P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI112H, URI117H, URI118H, URI120H, URI36H, URI39H, URI40H, URI42H, URI44H, URI46H, URI47H, URI56H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: cp32-3
#
# Gene: group_1977
# Best Replicon: lp28-3
# Total assemblies: 42
# Number of discrepant assemblies: 4
# Discrepant assemblies: UCT35H, URI112H, URI39H, URI86H
# Replicons in discrepant assemblies: lp28-4, lp21, chromosome, lp28-4
# Number of non-discrepant assemblies: 38
# Non-discrepant assemblies: UCT109H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT92H, UCT96H, UNY149P, UNY172P, UNY193P, UNY203P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI111H, URI117H, URI118H, URI120H, URI34H, URI40H, URI41H, URI42H, URI44H, URI46H, URI47H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp28-3
#
# Gene: group_1979
# Best Replicon: lp28-3
# Total assemblies: 47
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT35H, URI112H, URI86H
# Replicons in discrepant assemblies: lp28-4, lp21, lp28-4
# Number of non-discrepant assemblies: 44
# Non-discrepant assemblies: UCT109H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, UNY203P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI111H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI42H, URI44H, URI46H, URI47H, URI48H, URI56H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp28-3
#
# Gene: group_1980
# Best Replicon: lp28-3
# Total assemblies: 47
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT35H, URI112H, URI86H
# Replicons in discrepant assemblies: lp28-4, lp21, lp28-4
# Number of non-discrepant assemblies: 44
# Non-discrepant assemblies: UCT109H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, UNY203P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI111H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI42H, URI44H, URI46H, URI47H, URI48H, URI56H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp28-3
#
# Gene: group_261
# Best Replicon: cp32-9
# Total assemblies: 29
# Number of discrepant assemblies: 1
# Discrepant assemblies: URI36H
# Replicons in discrepant assemblies: cp32-8
# Number of non-discrepant assemblies: 28
# Non-discrepant assemblies: UWI283P, URI117H, ESI26H, UCT109H, UCT29H, UCT31H, UCT50H, UCT92H, UNY149P, UNY169P, UNY172P, URI101H, URI102H, URI103H, URI107H, URI111H, URI120H, URI39H, URI40H, URI41H, URI42H, URI44H, URI47H, URI87H, URI89H, URI91H, URI93H, UWI263P
# Replicons in non-discrepant assemblies: cp32-9
#
# Gene: group_3290
# Best Replicon: lp17
# Total assemblies: 27
# Number of discrepant assemblies: 1
# Discrepant assemblies: URI93H
# Replicons in discrepant assemblies: lp28-3
# Number of non-discrepant assemblies: 26
# Non-discrepant assemblies: UCT96H, UCT109H, UCT110H, UCT30H, UCT31H, UCT32H, URI102H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI36H, URI39H, URI40H, URI44H, URI46H, URI47H, URI56H, URI86H, URI87H, URI88H, URI89H, URI91H
# Replicons in non-discrepant assemblies: lp17
#
# Gene: group_3291
# Best Replicon: lp17
# Total assemblies: 47
# Number of discrepant assemblies: 1
# Discrepant assemblies: URI93H
# Replicons in discrepant assemblies: lp28-3
# Number of non-discrepant assemblies: 46
# Non-discrepant assemblies: UCT96H, URI42H, ESI26H, UCT109H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT35H, UCT50H, UCT92H, UNY149P, UNY169P, UNY172P, UNY193P, UNY203P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI111H, URI112H, URI117H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, URI87H, URI88H, URI89H, URI91H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp17
#
# Gene: group_3525
# Best Replicon: lp28-4
# Total assemblies: 48
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT109H, URI102H, URI42H
# Replicons in discrepant assemblies: lp28-2, lp28-2, cp32-10
# Number of non-discrepant assemblies: 45
# Non-discrepant assemblies: UCT96H, ESI26H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT35H, UCT50H, UCT92H, UNY149P, UNY169P, UNY172P, UNY193P, UNY208P, URI101H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI41H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp28-4
#
# Gene: group_3568
# Best Replicon: lp17
# Total assemblies: 49
# Number of discrepant assemblies: 2
# Discrepant assemblies: URI41H, URI93H
# Replicons in discrepant assemblies: lp28-3, lp28-3
# Number of non-discrepant assemblies: 47
# Non-discrepant assemblies: ESI26H, UCT109H, UCT110H, UCT113H, UCT29H, UCT30H, UCT31H, UCT32H, UCT35H, UCT50H, UCT92H, UCT96H, UNY149P, UNY169P, UNY172P, UNY193P, UNY203P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI111H, URI112H, URI117H, URI118H, URI120H, URI33H, URI34H, URI36H, URI39H, URI40H, URI42H, URI44H, URI46H, URI47H, URI48H, URI56H, URI86H, URI87H, URI88H, URI89H, URI91H, UWI247P, UWI248P, UWI263P, UWI283P
# Replicons in non-discrepant assemblies: lp17
#
# Gene: group_604
# Best Replicon: cp32-9
# Total assemblies: 27
# Number of discrepant assemblies: 3
# Discrepant assemblies: URI48H, URI36H, UWI283P
# Replicons in discrepant assemblies: cp32-10, cp32-4, cp32-4
# Number of non-discrepant assemblies: 24
# Non-discrepant assemblies: URI101H, ESI26H, UCT109H, UCT29H, UCT31H, UCT96H, URI102H, URI107H, URI111H, URI120H, URI39H, URI40H, URI41H, URI42H, URI87H, URI89H, URI91H, URI93H, UCT92H, UNY149P, URI103H, URI117H, URI44H, URI47H
# Replicons in non-discrepant assemblies: cp32-9
#
# Gene: group_624
# Best Replicon: cp32-3
# Total assemblies: 34
# Number of discrepant assemblies: 3
# Discrepant assemblies: URI111H, URI41H, UNY172P
# Replicons in discrepant assemblies: cp32-10, cp32-10, cp32-7
# Number of non-discrepant assemblies: 31
# Non-discrepant assemblies: URI36H, UCT29H, UCT109H, UCT31H, UCT96H, URI102H, URI107H, URI120H, URI39H, URI40H, URI42H, URI87H, URI89H, URI91H, URI93H, UWI283P, UNY208P, URI88H, URI56H, UCT30H, UCT32H, UCT92H, UNY149P, URI103H, URI118H, URI44H, URI47H, UWI247P, URI101H, UWI248P, UWI263P
# Replicons in non-discrepant assemblies: cp32-3
#
# Gene: group_699
# Best Replicon: lp36
# Total assemblies: 26
# Number of discrepant assemblies: 2
# Discrepant assemblies: UCT29H, UCT35H
# Replicons in discrepant assemblies: lp38, lp28-1
# Number of non-discrepant assemblies: 24
# Non-discrepant assemblies: URI39H, ESI26H, UCT109H, UCT31H, UCT96H, UNY193P, UNY203P, URI101H, URI102H, URI107H, URI111H, URI120H, URI33H, URI34H, URI36H, URI40H, URI41H, URI42H, URI48H, URI56H, URI87H, URI89H, URI91H, URI93H
# Replicons in non-discrepant assemblies: lp36
#
# Gene: group_862
# Best Replicon: lp28-4
# Total assemblies: 46
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT109H, URI102H, URI42H
# Replicons in discrepant assemblies: lp28-2, lp28-2, cp32-10
# Number of non-discrepant assemblies: 43
# Non-discrepant assemblies: URI39H, ESI26H, UCT110H, UCT30H, UCT32H, UCT35H, UCT50H, UCT92H, UNY149P, UNY169P, UNY172P, UNY193P, URI103H, URI112H, URI117H, URI118H, URI34H, URI44H, URI46H, URI47H, URI86H, UWI247P, UWI248P, UWI263P, UWI283P, UCT113H, UNY208P, URI88H, UCT29H, UCT31H, UCT96H, URI101H, URI107H, URI111H, URI120H, URI40H, URI41H, URI87H, URI89H, URI91H, URI93H, URI33H, URI48H
# Replicons in non-discrepant assemblies: lp28-4
#
# Gene: insQ
# Best Replicon: lp28-3
# Total assemblies: 25
# Number of discrepant assemblies: 2
# Discrepant assemblies: URI118H, URI112H
# Replicons in discrepant assemblies: lp36, lp21
# Number of non-discrepant assemblies: 23
# Non-discrepant assemblies: URI101H, UCT109H, UCT110H, UCT29H, UCT31H, UCT32H, URI102H, URI103H, URI107H, URI111H, URI120H, URI40H, URI41H, URI42H, URI46H, URI47H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P
# Replicons in non-discrepant assemblies: lp28-3
#
# Gene: repU
# Best Replicon: lp28-3
# Total assemblies: 32
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT35H, URI112H, URI86H
# Replicons in discrepant assemblies: lp28-4, lp21, lp28-4
# Number of non-discrepant assemblies: 29
# Non-discrepant assemblies: UCT110H, UCT29H, UCT30H, UCT31H, UCT32H, UCT92H, UNY149P, UNY169P, UNY172P, UNY203P, UNY208P, URI101H, URI103H, URI111H, URI117H, URI118H, URI120H, URI40H, URI41H, URI42H, URI44H, URI46H, URI47H, URI48H, URI87H, URI88H, URI89H, URI91H, UWI263P
# Replicons in non-discrepant assemblies: lp28-3
#
# Gene: yeeA
# Best Replicon: lp28-3
# Total assemblies: 39
# Number of discrepant assemblies: 3
# Discrepant assemblies: UCT35H, URI112H, URI86H
# Replicons in discrepant assemblies: lp28-4, lp21, lp28-4
# Number of non-discrepant assemblies: 36
# Non-discrepant assemblies: URI48H, UCT109H, UCT110H, UCT29H, UCT30H, UCT31H, UCT32H, UCT92H, UNY149P, UNY193P, UNY203P, UNY208P, URI101H, URI102H, URI103H, URI107H, URI111H, URI118H, URI120H, URI34H, URI40H, URI41H, URI42H, URI44H, URI46H, URI47H, URI87H, URI88H, URI89H, URI91H, URI93H, UWI247P, UWI248P, UWI263P, UCT113H, URI33H
# Replicons in non-discrepant assemblies: lp28-3
#
# Summary Statistics:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 62
#      60 # Summary statistics
#      61 print("\nSummary Statistics:")
# ---> 62 total_genes = len(gene_summary)
#      63 genes_with_discrepancies = len(discrepancies)
#      64 print(f"Total number of genes analyzed: {total_genes}")
#
# NameError: name 'gene_summary' is not defined

# %%
import pandas as pd
import numpy as np

def analyze_bulk_replicon_discrepancies(file_path, threshold=4):
    # Read the CSV file
    df = pd.read_csv(file_path)

    print("Data shape:", df.shape)
    print("Columns:", df.columns.tolist())

    # Identify discrepancies
    df['is_discrepant'] = df['replicon_name'] != df['best_replicon']

    # Group by replicon_name and summarize discrepancies
    replicon_summary = df.groupby('replicon_name').agg({
        'is_discrepant': 'sum',
        'assembly': lambda x: list(x[df.loc[x.index, 'is_discrepant']].unique()),
        'gene': lambda x: list(x[df.loc[x.index, 'is_discrepant']].unique()),
        'best_replicon': lambda x: x[~df.loc[x.index, 'is_discrepant']].unique().tolist()
    }).reset_index()

    # Rename columns for clarity
    replicon_summary.columns = ['replicon_name', 'discrepancy_count', 'discrepant_assemblies', 'discrepant_genes', 'expected_replicons']

    # Calculate total assemblies and genes for each replicon
    replicon_summary['total_assemblies'] = df.groupby('replicon_name')['assembly'].nunique().values
    replicon_summary['total_genes'] = df.groupby('replicon_name')['gene'].nunique().values

    # Calculate non-discrepant counts
    replicon_summary['non_discrepant_count'] = replicon_summary['total_assemblies'] - replicon_summary['discrepancy_count']

    # Filter based on threshold
    replicon_summary = replicon_summary[
        (replicon_summary['discrepancy_count'] > 0) &
        (replicon_summary['discrepancy_count'] <= threshold)
    ]

    return replicon_summary

discrepancies = analyze_bulk_replicon_discrepancies(infile)

print("\nBulk Replicon Discrepancy Analysis:")
if not discrepancies.empty:
    for _, disc in discrepancies.iterrows():
        print(f"\nReplicon: {disc['replicon_name']}")
        print(f"Expected Replicon(s): {', '.join(disc['expected_replicons'])}")
        print(f"Total assemblies: {disc['total_assemblies']}")
        print(f"Number of discrepant assemblies: {disc['discrepancy_count']}")
        print(f"Discrepant assemblies: {', '.join(disc['discrepant_assemblies'])}")
        print(f"Total genes on this replicon: {disc['total_genes']}")
        print(f"Number of discrepant genes: {len(disc['discrepant_genes'])}")
        print(f"Discrepant genes: {', '.join(disc['discrepant_genes'])}")
else:
    print("No discrepancies found matching the current criteria.")

# Summary statistics
print("\nSummary Statistics:")
total_replicons = len(pd.unique(df['replicon_name']))
replicons_with_discrepancies = len(discrepancies)
print(f"Total number of replicons analyzed: {total_replicons}")
print(f"Number of replicons with discrepancies: {replicons_with_discrepancies}")
print(f"Percentage of replicons with discrepancies: {(replicons_with_discrepancies / total_replicons) * 100:.2f}%")
# Out:
# Data shape: (49718, 46)
# Columns: ['assembly', 'gene', 'replicon_name', 'color', 'best_replicon', 'pos', 'Unclassified', 'chromosome', 'cp26', 'cp32-1', 'cp32-10', 'cp32-11', 'cp32-12', 'cp32-13', 'cp32-2', 'cp32-3', 'cp32-4', 'cp32-5', 'cp32-6', 'cp32-7', 'cp32-8', 'cp32-9', 'cp32-9-4', 'cp9', 'cp9-3', 'lp17', 'lp21', 'lp21-cp9', 'lp25', 'lp28-1', 'lp28-11', 'lp28-2', 'lp28-3', 'lp28-4', 'lp28-5', 'lp28-6', 'lp28-7', 'lp28-8', 'lp28-9', 'lp36', 'lp38', 'lp5', 'lp54', 'lp56', 'lipo', 'surface_lipo']
#
# Bulk Replicon Discrepancy Analysis:
#
# Replicon: chromosome
# Expected Replicon(s): chromosome
# Total assemblies: 49
# Number of discrepant assemblies: 2
# Discrepant assemblies: URI39H, URI36H
# Total genes on this replicon: 814
# Number of discrepant genes: 2
# Discrepant genes: group_1977, group_223
#
# Replicon: lp28-8
# Expected Replicon(s):
# Total assemblies: 1
# Number of discrepant assemblies: 4
# Discrepant assemblies: URI33H
# Total genes on this replicon: 4
# Number of discrepant genes: 4
# Discrepant genes: group_1483, putative helicase, group_776, transposase
#
# Replicon: lp28-9
# Expected Replicon(s):
# Total assemblies: 1
# Number of discrepant assemblies: 3
# Discrepant assemblies: ESI26H
# Total genes on this replicon: 3
# Number of discrepant genes: 3
# Discrepant genes: rdgC, group_3828, group_1233
#
# Summary Statistics:
# Total number of replicons analyzed: 30
# Number of replicons with discrepancies: 3
# Percentage of replicons with discrepancies: 10.00%
