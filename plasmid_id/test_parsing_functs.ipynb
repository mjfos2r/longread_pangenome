# %%
import subprocess
import os
import pandas
import pickle
from pathlib import Path
from Bio.Blast import NCBIXML
from collections import defaultdict
from intervaltree import Interval, IntervalTree

# %%
def get_output_path(input_file, output_dir, results_dir):
    file_id = Path(input_file).stem
    cwd = Path(os.getcwd())
    output_path = cwd.joinpath(output_dir, file_id, results_dir)
    if not os.path.exists(output_path):
        print(f"Creating output path: {output_path}")
        os.makedirs(output_path)
    return output_path

# %%
def run_command(command):
    result = subprocess.run(command, check=True, capture_output=True, text=True)
    return result.stdout if result.returncode == 0 else result.stderr

# %%
def get_db_type(db_dir):
    """ Get the individual database for blast and the database type """
    command = ['blastdbcmd', '-list', f'{db_dir}', '-recursive',]
    output = run_command(command)
    dbs = []
    progs = []
    for line in output.split('\n')[:-1]: # last line is empty so don't iterate to it!
        db_info = line.split(' ')
        print(db_info)
        db_name = db_info[0]
        db_type = db_info[1].lower()
        dbs.append(db_name)
        if db_type == 'protein':
            progs.append('blastx')
        elif db_type == 'nucleotide':
            progs.append('blastn')
    return list(zip(dbs, progs))

# %%
test_inputs = []
for i in range(1,100):
    test_inputs.append(f'test_{i}.fasta')

# %%
dbs = get_db_type('dbs/')
# Out:
# ['dbs/all_pf32_db/all_pf32_db', 'Protein']
# ['dbs/pf32_v3/pf32', 'Protein']
# ['dbs/plasmid_db/wp_db', 'Nucleotide']
# ['dbs/plasmid_db/wpdb', 'Nucleotide']

# %%
output = 'test_output'
for db in dbs:
    db_path = db[0]
    prog = db[1]
    results_dir = f'{Path(db_path).stem}'
    for file in test_inputs:
        get_output_path(file, output, results_dir)
# Out:
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_1/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_2/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_3/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_4/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_5/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_6/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_7/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_8/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_9/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_10/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_11/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_12/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_13/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_14/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_15/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_16/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_17/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_18/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_19/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_20/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_21/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_22/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_23/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_24/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_25/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_26/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_27/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_28/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_29/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_30/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_31/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_32/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_33/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_34/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_35/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_36/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_37/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_38/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_39/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_40/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_41/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_42/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_43/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_44/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_45/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_46/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_47/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_48/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_49/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_50/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_51/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_52/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_53/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_54/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_55/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_56/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_57/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_58/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_59/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_60/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_61/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_62/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_63/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_64/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_65/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_66/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_67/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_68/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_69/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_70/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_71/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_72/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_73/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_74/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_75/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_76/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_77/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_78/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_79/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_80/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_81/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_82/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_83/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_84/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_85/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_86/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_87/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_88/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_89/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_90/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_91/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_92/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_93/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_94/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_95/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_96/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_97/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_98/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_99/all_pf32_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_1/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_2/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_3/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_4/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_5/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_6/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_7/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_8/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_9/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_10/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_11/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_12/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_13/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_14/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_15/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_16/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_17/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_18/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_19/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_20/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_21/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_22/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_23/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_24/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_25/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_26/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_27/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_28/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_29/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_30/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_31/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_32/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_33/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_34/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_35/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_36/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_37/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_38/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_39/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_40/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_41/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_42/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_43/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_44/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_45/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_46/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_47/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_48/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_49/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_50/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_51/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_52/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_53/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_54/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_55/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_56/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_57/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_58/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_59/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_60/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_61/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_62/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_63/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_64/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_65/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_66/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_67/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_68/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_69/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_70/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_71/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_72/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_73/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_74/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_75/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_76/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_77/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_78/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_79/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_80/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_81/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_82/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_83/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_84/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_85/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_86/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_87/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_88/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_89/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_90/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_91/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_92/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_93/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_94/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_95/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_96/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_97/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_98/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_99/pf32
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_1/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_2/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_3/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_4/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_5/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_6/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_7/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_8/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_9/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_10/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_11/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_12/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_13/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_14/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_15/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_16/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_17/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_18/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_19/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_20/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_21/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_22/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_23/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_24/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_25/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_26/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_27/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_28/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_29/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_30/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_31/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_32/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_33/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_34/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_35/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_36/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_37/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_38/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_39/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_40/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_41/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_42/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_43/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_44/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_45/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_46/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_47/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_48/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_49/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_50/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_51/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_52/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_53/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_54/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_55/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_56/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_57/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_58/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_59/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_60/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_61/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_62/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_63/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_64/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_65/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_66/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_67/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_68/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_69/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_70/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_71/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_72/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_73/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_74/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_75/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_76/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_77/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_78/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_79/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_80/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_81/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_82/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_83/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_84/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_85/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_86/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_87/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_88/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_89/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_90/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_91/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_92/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_93/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_94/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_95/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_96/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_97/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_98/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_99/wp_db
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_1/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_2/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_3/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_4/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_5/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_6/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_7/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_8/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_9/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_10/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_11/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_12/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_13/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_14/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_15/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_16/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_17/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_18/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_19/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_20/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_21/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_22/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_23/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_24/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_25/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_26/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_27/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_28/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_29/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_30/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_31/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_32/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_33/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_34/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_35/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_36/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_37/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_38/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_39/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_40/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_41/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_42/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_43/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_44/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_45/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_46/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_47/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_48/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_49/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_50/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_51/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_52/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_53/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_54/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_55/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_56/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_57/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_58/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_59/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_60/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_61/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_62/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_63/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_64/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_65/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_66/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_67/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_68/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_69/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_70/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_71/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_72/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_73/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_74/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_75/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_76/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_77/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_78/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_79/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_80/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_81/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_82/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_83/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_84/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_85/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_86/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_87/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_88/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_89/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_90/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_91/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_92/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_93/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_94/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_95/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_96/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_97/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_98/wpdb
# Creating output path: /home/mf019/longread_pangenome/plasmid_id/test_output/test_99/wpdb

# %%
for db in dbs:
    db_path = db[0]
    prog = db[1]
    print(db_path, prog)
# Out:
# dbs/all_pf32_db/all_pf32_db blastx
# dbs/pf32_v3/pf32 blastx
# dbs/plasmid_db/wp_db blastn
# dbs/plasmid_db/wpdb blastn

# %%
pf_results_test = 'blast_results_v8/pf32_v3/ESI26H_pf32.xml'
wp_results_test = '/home/mf019/borrelia_plasmid_classifier_v3/output/blast_results_v7/whole_plasmid/ESI26H_whole_plasmid.xml'

# %%
output_test = 'test_outdir'

# %%
## Function to calculate overall percent identity and coverage using HSPs
#def calculate_percent_identity_and_coverage(intervals, alignment):
#    total_identities = 0
#    total_alignment_length = 0
#    covered_intervals = []
#    query_intervals = []
#    subject_hit_coords = []
#    hsp_counter = 0
#    interval_groups = set()
#    
#    for hsp in alignment.hsps:
#        total_identities += hsp.identities
#        total_alignment_length += hsp.align_length
#
#        # Add HSP interval to the hit location list. this is to check the annotation.
#        subj_start = hsp.sbjct_start
#        subj_end = hsp.sbjct_end
#
#        # Add 'em to our list of subject hit coords.
#        subject_hit_coords.append((subj_start, subj_end))
#
#        # Add abs HSP interval to the covered intervals list, take the min/max to make sure the coordinates are correct! (This is for raw coverage)
#        abs_subj_start = min(subj_start, subj_end)
#        abs_subj_end = max(subj_start, subj_end)
#
#        # Also add query coordinates so we can see where on the contig we are aligning.
#        query_start = hsp.query_start
#        query_end = hsp.query_end
#
#        # Add this to the query_intervals list
#        query_intervals.append((query_start,query_end))
#
#        # Add abs HSP interval to the covered intervals list
#        covered_intervals.append((abs_subj_start, abs_subj_end))
#        
#        interval_groups.add(intervals.add_interval(query_start, query_end))
#
#    # Merge overlapping intervals to calculate the covered length
#    merged_intervals = merge_intervals(covered_intervals)
#    covered_length = sum(end - start for start, end in merged_intervals)
#
#    # Calculate overall percent identity
#    overall_percent_identity = (total_identities / total_alignment_length) * 100 if total_alignment_length != 0 else 0
#
#    # Calculate coverage percentage
#    reference_length = alignment.length
#    coverage_percentage = (covered_length / reference_length) * 100 if reference_length != 0 else 0
#    
#    if len(interval_groups) == 1:
#        interval_groups = int(next(iter(interval_groups)))
#    
#    return interval_groups, overall_percent_identity, coverage_percentage, covered_length, covered_intervals, query_intervals, subject_hit_coords

# Function to calculate overall percent identity and coverage using HSPs
def calculate_percent_identity_and_coverage(alignment):
    total_identities = 0
    total_alignment_length = 0
    query_intervals = IntervalTree()
    subject_intervals = IntervalTree()

    for hsp in alignment.hsps:
        total_identities += hsp.identities
        total_alignment_length += hsp.align_length

        # Add HSP interval to the query and subject intervals
        query_start, query_end = sorted([hsp.query_start, hsp.query_end])
        subject_start, subject_end = sorted([hsp.sbjct_start, hsp.sbjct_end])
        
        query_intervals.addi(query_start, query_end)
        subject_intervals.addi(subject_start, subject_end)

    # Merge overlapping intervals to calculate the covered length
    covered_length = sum(interval.length() for interval in subject_intervals)
    
    # Calculate overall percent identity
    overall_percent_identity = (total_identities / total_alignment_length) * 100 if total_alignment_length != 0 else 0

    # Calculate coverage percentage
    reference_length = alignment.length
    coverage_percentage = (covered_length / reference_length) * 100 if reference_length != 0 else 0
    
    return {
        "overall_percent_identity": overall_percent_identity,
        "coverage_percentage": coverage_percentage,
        "covered_length": covered_length,
        "covered_intervals": [(interval.begin, interval.end) for interval in subject_intervals],
        "query_intervals": [(interval.begin, interval.end) for interval in query_intervals],
        "subject_hit_coords": [(hsp.sbjct_start, hsp.sbjct_end) for hsp in alignment.hsps]
    }

# %%
class IntervalGroupManager:
    def __init__(self):
        self.groups = []
        self.trees = []

    def get_groups(self):
        return self.groups

    def get_trees(self):
        return self.trees
    
    def add_interval(self, start, end):
        new_interval = Interval(start, end)
        for idx, tree in enumerate(self.trees):
            if tree.overlaps(start, end):
                tree.add(new_interval)
                self.groups[idx].append((start, end))
                return idx
        # If no existing tree can accommodate the new interval, create a new group, 
        # this indicates multiple homologous regions?
        new_tree = IntervalTree()
        new_tree.add(new_interval)
        self.trees.append(new_tree)
        self.groups.append([(start, end)])
        return len(self.groups) - 1

def get_name_from_acc(hit_id, parsing_dict):
    acc_id = hit_id.split('|')[1]
    name = parsing_dict[acc_id]['name']
    strain = parsing_dict[acc_id]['strain']
    return strain, name

def parse_hit_id(hit_id):
    gene_id_list = hit_id.strip().split('_')
    if len(gene_id_list) == 2:
        strain = gene_id_list[0]
        plasmid_id = gene_id_list[-1]
    elif len(gene_id_list) == 1: # this is the weird pdb case.
        strain = gene_id_list[0].split('|')[1]
        plasmid_id = gene_id_list[0].split('|')[-1]
    elif gene_id_list[0] == 'NE': # this is the NE_1234 strains single case, hate this too.
        strain = '_'.join(gene_id_list[0:2])
        plasmid_id = gene_id_list[2]
    else:
        strain = gene_id_list[0]
        plasmid_id = gene_id_list[1]
    return strain, plasmid_id     

def parse_blast_xml(xml_file, **kwargs):
    assembly_id = Path(xml_file).stem.split('_')[0]
    parsing_type = kwargs.get('parsing_type', 'general')
    
    with open(xml_file, 'r') as handle:
        records = NCBIXML.parse(handle)
        
        # Dictionary to store contig IDs and their interval group managers
        contig_interval_groups = kwargs.get('contig_interval_groups', defaultdict(IntervalGroupManager))
        print(parsing_type)
        parsing_pickle = '/home/mf019/borrelia_plasmid_classifier_v3/parsing_tables/blast_parsing_dict.pkl'
        parsing_dict = pickle.load(open(parsing_pickle, 'rb'))
        
        # set up dict for intervals
        blast_hits = defaultdict(dict)
        
        for record in records:
            keys = [
                "assembly_id", "contig_id", "plasmid_id", "plasmid_name", "strain", "query_length", 
                "ref_length", "overall_percent_identity", "coverage_percentage", 
                "covered_length", "covered_intervals", "query_intervals", "subject_hit_coords",
            ]
            contig_id = record.query
            query_length = record.query_length
            hsp_counter = 0
            
            if contig_id not in blast_hits:
                blast_hits[contig_id] = []
            hits = blast_hits[contig_id]
            
            if len(record.alignments) == 0:
                hits = dict(zip(keys, 'NaN'*len(keys)))
            for alignment in record.alignments:
                plasmid_id = alignment.hit_id
                ref_length = alignment.length
                
                
                if parsing_type == 'wp':
                    strain, plasmid_name = get_name_from_acc(plasmid_id, parsing_dict)
                elif parsing_type == 'pf32':
                    strain, plasmid_name = parse_hit_id(plasmid_id)
                else:
                    strain = 'unknown' # this needs work
                    plasmid_name = alignment.hit_id

                results = {
                    "assembly_id": assembly_id,
                    "contig_id": contig_id,
                    "plasmid_id": plasmid_id,
                    "plasmid_name": plasmid_name,
                    "strain": strain,
                    "query_length": query_length,
                    "ref_length": ref_length,
                }
                alignment_results = calculate_percent_identity_and_coverage(alignment)
                results.update(alignment_results)
                hits.append(results)
        return blast_hits

# Function to determine the best match
def get_best_match(matches, key):
    """Highest percent identity takes the cake. specify which feature to compare.
    ex: get_best_match(matches, "percent_identity")"""
    best_match = None
    best_score = -1
    for match in matches:
        if match[key] > best_score:
            best_score = match[key]
            best_match = match
    return best_match

def get_hits_table(hits):
    rows = []
    for contig, hits in hits.items():
        for hit in hits:
            rows.append(hit)
    return pandas.DataFrame(rows)

        #hits_names = [parse_hit_id(name)[1] for name in hits]
        #print(f'{asm_id}\t{contig}\t{hits_names}')
        #for contig, intervals in contig_hit_intervals.items():
        #    if len(intervals) > 1:
        #        sorted_interval = sorted(intervals)
        #        print(contig, sorted_interval)
        #        previous_interval = sorted_interval[0]
        #        multiple_non_ovlp = False
        #        for current_interval in sorted_interval[1:]: 
        #            if previous_interval.end < current_interval.begin:
        #                multiple_non_ovlp = True
        #            previous_interval = current_interval
        #        if multiple_non_ovlp:
        #            print(f"{contig} has multiple non-overlapping pf32 hits!")
        #    else:
        #        print(contig, intervals)

# %%
wp_hits = parse_blast_xml(wp_results_test, parsing_type='wp')
pf32_hits= parse_blast_xml(pf_results_test, parsing_type='pf32')
pf32_hits_df = get_hits_table(pf32_hits)
wp_hits_df = get_hits_table(wp_hits)
# Out:
# wp
# pf32

# %%
wp_hits_df
# Out:
#     assembly_id     contig_id      plasmid_id plasmid_name   strain  \
# 0        ESI26H  contig000001  gb|CP124100.1|   chromosome  NE_5261
# 1        ESI26H  contig000001  gb|CP124096.1|   chromosome  NE_5267
# 2        ESI26H  contig000001  gb|CP124104.1|   chromosome  NE_5248
# 3        ESI26H  contig000001  gb|CP124088.1|   chromosome    Am315
# 4        ESI26H  contig000001  gb|CP031412.1|   chromosome      MM1
# ..          ...           ...             ...          ...      ...
# 240      ESI26H  contig000051  gb|AE001577.1|       cp32-4      B31
# 241      ESI26H  contig000051  gb|CP019759.1|       cp32-4  B31_NRZ
# 242      ESI26H  contig000051  gb|CP019757.1|       cp32-2  B31_NRZ
# 243      ESI26H  contig000051  gb|CP001572.1|       cp32-5    Bol26
# 244      ESI26H  contig000051  gb|CP001565.1|      cp32-12    Bol26
#
#      query_length  ref_length  overall_percent_identity  coverage_percentage  \
# 0          910396      910422                 99.952394           101.286986
# 1          910396      910422                 99.952178           101.286986
# 2          910396      910663                 99.927423           101.218014
# 3          910396      910229                 99.554979           101.491713
# 4          910396      908512                 99.290610           101.389965
# ..            ...         ...                       ...                  ...
# 240           210       30299                100.000000             0.689792
# 241           210       30300                100.000000             0.689769
# 242           210       31245                100.000000             0.668907
# 243           210       30186                100.000000             0.692374
# 244           210       31433                100.000000             0.664906
#
#      covered_length                                  covered_intervals  \
# 0            922139  [(213508, 214315), (213184, 213667), (213670, ...
# 1            922139  [(213183, 213990), (435132, 438330), (213345, ...
# 2            921755  [(213179, 214148), (438374, 441571), (909788, ...
# 3            923807  [(909447, 910227), (213287, 213932), (213125, ...
# 4            921140  [(213217, 214024), (904706, 907514), (213055, ...
# ..              ...                                                ...
# 240             209                                   [(10178, 10387)]
# 241             209                                   [(10179, 10388)]
# 242             209                                   [(10153, 10362)]
# 243             209                                   [(10146, 10355)]
# 244             209                                   [(10145, 10354)]
#
#                                        query_intervals  \
# 0    [(438371, 441568), (1, 910396), (213176, 21414...
# 1    [(438371, 441568), (1, 910396), (213176, 21414...
# 2    [(438371, 441568), (1, 909583), (213176, 21414...
# 3    [(438371, 441568), (213176, 214145), (213338, ...
# 4    [(213176, 214145), (905896, 908705), (336791, ...
# ..                                                 ...
# 240                                         [(1, 210)]
# 241                                         [(1, 210)]
# 242                                         [(1, 210)]
# 243                                         [(1, 210)]
# 244                                         [(1, 210)]
#
#                                     subject_hit_coords
# 0    [(1, 910420), (438379, 441576), (435133, 43833...
# 1    [(1, 910420), (438378, 441575), (435132, 43833...
# 2    [(1, 909646), (435128, 438326), (438374, 44157...
# 3    [(1, 909305), (434768, 437966), (438014, 44121...
# 4    [(1, 904621), (434870, 438062), (438118, 44131...
# ..                                                 ...
# 240                                   [(10178, 10387)]
# 241                                   [(10179, 10388)]
# 242                                   [(10153, 10362)]
# 243                                   [(10146, 10355)]
# 244                                   [(10145, 10354)]
#
# [245 rows x 13 columns]

# %%
pf32_hits_df
# Out:
#    assembly_id     contig_id                 plasmid_id plasmid_name   strain  \
# 0       ESI26H  contig000001  NE_5261_chromosome_ParA_2   chromosome  NE_5261
# 1       ESI26H  contig000001     B379_chromosome_ParA_2   chromosome     B379
# 2       ESI26H  contig000001      80a_chromosome_ParA_2   chromosome      80a
# 3       ESI26H  contig000001     B500_chromosome_ParA_2   chromosome     B500
# 4       ESI26H  contig000001  NE_5261_chromosome_ParA_1   chromosome  NE_5261
# 5       ESI26H  contig000002         JD1_cp32-12_ParA_1      cp32-12      JD1
# 6       ESI26H  contig000002         ZS7_cp32-12_ParA_1      cp32-12      ZS7
# 7       ESI26H  contig000002                297_cp32-12      cp32-12      297
# 8       ESI26H  contig000002         N40_cp32-12_ParA_1      cp32-12      N40
# 9       ESI26H  contig000002                 B31_cp32-5       cp32-5      B31
# 10      ESI26H  contig000003               Bol26_lp28-9       lp28-9    Bol26
# 11      ESI26H  contig000003                 JD1_lp28-7       lp28-7      JD1
# 12      ESI26H  contig000003                 B31_lp28-1       lp28-1      B31
# 13      ESI26H  contig000003           pdb|118a|cp32-13      cp32-13     118a
# 14      ESI26H  contig000004                   B31_lp36         lp36      B31
# 15      ESI26H  contig000004            MM1_lp36_ParA_1         lp36      MM1
# 16      ESI26H  contig000005          MM1_cp32-6_ParA_1       cp32-6      MM1
# 17      ESI26H  contig000005                 JD1_cp32-6       cp32-6      JD1
# 18      ESI26H  contig000006       ZS7_cp32-3+10_ParA_3    cp32-3+10      ZS7
# 19      ESI26H  contig000006     WI91-23_cp32-10_ParA_1      cp32-10  WI91-23
# 20      ESI26H  contig000006         94a_cp32-10_ParA_1      cp32-10      94a
# 21      ESI26H  contig000006                B31_cp32-10      cp32-10      B31
# 22      ESI26H  contig000006         N40_cp32-12_ParA_1      cp32-12      N40
# 23      ESI26H  contig000007        Bol26_lp28-3_ParA_2       lp28-3    Bol26
# 24      ESI26H  contig000007          JD1_lp28-3_ParA_1       lp28-3      JD1
# 25      ESI26H  contig000007                 JD1_lp28-6       lp28-6      JD1
# 26      ESI26H  contig000007      WI91-23_lp28-6_ParA_2       lp28-6  WI91-23
# 27      ESI26H  contig000007            MM1_lp36_ParA_1         lp36      MM1
# 28      ESI26H  contig000008      WI91-23_lp28-4_ParA_1       lp28-4  WI91-23
# 29      ESI26H  contig000008                 B31_lp28-4       lp28-4      B31
# 30      ESI26H  contig000009        NE_5261_cp26_ParA_1         cp26  NE_5261
# 31      ESI26H  contig000009                   B31_cp26         cp26      B31
# 32      ESI26H  contig000009            MM1_cp26_ParA_1         cp26      MM1
# 33      ESI26H  contig000009            N40_cp26_ParA_1         cp26      N40
# 34      ESI26H  contig000009            94a_cp26_ParA_1         cp26      94a
# 35      ESI26H  contig000010                   B31_lp17         lp17      B31
# 36      ESI26H  contig000011                 B31_cp32-9       cp32-9      B31
# 37      ESI26H  contig000011          JD1_cp32-9_ParA_1       cp32-9      JD1
# 38      ESI26H  contig000012                 B31_cp32-1       cp32-1      B31
# 39      ESI26H  contig000012          MM1_cp32-1_ParA_1       cp32-1      MM1
# 40      ESI26H  contig000012                  DN127_cp9          cp9    DN127
#
#     query_length  ref_length  overall_percent_identity  coverage_percentage  \
# 0         910396         380                100.000000            96.052632
# 1         910396         380                 99.453552            96.052632
# 2         910396         380                 99.453552            96.052632
# 3         910396         380                 99.450549            95.526316
# 4         910396         295                100.000000            99.661017
# 5          61321         260                 99.615385            99.615385
# 6          61321         260                 98.846154            99.615385
# 7          61321         260                 98.841699            99.230769
# 8          61321         260                 92.277992            98.461538
# 9          61321         257                100.000000            99.610895
# 10         51152         254                100.000000            99.606299
# 11         51152         253                 96.047431            99.604743
# 12         51152         254                 83.070866            99.606299
# 13         51152         254                 78.656126            99.212598
# 14         34728         249                100.000000            97.188755
# 15         34728         249                 99.588477            97.188755
# 16         30286         249                100.000000            99.598394
# 17         30286         249                 99.598394            99.598394
# 18         27753         251                100.000000            99.601594
# 19         27753         251                 89.641434            99.601594
# 20         27753         251                 89.641434            99.601594
# 21         27753         251                 89.243028            99.601594
# 22         27753         260                 79.200000            95.769231
# 23         26979         251                 98.790323            98.406375
# 24         26979         251                 97.580645            98.406375
# 25         26979         251                 72.580645            98.406375
# 26         26979         251                 72.177419            98.406375
# 27         26979         249                 69.758065            99.196787
# 28         26691         250                100.000000            99.600000
# 29         26691         250                 98.800000            99.600000
# 30         26508         253                100.000000            99.604743
# 31         26508         253                 99.604743            99.604743
# 32         26508         253                 99.604743            99.604743
# 33         26508         253                 99.209486            99.604743
# 34         26508         253                 99.209486            99.604743
# 35         24163         246                100.000000            97.967480
# 36         18933         251                100.000000            98.406375
# 37         18933         251                 99.596774            98.406375
# 38         11699         246                100.000000            99.593496
# 39         11699         246                 99.593496            99.593496
# 40         11699         246                 80.165289            97.967480
#
#     covered_length covered_intervals     query_intervals subject_hit_coords
# 0              365        [(1, 366)]  [(368852, 369949)]         [(1, 366)]
# 1              365        [(1, 366)]  [(368852, 369949)]         [(1, 366)]
# 2              365        [(1, 366)]  [(368852, 369949)]         [(1, 366)]
# 3              363        [(1, 364)]  [(368852, 369943)]         [(1, 364)]
# 4              294        [(1, 295)]  [(281792, 282676)]         [(1, 295)]
# 5              259        [(1, 260)]    [(49214, 49993)]         [(1, 260)]
# 6              259        [(1, 260)]    [(49214, 49993)]         [(1, 260)]
# 7              258        [(1, 259)]    [(49217, 49993)]         [(1, 259)]
# 8              256        [(1, 257)]    [(49217, 49993)]         [(1, 257)]
# 9              256        [(1, 257)]    [(18558, 19328)]         [(1, 257)]
# 10             253        [(1, 254)]    [(35231, 35992)]         [(1, 254)]
# 11             252        [(1, 253)]      [(7505, 8263)]         [(1, 253)]
# 12             253        [(1, 254)]    [(35231, 35992)]         [(1, 254)]
# 13             252        [(1, 253)]    [(35234, 35992)]         [(1, 253)]
# 14             242        [(1, 243)]    [(22554, 23282)]         [(1, 243)]
# 15             242        [(1, 243)]    [(22554, 23282)]         [(1, 243)]
# 16             248        [(1, 249)]      [(5090, 5836)]         [(1, 249)]
# 17             248        [(1, 249)]      [(5090, 5836)]         [(1, 249)]
# 18             250        [(1, 251)]    [(23067, 23819)]         [(1, 251)]
# 19             250        [(1, 251)]    [(23067, 23819)]         [(1, 251)]
# 20             250        [(1, 251)]    [(23067, 23819)]         [(1, 251)]
# 21             250        [(1, 251)]    [(23067, 23819)]         [(1, 251)]
# 22             249        [(1, 250)]    [(23070, 23819)]         [(1, 250)]
# 23             247        [(1, 248)]    [(15942, 16685)]         [(1, 248)]
# 24             247        [(1, 248)]    [(15942, 16685)]         [(1, 248)]
# 25             247        [(1, 248)]    [(15942, 16685)]         [(1, 248)]
# 26             247        [(1, 248)]    [(15942, 16685)]         [(1, 248)]
# 27             247        [(1, 248)]    [(15942, 16685)]         [(1, 248)]
# 28             249        [(1, 250)]    [(12526, 13275)]         [(1, 250)]
# 29             249        [(1, 250)]    [(12526, 13275)]         [(1, 250)]
# 30             252        [(1, 253)]       [(434, 1192)]         [(1, 253)]
# 31             252        [(1, 253)]       [(434, 1192)]         [(1, 253)]
# 32             252        [(1, 253)]       [(434, 1192)]         [(1, 253)]
# 33             252        [(1, 253)]       [(434, 1192)]         [(1, 253)]
# 34             252        [(1, 253)]       [(434, 1192)]         [(1, 253)]
# 35             241        [(1, 242)]    [(18524, 19249)]         [(1, 242)]
# 36             247        [(1, 248)]    [(14279, 15022)]         [(1, 248)]
# 37             247        [(1, 248)]    [(14279, 15022)]         [(1, 248)]
# 38             245        [(1, 246)]      [(6785, 7522)]         [(1, 246)]
# 39             245        [(1, 246)]      [(6785, 7522)]         [(1, 246)]
# 40             241        [(1, 242)]      [(6797, 7522)]         [(1, 242)]

# %%
pf_df = get_pf32_table('ESI26H', pf32_hits)
wp_df = get_wp_table('ESI26H', wp_hits)
merged = pandas.merge(wp_df, pf_df, on=['assembly', 'contig', 'homology_group'], how='outer')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 pf_df = get_pf32_table('ESI26H', pf32_hits)
#       2 wp_df = get_wp_table('ESI26H', wp_hits)
#       3 merged = pandas.merge(wp_df, pf_df, on=['assembly', 'contig', 'homology_group'], how='outer')
#
# Cell In[104], line 136, in get_pf32_table(asm_id, hits_dict)
#     134 percent_identity = 0
#     135 query_coordinates = (0,0)
# --> 136 if len(groups) == 0:
#     137     rows.append({'assembly': asm_id, 'contig': contig, 'homology_group': group, 'pf32_id': plasmid_id, 'pf32_name': plasmid_name, 'pf32_percent_identity': percent_identity, 'pf32_query_coords': query_coordinates})
#     138 else:
#
# NameError: name 'groups' is not defined

# %%
merged[merged['contig']=='contig000002']
# Out:
#   assembly        contig  contig_len  homology_group       wp_id  wp_name  \
# 1   ESI26H  contig000002       61321               0  CP001565.1  cp32-12
# 2   ESI26H  contig000002       61321               1  CP001565.1  cp32-12
# 3   ESI26H  contig000002       61321               2  CP001565.1  cp32-12
# 4   ESI26H  contig000002       61321               3  CP001565.1  cp32-12
# 5   ESI26H  contig000002       61321               4  CP001565.1  cp32-12
# 6   ESI26H  contig000002       61321               5  CP001565.1  cp32-12
#
#    wp_percent_identity wp_query_coords             pf32_id pf32_name  \
# 1            95.634673      (1, 10018)  JD1_cp32-12_ParA_1   cp32-12
# 2            95.634673  (10019, 12990)                 NaN       NaN
# 3            95.634673  (13472, 13919)          B31_cp32-5    cp32-5
# 4            95.634673  (13829, 18366)                 NaN       NaN
# 5            95.634673  (18633, 22346)                 NaN       NaN
# 6            95.634673  (22432, 39900)                 NaN       NaN
#
#    pf32_percent_identity pf32_query_coords
# 1              99.615385  [(49214, 49993)]
# 2                    NaN               NaN
# 3             100.000000  [(18558, 19328)]
# 4                    NaN               NaN
# 5                    NaN               NaN
# 6                    NaN               NaN

# %%
wp_hits['contig000002'][0]
# Out:
# [{'contig_id': 'contig000002',
#   'plasmid_id': 'CP001565.1',
#   'plasmid_name': 'cp32-12',
#   'query_length': 61321,
#   'ref_length': 31433,
#   'overall_percent_identity': 95.63467288798344,
#   'coverage_percentage': 99.99681863010213,
#   'covered_positions': 31432,
#   'covered_intervals': [(10018, 31433),
#    (1, 17505),
#    (1, 10017),
#    (22311, 26898),
#    (28477, 31433),
#    (18267, 22039),
#    (27531, 27987)],
#   'query_intervals': [(1, 10018),
#    (10019, 12990),
#    (13472, 13919),
#    (13829, 18366),
#    (18633, 22346),
#    (22432, 39900),
#    (39901, 61321)],
#   'subject_hit_coords': [(31433, 10018),
#    (17505, 1),
#    (10017, 1),
#    (26898, 22311),
#    (31433, 28477),
#    (22039, 18267),
#    (27987, 27531)]},
#  {'contig_id': 'contig000002',
#   'plasmid_id': 'CP019921.1',
#   'plasmid_name': 'cp32-9-4',
#   'query_length': 61321,
#   'ref_length': 62238,
#   'overall_percent_identity': 92.983426064249,
#   'coverage_percentage': 72.71763231466308,
#   'covered_positions': 45258,
#   'covered_intervals': [(26761, 47088),
#    (27696, 40708),
#    (1, 10312),
#    (1, 10037),
#    (40709, 47088),
#    (10488, 16575),
#    (10444, 16575),
#    (58276, 62238),
#    (21751, 26278),
#    (58283, 62238)],
#   'query_intervals': [(1, 12985),
#    (1, 10018),
#    (8738, 12704),
#    (13850, 18396),
#    (23526, 43848),
#    (23526, 29646),
#    (29620, 39900),
#    (38620, 42583),
#    (54941, 61321),
#    (54941, 61029)],
#   'subject_hit_coords': [(47088, 26761),
#    (40708, 27696),
#    (10312, 1),
#    (10037, 1),
#    (47088, 40709),
#    (16575, 10488),
#    (16575, 10444),
#    (62238, 58276),
#    (26278, 21751),
#    (62238, 58283)]},
#  {'contig_id': 'contig000002',
#   'plasmid_id': 'CP001200.1',
#   'plasmid_name': 'cp32-12',
#   'query_length': 61321,
#   'ref_length': 29806,
#   'overall_percent_identity': 95.33029222115516,
#   'coverage_percentage': 99.56720123465074,
#   'covered_positions': 29677,
#   'covered_intervals': [(1, 17295),
#    (1, 10021),
#    (17139, 26996),
#    (10022, 17276),
#    (21849, 26436),
#    (27124, 29806),
#    (27131, 29806),
#    (17805, 21577)],
#   'query_intervals': [(1, 10018),
#    (10019, 12704),
#    (13829, 18366),
#    (18633, 22346),
#    (22639, 39900),
#    (39901, 42583),
#    (43888, 53757),
#    (54067, 61321)],
#   'subject_hit_coords': [(17295, 1),
#    (10021, 1),
#    (26996, 17139),
#    (17276, 10022),
#    (26436, 21849),
#    (29806, 27124),
#    (29806, 27131),
#    (21577, 17805)]},
#  {'contig_id': 'contig000002',
#   'plasmid_id': 'CP001572.1',
#   'plasmid_name': 'cp32-5',
#   'query_length': 61321,
#   'ref_length': 30186,
#   'overall_percent_identity': 95.23603141306798,
#   'coverage_percentage': 97.42264625985555,
#   'covered_positions': 29408,
#   'covered_intervals': [(1, 16386),
#    (17866, 30186),
#    (1, 10018),
#    (10074, 16386),
#    (21839, 26376),
#    (17163, 21572),
#    (27215, 30186),
#    (26286, 26733)],
#   'query_intervals': [(1, 10018),
#    (10019, 22339),
#    (23526, 39900),
#    (39901, 42857),
#    (43353, 43809),
#    (44442, 49029),
#    (49301, 53764),
#    (54941, 61266)],
#   'subject_hit_coords': [(16386, 1),
#    (30186, 17866),
#    (10018, 1),
#    (16386, 10074),
#    (26376, 21839),
#    (21572, 17163),
#    (30186, 27215),
#    (26733, 26286)]},
#  {'contig_id': 'contig000002',
#   'plasmid_id': 'CP001206.1',
#   'plasmid_name': 'cp32-1',
#   'query_length': 61321,
#   'ref_length': 30330,
#   'overall_percent_identity': 91.48222785865676,
#   'coverage_percentage': 96.00395647873393,
#   'covered_positions': 29118,
#   'covered_intervals': [(1, 16398),
#    (1, 10021),
#    (10077, 16398),
#    (17887, 22669),
#    (22609, 26643),
#    (17175, 22758),
#    (22517, 26534),
#    (27652, 30330),
#    (27652, 30330),
#    (26874, 27449)],
#   'query_intervals': [(1, 10018),
#    (10019, 12712),
#    (12881, 13463),
#    (13705, 17738),
#    (17516, 22339),
#    (23526, 39900),
#    (39901, 42584),
#    (44442, 48488),
#    (48175, 53764),
#    (54941, 61266)],
#   'subject_hit_coords': [(16398, 1),
#    (10021, 1),
#    (16398, 10077),
#    (22669, 17887),
#    (26643, 22609),
#    (22758, 17175),
#    (26534, 22517),
#    (30330, 27652),
#    (30330, 27652),
#    (27449, 26874)]}]

# %%
os.listdir('dbs_v3/wp')
# Out:
# ['.ipynb_checkpoints',
#  'wp.nto',
#  'wp.nhd',
#  'wp.ndb',
#  'wp.not',
#  'wp.njs',
#  'wp.nog',
#  'wp.nhi',
#  'wp.ntf',
#  'wp.nsq',
#  'wp.nhr',
#  'wp.nos',
#  'wp.nin']

# %%
for file in os.listdir('dbs_v3/wp')[1:]:
    new_name = f'{file.split(".")[0]}_db.{file.split(".")[1]}'
    os.rename(f'dbs_v3/wp/{file}', f'dbs_v3/wp/{new_name}')

# %%
command = ['blastn', '-query', '/home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI111H/URI111H.fna', '-task', '"blastn"', '-db', 'dbs_v3/wp_v2/wp', '-out', '/home/mf019/longread_pangenome/plasmid_id/calls_v8/wp/xml_files/URI111H_blast_results.xml', '-evalue 1e-100', '-num_threads 4', '-outfmt 5', '-max_target_seqs 5', '-max_hsps', '10']
print(' '.join(command))
# Out:
# blastn -query /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI111H/URI111H.fna -task "blastn" -db dbs_v3/wp_v2/wp -out /home/mf019/longread_pangenome/plasmid_id/calls_v8/wp/xml_files/URI111H_blast_results.xml -evalue 1e-100 -num_threads 4 -outfmt 5 -max_target_seqs 5 -max_hsps 10

# %%
get_db_type('dbs_v3')
# Out:
# ['dbs_v3/pf32_v3/pf32', 'Protein']
# ['dbs_v3/wp_v2/wp', 'Nucleotide']
# [('dbs_v3/pf32_v3/pf32', 'blastx'), ('dbs_v3/wp_v2/wp', 'blastn')]
