# %%
import pandas
import pickle

# %%
# Ok let's crack open this jar of pickled plasmids.
parsing_table = pickle.load(open('parsing_tables/blast_parsing_dict.pkl', 'rb'))
# ok now let's set up the columns for our matrix and drop the synthetic vector I added a while back...
plasmids_in_db = {k : v for k, v in parsing_table.items()}
matrix_cols = []
for k in plasmids_in_db:
    matrix_cols.append(plasmids_in_db[k]['name'])
matrix_cols = list(set(matrix_cols))
matrix_cols.sort()
matrix_cols.remove('pBSV2')
matrix_cols.remove('lp21-cp9')
print(matrix_cols)
# Out:
# ['chromosome', 'cp26', 'cp32-1', 'cp32-1+5', 'cp32-10', 'cp32-11', 'cp32-12', 'cp32-2', 'cp32-3', 'cp32-3+10', 'cp32-4', 'cp32-5', 'cp32-5+1', 'cp32-5-1', 'cp32-6', 'cp32-7', 'cp32-8', 'cp32-9', 'cp32-9-4', 'cp9', 'cp9-3', 'lp17', 'lp21', 'lp25', 'lp28-1', 'lp28-11', 'lp28-2', 'lp28-3', 'lp28-4', 'lp28-5', 'lp28-6', 'lp28-7', 'lp28-8', 'lp28-9', 'lp36', 'lp38', 'lp5', 'lp54', 'lp56']

# %%
def make_method_dicts(subset_df):
    # Create a dictionary to store the sets
    sr_plasmids, lr_plasmids = {}, {}
    
    sr_subset = subset[subset['method'] == 'shortread']
    lr_subset = subset[subset['method'] == 'longread']
    
    # Group by the 'name' column and create sets of 'best_hit'
    for name, group in sr_subset.groupby('name'):
        best_hit_set = set(group['best_hit'])
        sr_plasmids[name] = best_hit_set
    
    # Group by the 'name' column and create sets of 'best_hit'
    for name, group in lr_subset.groupby('name'):
        best_hit_set = set(group['best_hit'])
        lr_plasmids[name] = best_hit_set
    
    print("lr_plasmids:", lr_plasmids)
    print(len(lr_plasmids.keys()))
    
    print("sr_plasmids:", sr_plasmids)
    print(len(sr_plasmids.keys()))
    return sr_plasmids, lr_plasmids

def generate_matrix(sr_plasmids, lr_plasmids, version, cutoff):
    for k in lr_plasmids:
        print(f'longread: {k} : len:{len(list(set(lr_plasmids[k])))} : {list(set(lr_plasmids[k]))}')
        lr_plasmids[k] = list(set(lr_plasmids[k]))
        print(f'shortread: {k[:-1]} : len: {len(list(set(sr_plasmids[k[:-1]])))}{list(set(sr_plasmids[k[:-1]]))}')
        sr_plasmids[k[:-1]] = list(set(sr_plasmids[k[:-1]]))
    
    dicts_of_results = [sr_plasmids, lr_plasmids]
    plasmid_presence_matrix = []
    for dict1 in dicts_of_results:
        for k in dict1:
            #print(k)
            for v in dict1[k]:
                #print(v)
                plasmid_presence_matrix.append((k,v))
    
    plasmid_df = pandas.DataFrame(plasmid_presence_matrix, columns=['key','val']).set_index(['key'])
    plasmid_count_matrix = plasmid_df.pivot_table(index='key', columns='val',aggfunc=len,fill_value=0,sort=True)
    plasmid_count_matrix['Sum'] = plasmid_count_matrix.sum(axis=1)
    print(plasmid_count_matrix)
    # make filename
    outfile = f'plasmid_presence_matrix_{version}_{cutoff}.csv'
    plasmid_count_matrix.to_csv(outfile)

# %%
new_csv = 'best_matches_v6_1kb.tsv'
version = 'v6'
df_1000bp_cutoff = pandas.read_csv(new_csv,header=0,delimiter='\t')
df_2500bp_cutoff = df_1000bp_cutoff[plasmid_results_df['contig_len'] >= 2500]
df_5000bp_cutoff = df_1000bp_cutoff[plasmid_results_df['contig_len'] >= 5000]

# %%
subset1000 = df_1000bp_cutoff[['name','method','contig','best_hit','best_method','completeness']]
subset2500 = df_2500bp_cutoff[['name','method','contig','best_hit','best_method','completeness']]
subset5000 = df_5000bp_cutoff[['name','method','contig','best_hit','best_method','completeness']]

# %%
sr_pl_1000, lr_pl_1000 = make_method_dicts(subset1000)
sr_pl_2500, lr_pl_2500 = make_method_dicts(subset2500)
sr_pl_5000, lr_pl_5000 = make_method_dicts(subset5000)
# Out:
# lr_plasmids: {'ESI26H': {'lp36', 'cp32-1', 'cp32-6', 'lp28-4', nan, 'cp32-5', 'lp28-3', 'chromosome', 'lp54', 'cp32-3+10', 'cp32-9', 'cp26', 'cp32-3', 'cp32-9-4', 'lp17', 'lp28-9'}, 'UCT109H': {'lp25', 'cp32-7', 'lp28-2', 'cp32-10', 'lp36', 'cp32-6', 'cp32-4', nan, 'lp28-1', 'cp32-5', 'lp28-3', 'chromosome', 'lp38', 'lp54', 'cp32-9', 'cp26', 'cp32-3', 'lp17'}, 'UCT110H': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'cp32-2', 'lp28-4', 'lp21', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT113H': {'cp32-7', 'lp28-5', nan, 'lp28-1', 'chromosome', 'lp36', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'lp25', 'lp28-4', 'lp21', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT29H': {'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp32-10', 'cp32-1', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'lp21', 'lp28-4', 'cp32-11', 'lp38', 'cp9'}, 'UCT30H': {'lp28-5', 'cp32-7', nan, 'cp32-5', 'chromosome', 'lp36', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'lp28-6', 'lp17', 'cp32-9', 'cp32-3', 'lp28-4', 'lp21', 'cp32-6', 'cp32-2', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT31H': {'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'cp32-1', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'lp21', 'lp28-4', 'cp32-11', 'cp9'}, 'UCT32H': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp32-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'cp32-2', 'lp28-4', 'cp32-12', 'cp32-11', 'lp38'}, 'UCT35H': {'cp32-7', 'cp32-10', nan, 'lp28-4', 'cp32-4', 'lp28-1', 'lp28-8', 'cp32-12', 'cp32-5', 'chromosome', 'lp54', 'cp9', 'cp26', 'cp32-3', 'cp32-13', 'lp17', 'lp5'}, 'UCT50H': {'lp25', 'cp32-7', 'lp36', 'cp32-10', 'lp28-4', 'cp32-4', nan, 'cp32-5', 'cp32-12', 'cp32-11', 'chromosome', 'lp38', 'lp54', 'cp9', 'cp32-9', 'cp26', 'cp32-13', 'lp17'}, 'UCT92H': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-1', 'cp32-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-9', 'cp32-3', 'cp32-6', 'cp32-2', 'lp28-4', 'cp32-12', 'cp32-11', 'lp38'}, 'UCT96H': {'cp32-7', 'lp28-5', 'lp28-2', nan, 'lp28-1', 'chromosome', 'lp36', 'cp32-1', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'lp28-4', 'cp32-11', 'lp38'}, 'UNY149P': {'cp32-7', 'lp28-5', 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'cp32-2', 'lp28-4', 'cp32-11', 'lp38'}, 'UNY169P': {'lp25', 'cp32-7', 'lp28-2', 'cp32-10', 'lp36', 'lp28-4', 'cp32-4', 'cp32-5', 'cp32-12', 'lp28-3', 'chromosome', 'lp38', 'cp9', 'lp54', 'cp32-9', 'cp26', 'lp17'}, 'UNY172P': {'lp25', 'cp32-7', 'lp28-2', 'lp36', 'lp28-4', 'cp32-4', 'cp32-5', 'cp32-12', 'lp28-3', 'chromosome', 'lp38', 'lp54', 'cp32-9', 'cp26', 'cp32-3', 'lp17'}, 'UNY193P': {'cp32-7', 'lp28-2', 'chromosome', 'cp32-10', 'lp36', 'lp28-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'lp5', 'cp32-13', 'lp25', 'cp32-6', 'lp28-4', 'cp32-12', 'cp9', 'lp28-7'}, 'UNY203P': {'cp32-7', 'cp32-10', 'lp36', 'cp32-6', 'cp32-4', 'lp28-6', 'lp28-1', 'cp32-5', 'cp32-12', 'lp28-3', 'chromosome', 'lp28-8', 'cp9', 'lp54', 'cp26', 'lp17', 'lp5'}, 'UNY208P': {'lp25', 'cp32-7', 'lp36', 'cp32-1', 'lp28-4', 'cp32-4', 'cp32-8', 'lp28-6', 'lp28-1', 'cp32-5', 'cp32-12', 'cp32-11', 'chromosome', 'lp28-3', 'lp54', 'cp26', 'cp32-3', 'lp17'}, 'URI101H': {'cp32-7', 'lp28-5', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'lp21', 'lp28-4', 'lp56', 'cp32-11', 'lp38'}, 'URI102H': {'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp32-10', 'lp36', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'cp32-2', 'lp56', 'lp38'}, 'URI103H': {'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome',  ...
# 49
# sr_plasmids: {'ESI26': {'lp28-2', 'lp36', 'cp32-1', 'cp32-6', nan, 'cp32-8', 'lp28-3', 'cp32-12', 'cp32-5', 'chromosome', 'lp28-9', 'lp54', 'cp32-3+10', 'cp32-9', 'cp26', 'lp17', 'lp28-7'}, 'UCT109': {'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-2', 'cp32-6', 'lp56', 'cp32-11', 'lp38', 'cp9'}, 'UCT110': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-2', 'cp32-6', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT113': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'chromosome', 'lp36', 'cp32-1', 'cp32-10', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'lp28-6', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'cp32-5-1', 'lp28-4', 'cp32-6', 'lp21', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT29': {'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-1', 'lp28-3', 'lp54', 'cp26', 'cp9-3', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'cp32-11', 'cp32-12', 'lp38', 'cp9', 'cp32-9-4'}, 'UCT30': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'cp9-3', 'lp17', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'lp21', 'cp32-2', 'cp32-6', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT31': {'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-1', 'cp32-10', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'cp9-3', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'lp21', 'cp32-2', 'cp32-6', 'lp56', 'cp32-11', 'cp32-12', 'cp9'}, 'UCT32': {'lp28-5', 'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-2', 'lp21', 'cp32-6', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT35': {'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'cp32-8', 'lp28-8', 'lp28-3', 'lp28-11', 'lp54', 'cp26', 'lp17', 'lp5', 'cp32-4', 'cp32-3', 'cp32-13', 'lp25', 'lp28-4', 'cp32-6', 'cp32-12', 'cp32-11', 'cp9'}, 'UCT50': {'cp32-7', nan, 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-13', 'lp25', 'lp28-4', 'cp32-6', 'cp32-12', 'cp32-11', 'lp38', 'cp9'}, 'UCT92': {'lp28-5', 'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-1', 'cp32-8', 'lp28-3', 'lp28-11', 'lp54', 'lp28-6', 'cp26', 'cp9-3', 'lp17', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'lp21', 'cp32-2', 'cp32-6', 'cp32-12', 'cp32-11', 'lp38'}, 'UCT96': {'lp28-5', 'cp32-7', 'lp28-2', nan, 'lp28-1', 'chromosome', 'lp36', 'cp32-1', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'lp28-6', 'lp17', 'lp5', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-6', 'cp32-11', 'lp38'}, 'UNY149': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'lp28-6', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-2', 'lp21', 'cp32-6', 'cp32-12', 'cp32-11', 'lp38'}, 'UNY169': {'cp32-7', 'lp28-2', nan, 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-6', 'cp32-12', 'lp38', 'cp9'}, 'UNY172': {'cp32-7', 'lp28-2', nan, 'cp32-5', 'chromosome', 'lp36', 'cp32-1', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-6', 'cp32-12', 'cp32-11', 'lp38'}, 'UNY193': {'cp32-7', 'lp28-5', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'cp32-8', 'lp28-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'cp9-3', 'lp17', 'lp5', 'cp32-4', 'cp32-9', 'cp32-3', 'cp32-13', 'lp25', 'lp28-4', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'cp32-12', 'cp32-11', 'lp38', 'cp9', 'lp28-7'}, 'UNY203': {'cp32-7', 'lp28-5', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'cp32-1+5', 'lp28-8', 'lp28-3', 'lp28-11', 'lp54', 'lp28-6', 'cp26', 'lp17', 'lp5', 'cp32-4', 'cp32-3', 'cp32-13', 'lp25', 'lp28-4', 'c ...
# 49
# lr_plasmids: {'ESI26H': {'lp36', 'cp32-1', 'cp32-6', 'lp28-4', nan, 'cp32-5', 'lp28-3', 'chromosome', 'lp54', 'cp32-3+10', 'cp32-9', 'cp26', 'cp32-3', 'cp32-9-4', 'lp17', 'lp28-9'}, 'UCT109H': {'lp25', 'cp32-7', 'lp28-2', 'cp32-10', 'lp36', 'cp32-6', 'cp32-4', nan, 'lp28-1', 'cp32-5', 'lp28-3', 'chromosome', 'lp38', 'lp54', 'cp32-9', 'cp26', 'cp32-3', 'lp17'}, 'UCT110H': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'cp32-2', 'lp28-4', 'lp21', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT113H': {'cp32-7', 'lp28-5', nan, 'lp28-1', 'chromosome', 'lp36', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'lp25', 'lp28-4', 'lp21', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT29H': {'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp32-10', 'cp32-1', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'lp21', 'lp28-4', 'cp32-11', 'lp38', 'cp9'}, 'UCT30H': {'lp28-5', 'cp32-7', nan, 'cp32-5', 'chromosome', 'lp36', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'lp28-6', 'lp17', 'cp32-9', 'cp32-3', 'lp28-4', 'lp21', 'cp32-6', 'cp32-2', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT31H': {'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'cp32-1', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'lp21', 'lp28-4', 'cp32-11', 'cp9'}, 'UCT32H': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp32-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'cp32-2', 'lp28-4', 'cp32-12', 'cp32-11', 'lp38'}, 'UCT35H': {'cp32-7', 'cp32-10', nan, 'lp28-4', 'cp32-4', 'lp28-1', 'lp28-8', 'cp32-12', 'cp32-5', 'chromosome', 'lp54', 'cp9', 'cp26', 'cp32-3', 'cp32-13', 'lp17', 'lp5'}, 'UCT50H': {'lp25', 'cp32-7', 'lp36', 'cp32-10', 'lp28-4', 'cp32-4', nan, 'cp32-5', 'cp32-12', 'cp32-11', 'chromosome', 'lp38', 'lp54', 'cp9', 'cp32-9', 'cp26', 'cp32-13', 'lp17'}, 'UCT92H': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-1', 'cp32-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-9', 'cp32-3', 'cp32-6', 'cp32-2', 'lp28-4', 'cp32-12', 'cp32-11', 'lp38'}, 'UCT96H': {'cp32-7', 'lp28-5', 'lp28-2', nan, 'lp28-1', 'chromosome', 'lp36', 'cp32-1', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'lp28-4', 'cp32-11', 'lp38'}, 'UNY149P': {'cp32-7', 'lp28-5', 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'cp32-2', 'lp28-4', 'cp32-11', 'lp38'}, 'UNY169P': {'lp25', 'cp32-7', 'lp28-2', 'cp32-10', 'lp36', 'lp28-4', 'cp32-4', 'cp32-5', 'cp32-12', 'lp28-3', 'chromosome', 'lp38', 'cp9', 'lp54', 'cp32-9', 'cp26', 'lp17'}, 'UNY172P': {'lp25', 'cp32-7', 'lp28-2', 'lp36', 'lp28-4', 'cp32-4', 'cp32-5', 'cp32-12', 'lp28-3', 'chromosome', 'lp38', 'lp54', 'cp32-9', 'cp26', 'cp32-3', 'lp17'}, 'UNY193P': {'cp32-7', 'lp28-2', 'chromosome', 'cp32-10', 'lp36', 'lp28-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'lp5', 'cp32-13', 'lp25', 'cp32-6', 'lp28-4', 'cp32-12', 'cp9', 'lp28-7'}, 'UNY203P': {'cp32-7', 'cp32-10', 'lp36', 'cp32-6', 'cp32-4', 'lp28-6', 'lp28-1', 'cp32-5', 'cp32-12', 'lp28-3', 'chromosome', 'lp28-8', 'cp9', 'lp54', 'cp26', 'lp17', 'lp5'}, 'UNY208P': {'lp25', 'cp32-7', 'lp36', 'cp32-1', 'lp28-4', 'cp32-4', 'cp32-8', 'lp28-6', 'lp28-1', 'cp32-5', 'cp32-12', 'cp32-11', 'chromosome', 'lp28-3', 'lp54', 'cp26', 'cp32-3', 'lp17'}, 'URI101H': {'cp32-7', 'lp28-5', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'lp21', 'lp28-4', 'lp56', 'cp32-11', 'lp38'}, 'URI102H': {'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp32-10', 'lp36', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'cp32-2', 'lp56', 'lp38'}, 'URI103H': {'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome',  ...
# 49
# sr_plasmids: {'ESI26': {'lp28-2', 'lp36', 'cp32-1', 'cp32-6', nan, 'cp32-8', 'lp28-3', 'cp32-12', 'cp32-5', 'chromosome', 'lp28-9', 'lp54', 'cp32-3+10', 'cp32-9', 'cp26', 'lp17', 'lp28-7'}, 'UCT109': {'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-2', 'cp32-6', 'lp56', 'cp32-11', 'lp38', 'cp9'}, 'UCT110': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-2', 'cp32-6', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT113': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'chromosome', 'lp36', 'cp32-1', 'cp32-10', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'lp28-6', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'cp32-5-1', 'lp28-4', 'cp32-6', 'lp21', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT29': {'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-1', 'lp28-3', 'lp54', 'cp26', 'cp9-3', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'cp32-11', 'cp32-12', 'lp38', 'cp9', 'cp32-9-4'}, 'UCT30': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'cp9-3', 'lp17', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'lp21', 'cp32-2', 'cp32-6', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT31': {'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-1', 'cp32-10', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'cp9-3', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'lp21', 'cp32-2', 'cp32-6', 'lp56', 'cp32-11', 'cp32-12', 'cp9'}, 'UCT32': {'lp28-5', 'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-2', 'lp21', 'cp32-6', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT35': {'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'cp32-8', 'lp28-8', 'lp28-3', 'lp28-11', 'lp54', 'cp26', 'lp17', 'lp5', 'cp32-4', 'cp32-3', 'cp32-13', 'lp25', 'lp28-4', 'cp32-6', 'cp32-12', 'cp32-11', 'cp9'}, 'UCT50': {'cp32-7', nan, 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-13', 'lp25', 'lp28-4', 'cp32-6', 'cp32-12', 'cp32-11', 'lp38', 'cp9'}, 'UCT92': {'lp28-5', 'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-1', 'cp32-8', 'lp28-3', 'lp28-11', 'lp54', 'lp28-6', 'cp26', 'cp9-3', 'lp17', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'lp21', 'cp32-2', 'cp32-6', 'cp32-12', 'cp32-11', 'lp38'}, 'UCT96': {'lp28-5', 'cp32-7', 'lp28-2', nan, 'lp28-1', 'chromosome', 'lp36', 'cp32-1', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'lp28-6', 'lp17', 'lp5', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-6', 'cp32-11', 'lp38'}, 'UNY149': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'lp28-6', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-2', 'lp21', 'cp32-6', 'cp32-12', 'cp32-11', 'lp38'}, 'UNY169': {'cp32-7', 'lp28-2', nan, 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-6', 'cp32-12', 'lp38', 'cp9'}, 'UNY172': {'cp32-7', 'lp28-2', nan, 'cp32-5', 'chromosome', 'lp36', 'cp32-1', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-6', 'cp32-12', 'cp32-11', 'lp38'}, 'UNY193': {'cp32-7', 'lp28-5', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'cp32-8', 'lp28-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'cp9-3', 'lp17', 'lp5', 'cp32-4', 'cp32-9', 'cp32-3', 'cp32-13', 'lp25', 'lp28-4', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'cp32-12', 'cp32-11', 'lp38', 'cp9', 'lp28-7'}, 'UNY203': {'cp32-7', 'lp28-5', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'cp32-1+5', 'lp28-8', 'lp28-3', 'lp28-11', 'lp54', 'lp28-6', 'cp26', 'lp17', 'lp5', 'cp32-4', 'cp32-3', 'cp32-13', 'lp25', 'lp28-4', 'c ...
# 49
# lr_plasmids: {'ESI26H': {'lp36', 'cp32-1', 'cp32-6', 'lp28-4', nan, 'cp32-5', 'lp28-3', 'chromosome', 'lp54', 'cp32-3+10', 'cp32-9', 'cp26', 'cp32-3', 'cp32-9-4', 'lp17', 'lp28-9'}, 'UCT109H': {'lp25', 'cp32-7', 'lp28-2', 'cp32-10', 'lp36', 'cp32-6', 'cp32-4', nan, 'lp28-1', 'cp32-5', 'lp28-3', 'chromosome', 'lp38', 'lp54', 'cp32-9', 'cp26', 'cp32-3', 'lp17'}, 'UCT110H': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'cp32-2', 'lp28-4', 'lp21', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT113H': {'cp32-7', 'lp28-5', nan, 'lp28-1', 'chromosome', 'lp36', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'lp25', 'lp28-4', 'lp21', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT29H': {'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp32-10', 'cp32-1', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'lp21', 'lp28-4', 'cp32-11', 'lp38', 'cp9'}, 'UCT30H': {'lp28-5', 'cp32-7', nan, 'cp32-5', 'chromosome', 'lp36', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'lp28-6', 'lp17', 'cp32-9', 'cp32-3', 'lp28-4', 'lp21', 'cp32-6', 'cp32-2', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT31H': {'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'cp32-1', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'lp21', 'lp28-4', 'cp32-11', 'cp9'}, 'UCT32H': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp32-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'cp32-2', 'lp28-4', 'cp32-12', 'cp32-11', 'lp38'}, 'UCT35H': {'cp32-7', 'cp32-10', nan, 'lp28-4', 'cp32-4', 'lp28-1', 'lp28-8', 'cp32-12', 'cp32-5', 'chromosome', 'lp54', 'cp9', 'cp26', 'cp32-3', 'cp32-13', 'lp17', 'lp5'}, 'UCT50H': {'lp25', 'cp32-7', 'lp36', 'cp32-10', 'lp28-4', 'cp32-4', nan, 'cp32-5', 'cp32-12', 'cp32-11', 'chromosome', 'lp38', 'lp54', 'cp9', 'cp32-9', 'cp26', 'cp32-13', 'lp17'}, 'UCT92H': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-1', 'cp32-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-9', 'cp32-3', 'cp32-6', 'cp32-2', 'lp28-4', 'cp32-12', 'cp32-11', 'lp38'}, 'UCT96H': {'cp32-7', 'lp28-5', 'lp28-2', nan, 'lp28-1', 'chromosome', 'lp36', 'cp32-1', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'lp28-4', 'cp32-11', 'lp38'}, 'UNY149P': {'cp32-7', 'lp28-5', 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'cp32-2', 'lp28-4', 'cp32-11', 'lp38'}, 'UNY169P': {'lp25', 'cp32-7', 'lp28-2', 'cp32-10', 'lp36', 'lp28-4', 'cp32-4', 'cp32-5', 'cp32-12', 'lp28-3', 'chromosome', 'lp38', 'cp9', 'lp54', 'cp32-9', 'cp26', 'lp17'}, 'UNY172P': {'lp25', 'cp32-7', 'lp28-2', 'lp36', 'lp28-4', 'cp32-4', 'cp32-5', 'cp32-12', 'lp28-3', 'chromosome', 'lp38', 'lp54', 'cp32-9', 'cp26', 'cp32-3', 'lp17'}, 'UNY193P': {'cp32-7', 'lp28-2', 'chromosome', 'cp32-10', 'lp36', 'lp28-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'lp5', 'cp32-13', 'lp25', 'cp32-6', 'lp28-4', 'cp32-12', 'cp9', 'lp28-7'}, 'UNY203P': {'cp32-7', 'cp32-10', 'lp36', 'cp32-6', 'cp32-4', 'lp28-6', 'lp28-1', 'cp32-5', 'cp32-12', 'lp28-3', 'chromosome', 'lp28-8', 'cp9', 'lp54', 'cp26', 'lp17', 'lp5'}, 'UNY208P': {'lp25', 'cp32-7', 'lp36', 'cp32-1', 'lp28-4', 'cp32-4', 'cp32-8', 'lp28-6', 'lp28-1', 'cp32-5', 'cp32-12', 'cp32-11', 'chromosome', 'lp28-3', 'lp54', 'cp26', 'cp32-3', 'lp17'}, 'URI101H': {'cp32-7', 'lp28-5', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'lp21', 'lp28-4', 'lp56', 'cp32-11', 'lp38'}, 'URI102H': {'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp32-10', 'lp36', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'cp32-2', 'lp56', 'lp38'}, 'URI103H': {'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome',  ...
# 49
# sr_plasmids: {'ESI26': {'lp28-2', 'lp36', 'cp32-1', 'cp32-6', nan, 'cp32-8', 'lp28-3', 'cp32-12', 'cp32-5', 'chromosome', 'lp28-9', 'lp54', 'cp32-3+10', 'cp32-9', 'cp26', 'lp17', 'lp28-7'}, 'UCT109': {'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-2', 'cp32-6', 'lp56', 'cp32-11', 'lp38', 'cp9'}, 'UCT110': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-2', 'cp32-6', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT113': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'chromosome', 'lp36', 'cp32-1', 'cp32-10', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'lp28-6', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'cp32-5-1', 'lp28-4', 'cp32-6', 'lp21', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT29': {'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-1', 'lp28-3', 'lp54', 'cp26', 'cp9-3', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'cp32-11', 'cp32-12', 'lp38', 'cp9', 'cp32-9-4'}, 'UCT30': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'cp9-3', 'lp17', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'lp21', 'cp32-2', 'cp32-6', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT31': {'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-1', 'cp32-10', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'cp9-3', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'lp21', 'cp32-2', 'cp32-6', 'lp56', 'cp32-11', 'cp32-12', 'cp9'}, 'UCT32': {'lp28-5', 'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-2', 'lp21', 'cp32-6', 'cp32-11', 'cp32-12', 'lp38'}, 'UCT35': {'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'cp32-8', 'lp28-8', 'lp28-3', 'lp28-11', 'lp54', 'cp26', 'lp17', 'lp5', 'cp32-4', 'cp32-3', 'cp32-13', 'lp25', 'lp28-4', 'cp32-6', 'cp32-12', 'cp32-11', 'cp9'}, 'UCT50': {'cp32-7', nan, 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-13', 'lp25', 'lp28-4', 'cp32-6', 'cp32-12', 'cp32-11', 'lp38', 'cp9'}, 'UCT92': {'lp28-5', 'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-1', 'cp32-8', 'lp28-3', 'lp28-11', 'lp54', 'lp28-6', 'cp26', 'cp9-3', 'lp17', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'lp21', 'cp32-2', 'cp32-6', 'cp32-12', 'cp32-11', 'lp38'}, 'UCT96': {'lp28-5', 'cp32-7', 'lp28-2', nan, 'lp28-1', 'chromosome', 'lp36', 'cp32-1', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'lp28-6', 'lp17', 'lp5', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-6', 'cp32-11', 'lp38'}, 'UNY149': {'lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'lp28-6', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-2', 'lp21', 'cp32-6', 'cp32-12', 'cp32-11', 'lp38'}, 'UNY169': {'cp32-7', 'lp28-2', nan, 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-6', 'cp32-12', 'lp38', 'cp9'}, 'UNY172': {'cp32-7', 'lp28-2', nan, 'cp32-5', 'chromosome', 'lp36', 'cp32-1', 'cp32-8', 'lp28-3', 'lp54', 'cp26', 'lp17', 'cp32-4', 'cp32-9', 'cp32-3', 'lp25', 'lp28-4', 'cp32-6', 'cp32-12', 'cp32-11', 'lp38'}, 'UNY193': {'cp32-7', 'lp28-5', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'cp32-8', 'lp28-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'cp9-3', 'lp17', 'lp5', 'cp32-4', 'cp32-9', 'cp32-3', 'cp32-13', 'lp25', 'lp28-4', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'cp32-12', 'cp32-11', 'lp38', 'cp9', 'lp28-7'}, 'UNY203': {'cp32-7', 'lp28-5', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'cp32-1+5', 'lp28-8', 'lp28-3', 'lp28-11', 'lp54', 'lp28-6', 'cp26', 'lp17', 'lp5', 'cp32-4', 'cp32-3', 'cp32-13', 'lp25', 'lp28-4', 'c ...
# 49

# %%
generate_matrix(sr_pl_1000, lr_pl_1000, version, '1000bp')
generate_matrix(sr_pl_2500, lr_pl_2500, version, '2500bp')
generate_matrix(sr_pl_5000, lr_pl_5000, version, '5000bp')
# Out:
# longread: ESI26H : len:16 : [nan, 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp36', 'cp32-1', 'cp32-6', 'lp28-4', 'lp28-3', 'lp54', 'cp32-3+10', 'cp26', 'cp32-9-4', 'lp17', 'lp28-9']
# shortread: ESI26 : len: 17['lp28-2', nan, 'cp32-5', 'chromosome', 'cp32-9', 'lp28-7', 'lp36', 'cp32-1', 'cp32-6', 'cp32-8', 'lp28-3', 'cp32-12', 'lp54', 'cp32-3+10', 'cp26', 'lp17', 'lp28-9']
# longread: UCT109H : len:18 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'cp32-10', 'lp36', 'cp32-6', 'lp28-3', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: UCT109 : len: 22['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-6', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp9', 'cp26', 'lp17']
# longread: UCT110H : len:23 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-6', 'cp32-2', 'cp32-8', 'lp28-4', 'lp21', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: UCT110 : len: 23['lp28-5', 'cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'cp32-6', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# longread: UCT113H : len:19 : ['cp32-7', 'lp28-5', nan, 'cp32-4', 'lp28-1', 'chromosome', 'cp26', 'cp32-9', 'lp25', 'lp36', 'lp28-4', 'lp21', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: UCT113 : len: 25['lp28-5', 'cp32-7', nan, 'cp32-4', 'lp28-1', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'cp32-5-1', 'lp36', 'cp32-1', 'cp32-10', 'lp28-4', 'cp32-8', 'lp28-6', 'cp32-6', 'lp21', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: UCT29H : len:22 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'cp32-10', 'cp32-1', 'cp32-6', 'lp21', 'lp28-4', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp9', 'cp26', 'lp17']
# shortread: UCT29 : len: 27['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp9', 'cp26', 'cp9-3', 'cp32-9-4', 'lp17']
# longread: UCT30H : len:21 : ['lp28-5', 'cp32-7', nan, 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'lp28-6', 'cp32-6', 'cp32-2', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: UCT30 : len: 24['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-2', 'cp32-6', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'cp9-3', 'lp17']
# longread: UCT31H : len:22 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-1', 'cp32-6', 'lp21', 'lp28-4', 'lp28-3', 'cp32-11', 'lp54', 'cp9', 'cp26', 'lp17']
# shortread: UCT31 : len: 27['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-10', 'lp28-4', 'cp32-8', 'lp21', 'cp32-2', 'cp32-6', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp54', 'cp9', 'cp26', 'cp9-3', 'lp17']
# longread: UCT32H : len:21 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'cp32-2', 'cp32-8', 'lp28-4', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: UCT32 : len: 24['lp28-5', 'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'lp21', 'cp32-6', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# longread: UCT35H : len:17 : ['cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-3', 'cp32-13', 'cp32-10', 'lp28-4', 'lp28-8', 'cp32-12', 'lp54', 'cp9', 'cp26', 'lp17', 'lp5']
# shortread: UCT35 : len: 24['cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-3', 'cp32-13', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'cp32-8', 'lp28-8', 'lp28-3', 'cp32-12', 'cp32-11', 'lp28-11', 'lp54', 'cp9', 'cp26', 'lp17', 'lp5']
# longread: UCT50H : len:18 : ['cp32-7', nan, 'cp32-4', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-13', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp9', 'cp26', 'lp17']
# shortread: UCT50 : len: 19['cp32-7', nan, 'cp32-4', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-13', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp9', 'cp26', 'lp17']
# longread: UCT92H : len:22 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp36', 'cp32-1', 'cp32-6', 'cp32-2', 'cp32-8', 'lp28-4', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: UCT92 : len: 27['lp28-5', 'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'lp21', 'cp32-8', 'cp32-2', 'cp32-6', 'lp28-3', 'cp32-12', 'cp32-11', 'lp28-11', 'lp38', 'lp54', 'lp28-6', 'cp9-3', 'lp17']
# longread: UCT96H : len:21 : ['cp32-7', 'lp28-5', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-6', 'lp28-4', 'cp32-8', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: UCT96 : len: 23['lp28-5', 'cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'cp32-6', 'cp32-8', 'lp28-6', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17', 'lp5']
# longread: UNY149P : len:19 : ['cp32-7', 'lp28-5', 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-6', 'cp32-2', 'lp28-4', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: UNY149 : len: 22['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'lp28-6', 'lp21', 'cp32-6', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp26']
# longread: UNY169P : len:17 : ['cp32-7', 'lp28-2', 'cp32-4', 'cp32-5', 'chromosome', 'cp32-9', 'lp25', 'cp32-10', 'lp36', 'lp28-4', 'lp28-3', 'cp32-12', 'lp38', 'cp9', 'lp54', 'cp26', 'lp17']
# shortread: UNY169 : len: 21['cp32-7', 'lp28-2', nan, 'cp32-4', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'lp28-3', 'cp32-12', 'lp38', 'lp54', 'cp9', 'lp28-6', 'lp17']
# longread: UNY172P : len:16 : ['cp32-7', 'lp28-2', 'cp32-4', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp28-3', 'cp32-12', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: UNY172 : len: 21['cp32-7', 'lp28-2', nan, 'cp32-4', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'cp32-6', 'cp32-8', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: UNY193P : len:19 : ['cp32-7', 'lp28-2', 'chromosome', 'cp26', 'cp32-13', 'lp25', 'cp32-10', 'lp36', 'cp32-6', 'lp28-4', 'lp28-8', 'lp28-3', 'cp32-12', 'lp54', 'cp9', 'lp28-6', 'lp17', 'lp5', 'lp28-7']
# shortread: UNY193 : len: 33['cp32-7', 'lp28-5', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'cp32-8', 'lp28-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'cp9-3', 'lp17', 'lp5', 'cp32-4', 'cp32-9', 'cp32-3', 'cp32-13', 'lp25', 'lp28-4', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'cp32-12', 'cp32-11', 'lp38', 'cp9', 'lp28-7']
# longread: UNY203P : len:17 : ['cp32-7', 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-10', 'lp36', 'cp32-6', 'lp28-8', 'lp28-3', 'cp32-12', 'cp9', 'lp54', 'lp28-6', 'lp17', 'lp5']
# shortread: UNY203 : len: 27['cp32-7', 'lp28-5', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-3', 'cp32-13', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'cp32-1+5', 'lp28-8', 'lp28-3', 'cp32-12', 'cp32-11', 'lp28-11', 'lp38', 'lp54', 'cp9', 'lp28-6', 'lp17', 'lp5']
# longread: UNY208P : len:18 : ['cp32-7', 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'cp32-8', 'lp28-3', 'cp32-12', 'cp32-11', 'lp54', 'lp28-6', 'lp17']
# shortread: UNY208 : len: 21['cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'cp32-2', 'cp32-8', 'lp28-6', 'lp28-3', 'cp32-12', 'cp32-11', 'lp54', 'cp26', 'cp32-9-4', 'lp17']
# longread: URI101H : len:23 : ['cp32-7', 'lp28-5', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp21', 'lp28-4', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI101 : len: 25['lp28-5', 'cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17']
# longread: URI102H : len:19 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'cp32-10', 'lp36', 'cp32-2', 'lp56', 'lp28-3', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI102 : len: 22['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'lp28-6', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: URI103H : len:19 : ['cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'cp32-2', 'lp28-4', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: URI103 : len: 24['lp28-5', 'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'lp21', 'cp32-6', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# longread: URI107H : len:20 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp28-4', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI107 : len: 21['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-6', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: URI111H : len:21 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp21', 'lp28-4', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI111 : len: 25['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-2', 'cp32-6', 'lp56', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17']
# longread: URI112H : len:22 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'cp32-2', 'cp32-8', 'lp28-4', 'lp21', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: URI112 : len: 24['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'cp32-2', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'cp9-3', 'lp17']
# longread: URI117H : len:22 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-6', 'lp28-4', 'cp32-2', 'lp21', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: URI117 : len: 22['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-6', 'cp32-2', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# longread: URI118H : len:20 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp36', 'cp32-6', 'cp32-2', 'cp32-8', 'lp28-6', 'lp28-4', 'lp28-3', 'cp32-11', 'cp32-12', 'lp54', 'cp26', 'lp17']
# shortread: URI118 : len: 21['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-6', 'cp32-2', 'lp21', 'lp28-3', 'cp32-11', 'cp32-12', 'lp54', 'lp28-6', 'lp17']
# longread: URI120H : len:25 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-1', 'cp32-6', 'cp32-8', 'lp21', 'lp28-4', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI120 : len: 26['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp9', 'cp26', 'cp9-3', 'lp17']
# longread: URI33H : len:18 : [nan, 'cp32-5', 'chromosome', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp21', 'cp32-8', 'lp28-4', 'lp28-8', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17', 'lp28-7']
# shortread: URI33 : len: 26['cp32-7', 'lp28-2', nan, 'cp32-4', 'cp32-5', 'chromosome', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'lp21', 'cp32-8', 'cp32-2', 'cp32-6', 'lp28-8', 'lp28-3', 'cp32-11', 'cp32-12', 'lp28-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'cp32-9-4', 'lp17', 'lp28-7']
# longread: URI34H : len:22 : ['lp28-5', 'cp32-7', 'lp28-2', nan, 'chromosome', 'cp26', 'cp32-9', 'cp32-13', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'cp32-2', 'lp28-8', 'lp28-3', 'cp32-12', 'lp54', 'cp9', 'lp28-6', 'lp17', 'lp5', 'lp28-7']
# shortread: URI34 : len: 26['cp32-7', 'lp28-5', 'lp28-2', nan, 'cp32-4', 'chromosome', 'cp26', 'cp32-9', 'cp32-13', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'cp32-8', 'cp32-2', 'lp28-8', 'lp28-3', 'lp56', 'cp32-12', 'lp54', 'cp9', 'lp28-6', 'lp17', 'lp5', 'lp28-7']
# longread: URI36H : len:23 : ['cp32-7', 'lp28-5', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-3', 'lp25', 'lp36', 'cp32-6', 'lp28-4', 'cp32-8', 'lp28-6', 'lp21', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp9', 'cp26', 'lp17']
# shortread: URI36 : len: 23['lp28-5', 'cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp9', 'lp28-6', 'lp17']
# longread: URI39H : len:23 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp21', 'cp32-8', 'lp28-4', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI39 : len: 27['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-1', 'lp28-4', 'cp32-8', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17']
# longread: URI40H : len:25 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp28-4', 'cp32-8', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'cp32-9-4', 'lp17']
# shortread: URI40 : len: 26['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'cp32-2', 'lp56', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp9', 'cp26', 'cp9-3', 'lp17']
# longread: URI41H : len:19 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp21', 'lp28-4', 'lp56', 'lp28-3', 'cp32-11', 'lp54', 'cp26']
# shortread: URI41 : len: 25['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'lp21', 'cp32-8', 'cp32-2', 'cp32-6', 'lp56', 'lp28-3', 'cp32-12', 'cp32-11', 'lp54', 'cp26', 'cp9-3', 'lp17']
# longread: URI42H : len:22 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'cp32-2', 'cp32-8', 'lp56', 'lp28-3', 'cp32-11', 'lp54', 'cp26', 'cp32-9-4', 'lp17']
# shortread: URI42 : len: 22['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-6', 'cp32-8', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp54', 'cp26', 'lp17']
# longread: URI44H : len:22 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-6', 'cp32-2', 'cp32-8', 'lp28-4', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: URI44 : len: 23['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'lp21', 'cp32-6', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# longread: URI46H : len:21 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-6', 'cp32-2', 'lp28-4', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: URI46 : len: 24['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'lp21', 'cp32-6', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'cp9-3', 'lp17']
# longread: URI47H : len:21 : ['cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp36', 'lp28-4', 'cp32-6', 'cp32-8', 'cp32-2', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp9', 'lp28-6', 'lp17']
# shortread: URI47 : len: 24['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'lp21', 'cp32-6', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp9', 'lp28-6', 'lp17']
# longread: URI48H : len:17 : [nan, 'cp32-5', 'chromosome', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'cp32-8', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17', 'lp28-7']
# shortread: URI48 : len: 25['lp28-5', 'cp32-7', 'lp28-2', nan, 'cp32-4', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'cp32-8', 'lp28-8', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17', 'lp28-7']
# longread: URI56H : len:19 : ['cp32-7', nan, 'cp32-5', 'chromosome', 'cp26', 'cp32-3', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'cp9-3', 'lp17']
# shortread: URI56 : len: 22['cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'cp9-3', 'lp17']
# longread: URI86H : len:19 : ['cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'cp32-6', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: URI86 : len: 22['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'lp25', 'lp36', 'lp28-4', 'cp32-6', 'cp32-8', 'cp32-2', 'lp21', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# longread: URI87H : len:22 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'cp32-10', 'lp36', 'cp32-6', 'lp28-4', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI87 : len: 23['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'cp32-6', 'cp32-8', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: URI88H : len:22 : ['cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-3', 'cp32-1', 'lp28-4', 'cp32-6', 'cp32-8', 'lp28-6', 'lp21', 'lp28-3', 'cp32-12', 'cp32-11', 'lp28-11', 'lp38', 'lp54', 'cp26', 'lp17', 'lp28-7']
# shortread: URI88 : len: 25['cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-3', 'lp36', 'cp32-1', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp28-11', 'lp38', 'lp54', 'lp28-6', 'cp9-3', 'lp17', 'lp28-7']
# longread: URI89H : len:23 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-6', 'lp28-4', 'cp32-8', 'lp21', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI89 : len: 27['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-10', 'lp28-4', 'cp32-8', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17']
# longread: URI91H : len:24 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-1', 'cp32-6', 'cp32-8', 'lp28-4', 'lp21', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI91 : len: 26['lp28-5', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-10', 'lp28-4', 'cp32-8', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: URI93H : len:19 : ['lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'cp32-10', 'lp36', 'lp28-4', 'cp32-2', 'lp21', 'lp28-3', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI93 : len: 22['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17']
# longread: UWI247P : len:17 : ['cp32-7', 'lp28-5', 'cp32-4', 'lp28-1', 'chromosome', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-6', 'lp28-4', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: UWI247 : len: 22['lp28-5', 'cp32-7', nan, 'cp32-4', 'lp28-1', 'chromosome', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-10', 'lp28-4', 'cp32-8', 'cp32-2', 'cp32-6', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: UWI248P : len:18 : ['cp32-7', 'lp28-5', 'cp32-4', 'lp28-1', 'chromosome', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-6', 'lp28-4', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: UWI248 : len: 21['lp28-5', 'cp32-7', nan, 'cp32-4', 'lp28-1', 'chromosome', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'cp32-6', 'cp32-1+5', 'cp32-2', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: UWI263P : len:19 : ['lp28-5', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'cp32-10', 'lp36', 'cp32-6', 'lp28-4', 'cp32-8', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp9', 'cp26', 'lp17']
# shortread: UWI263 : len: 26['lp28-5', 'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'cp32-5-1', 'lp36', 'cp32-1', 'cp32-10', 'lp28-4', 'cp32-8', 'cp32-6', 'cp32-2', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp9', 'cp26', 'lp17']
# longread: UWI283P : len:16 : ['lp28-5', 'lp28-2', 'cp32-4', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'lp28-3', 'cp32-12', 'lp54', 'cp26', 'lp17']
# shortread: UWI283 : len: 23['lp28-5', 'cp32-7', 'lp28-2', nan, 'cp32-4', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'cp32-8', 'cp32-1+5', 'lp56', 'lp28-3', 'cp32-12', 'cp32-11', 'lp54', 'lp28-6', 'lp17']
# val      chromosome  cp26  cp32-1  cp32-1+5  cp32-10  cp32-11  cp32-12  \
# key
# ESI26             1     1       1         0        0        0        1
# ESI26H            1     1       1         0        0        0        0
# UCT109            1     1       0         0        0        1        0
# UCT109H           1     1       0         0        1        0        0
# UCT110            1     1       0         0        0        1        1
# ...             ...   ...     ...       ...      ...      ...      ...
# UWI248P           1     1       1         0        0        1        1
# UWI263            1     1       1         0        1        1        1
# UWI263P           1     1       0         0        1        1        0
# UWI283            1     1       1         1        0        1        1
# UWI283P           1     1       1         0        0        0        1
#
# val      cp32-13  cp32-2  cp32-3  ...  lp28-6  lp28-7  lp28-8  lp28-9  lp36  \
# key                               ...
# ESI26          0       0       0  ...       0       1       0       1     1
# ESI26H         0       0       1  ...       0       0       0       1     1
# UCT109         0       1       1  ...       0       0       0       0     1
# UCT109H        0       0       1  ...       0       0       0       0     1
# UCT110         0       1       1  ...       1       0       0       0     1
# ...          ...     ...     ...  ...     ...     ...     ...     ...   ...
# UWI248P        0       0       1  ...       0       0       0       0     1
# UWI263         0       1       1  ...       0       0       0       0     1
# UWI263P        0       0       1  ...       0       0       0       0     1
# UWI283         0       0       1  ...       1       0       0       0     1
# UWI283P        0       0       1  ...       0       0       0       0     1
#
# val      lp38  lp5  lp54  lp56  Sum
# key
# ESI26       0    0     1     0   16
# ESI26H      0    0     1     0   15
# UCT109      1    0     1     1   21
# UCT109H     1    0     1     0   17
# UCT110      1    0     1     0   22
# ...       ...  ...   ...   ...  ...
# UWI248P     1    0     1     0   18
# UWI263      1    0     1     0   25
# UWI263P     1    0     1     0   19
# UWI283      0    0     1     1   22
# UWI283P     0    0     1     0   16
#
# [98 rows x 40 columns]
# longread: ESI26H : len:16 : [nan, 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp36', 'cp32-1', 'cp32-6', 'lp28-4', 'lp28-3', 'lp54', 'cp32-3+10', 'cp26', 'cp32-9-4', 'lp17', 'lp28-9']
# shortread: ESI26 : len: 17['lp28-2', nan, 'cp32-5', 'chromosome', 'cp32-9', 'lp28-7', 'lp36', 'cp32-1', 'cp32-6', 'cp32-8', 'lp28-3', 'cp32-12', 'lp54', 'cp32-3+10', 'cp26', 'lp17', 'lp28-9']
# longread: UCT109H : len:18 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'cp32-10', 'lp36', 'cp32-6', 'lp28-3', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: UCT109 : len: 22['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-6', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp9', 'cp26', 'lp17']
# longread: UCT110H : len:23 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-6', 'cp32-2', 'cp32-8', 'lp28-4', 'lp21', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: UCT110 : len: 23['lp28-5', 'cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'cp32-6', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# longread: UCT113H : len:19 : ['cp32-7', 'lp28-5', nan, 'cp32-4', 'lp28-1', 'chromosome', 'cp26', 'cp32-9', 'lp25', 'lp36', 'lp28-4', 'lp21', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: UCT113 : len: 25['lp28-5', 'cp32-7', nan, 'cp32-4', 'lp28-1', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'cp32-5-1', 'lp36', 'cp32-1', 'cp32-10', 'lp28-4', 'cp32-8', 'lp28-6', 'cp32-6', 'lp21', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: UCT29H : len:22 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'cp32-10', 'cp32-1', 'cp32-6', 'lp21', 'lp28-4', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp9', 'cp26', 'lp17']
# shortread: UCT29 : len: 27['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp9', 'cp26', 'cp9-3', 'cp32-9-4', 'lp17']
# longread: UCT30H : len:21 : ['lp28-5', 'cp32-7', nan, 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'lp28-6', 'cp32-6', 'cp32-2', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: UCT30 : len: 24['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-2', 'cp32-6', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'cp9-3', 'lp17']
# longread: UCT31H : len:22 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-1', 'cp32-6', 'lp21', 'lp28-4', 'lp28-3', 'cp32-11', 'lp54', 'cp9', 'cp26', 'lp17']
# shortread: UCT31 : len: 27['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-10', 'lp28-4', 'cp32-8', 'lp21', 'cp32-2', 'cp32-6', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp54', 'cp9', 'cp26', 'cp9-3', 'lp17']
# longread: UCT32H : len:21 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'cp32-2', 'cp32-8', 'lp28-4', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: UCT32 : len: 24['lp28-5', 'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'lp21', 'cp32-6', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# longread: UCT35H : len:17 : ['cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-3', 'cp32-13', 'cp32-10', 'lp28-4', 'lp28-8', 'cp32-12', 'lp54', 'cp9', 'cp26', 'lp17', 'lp5']
# shortread: UCT35 : len: 24['cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-3', 'cp32-13', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'cp32-8', 'lp28-8', 'lp28-3', 'cp32-12', 'cp32-11', 'lp28-11', 'lp54', 'cp9', 'cp26', 'lp17', 'lp5']
# longread: UCT50H : len:18 : ['cp32-7', nan, 'cp32-4', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-13', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp9', 'cp26', 'lp17']
# shortread: UCT50 : len: 19['cp32-7', nan, 'cp32-4', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-13', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp9', 'cp26', 'lp17']
# longread: UCT92H : len:22 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp36', 'cp32-1', 'cp32-6', 'cp32-2', 'cp32-8', 'lp28-4', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: UCT92 : len: 27['lp28-5', 'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'lp21', 'cp32-8', 'cp32-2', 'cp32-6', 'lp28-3', 'cp32-12', 'cp32-11', 'lp28-11', 'lp38', 'lp54', 'lp28-6', 'cp9-3', 'lp17']
# longread: UCT96H : len:21 : ['cp32-7', 'lp28-5', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-6', 'lp28-4', 'cp32-8', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: UCT96 : len: 23['lp28-5', 'cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'cp32-6', 'cp32-8', 'lp28-6', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17', 'lp5']
# longread: UNY149P : len:19 : ['cp32-7', 'lp28-5', 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-6', 'cp32-2', 'lp28-4', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: UNY149 : len: 22['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'lp28-6', 'lp21', 'cp32-6', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp26']
# longread: UNY169P : len:17 : ['cp32-7', 'lp28-2', 'cp32-4', 'cp32-5', 'chromosome', 'cp32-9', 'lp25', 'cp32-10', 'lp36', 'lp28-4', 'lp28-3', 'cp32-12', 'lp38', 'cp9', 'lp54', 'cp26', 'lp17']
# shortread: UNY169 : len: 21['cp32-7', 'lp28-2', nan, 'cp32-4', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'lp28-3', 'cp32-12', 'lp38', 'lp54', 'cp9', 'lp28-6', 'lp17']
# longread: UNY172P : len:16 : ['cp32-7', 'lp28-2', 'cp32-4', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp28-3', 'cp32-12', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: UNY172 : len: 21['cp32-7', 'lp28-2', nan, 'cp32-4', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'cp32-6', 'cp32-8', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: UNY193P : len:19 : ['cp32-7', 'lp28-2', 'chromosome', 'cp26', 'cp32-13', 'lp25', 'cp32-10', 'lp36', 'cp32-6', 'lp28-4', 'lp28-8', 'lp28-3', 'cp32-12', 'lp54', 'cp9', 'lp28-6', 'lp17', 'lp5', 'lp28-7']
# shortread: UNY193 : len: 33['cp32-7', 'lp28-5', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'lp36', 'cp32-10', 'cp32-8', 'lp28-8', 'lp28-3', 'lp54', 'lp28-6', 'cp26', 'cp9-3', 'lp17', 'lp5', 'cp32-4', 'cp32-9', 'cp32-3', 'cp32-13', 'lp25', 'lp28-4', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'cp32-12', 'cp32-11', 'lp38', 'cp9', 'lp28-7']
# longread: UNY203P : len:17 : ['cp32-7', 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-10', 'lp36', 'cp32-6', 'lp28-8', 'lp28-3', 'cp32-12', 'cp9', 'lp54', 'lp28-6', 'lp17', 'lp5']
# shortread: UNY203 : len: 27['cp32-7', 'lp28-5', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-3', 'cp32-13', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'cp32-1+5', 'lp28-8', 'lp28-3', 'cp32-12', 'cp32-11', 'lp28-11', 'lp38', 'lp54', 'cp9', 'lp28-6', 'lp17', 'lp5']
# longread: UNY208P : len:18 : ['cp32-7', 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'cp32-8', 'lp28-3', 'cp32-12', 'cp32-11', 'lp54', 'lp28-6', 'lp17']
# shortread: UNY208 : len: 21['cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'cp32-2', 'cp32-8', 'lp28-6', 'lp28-3', 'cp32-12', 'cp32-11', 'lp54', 'cp26', 'cp32-9-4', 'lp17']
# longread: URI101H : len:23 : ['cp32-7', 'lp28-5', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp21', 'lp28-4', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI101 : len: 25['lp28-5', 'cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17']
# longread: URI102H : len:19 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'cp32-10', 'lp36', 'cp32-2', 'lp56', 'lp28-3', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI102 : len: 22['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'lp28-6', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: URI103H : len:19 : ['cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'cp32-2', 'lp28-4', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: URI103 : len: 24['lp28-5', 'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'lp21', 'cp32-6', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# longread: URI107H : len:20 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp28-4', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI107 : len: 21['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-6', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: URI111H : len:21 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp21', 'lp28-4', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI111 : len: 25['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-2', 'cp32-6', 'lp56', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17']
# longread: URI112H : len:22 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'cp32-2', 'cp32-8', 'lp28-4', 'lp21', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: URI112 : len: 24['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'cp32-2', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'cp9-3', 'lp17']
# longread: URI117H : len:22 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-6', 'lp28-4', 'cp32-2', 'lp21', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: URI117 : len: 22['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-6', 'cp32-2', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# longread: URI118H : len:20 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp36', 'cp32-6', 'cp32-2', 'cp32-8', 'lp28-6', 'lp28-4', 'lp28-3', 'cp32-11', 'cp32-12', 'lp54', 'cp26', 'lp17']
# shortread: URI118 : len: 21['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-6', 'cp32-2', 'lp21', 'lp28-3', 'cp32-11', 'cp32-12', 'lp54', 'lp28-6', 'lp17']
# longread: URI120H : len:25 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-1', 'cp32-6', 'cp32-8', 'lp21', 'lp28-4', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI120 : len: 26['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp9', 'cp26', 'cp9-3', 'lp17']
# longread: URI33H : len:18 : [nan, 'cp32-5', 'chromosome', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp21', 'cp32-8', 'lp28-4', 'lp28-8', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17', 'lp28-7']
# shortread: URI33 : len: 26['cp32-7', 'lp28-2', nan, 'cp32-4', 'cp32-5', 'chromosome', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'lp21', 'cp32-8', 'cp32-2', 'cp32-6', 'lp28-8', 'lp28-3', 'cp32-11', 'cp32-12', 'lp28-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'cp32-9-4', 'lp17', 'lp28-7']
# longread: URI34H : len:22 : ['lp28-5', 'cp32-7', 'lp28-2', nan, 'chromosome', 'cp26', 'cp32-9', 'cp32-13', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'cp32-2', 'lp28-8', 'lp28-3', 'cp32-12', 'lp54', 'cp9', 'lp28-6', 'lp17', 'lp5', 'lp28-7']
# shortread: URI34 : len: 26['cp32-7', 'lp28-5', 'lp28-2', nan, 'cp32-4', 'chromosome', 'cp26', 'cp32-9', 'cp32-13', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'cp32-8', 'cp32-2', 'lp28-8', 'lp28-3', 'lp56', 'cp32-12', 'lp54', 'cp9', 'lp28-6', 'lp17', 'lp5', 'lp28-7']
# longread: URI36H : len:23 : ['cp32-7', 'lp28-5', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-3', 'lp25', 'lp36', 'cp32-6', 'lp28-4', 'cp32-8', 'lp28-6', 'lp21', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp9', 'cp26', 'lp17']
# shortread: URI36 : len: 23['lp28-5', 'cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp9', 'lp28-6', 'lp17']
# longread: URI39H : len:23 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp21', 'cp32-8', 'lp28-4', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI39 : len: 27['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-1', 'lp28-4', 'cp32-8', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17']
# longread: URI40H : len:25 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp28-4', 'cp32-8', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'cp32-9-4', 'lp17']
# shortread: URI40 : len: 26['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'cp32-2', 'lp56', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp9', 'cp26', 'cp9-3', 'lp17']
# longread: URI41H : len:19 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp21', 'lp28-4', 'lp56', 'lp28-3', 'cp32-11', 'lp54', 'cp26']
# shortread: URI41 : len: 25['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'lp21', 'cp32-8', 'cp32-2', 'cp32-6', 'lp56', 'lp28-3', 'cp32-12', 'cp32-11', 'lp54', 'cp26', 'cp9-3', 'lp17']
# longread: URI42H : len:22 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'cp32-2', 'cp32-8', 'lp56', 'lp28-3', 'cp32-11', 'lp54', 'cp26', 'cp32-9-4', 'lp17']
# shortread: URI42 : len: 22['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-6', 'cp32-8', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp54', 'cp26', 'lp17']
# longread: URI44H : len:22 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-6', 'cp32-2', 'cp32-8', 'lp28-4', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: URI44 : len: 23['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'lp21', 'cp32-6', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# longread: URI46H : len:21 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-6', 'cp32-2', 'lp28-4', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: URI46 : len: 24['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'lp21', 'cp32-6', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'cp9-3', 'lp17']
# longread: URI47H : len:21 : ['cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp36', 'lp28-4', 'cp32-6', 'cp32-8', 'cp32-2', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp9', 'lp28-6', 'lp17']
# shortread: URI47 : len: 24['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'lp21', 'cp32-6', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp9', 'lp28-6', 'lp17']
# longread: URI48H : len:17 : [nan, 'cp32-5', 'chromosome', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'cp32-8', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17', 'lp28-7']
# shortread: URI48 : len: 25['lp28-5', 'cp32-7', 'lp28-2', nan, 'cp32-4', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'cp32-8', 'lp28-8', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17', 'lp28-7']
# longread: URI56H : len:19 : ['cp32-7', nan, 'cp32-5', 'chromosome', 'cp26', 'cp32-3', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'cp9-3', 'lp17']
# shortread: URI56 : len: 22['cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'cp9-3', 'lp17']
# longread: URI86H : len:19 : ['cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'cp32-6', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: URI86 : len: 22['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'lp25', 'lp36', 'lp28-4', 'cp32-6', 'cp32-8', 'cp32-2', 'lp21', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# longread: URI87H : len:22 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'cp32-10', 'lp36', 'cp32-6', 'lp28-4', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI87 : len: 23['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'cp32-6', 'cp32-8', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: URI88H : len:22 : ['cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-3', 'cp32-1', 'lp28-4', 'cp32-6', 'cp32-8', 'lp28-6', 'lp21', 'lp28-3', 'cp32-12', 'cp32-11', 'lp28-11', 'lp38', 'lp54', 'cp26', 'lp17', 'lp28-7']
# shortread: URI88 : len: 25['cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-3', 'lp36', 'cp32-1', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp28-11', 'lp38', 'lp54', 'lp28-6', 'cp9-3', 'lp17', 'lp28-7']
# longread: URI89H : len:23 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-6', 'lp28-4', 'cp32-8', 'lp21', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI89 : len: 27['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-10', 'lp28-4', 'cp32-8', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17']
# longread: URI91H : len:24 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-1', 'cp32-6', 'cp32-8', 'lp28-4', 'lp21', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI91 : len: 26['lp28-5', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-10', 'lp28-4', 'cp32-8', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: URI93H : len:19 : ['lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'cp32-10', 'lp36', 'lp28-4', 'cp32-2', 'lp21', 'lp28-3', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI93 : len: 22['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17']
# longread: UWI247P : len:17 : ['cp32-7', 'lp28-5', 'cp32-4', 'lp28-1', 'chromosome', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-6', 'lp28-4', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: UWI247 : len: 22['lp28-5', 'cp32-7', nan, 'cp32-4', 'lp28-1', 'chromosome', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-10', 'lp28-4', 'cp32-8', 'cp32-2', 'cp32-6', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: UWI248P : len:18 : ['cp32-7', 'lp28-5', 'cp32-4', 'lp28-1', 'chromosome', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-6', 'lp28-4', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: UWI248 : len: 21['lp28-5', 'cp32-7', nan, 'cp32-4', 'lp28-1', 'chromosome', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'cp32-6', 'cp32-1+5', 'cp32-2', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# ...
# longread: URI107H : len:20 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp28-4', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI107 : len: 21['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-6', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: URI111H : len:21 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp21', 'lp28-4', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI111 : len: 25['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-2', 'cp32-6', 'lp56', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17']
# longread: URI112H : len:22 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'cp32-6', 'cp32-2', 'cp32-8', 'lp28-4', 'lp21', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: URI112 : len: 24['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'cp32-2', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'cp9-3', 'lp17']
# longread: URI117H : len:22 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-6', 'lp28-4', 'cp32-2', 'lp21', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: URI117 : len: 22['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-6', 'cp32-2', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# longread: URI118H : len:20 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp36', 'cp32-6', 'cp32-2', 'cp32-8', 'lp28-6', 'lp28-4', 'lp28-3', 'cp32-11', 'cp32-12', 'lp54', 'cp26', 'lp17']
# shortread: URI118 : len: 21['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-6', 'cp32-2', 'lp21', 'lp28-3', 'cp32-11', 'cp32-12', 'lp54', 'lp28-6', 'lp17']
# longread: URI120H : len:25 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-1', 'cp32-6', 'cp32-8', 'lp21', 'lp28-4', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI120 : len: 26['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp9', 'cp26', 'cp9-3', 'lp17']
# longread: URI33H : len:18 : [nan, 'cp32-5', 'chromosome', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp21', 'cp32-8', 'lp28-4', 'lp28-8', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17', 'lp28-7']
# shortread: URI33 : len: 26['cp32-7', 'lp28-2', nan, 'cp32-4', 'cp32-5', 'chromosome', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'lp21', 'cp32-8', 'cp32-2', 'cp32-6', 'lp28-8', 'lp28-3', 'cp32-11', 'cp32-12', 'lp28-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'cp32-9-4', 'lp17', 'lp28-7']
# longread: URI34H : len:22 : ['lp28-5', 'cp32-7', 'lp28-2', nan, 'chromosome', 'cp26', 'cp32-9', 'cp32-13', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'cp32-2', 'lp28-8', 'lp28-3', 'cp32-12', 'lp54', 'cp9', 'lp28-6', 'lp17', 'lp5', 'lp28-7']
# shortread: URI34 : len: 26['cp32-7', 'lp28-5', 'lp28-2', nan, 'cp32-4', 'chromosome', 'cp26', 'cp32-9', 'cp32-13', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'cp32-8', 'cp32-2', 'lp28-8', 'lp28-3', 'lp56', 'cp32-12', 'lp54', 'cp9', 'lp28-6', 'lp17', 'lp5', 'lp28-7']
# longread: URI36H : len:23 : ['cp32-7', 'lp28-5', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-3', 'lp25', 'lp36', 'cp32-6', 'lp28-4', 'cp32-8', 'lp28-6', 'lp21', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp9', 'cp26', 'lp17']
# shortread: URI36 : len: 23['lp28-5', 'cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp9', 'lp28-6', 'lp17']
# longread: URI39H : len:23 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp21', 'cp32-8', 'lp28-4', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI39 : len: 27['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-1', 'lp28-4', 'cp32-8', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17']
# longread: URI40H : len:25 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp28-4', 'cp32-8', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'cp32-9-4', 'lp17']
# shortread: URI40 : len: 26['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'cp32-2', 'lp56', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp9', 'cp26', 'cp9-3', 'lp17']
# longread: URI41H : len:19 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'lp21', 'lp28-4', 'lp56', 'lp28-3', 'cp32-11', 'lp54', 'cp26']
# shortread: URI41 : len: 25['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'lp21', 'cp32-8', 'cp32-2', 'cp32-6', 'lp56', 'lp28-3', 'cp32-12', 'cp32-11', 'lp54', 'cp26', 'cp9-3', 'lp17']
# longread: URI42H : len:22 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-6', 'cp32-2', 'cp32-8', 'lp56', 'lp28-3', 'cp32-11', 'lp54', 'cp26', 'cp32-9-4', 'lp17']
# shortread: URI42 : len: 22['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-6', 'cp32-8', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp54', 'cp26', 'lp17']
# longread: URI44H : len:22 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-6', 'cp32-2', 'cp32-8', 'lp28-4', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: URI44 : len: 23['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'lp21', 'cp32-6', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# longread: URI46H : len:21 : ['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-6', 'cp32-2', 'lp28-4', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: URI46 : len: 24['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'lp21', 'cp32-6', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'cp9-3', 'lp17']
# longread: URI47H : len:21 : ['cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp36', 'lp28-4', 'cp32-6', 'cp32-8', 'cp32-2', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp9', 'lp28-6', 'lp17']
# shortread: URI47 : len: 24['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'lp21', 'cp32-6', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp9', 'lp28-6', 'lp17']
# longread: URI48H : len:17 : [nan, 'cp32-5', 'chromosome', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'cp32-8', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17', 'lp28-7']
# shortread: URI48 : len: 25['lp28-5', 'cp32-7', 'lp28-2', nan, 'cp32-4', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'lp28-4', 'cp32-6', 'cp32-8', 'lp28-8', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17', 'lp28-7']
# longread: URI56H : len:19 : ['cp32-7', nan, 'cp32-5', 'chromosome', 'cp26', 'cp32-3', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'cp9-3', 'lp17']
# shortread: URI56 : len: 22['cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'lp28-6', 'cp9-3', 'lp17']
# longread: URI86H : len:19 : ['cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'lp25', 'lp36', 'lp28-4', 'cp32-2', 'cp32-8', 'cp32-6', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# shortread: URI86 : len: 22['lp28-5', 'cp32-7', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'lp25', 'lp36', 'lp28-4', 'cp32-6', 'cp32-8', 'cp32-2', 'lp21', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'lp28-6', 'lp17']
# longread: URI87H : len:22 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'cp32-10', 'lp36', 'cp32-6', 'lp28-4', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI87 : len: 23['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'cp32-6', 'cp32-8', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: URI88H : len:22 : ['cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-3', 'cp32-1', 'lp28-4', 'cp32-6', 'cp32-8', 'lp28-6', 'lp21', 'lp28-3', 'cp32-12', 'cp32-11', 'lp28-11', 'lp38', 'lp54', 'cp26', 'lp17', 'lp28-7']
# shortread: URI88 : len: 25['cp32-7', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp26', 'cp32-3', 'lp36', 'cp32-1', 'lp28-4', 'lp21', 'cp32-8', 'cp32-6', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp28-11', 'lp38', 'lp54', 'lp28-6', 'cp9-3', 'lp17', 'lp28-7']
# longread: URI89H : len:23 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-6', 'lp28-4', 'cp32-8', 'lp21', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI89 : len: 27['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-10', 'lp28-4', 'cp32-8', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17']
# longread: URI91H : len:24 : ['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-10', 'cp32-1', 'cp32-6', 'cp32-8', 'lp28-4', 'lp21', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI91 : len: 26['lp28-5', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-10', 'lp28-4', 'cp32-8', 'lp21', 'cp32-6', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'cp32-12', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: URI93H : len:19 : ['lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'cp32-10', 'lp36', 'lp28-4', 'cp32-2', 'lp21', 'lp28-3', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: URI93 : len: 22['cp32-7', 'lp28-2', nan, 'cp32-4', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'lp28-4', 'lp21', 'cp32-2', 'lp56', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'cp9-3', 'lp17']
# longread: UWI247P : len:17 : ['cp32-7', 'lp28-5', 'cp32-4', 'lp28-1', 'chromosome', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-6', 'lp28-4', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: UWI247 : len: 22['lp28-5', 'cp32-7', nan, 'cp32-4', 'lp28-1', 'chromosome', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-10', 'lp28-4', 'cp32-8', 'cp32-2', 'cp32-6', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: UWI248P : len:18 : ['cp32-7', 'lp28-5', 'cp32-4', 'lp28-1', 'chromosome', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'cp32-6', 'lp28-4', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# shortread: UWI248 : len: 21['lp28-5', 'cp32-7', nan, 'cp32-4', 'lp28-1', 'chromosome', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'cp32-6', 'cp32-1+5', 'cp32-2', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp26', 'lp17']
# longread: UWI263P : len:19 : ['lp28-5', 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'cp32-10', 'lp36', 'cp32-6', 'lp28-4', 'cp32-8', 'lp28-3', 'cp32-11', 'lp38', 'lp54', 'cp9', 'cp26', 'lp17']
# shortread: UWI263 : len: 26['lp28-5', 'cp32-7', 'lp28-2', nan, 'lp28-1', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'cp32-5-1', 'lp36', 'cp32-1', 'cp32-10', 'lp28-4', 'cp32-8', 'cp32-6', 'cp32-2', 'lp28-3', 'cp32-12', 'cp32-11', 'lp38', 'lp54', 'cp9', 'cp26', 'lp17']
# longread: UWI283P : len:16 : ['lp28-5', 'lp28-2', 'cp32-4', 'cp32-5', 'chromosome', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'lp28-3', 'cp32-12', 'lp54', 'cp26', 'lp17']
# shortread: UWI283 : len: 23['lp28-5', 'cp32-7', 'lp28-2', nan, 'cp32-4', 'cp32-5', 'chromosome', 'cp26', 'cp32-9', 'cp32-3', 'lp25', 'lp36', 'cp32-1', 'lp28-4', 'cp32-8', 'cp32-1+5', 'lp56', 'lp28-3', 'cp32-12', 'cp32-11', 'lp54', 'lp28-6', 'lp17']
# val      chromosome  cp26  cp32-1  cp32-1+5  cp32-10  cp32-11  cp32-12  \
# key
# ESI26             1     1       1         0        0        0        1
# ESI26H            1     1       1         0        0        0        0
# UCT109            1     1       0         0        0        1        0
# UCT109H           1     1       0         0        1        0        0
# UCT110            1     1       0         0        0        1        1
# ...             ...   ...     ...       ...      ...      ...      ...
# UWI248P           1     1       1         0        0        1        1
# UWI263            1     1       1         0        1        1        1
# UWI263P           1     1       0         0        1        1        0
# UWI283            1     1       1         1        0        1        1
# UWI283P           1     1       1         0        0        0        1
#
# val      cp32-13  cp32-2  cp32-3  ...  lp28-6  lp28-7  lp28-8  lp28-9  lp36  \
# key                               ...
# ESI26          0       0       0  ...       0       1       0       1     1
# ESI26H         0       0       1  ...       0       0       0       1     1
# UCT109         0       1       1  ...       0       0       0       0     1
# UCT109H        0       0       1  ...       0       0       0       0     1
# UCT110         0       1       1  ...       1       0       0       0     1
# ...          ...     ...     ...  ...     ...     ...     ...     ...   ...
# UWI248P        0       0       1  ...       0       0       0       0     1
# UWI263         0       1       1  ...       0       0       0       0     1
# UWI263P        0       0       1  ...       0       0       0       0     1
# UWI283         0       0       1  ...       1       0       0       0     1
# UWI283P        0       0       1  ...       0       0       0       0     1
#
# val      lp38  lp5  lp54  lp56  Sum
# key
# ESI26       0    0     1     0   16
# ESI26H      0    0     1     0   15
# UCT109      1    0     1     1   21
# UCT109H     1    0     1     0   17
# UCT110      1    0     1     0   22
# ...       ...  ...   ...   ...  ...
# UWI248P     1    0     1     0   18
# UWI263      1    0     1     0   25
# UWI263P     1    0     1     0   19
# UWI283      0    0     1     1   22
# UWI283P     0    0     1     0   16
#
# [98 rows x 40 columns]
