# %%
import os
import glob
import pandas
import tempfile
from pathlib import Path
from Bio import SeqIO
from collections import defaultdict
from pygenomeviz import GenomeViz
from pygenomeviz.parser import Genbank
from pygenomeviz.align import AlignCoord
from pygenomeviz.utils import ColorCycler

# %%
# Lets start with some functions to process the contig, this will come from iterating through the align_coords.tsv dataframe
# and grouping by contig_id.

def process_assembly(homologies_file, syntenies_file, reference_gb, assembly_gb, output_dir, **kwargs):
    # process the alignments and spit out a plot for each contig :)
    gbk_assembly = list(SeqIO.parse(open(assembly_gb, 'r'), 'genbank'))
    gbk_reference = list(SeqIO.parse(open(reference_gb, 'r'), 'genbank'))
    assembly_id = Path(assembly_gb).stem
    reference_id = '.'.join(os.path.basename(reference_gb).split('.')[:-1])

    output_path = os.path.join(output_dir, assembly_id)
    png_path = os.path.join(output_path, 'png')
    html_path = os.path.join(output_path, 'html')

    check_n_make(output_path)
    check_n_make(png_path)
    check_n_make(html_path)

    homologies = pandas.read_csv(homologies_file, sep='\t')
    syntenies = pandas.read_csv(syntenies_file, sep = '\t')

    grouped_homologies = homologies.groupby('REF_NAME', ) # THIS WILL REQUIRE CHANGING IN THE FUTURE {{TO-DO: FIX FOR NON B31 CASE}}
    grouped_syntenies  = syntenies.groupby('REF_NAME', ) # THIS WILL REQUIRE CHANGING IN THE FUTURE {{TO-DO: FIX FOR NON B31 CASE}}

    for contig_id, contig_df in grouped_homologies:
        num_homologies = len(contig_df)
        if check_group_exists(grouped_syntenies, contig_id):
            num_syntenies = len(grouped_syntenies.get_group(contig_id))
        else:
            num_syntenies = 0
        print(f'Processing {contig_id}: homologies:{num_homologies}, syntenies:{num_syntenies}')
        if num_syntenies > 0:
            process_and_plot(contig_id, contig_df, grouped_syntenies, gbk_assembly, gbk_reference, assembly_id, reference_id, output_path)
        else:
            print(f"\tError plotting {contig_id}! No syntenies! Attempting to only plot homology!\n")
            process_and_plot(contig_id, contig_df, grouped_syntenies, gbk_assembly, gbk_reference, assembly_id, reference_id, output_path, homology_only=True)
    print(f"Finished plotting contigs for {assembly_id}! Have a wonderful day :)")

def process_and_plot(contig_id, contig_df, grouped_syntenies, gbk_assembly, gbk_reference, assembly_id, reference_id, output_path, **kwargs):
    # Process contig alignments for homology and synteny
    homology_only = kwargs.get('homology_only', False)
    # ok now let's parse this out,
    ref_homology_ids, homology_coords = process_contig_alignments(contig_df)
    if homology_only:
        reference_ids = ref_homology_ids
    else:
        ref_synteny_ids, synteny_coords = process_contig_alignments(grouped_syntenies.get_group(contig_id))
        reference_ids = ref_homology_ids.union(ref_synteny_ids)

    # Parse GenBank files for assembly and reference
    gbks = []
    gbk_asm = parse_split_genbank(gbk_assembly, contig_id, assembly_id)
    gbks.append(gbk_asm)
    gbk_ref = parse_split_genbank(gbk_reference, reference_ids, reference_id)
    gbks.append(gbk_ref)

    # Initialize GenomeViz
    gv = GenomeViz(track_align_type="center")
    gv.set_scale_bar()
    # Add tracks for each GenBank file
    track_number = 0
    for gbk in gbks:
        if track_number == 0:
            sublabel_pos = "top-center"
        else:
            sublabel_pos = "bottom-center"
        color = ColorCycler()
        #print(gbk.name)
        track = gv.add_feature_track(gbk.name, gbk.get_seqid2size(), space=0.05, label_kws=dict(color=color), align_label=False)
        for seqid, features in gbk.get_seqid2features(feature_type="CDS").items():
            segment = track.get_segment(seqid)

            segment.add_sublabel(f"{segment.name}: {segment.start:,}-{segment.end:,}bp", size = 8, pos = sublabel_pos, ymargin=0.3)
            for feature in features:
                segment.add_features(feature, fc="blue", lw=0.077, ignore_outside_range = True, plotstyle="arrow")

        track_number += 1
    # Add homology and synteny links
    if len(homology_coords) > 0:
        min_ident = int(min([ac.identity for ac in homology_coords if ac.identity]))
        color, inverted_color = "grey", "red"
        for ac in homology_coords:
            gv.add_link(ac.query_link, ac.ref_link, color=color, inverted_color=inverted_color, filter_length=250, curve=True, v=ac.identity, vmin=min_ident)
        gv.set_colorbar([color, inverted_color], vmin=min_ident, bar_label="Identity")
    if not homology_only:
        color, inverted_color = "blue", "purple"
        for sc in synteny_coords:
            gv.add_link(sc.query_link, sc.ref_link, color=color, inverted_color=inverted_color, curve=True)

    # Save the plot as PNG and HTML
    output_png = os.path.join(output_path, 'png', f'{contig_id}_synteny_plot.png')
    output_html = os.path.join(output_path, 'html', f'{contig_id}_synteny_plot.html')
    gv.savefig(output_png)
    gv.savefig_html(output_html)
    print(f'Finished plotting {contig_id}\n')

def process_contig_alignments(contig_df):
    #keys = ['QUERY_ID', 'QUERY_NAME', 'QUERY_START', 'QUERY_END', 'QUERY_LENGTH',
    #   'REF_ID', 'REF_NAME', 'REF_START', 'REF_END', 'REF_LENGTH', 'IDENTITY',
    #   'EVALUE']
    reference_ids = set()
    acs = []
    for index, row in contig_df.iterrows():
        row_dict = {k:v for k,v in row.items()}
        reference_ids.add(row_dict['QUERY_NAME']) # change this to query_id for all_v_all ? doesn't matter for B31
        acs.append(
            AlignCoord(
                row_dict['QUERY_ID'],
                row_dict['QUERY_NAME'],
                row_dict['QUERY_START'],
                row_dict['QUERY_END'],
                row_dict['REF_ID'],
                row_dict['REF_NAME'],
                row_dict['REF_START'],
                row_dict['REF_END'],
                row_dict['IDENTITY'],
            )
        )
    return reference_ids, acs

def parse_genbanks_for_contig(reference_ids):
    files = []
    for genbank_id in reference_ids:
        genbank_file = get_genbank_file(genbank_id)
        files.append(genbank_file)
    combined_temp_file = concatenate_genbank_files(files)
    gbk_ref = Genbank(combined_temp_file)
    return gbk_ref

def parse_split_genbank(records, record_ids, temp_file_name):
    temp_dir = tempfile.gettempdir()
    temp_file_path = os.path.join(temp_dir, temp_file_name)
    filtered_records = [record for record in records if record.id in record_ids]
    with open(temp_file_path, 'w') as outfile:
        SeqIO.write(filtered_records, outfile, 'genbank')
    gbk_ref = Genbank(temp_file_path, name=temp_file_name)
    return gbk_ref

def check_group_exists(grouped_df, group_name):
    return group_name in grouped_df.groups

def check_n_make(path):
    if not os.path.exists(path):
        os.makedirs(path)

def concatenate_genbank_files(file_list):
    # Create a temporary file
    temp_file = tempfile.NamedTemporaryFile(delete=False, mode='w', suffix='.gb')

    with open(temp_file.name, 'w') as outfile:
        for file_name in file_list:
            with open(file_name, 'r') as infile:
                records = SeqIO.parse(infile, 'genbank')
                SeqIO.write(records, outfile, 'genbank')
    # Return the name of the temporary file
    return temp_file.name

def get_genbank_file(genbank_id, where_to_look):
    file_path = os.path.join(where_to_look, f'{genbank_id}.gbff')
    if os.path.exists(file_path):
        return genbank_file
    else:
        raise FileNotFoundError(f"The file at path '{file_path}' does not exist.")

def make_track_from_gb(gv, track_id, lens, features):
    track = gv.add_feature_track(track_id, lens)
    track.add_sublabel()
    track.add_features(features)
    return track

# %%
cwd = os.getcwd()
test_output_dir = os.path.join(cwd,'script_testing_output')

# %%
assembly_genbanks_dir = '/home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation'
assembly_genbanks = glob.glob(f'{assembly_genbanks_dir}/**/*.gbff', recursive=True)

# %%
test_homology_file = 'asms_vs_B31_v2/ESI26H/align_coords.tsv'
test_homology = pandas.read_csv(test_homology_file, sep = '\t', )
test_homology = test_homology.drop(['EVALUE'], axis=1)

test_synteny_file = 'asms_vs_B31_prot/ESI26H/align_coords.tsv'
test_synteny = pandas.read_csv(test_synteny_file, sep = '\t', )
test_synteny = test_synteny.drop(['EVALUE'], axis=1)

test_assembly_genbank = '/home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/ESI26H/ESI26H.gbff'
b31_genbank = 'renamed_GCF_000008685.2.gbff'

# %%
fig = process_assembly(test_homology_file, test_synteny_file,
                       b31_genbank, test_assembly_genbank, test_output_dir)
# Out:
# Processing contig000001: homologies:3, syntenies:746
# Finished plotting contig000001
#
# Processing contig000002: homologies:12, syntenies:54
# Finished plotting contig000002
#
# Processing contig000003: homologies:15, syntenies:31
# Finished plotting contig000003
#
# Processing contig000004: homologies:2, syntenies:26
# Finished plotting contig000004
#
# Processing contig000005: homologies:3, syntenies:29
# Finished plotting contig000005
#
# Processing contig000006: homologies:1, syntenies:1
# Finished plotting contig000006
#
# Processing contig000007: homologies:6, syntenies:9
# Finished plotting contig000007
#
# Processing contig000008: homologies:7, syntenies:14
# Finished plotting contig000008
#
# Processing contig000009: homologies:3, syntenies:23
# Finished plotting contig000009
#
# Processing contig000010: homologies:7, syntenies:13
# Finished plotting contig000010
#
# Processing contig000011: homologies:2, syntenies:18
# Finished plotting contig000011
#
# Processing contig000012: homologies:4, syntenies:8
# Finished plotting contig000012
#
# Processing contig000013: homologies:1, syntenies:1
# Finished plotting contig000013
#
# Processing contig000016: homologies:1, syntenies:0
# 	Error plotting contig000016! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000016
#
# Processing contig000019: homologies:1, syntenies:1
# Finished plotting contig000019
#
# Processing contig000020: homologies:1, syntenies:0
# 	Error plotting contig000020! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000020
#
# Processing contig000029: homologies:1, syntenies:0
# 	Error plotting contig000029! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000029
#
# Processing contig000033: homologies:1, syntenies:0
# 	Error plotting contig000033! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000033
#
# Processing contig000040: homologies:1, syntenies:0
# 	Error plotting contig000040! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000040
#
# Processing contig000041: homologies:1, syntenies:0
# 	Error plotting contig000041! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000041
#
# Processing contig000044: homologies:1, syntenies:0
# 	Error plotting contig000044! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000044
#
# Processing contig000051: homologies:1, syntenies:0
# 	Error plotting contig000051! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000051
#
# Processing contig000055: homologies:1, syntenies:0
# 	Error plotting contig000055! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000055
#
# Processing contig000062: homologies:1, syntenies:0
# 	Error plotting contig000062! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000062
#
# Finished plotting contigs for ESI26H! Have a wonderful day :)

# %%
assembly_genbanks_dir = '/home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation'
assembly_genbanks = glob.glob(f'{assembly_genbanks_dir}/**/*.gbff', recursive=True)
b31_genbank = 'renamed_GCF_000008685.2.gbff'

# %%
for assembly in assembly_genbanks:
    asm_id = Path(assembly).stem
    print(asm_id)
    homologies = f'asms_vs_B31_v2/{asm_id}/align_coords.tsv'
    syntenies = f'asms_vs_B31_prot/{asm_id}/align_coords.tsv'
    print(os.path.exists(homologies))
    print(os.path.exists(syntenies))
    cwd = os.getcwd()
    output_dir = os.path.join(cwd, 'asm_v_b31_subplots')
    print(output_dir)
    process_assembly(homologies, syntenies,
                       b31_genbank, assembly, output_dir)
# Out:
# URI87H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/URI87H
# Processing contig000001: homologies:3, syntenies:746
# Finished plotting contig000001
#
# Processing contig000002: homologies:1, syntenies:53
# Finished plotting contig000002
#
# Processing contig000003: homologies:1, syntenies:23
# Finished plotting contig000003
#
# Processing contig000004: homologies:1, syntenies:24
# Finished plotting contig000004
#
# Processing contig000005: homologies:2, syntenies:22
# Finished plotting contig000005
#
# Processing contig000006: homologies:1, syntenies:9
# Finished plotting contig000006
#
# Processing contig000007: homologies:1, syntenies:14
# Finished plotting contig000007
#
# Processing contig000008: homologies:3, syntenies:13
# Finished plotting contig000008
#
# Processing contig000009: homologies:3, syntenies:26
# Finished plotting contig000009
#
# Processing contig000010: homologies:2, syntenies:31
# Finished plotting contig000010
#
# Processing contig000011: homologies:2, syntenies:39
# Finished plotting contig000011
#
# Processing contig000012: homologies:2, syntenies:39
# Finished plotting contig000012
#
# Processing contig000013: homologies:2, syntenies:34
# Finished plotting contig000013
#
# Processing contig000014: homologies:1, syntenies:29
# Finished plotting contig000014
#
# Processing contig000015: homologies:1, syntenies:12
# Finished plotting contig000015
#
# Processing contig000016: homologies:1, syntenies:12
# Finished plotting contig000016
#
# Processing contig000017: homologies:2, syntenies:23
# Finished plotting contig000017
#
# Processing contig000018: homologies:2, syntenies:16
# Finished plotting contig000018
#
# Processing contig000019: homologies:2, syntenies:11
# Finished plotting contig000019
#
# Processing contig000020: homologies:1, syntenies:5
# Finished plotting contig000020
#
# Processing contig000022: homologies:1, syntenies:0
# 	Error plotting contig000022! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000022
#
# Processing contig000023: homologies:2, syntenies:0
# 	Error plotting contig000023! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000023
#
# Processing contig000026: homologies:1, syntenies:0
# 	Error plotting contig000026! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000026
#
# Processing contig000027: homologies:2, syntenies:0
# 	Error plotting contig000027! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000027
#
# Processing contig000028: homologies:1, syntenies:1
# Finished plotting contig000028
#
# Processing contig000029: homologies:1, syntenies:0
# 	Error plotting contig000029! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000029
#
# Processing contig000035: homologies:1, syntenies:0
# 	Error plotting contig000035! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000035
#
# Processing contig000036: homologies:1, syntenies:0
# 	Error plotting contig000036! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000036
#
# Processing contig000037: homologies:1, syntenies:0
# 	Error plotting contig000037! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000037
#
# Processing contig000042: homologies:1, syntenies:0
# 	Error plotting contig000042! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000042
#
# Processing contig000045: homologies:1, syntenies:0
# 	Error plotting contig000045! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000045
#
# Processing contig000051: homologies:1, syntenies:0
# 	Error plotting contig000051! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000051
#
# Processing contig000052: homologies:1, syntenies:0
# 	Error plotting contig000052! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000052
#
# Processing contig000054: homologies:1, syntenies:0
# 	Error plotting contig000054! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000054
#
# Processing contig000055: homologies:1, syntenies:0
# 	Error plotting contig000055! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000055
#
# Processing contig000062: homologies:1, syntenies:0
# 	Error plotting contig000062! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000062
#
# Processing contig000066: homologies:1, syntenies:0
# 	Error plotting contig000066! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000066
#
# Finished plotting contigs for URI87H! Have a wonderful day :)
# URI34H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/URI34H
# Processing contig000001: homologies:3, syntenies:745
# Finished plotting contig000001
#
# Processing contig000002: homologies:4, syntenies:54
# Finished plotting contig000002
#
# Processing contig000003: homologies:2, syntenies:12
# Finished plotting contig000003
#
# Processing contig000004: homologies:8, syntenies:34
# Finished plotting contig000004
#
# Processing contig000005: homologies:7, syntenies:16
# Finished plotting contig000005
#
# Processing contig000006: homologies:10, syntenies:13
# Finished plotting contig000006
#
# Processing contig000007: homologies:2, syntenies:6
# Finished plotting contig000007
#
# Processing contig000008: homologies:2, syntenies:13
# Finished plotting contig000008
#
# Processing contig000009: homologies:2, syntenies:24
# Finished plotting contig000009
#
# Processing contig000010: homologies:6, syntenies:7
# Finished plotting contig000010
#
# Processing contig000011: homologies:7, syntenies:19
# Finished plotting contig000011
#
# Processing contig000012: homologies:5, syntenies:11
# Finished plotting contig000012
#
# Processing contig000013: homologies:1, syntenies:1
# Finished plotting contig000013
#
# Processing contig000014: homologies:6, syntenies:19
# Finished plotting contig000014
#
# Processing contig000015: homologies:3, syntenies:9
# Finished plotting contig000015
#
# Processing contig000016: homologies:3, syntenies:7
# Finished plotting contig000016
#
# Processing contig000017: homologies:4, syntenies:7
# Finished plotting contig000017
#
# Processing contig000018: homologies:4, syntenies:6
# Finished plotting contig000018
#
# Processing contig000019: homologies:1, syntenies:4
# Finished plotting contig000019
#
# Processing contig000020: homologies:2, syntenies:2
# Finished plotting contig000020
#
# Processing contig000021: homologies:1, syntenies:0
# 	Error plotting contig000021! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000021
#
# Processing contig000022: homologies:1, syntenies:1
# Finished plotting contig000022
#
# Processing contig000023: homologies:1, syntenies:1
# Finished plotting contig000023
#
# Processing contig000027: homologies:2, syntenies:1
# Finished plotting contig000027
#
# Processing contig000028: homologies:1, syntenies:1
# Finished plotting contig000028
#
# Processing contig000029: homologies:1, syntenies:1
# Finished plotting contig000029
#
# Processing contig000030: homologies:1, syntenies:1
# Finished plotting contig000030
#
# Processing contig000031: homologies:1, syntenies:0
# 	Error plotting contig000031! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000031
#
# Processing contig000032: homologies:1, syntenies:1
# Finished plotting contig000032
#
# Processing contig000033: homologies:1, syntenies:1
# Finished plotting contig000033
#
# Processing contig000034: homologies:1, syntenies:0
# 	Error plotting contig000034! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000034
#
# Processing contig000035: homologies:1, syntenies:1
# Finished plotting contig000035
#
# Processing contig000036: homologies:2, syntenies:0
# 	Error plotting contig000036! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000036
#
# Processing contig000037: homologies:1, syntenies:0
# 	Error plotting contig000037! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000037
#
# Processing contig000039: homologies:1, syntenies:0
# 	Error plotting contig000039! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000039
#
# Processing contig000040: homologies:1, syntenies:0
# 	Error plotting contig000040! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000040
#
# Processing contig000041: homologies:1, syntenies:1
# Finished plotting contig000041
#
# Processing contig000043: homologies:1, syntenies:0
# 	Error plotting contig000043! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000043
#
# Processing contig000047: homologies:1, syntenies:0
# 	Error plotting contig000047! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000047
#
# Processing contig000051: homologies:1, syntenies:0
# 	Error plotting contig000051! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000051
#
# Processing contig000054: homologies:2, syntenies:0
# 	Error plotting contig000054! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000054
#
# Processing contig000055: homologies:1, syntenies:0
# 	Error plotting contig000055! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000055
#
# Processing contig000057: homologies:1, syntenies:0
# 	Error plotting contig000057! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000057
#
# Processing contig000059: homologies:1, syntenies:0
# 	Error plotting contig000059! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000059
#
# Processing contig000060: homologies:1, syntenies:0
# 	Error plotting contig000060! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000060
#
# Processing contig000061: homologies:1, syntenies:0
# 	Error plotting contig000061! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000061
#
# Processing contig000062: homologies:1, syntenies:0
# 	Error plotting contig000062! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000062
#
# Processing contig000063: homologies:1, syntenies:0
# 	Error plotting contig000063! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000063
#
# Processing contig000065: homologies:1, syntenies:0
# 	Error plotting contig000065! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000065
#
# Processing contig000066: homologies:1, syntenies:0
# 	Error plotting contig000066! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000066
#
# Processing contig000069: homologies:1, syntenies:0
# 	Error plotting contig000069! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000069
#
# Processing contig000070: homologies:1, syntenies:0
# 	Error plotting contig000070! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000070
#
# Processing contig000073: homologies:1, syntenies:0
# 	Error plotting contig000073! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000073
#
# Processing contig000075: homologies:1, syntenies:0
# 	Error plotting contig000075! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000075
#
# Processing contig000078: homologies:1, syntenies:0
# 	Error plotting contig000078! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000078
#
# Finished plotting contigs for URI34H! Have a wonderful day :)
# URI88H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/URI88H
# Processing contig000001: homologies:3, syntenies:745
# Finished plotting contig000001
#
# Processing contig000002: homologies:12, syntenies:26
# Finished plotting contig000002
#
# Processing contig000003: homologies:9, syntenies:19
# Finished plotting contig000003
#
# Processing contig000004: homologies:4, syntenies:54
# Finished plotting contig000004
#
# Processing contig000005: homologies:11, syntenies:31
# Finished plotting contig000005
#
# Processing contig000006: homologies:5, syntenies:24
# Finished plotting contig000006
#
# Processing contig000007: homologies:1, syntenies:22
# Finished plotting contig000007
#
# Processing contig000008: homologies:4, syntenies:17
# Finished plotting contig000008
#
# Processing contig000009: homologies:5, syntenies:20
# Finished plotting contig000009
#
# Processing contig000010: homologies:2, syntenies:18
# Finished plotting contig000010
#
# Processing contig000011: homologies:3, syntenies:16
# Finished plotting contig000011
#
# Processing contig000012: homologies:6, syntenies:14
# Finished plotting contig000012
#
# Processing contig000013: homologies:8, syntenies:13
# Finished plotting contig000013
#
# Processing contig000014: homologies:9, syntenies:18
# Finished plotting contig000014
#
# Processing contig000015: homologies:3, syntenies:12
# Finished plotting contig000015
#
# Processing contig000016: homologies:2, syntenies:24
# Finished plotting contig000016
#
# Processing contig000017: homologies:5, syntenies:9
# Finished plotting contig000017
#
# Processing contig000018: homologies:2, syntenies:9
# Finished plotting contig000018
#
# Processing contig000019: homologies:2, syntenies:2
# Finished plotting contig000019
#
# Processing contig000020: homologies:6, syntenies:11
# Finished plotting contig000020
#
# Processing contig000024: homologies:1, syntenies:0
# 	Error plotting contig000024! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000024
#
# Processing contig000026: homologies:1, syntenies:0
# 	Error plotting contig000026! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000026
#
# Processing contig000029: homologies:1, syntenies:0
# 	Error plotting contig000029! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000029
#
# Processing contig000030: homologies:1, syntenies:0
# 	Error plotting contig000030! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000030
#
# Finished plotting contigs for URI88H! Have a wonderful day :)
# URI33H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/URI33H
# Processing contig000001: homologies:3, syntenies:744
# Finished plotting contig000001
#
# Processing contig000002: homologies:3, syntenies:54
# Finished plotting contig000002
#
# Processing contig000003: homologies:2, syntenies:24
# Finished plotting contig000003
#
# Processing contig000004: homologies:6, syntenies:11
# Finished plotting contig000004
#
# Processing contig000005: homologies:3, syntenies:9
# Finished plotting contig000005
#
# Processing contig000006: homologies:7, syntenies:18
# Finished plotting contig000006
#
# Processing contig000007: homologies:5, syntenies:26
# Finished plotting contig000007
#
# Processing contig000008: homologies:7, syntenies:24
# Finished plotting contig000008
#
# Processing contig000009: homologies:8, syntenies:32
# Finished plotting contig000009
#
# Processing contig000010: homologies:10, syntenies:18
# Finished plotting contig000010
#
# Processing contig000011: homologies:9, syntenies:24
# Finished plotting contig000011
#
# Processing contig000012: homologies:4, syntenies:13
# Finished plotting contig000012
#
# Processing contig000013: homologies:3, syntenies:24
# Finished plotting contig000013
#
# Processing contig000014: homologies:5, syntenies:12
# Finished plotting contig000014
#
# Processing contig000015: homologies:3, syntenies:4
# Finished plotting contig000015
#
# Processing contig000016: homologies:2, syntenies:5
# Finished plotting contig000016
#
# Processing contig000017: homologies:2, syntenies:1
# Finished plotting contig000017
#
# Processing contig000018: homologies:1, syntenies:0
# 	Error plotting contig000018! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000018
#
# Processing contig000019: homologies:1, syntenies:0
# 	Error plotting contig000019! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000019
#
# Processing contig000026: homologies:1, syntenies:0
# 	Error plotting contig000026! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000026
#
# Finished plotting contigs for URI33H! Have a wonderful day :)
# UCT110H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/UCT110H
# Processing contig000001: homologies:5, syntenies:746
# Finished plotting contig000001
#
# Processing contig000002: homologies:4, syntenies:54
# Finished plotting contig000002
#
# Processing contig000003: homologies:12, syntenies:32
# Finished plotting contig000003
#
# Processing contig000004: homologies:7, syntenies:26
# Finished plotting contig000004
#
# Processing contig000005: homologies:2, syntenies:14
# Finished plotting contig000005
#
# Processing contig000006: homologies:7, syntenies:30
# Finished plotting contig000006
#
# Processing contig000007: homologies:10, syntenies:14
# Finished plotting contig000007
#
# Processing contig000008: homologies:5, syntenies:14
# Finished plotting contig000008
#
# Processing contig000009: homologies:2, syntenies:2
# Finished plotting contig000009
#
# Processing contig000010: homologies:2, syntenies:24
# Finished plotting contig000010
#
# Processing contig000011: homologies:7, syntenies:12
# Finished plotting contig000011
#
# Processing contig000012: homologies:5, syntenies:6
# Finished plotting contig000012
#
# Processing contig000013: homologies:6, syntenies:22
# Finished plotting contig000013
#
# Processing contig000014: homologies:5, syntenies:9
# Finished plotting contig000014
#
# Processing contig000015: homologies:2, syntenies:13
# Finished plotting contig000015
#
# Processing contig000016: homologies:7, syntenies:16
# Finished plotting contig000016
#
# Processing contig000017: homologies:3, syntenies:6
# Finished plotting contig000017
#
# Processing contig000018: homologies:2, syntenies:4
# Finished plotting contig000018
#
# Processing contig000019: homologies:1, syntenies:6
# Finished plotting contig000019
#
# Processing contig000020: homologies:1, syntenies:2
# Finished plotting contig000020
#
# Processing contig000021: homologies:1, syntenies:0
# 	Error plotting contig000021! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000021
#
# Processing contig000022: homologies:1, syntenies:1
# Finished plotting contig000022
#
# Processing contig000023: homologies:1, syntenies:1
# Finished plotting contig000023
#
# Processing contig000027: homologies:1, syntenies:0
# 	Error plotting contig000027! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000027
#
# Processing contig000028: homologies:1, syntenies:0
# 	Error plotting contig000028! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000028
#
# Processing contig000033: homologies:1, syntenies:0
# 	Error plotting contig000033! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000033
#
# Processing contig000034: homologies:1, syntenies:1
# Finished plotting contig000034
#
# Processing contig000035: homologies:1, syntenies:1
# Finished plotting contig000035
#
# Processing contig000040: homologies:1, syntenies:0
# 	Error plotting contig000040! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000040
#
# Processing contig000049: homologies:1, syntenies:0
# 	Error plotting contig000049! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000049
#
# Processing contig000054: homologies:1, syntenies:0
# 	Error plotting contig000054! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000054
#
# Processing contig000057: homologies:1, syntenies:0
# 	Error plotting contig000057! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000057
#
# Processing contig000070: homologies:1, syntenies:0
# 	Error plotting contig000070! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000070
#
# Processing contig000073: homologies:1, syntenies:0
# 	Error plotting contig000073! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000073
#
# Processing contig000081: homologies:1, syntenies:0
# 	Error plotting contig000081! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000081
#
# Processing contig000089: homologies:1, syntenies:0
# 	Error plotting contig000089! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000089
#
# Processing contig000096: homologies:1, syntenies:0
# 	Error plotting contig000096! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000096
#
# Processing contig000099: homologies:1, syntenies:0
# 	Error plotting contig000099! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000099
#
# Processing contig000103: homologies:1, syntenies:0
# 	Error plotting contig000103! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000103
#
# Processing contig000107: homologies:1, syntenies:0
# 	Error plotting contig000107! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000107
#
# Processing contig000108: homologies:1, syntenies:0
# 	Error plotting contig000108! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000108
#
# Finished plotting contigs for UCT110H! Have a wonderful day :)
# URI39H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/URI39H
# Processing contig000001: homologies:4, syntenies:748
# Finished plotting contig000001
#
# Processing contig000002: homologies:1, syntenies:53
# Finished plotting contig000002
#
# Processing contig000003: homologies:2, syntenies:39
# Finished plotting contig000003
#
# Processing contig000004: homologies:2, syntenies:22
# Finished plotting contig000004
#
# Processing contig000005: homologies:2, syntenies:26
# Finished plotting contig000005
#
# Processing contig000006: homologies:3, syntenies:12
# Finished plotting contig000006
#
# Processing contig000007: homologies:2, syntenies:6
# Finished plotting contig000007
#
# Processing contig000008: homologies:2, syntenies:29
# Finished plotting contig000008
#
# Processing contig000009: homologies:1, syntenies:13
# Finished plotting contig000009
#
# Processing contig000010: homologies:2, syntenies:33
# Finished plotting contig000010
#
# Processing contig000011: homologies:2, syntenies:34
# Finished plotting contig000011
#
# Processing contig000012: homologies:3, syntenies:7
# Finished plotting contig000012
#
# Processing contig000013: homologies:2, syntenies:40
# Finished plotting contig000013
#
# Processing contig000014: homologies:7, syntenies:16
# Finished plotting contig000014
#
# Processing contig000015: homologies:1, syntenies:30
# Finished plotting contig000015
#
# Processing contig000016: homologies:2, syntenies:38
# Finished plotting contig000016
#
# Processing contig000017: homologies:2, syntenies:24
# Finished plotting contig000017
#
# Processing contig000018: homologies:2, syntenies:13
# Finished plotting contig000018
#
# Processing contig000019: homologies:1, syntenies:10
# Finished plotting contig000019
#
# Processing contig000020: homologies:1, syntenies:9
# Finished plotting contig000020
#
# Processing contig000021: homologies:1, syntenies:7
# Finished plotting contig000021
#
# Processing contig000022: homologies:1, syntenies:1
# Finished plotting contig000022
#
# Processing contig000023: homologies:1, syntenies:1
# Finished plotting contig000023
#
# Processing contig000024: homologies:2, syntenies:1
# Finished plotting contig000024
#
# Processing contig000025: homologies:1, syntenies:0
# 	Error plotting contig000025! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000025
#
# Finished plotting contigs for URI39H! Have a wonderful day :)
# URI91H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/URI91H
# Processing contig000001: homologies:3, syntenies:746
# Finished plotting contig000001
#
# Processing contig000002: homologies:2, syntenies:53
# Finished plotting contig000002
#
# Processing contig000003: homologies:1, syntenies:38
# Finished plotting contig000003
#
# Processing contig000004: homologies:2, syntenies:22
# Finished plotting contig000004
#
# Processing contig000005: homologies:1, syntenies:24
# Finished plotting contig000005
#
# Processing contig000006: homologies:1, syntenies:12
# Finished plotting contig000006
#
# Processing contig000007: homologies:2, syntenies:10
# Finished plotting contig000007
#
# Processing contig000008: homologies:1, syntenies:11
# Finished plotting contig000008
#
# Processing contig000009: homologies:1, syntenies:31
# Finished plotting contig000009
#
# Processing contig000010: homologies:1, syntenies:26
# Finished plotting contig000010
#
# Processing contig000011: homologies:3, syntenies:15
# Finished plotting contig000011
#
# Processing contig000012: homologies:1, syntenies:25
# Finished plotting contig000012
#
# Processing contig000013: homologies:3, syntenies:28
# Finished plotting contig000013
#
# Processing contig000014: homologies:2, syntenies:37
# Finished plotting contig000014
#
# Processing contig000015: homologies:2, syntenies:34
# Finished plotting contig000015
#
# Processing contig000016: homologies:2, syntenies:34
# Finished plotting contig000016
#
# Processing contig000017: homologies:1, syntenies:29
# Finished plotting contig000017
#
# Processing contig000018: homologies:1, syntenies:12
# Finished plotting contig000018
#
# Processing contig000019: homologies:4, syntenies:15
# Finished plotting contig000019
#
# Processing contig000020: homologies:2, syntenies:24
# Finished plotting contig000020
#
# Processing contig000021: homologies:2, syntenies:11
# Finished plotting contig000021
#
# Processing contig000022: homologies:2, syntenies:9
# Finished plotting contig000022
#
# Processing contig000023: homologies:1, syntenies:1
# Finished plotting contig000023
#
# Processing contig000024: homologies:1, syntenies:0
# 	Error plotting contig000024! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000024
#
# Processing contig000025: homologies:1, syntenies:0
# 	Error plotting contig000025! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000025
#
# Finished plotting contigs for URI91H! Have a wonderful day :)
# UCT35H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/UCT35H
# Processing contig000001: homologies:3, syntenies:746
# Finished plotting contig000001
#
# Processing contig000002: homologies:13, syntenies:39
# Finished plotting contig000002
#
# Processing contig000003: homologies:4, syntenies:54
# Finished plotting contig000003
#
# Processing contig000004: homologies:13, syntenies:20
# Finished plotting contig000004
#
# Processing contig000005: homologies:11, syntenies:41
# Finished plotting contig000005
#
# Processing contig000006: homologies:5, syntenies:26
# Finished plotting contig000006
#
# Processing contig000007: homologies:2, syntenies:2
# Finished plotting contig000007
#
# Processing contig000008: homologies:8, syntenies:13
# Finished plotting contig000008
#
# Processing contig000009: homologies:3, syntenies:24
# Finished plotting contig000009
#
# Processing contig000010: homologies:2, syntenies:4
# Finished plotting contig000010
#
# Processing contig000011: homologies:3, syntenies:9
# Finished plotting contig000011
#
# Processing contig000012: homologies:4, syntenies:12
# Finished plotting contig000012
#
# Processing contig000013: homologies:1, syntenies:7
# Finished plotting contig000013
#
# Processing contig000014: homologies:5, syntenies:6
# Finished plotting contig000014
#
# Processing contig000015: homologies:2, syntenies:3
# Finished plotting contig000015
#
# Processing contig000016: homologies:1, syntenies:3
# Finished plotting contig000016
#
# Processing contig000018: homologies:1, syntenies:1
# Finished plotting contig000018
#
# Processing contig000020: homologies:1, syntenies:0
# 	Error plotting contig000020! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000020
#
# Processing contig000023: homologies:2, syntenies:0
# 	Error plotting contig000023! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000023
#
# Processing contig000024: homologies:1, syntenies:0
# 	Error plotting contig000024! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000024
#
# Processing contig000026: homologies:1, syntenies:0
# 	Error plotting contig000026! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000026
#
# Finished plotting contigs for UCT35H! Have a wonderful day :)
# UWI247P
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/UWI247P
# Processing MC104_chr: homologies:5, syntenies:746
# Finished plotting MC104_chr
#
# Processing MC104_cp26: homologies:2, syntenies:24
# Finished plotting MC104_cp26
#
# Processing MC104_cp32-1: homologies:6, syntenies:11
# Finished plotting MC104_cp32-1
#
# Processing MC104_cp32-11: homologies:1, syntenies:19
# Finished plotting MC104_cp32-11
#
# Processing MC104_cp32-3: homologies:9, syntenies:32
# Finished plotting MC104_cp32-3
#
# Processing MC104_cp32-4: homologies:2, syntenies:17
# Finished plotting MC104_cp32-4
#
# Processing MC104_cp32-6: homologies:6, syntenies:27
# Finished plotting MC104_cp32-6
#
# Processing MC104_cp32-7: homologies:3, syntenies:11
# Finished plotting MC104_cp32-7
#
# Processing MC104_lp17: homologies:4, syntenies:9
# Finished plotting MC104_lp17
#
# Processing MC104_lp25: homologies:7, syntenies:11
# Finished plotting MC104_lp25
#
# Processing MC104_lp28-1: homologies:5, syntenies:6
# Finished plotting MC104_lp28-1
#
# Processing MC104_lp28-3: homologies:2, syntenies:16
# Finished plotting MC104_lp28-3
#
# Processing MC104_lp28-4: homologies:6, syntenies:14
# Finished plotting MC104_lp28-4
#
# Processing MC104_lp28-5: homologies:2, syntenies:3
# Finished plotting MC104_lp28-5
#
# Processing MC104_lp36: homologies:9, syntenies:18
# Finished plotting MC104_lp36
#
# Processing MC104_lp38: homologies:10, syntenies:14
# Finished plotting MC104_lp38
#
# Processing MC104_lp54: homologies:4, syntenies:53
# Finished plotting MC104_lp54
#
# Finished plotting contigs for UWI247P! Have a wonderful day :)
# URI120H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/URI120H
# Processing contig000001: homologies:1, syntenies:745
# Finished plotting contig000001
#
# Processing contig000002: homologies:1, syntenies:53
# Finished plotting contig000002
#
# Processing contig000003: homologies:1, syntenies:36
# Finished plotting contig000003
#
# Processing contig000004: homologies:1, syntenies:23
# Finished plotting contig000004
#
# Processing contig000005: homologies:1, syntenies:24
# Finished plotting contig000005
#
# Processing contig000006: homologies:1, syntenies:20
# Finished plotting contig000006
#
# Processing contig000008: homologies:2, syntenies:10
# Finished plotting contig000008
#
# Processing contig000009: homologies:1, syntenies:21
# Finished plotting contig000009
#
# Processing contig000010: homologies:3, syntenies:28
# Finished plotting contig000010
#
# Processing contig000011: homologies:2, syntenies:38
# Finished plotting contig000011
#
# Processing contig000012: homologies:2, syntenies:32
# Finished plotting contig000012
#
# Processing contig000013: homologies:2, syntenies:19
# Finished plotting contig000013
#
# Processing contig000014: homologies:1, syntenies:29
# Finished plotting contig000014
#
# Processing contig000015: homologies:1, syntenies:12
# Finished plotting contig000015
#
# Processing contig000016: homologies:2, syntenies:23
# Finished plotting contig000016
#
# Processing contig000017: homologies:7, syntenies:15
# Finished plotting contig000017
#
# Processing contig000018: homologies:2, syntenies:10
# Finished plotting contig000018
#
# Processing contig000019: homologies:3, syntenies:11
# Finished plotting contig000019
#
# Processing contig000020: homologies:2, syntenies:11
# Finished plotting contig000020
#
# Processing contig000021: homologies:2, syntenies:11
# Finished plotting contig000021
#
# Processing contig000022: homologies:2, syntenies:1
# Finished plotting contig000022
#
# Processing contig000023: homologies:1, syntenies:3
# Finished plotting contig000023
#
# Processing contig000024: homologies:1, syntenies:1
# Finished plotting contig000024
#
# Processing contig000026: homologies:1, syntenies:0
# 	Error plotting contig000026! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000026
#
# Processing contig000031: homologies:1, syntenies:0
# 	Error plotting contig000031! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000031
#
# Processing contig000037: homologies:1, syntenies:0
# 	Error plotting contig000037! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000037
#
# Processing contig000039: homologies:2, syntenies:0
# 	Error plotting contig000039! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000039
#
# Processing contig000055: homologies:1, syntenies:1
# Finished plotting contig000055
#
# Processing contig000056: homologies:1, syntenies:1
# Finished plotting contig000056
#
# Processing contig000064: homologies:1, syntenies:0
# 	Error plotting contig000064! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000064
#
# Processing contig000065: homologies:1, syntenies:0
# 	Error plotting contig000065! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000065
#
# Finished plotting contigs for URI120H! Have a wonderful day :)
# URI107H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/URI107H
# Processing contig000001: homologies:3, syntenies:746
# Finished plotting contig000001
#
# Processing contig000002: homologies:1, syntenies:53
# Finished plotting contig000002
#
# Processing contig000003: homologies:2, syntenies:37
# Finished plotting contig000003
#
# Processing contig000004: homologies:1, syntenies:23
# Finished plotting contig000004
#
# Processing contig000005: homologies:1, syntenies:24
# Finished plotting contig000005
#
# Processing contig000006: homologies:1, syntenies:9
# Finished plotting contig000006
#
# Processing contig000007: homologies:3, syntenies:10
# Finished plotting contig000007
#
# Processing contig000008: homologies:3, syntenies:25
# Finished plotting contig000008
#
# Processing contig000009: homologies:2, syntenies:27
# Finished plotting contig000009
#
# Processing contig000010: homologies:2, syntenies:39
# Finished plotting contig000010
#
# Processing contig000011: homologies:2, syntenies:38
# Finished plotting contig000011
#
# Processing contig000012: homologies:2, syntenies:30
# Finished plotting contig000012
#
# Processing contig000013: homologies:1, syntenies:29
# Finished plotting contig000013
#
# Processing contig000014: homologies:1, syntenies:25
# Finished plotting contig000014
#
# Processing contig000015: homologies:2, syntenies:12
# Finished plotting contig000015
#
# Processing contig000016: homologies:1, syntenies:12
# Finished plotting contig000016
#
# Processing contig000017: homologies:2, syntenies:16
# Finished plotting contig000017
#
# Processing contig000018: homologies:2, syntenies:23
# Finished plotting contig000018
#
# Processing contig000019: homologies:2, syntenies:11
# Finished plotting contig000019
#
# Processing contig000020: homologies:1, syntenies:0
# 	Error plotting contig000020! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000020
#
# Processing contig000021: homologies:2, syntenies:0
# 	Error plotting contig000021! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000021
#
# Processing contig000022: homologies:1, syntenies:0
# 	Error plotting contig000022! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000022
#
# Processing contig000023: homologies:1, syntenies:1
# Finished plotting contig000023
#
# Processing contig000024: homologies:1, syntenies:0
# 	Error plotting contig000024! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000024
#
# Processing contig000025: homologies:1, syntenies:0
# 	Error plotting contig000025! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000025
#
# Processing contig000026: homologies:1, syntenies:0
# 	Error plotting contig000026! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000026
#
# Processing contig000027: homologies:1, syntenies:0
# 	Error plotting contig000027! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000027
#
# Processing contig000030: homologies:1, syntenies:0
# 	Error plotting contig000030! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000030
#
# Processing contig000032: homologies:1, syntenies:0
# 	Error plotting contig000032! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000032
#
# Processing contig000035: homologies:1, syntenies:0
# 	Error plotting contig000035! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000035
#
# Processing contig000036: homologies:1, syntenies:0
# 	Error plotting contig000036! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000036
#
# Processing contig000037: homologies:1, syntenies:0
# 	Error plotting contig000037! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000037
#
# Processing contig000038: homologies:1, syntenies:0
# 	Error plotting contig000038! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000038
#
# Processing contig000039: homologies:1, syntenies:0
# 	Error plotting contig000039! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000039
#
# Processing contig000040: homologies:1, syntenies:0
# 	Error plotting contig000040! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000040
#
# Processing contig000043: homologies:1, syntenies:0
# 	Error plotting contig000043! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000043
#
# Processing contig000044: homologies:1, syntenies:0
# 	Error plotting contig000044! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000044
#
# Processing contig000049: homologies:1, syntenies:0
# 	Error plotting contig000049! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000049
#
# Finished plotting contigs for URI107H! Have a wonderful day :)
# UWI263P
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/UWI263P
# Processing MC123_chr: homologies:3, syntenies:745
# Finished plotting MC123_chr
#
# Processing MC123_cp26: homologies:3, syntenies:24
# Finished plotting MC123_cp26
#
# Processing MC123_cp32-11: homologies:4, syntenies:16
# Finished plotting MC123_cp32-11
#
# Processing MC123_cp32-12: homologies:3, syntenies:17
# Finished plotting MC123_cp32-12
#
# Processing MC123_cp32-4: homologies:7, syntenies:15
# Finished plotting MC123_cp32-4
#
# Processing MC123_cp32-5: homologies:6, syntenies:23
# Finished plotting MC123_cp32-5
#
# Processing MC123_cp32-6: homologies:4, syntenies:22
# Finished plotting MC123_cp32-6
#
# Processing MC123_cp32-7: homologies:8, syntenies:29
# Finished plotting MC123_cp32-7
#
# Processing MC123_cp32-9: homologies:4, syntenies:13
# Finished plotting MC123_cp32-9
#
# Processing MC123_cp9: homologies:5, syntenies:6
# Finished plotting MC123_cp9
#
# Processing MC123_lp17: homologies:4, syntenies:9
# Finished plotting MC123_lp17
#
# Processing MC123_lp25: homologies:7, syntenies:11
# Finished plotting MC123_lp25
#
# Processing MC123_lp28-1: homologies:5, syntenies:6
# Finished plotting MC123_lp28-1
#
# Processing MC123_lp28-3: homologies:3, syntenies:16
# Finished plotting MC123_lp28-3
#
# Processing MC123_lp28-4: homologies:6, syntenies:14
# Finished plotting MC123_lp28-4
#
# Processing MC123_lp28-5: homologies:3, syntenies:3
# Finished plotting MC123_lp28-5
#
# Processing MC123_lp36: homologies:9, syntenies:18
# Finished plotting MC123_lp36
#
# Processing MC123_lp38: homologies:11, syntenies:14
# Finished plotting MC123_lp38
#
# Processing MC123_lp54: homologies:4, syntenies:54
# Finished plotting MC123_lp54
#
# Finished plotting contigs for UWI263P! Have a wonderful day :)
# URI89H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/URI89H
# Processing contig000001: homologies:2, syntenies:745
# Finished plotting contig000001
#
# Processing contig000002: homologies:1, syntenies:53
# Finished plotting contig000002
#
# Processing contig000003: homologies:2, syntenies:22
# Finished plotting contig000003
#
# Processing contig000004: homologies:1, syntenies:24
# Finished plotting contig000004
#
# Processing contig000005: homologies:2, syntenies:29
# Finished plotting contig000005
#
# Processing contig000006: homologies:2, syntenies:12
# Finished plotting contig000006
#
# Processing contig000007: homologies:1, syntenies:9
# Finished plotting contig000007
#
# Processing contig000008: homologies:2, syntenies:14
# Finished plotting contig000008
#
# Processing contig000009: homologies:5, syntenies:28
# Finished plotting contig000009
#
# Processing contig000010: homologies:3, syntenies:13
# Finished plotting contig000010
#
# Processing contig000011: homologies:2, syntenies:28
# Finished plotting contig000011
#
# Processing contig000012: homologies:2, syntenies:39
# Finished plotting contig000012
#
# Processing contig000013: homologies:2, syntenies:38
# Finished plotting contig000013
#
# Processing contig000014: homologies:1, syntenies:29
# Finished plotting contig000014
#
# Processing contig000015: homologies:2, syntenies:29
# Finished plotting contig000015
#
# Processing contig000016: homologies:1, syntenies:12
# Finished plotting contig000016
#
# Processing contig000017: homologies:3, syntenies:15
# Finished plotting contig000017
#
# Processing contig000018: homologies:2, syntenies:23
# Finished plotting contig000018
#
# Processing contig000019: homologies:6, syntenies:16
# Finished plotting contig000019
#
# Processing contig000020: homologies:2, syntenies:11
# Finished plotting contig000020
#
# Processing contig000021: homologies:1, syntenies:1
# Finished plotting contig000021
#
# Processing contig000022: homologies:1, syntenies:7
# Finished plotting contig000022
#
# Processing contig000023: homologies:1, syntenies:3
# Finished plotting contig000023
#
# Processing contig000024: homologies:1, syntenies:2
# Finished plotting contig000024
#
# Processing contig000025: homologies:1, syntenies:1
# Finished plotting contig000025
#
# Processing contig000026: homologies:1, syntenies:1
# Finished plotting contig000026
#
# Processing contig000028: homologies:1, syntenies:0
# 	Error plotting contig000028! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000028
#
# Processing contig000043: homologies:1, syntenies:0
# 	Error plotting contig000043! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000043
#
# Processing contig000045: homologies:1, syntenies:0
# 	Error plotting contig000045! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000045
#
# Processing contig000068: homologies:1, syntenies:0
# 	Error plotting contig000068! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000068
#
# Processing contig000069: homologies:1, syntenies:0
# 	Error plotting contig000069! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000069
#
# Finished plotting contigs for URI89H! Have a wonderful day :)
# URI42H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/URI42H
# Processing contig000001: homologies:3, syntenies:745
# Finished plotting contig000001
#
# Processing contig000002: homologies:4, syntenies:48
# Finished plotting contig000002
#
# Processing contig000003: homologies:1, syntenies:53
# Finished plotting contig000003
#
# Processing contig000004: homologies:1, syntenies:25
# Finished plotting contig000004
#
# Processing contig000005: homologies:2, syntenies:12
# Finished plotting contig000005
#
# Processing contig000006: homologies:1, syntenies:9
# Finished plotting contig000006
#
# Processing contig000007: homologies:4, syntenies:22
# Finished plotting contig000007
#
# Processing contig000008: homologies:2, syntenies:30
# Finished plotting contig000008
#
# Processing contig000009: homologies:2, syntenies:31
# Finished plotting contig000009
#
# Processing contig000010: homologies:2, syntenies:36
# Finished plotting contig000010
#
# Processing contig000011: homologies:4, syntenies:13
# Finished plotting contig000011
#
# Processing contig000012: homologies:2, syntenies:38
# Finished plotting contig000012
#
# Processing contig000013: homologies:1, syntenies:29
# Finished plotting contig000013
#
# Processing contig000014: homologies:1, syntenies:12
# Finished plotting contig000014
#
# Processing contig000015: homologies:2, syntenies:23
# Finished plotting contig000015
#
# Processing contig000016: homologies:2, syntenies:11
# Finished plotting contig000016
#
# Processing contig000017: homologies:1, syntenies:3
# Finished plotting contig000017
#
# Processing contig000018: homologies:1, syntenies:2
# Finished plotting contig000018
#
# Processing contig000024: homologies:1, syntenies:0
# 	Error plotting contig000024! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000024
#
# Processing contig000028: homologies:1, syntenies:0
# 	Error plotting contig000028! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000028
#
# Processing contig000031: homologies:1, syntenies:0
# 	Error plotting contig000031! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000031
#
# Processing contig000041: homologies:1, syntenies:0
# 	Error plotting contig000041! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000041
#
# Processing contig000062: homologies:1, syntenies:0
# 	Error plotting contig000062! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000062
#
# Finished plotting contigs for URI42H! Have a wonderful day :)
# URI44H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/URI44H
# Processing contig000001: homologies:6, syntenies:752
# Finished plotting contig000001
#
# Processing contig000002: homologies:4, syntenies:54
# Finished plotting contig000002
#
# Processing contig000003: homologies:4, syntenies:29
# Finished plotting contig000003
#
# Processing contig000004: homologies:1, syntenies:14
# Finished plotting contig000004
#
# Processing contig000005: homologies:6, syntenies:31
# Finished plotting contig000005
#
# Processing contig000006: homologies:10, syntenies:14
# Finished plotting contig000006
#
# Processing contig000007: homologies:5, syntenies:13
# Finished plotting contig000007
#
# Processing contig000008: homologies:11, syntenies:19
# Finished plotting contig000008
#
# Processing contig000009: homologies:2, syntenies:2
# Finished plotting contig000009
#
# Processing contig000010: homologies:1, syntenies:13
# Finished plotting contig000010
#
# Processing contig000011: homologies:2, syntenies:24
# Finished plotting contig000011
#
# Processing contig000012: homologies:5, syntenies:6
# Finished plotting contig000012
#
# Processing contig000013: homologies:7, syntenies:11
# Finished plotting contig000013
#
# Processing contig000014: homologies:6, syntenies:22
# Finished plotting contig000014
#
# Processing contig000015: homologies:5, syntenies:9
# Finished plotting contig000015
#
# Processing contig000016: homologies:6, syntenies:16
# Finished plotting contig000016
#
# Processing contig000017: homologies:7, syntenies:11
# Finished plotting contig000017
#
# Processing contig000018: homologies:3, syntenies:8
# Finished plotting contig000018
#
# Processing contig000019: homologies:3, syntenies:4
# Finished plotting contig000019
#
# Processing contig000023: homologies:1, syntenies:0
# 	Error plotting contig000023! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000023
#
# Processing contig000026: homologies:1, syntenies:1
# Finished plotting contig000026
#
# Processing contig000027: homologies:1, syntenies:0
# 	Error plotting contig000027! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000027
#
# Processing contig000031: homologies:1, syntenies:0
# 	Error plotting contig000031! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000031
#
# Processing contig000034: homologies:1, syntenies:1
# Finished plotting contig000034
#
# Processing contig000055: homologies:1, syntenies:0
# 	Error plotting contig000055! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000055
#
# Processing contig000060: homologies:1, syntenies:0
# 	Error plotting contig000060! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000060
#
# Finished plotting contigs for URI44H! Have a wonderful day :)
# UCT109H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/UCT109H
# Processing contig000001: homologies:3, syntenies:746
# Finished plotting contig000001
#
# Processing contig000002: homologies:3, syntenies:45
# Finished plotting contig000002
#
# Processing contig000003: homologies:1, syntenies:53
# Finished plotting contig000003
#
# Processing contig000004: homologies:3, syntenies:39
# Finished plotting contig000004
#
# Processing contig000005: homologies:2, syntenies:23
# Finished plotting contig000005
#
# Processing contig000006: homologies:1, syntenies:24
# Finished plotting contig000006
#
# Processing contig000007: homologies:3, syntenies:12
# Finished plotting contig000007
#
# Processing contig000008: homologies:1, syntenies:9
# Finished plotting contig000008
#
# Processing contig000009: homologies:3, syntenies:14
# Finished plotting contig000009
#
# Processing contig000010: homologies:4, syntenies:26
# ...
#
# Finished plotting contig000055
#
# Finished plotting contigs for UCT92H! Have a wonderful day :)
# URI118H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/URI118H
# Processing contig000001: homologies:6, syntenies:752
# Finished plotting contig000001
#
# Processing contig000002: homologies:4, syntenies:54
# Finished plotting contig000002
#
# Processing contig000003: homologies:4, syntenies:24
# Finished plotting contig000003
#
# Processing contig000004: homologies:5, syntenies:26
# Finished plotting contig000004
#
# Processing contig000005: homologies:2, syntenies:14
# Finished plotting contig000005
#
# Processing contig000006: homologies:6, syntenies:27
# Finished plotting contig000006
#
# Processing contig000007: homologies:4, syntenies:3
# Finished plotting contig000007
#
# Processing contig000008: homologies:9, syntenies:24
# Finished plotting contig000008
#
# Processing contig000009: homologies:5, syntenies:15
# Finished plotting contig000009
#
# Processing contig000010: homologies:2, syntenies:23
# Finished plotting contig000010
#
# Processing contig000011: homologies:1, syntenies:12
# Finished plotting contig000011
#
# Processing contig000012: homologies:9, syntenies:18
# Finished plotting contig000012
#
# Processing contig000013: homologies:2, syntenies:11
# Finished plotting contig000013
#
# Processing contig000014: homologies:7, syntenies:13
# Finished plotting contig000014
#
# Processing contig000015: homologies:5, syntenies:8
# Finished plotting contig000015
#
# Processing contig000016: homologies:5, syntenies:6
# Finished plotting contig000016
#
# Processing contig000017: homologies:3, syntenies:4
# Finished plotting contig000017
#
# Processing contig000018: homologies:2, syntenies:4
# Finished plotting contig000018
#
# Processing contig000019: homologies:1, syntenies:2
# Finished plotting contig000019
#
# Processing contig000022: homologies:1, syntenies:0
# 	Error plotting contig000022! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000022
#
# Processing contig000024: homologies:1, syntenies:1
# Finished plotting contig000024
#
# Processing contig000025: homologies:1, syntenies:0
# 	Error plotting contig000025! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000025
#
# Processing contig000029: homologies:1, syntenies:0
# 	Error plotting contig000029! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000029
#
# Processing contig000034: homologies:1, syntenies:0
# 	Error plotting contig000034! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000034
#
# Processing contig000050: homologies:1, syntenies:0
# 	Error plotting contig000050! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000050
#
# Processing contig000051: homologies:1, syntenies:0
# 	Error plotting contig000051! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000051
#
# Processing contig000054: homologies:1, syntenies:0
# 	Error plotting contig000054! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000054
#
# Processing contig000055: homologies:1, syntenies:0
# 	Error plotting contig000055! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000055
#
# Processing contig000059: homologies:1, syntenies:0
# 	Error plotting contig000059! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000059
#
# Processing contig000078: homologies:1, syntenies:0
# 	Error plotting contig000078! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000078
#
# Finished plotting contigs for URI118H! Have a wonderful day :)
# UCT50H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/UCT50H
# Processing contig000001: homologies:4, syntenies:744
# Finished plotting contig000001
#
# Processing contig000002: homologies:13, syntenies:46
# Finished plotting contig000002
#
# Processing contig000003: homologies:3, syntenies:54
# Finished plotting contig000003
#
# Processing contig000004: homologies:4, syntenies:21
# Finished plotting contig000004
#
# Processing contig000005: homologies:6, syntenies:18
# Finished plotting contig000005
#
# Processing contig000006: homologies:2, syntenies:6
# Finished plotting contig000006
#
# Processing contig000007: homologies:8, syntenies:24
# Finished plotting contig000007
#
# Processing contig000008: homologies:2, syntenies:24
# Finished plotting contig000008
#
# Processing contig000009: homologies:4, syntenies:10
# Finished plotting contig000009
#
# Processing contig000010: homologies:6, syntenies:15
# Finished plotting contig000010
#
# Processing contig000011: homologies:5, syntenies:20
# Finished plotting contig000011
#
# Processing contig000012: homologies:4, syntenies:12
# Finished plotting contig000012
#
# Processing contig000013: homologies:4, syntenies:19
# Finished plotting contig000013
#
# Processing contig000014: homologies:6, syntenies:7
# Finished plotting contig000014
#
# Processing contig000015: homologies:3, syntenies:7
# Finished plotting contig000015
#
# Processing contig000016: homologies:2, syntenies:1
# Finished plotting contig000016
#
# Processing contig000024: homologies:1, syntenies:0
# 	Error plotting contig000024! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000024
#
# Processing contig000025: homologies:1, syntenies:1
# Finished plotting contig000025
#
# Processing contig000035: homologies:1, syntenies:0
# 	Error plotting contig000035! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000035
#
# Processing contig000048: homologies:1, syntenies:0
# 	Error plotting contig000048! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000048
#
# Processing contig000064: homologies:1, syntenies:0
# 	Error plotting contig000064! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000064
#
# Processing contig000074: homologies:1, syntenies:0
# 	Error plotting contig000074! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000074
#
# Finished plotting contigs for UCT50H! Have a wonderful day :)
# URI101H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/URI101H
# Processing contig000001: homologies:3, syntenies:745
# Finished plotting contig000001
#
# Processing contig000002: homologies:1, syntenies:53
# Finished plotting contig000002
#
# Processing contig000003: homologies:2, syntenies:37
# Finished plotting contig000003
#
# Processing contig000004: homologies:2, syntenies:22
# Finished plotting contig000004
#
# Processing contig000005: homologies:1, syntenies:24
# Finished plotting contig000005
#
# Processing contig000006: homologies:1, syntenies:12
# Finished plotting contig000006
#
# Processing contig000007: homologies:2, syntenies:9
# Finished plotting contig000007
#
# Processing contig000008: homologies:2, syntenies:14
# Finished plotting contig000008
#
# Processing contig000009: homologies:4, syntenies:28
# Finished plotting contig000009
#
# Processing contig000010: homologies:2, syntenies:28
# Finished plotting contig000010
#
# Processing contig000011: homologies:4, syntenies:34
# Finished plotting contig000011
#
# Processing contig000012: homologies:2, syntenies:39
# Finished plotting contig000012
#
# Processing contig000013: homologies:3, syntenies:13
# Finished plotting contig000013
#
# Processing contig000014: homologies:2, syntenies:29
# Finished plotting contig000014
#
# Processing contig000015: homologies:1, syntenies:29
# Finished plotting contig000015
#
# Processing contig000016: homologies:9, syntenies:16
# Finished plotting contig000016
#
# Processing contig000017: homologies:1, syntenies:12
# Finished plotting contig000017
#
# Processing contig000018: homologies:2, syntenies:24
# Finished plotting contig000018
#
# Processing contig000019: homologies:1, syntenies:13
# Finished plotting contig000019
#
# Processing contig000021: homologies:3, syntenies:11
# Finished plotting contig000021
#
# Processing contig000022: homologies:2, syntenies:0
# 	Error plotting contig000022! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000022
#
# Processing contig000023: homologies:1, syntenies:0
# 	Error plotting contig000023! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000023
#
# Processing contig000024: homologies:1, syntenies:1
# Finished plotting contig000024
#
# Processing contig000025: homologies:1, syntenies:0
# 	Error plotting contig000025! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000025
#
# Processing contig000026: homologies:1, syntenies:0
# 	Error plotting contig000026! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000026
#
# Processing contig000027: homologies:1, syntenies:0
# 	Error plotting contig000027! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000027
#
# Processing contig000028: homologies:1, syntenies:0
# 	Error plotting contig000028! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000028
#
# Processing contig000029: homologies:1, syntenies:0
# 	Error plotting contig000029! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000029
#
# Processing contig000030: homologies:1, syntenies:0
# 	Error plotting contig000030! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000030
#
# Processing contig000031: homologies:1, syntenies:0
# 	Error plotting contig000031! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000031
#
# Processing contig000032: homologies:1, syntenies:0
# 	Error plotting contig000032! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000032
#
# Finished plotting contigs for URI101H! Have a wonderful day :)
# URI46H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/URI46H
# Processing contig000001: homologies:4, syntenies:745
# Finished plotting contig000001
#
# Processing contig000002: homologies:11, syntenies:19
# Finished plotting contig000002
#
# Processing contig000003: homologies:4, syntenies:54
# Finished plotting contig000003
#
# Processing contig000004: homologies:8, syntenies:31
# Finished plotting contig000004
#
# Processing contig000005: homologies:5, syntenies:28
# Finished plotting contig000005
#
# Processing contig000006: homologies:8, syntenies:24
# Finished plotting contig000006
#
# Processing contig000007: homologies:10, syntenies:14
# Finished plotting contig000007
#
# Processing contig000008: homologies:3, syntenies:15
# Finished plotting contig000008
#
# Processing contig000009: homologies:4, syntenies:14
# Finished plotting contig000009
#
# Processing contig000010: homologies:2, syntenies:24
# Finished plotting contig000010
#
# Processing contig000011: homologies:7, syntenies:12
# Finished plotting contig000011
#
# Processing contig000012: homologies:6, syntenies:22
# Finished plotting contig000012
#
# Processing contig000013: homologies:4, syntenies:9
# Finished plotting contig000013
#
# Processing contig000014: homologies:7, syntenies:13
# Finished plotting contig000014
#
# Processing contig000015: homologies:3, syntenies:10
# Finished plotting contig000015
#
# Processing contig000016: homologies:5, syntenies:5
# Finished plotting contig000016
#
# Processing contig000017: homologies:4, syntenies:4
# Finished plotting contig000017
#
# Processing contig000018: homologies:2, syntenies:6
# Finished plotting contig000018
#
# Processing contig000019: homologies:2, syntenies:4
# Finished plotting contig000019
#
# Processing contig000020: homologies:1, syntenies:1
# Finished plotting contig000020
#
# Processing contig000021: homologies:1, syntenies:1
# Finished plotting contig000021
#
# Processing contig000022: homologies:1, syntenies:0
# 	Error plotting contig000022! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000022
#
# Processing contig000023: homologies:1, syntenies:1
# Finished plotting contig000023
#
# Processing contig000027: homologies:1, syntenies:0
# 	Error plotting contig000027! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000027
#
# Processing contig000028: homologies:1, syntenies:0
# 	Error plotting contig000028! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000028
#
# Processing contig000032: homologies:1, syntenies:0
# 	Error plotting contig000032! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000032
#
# Processing contig000063: homologies:1, syntenies:0
# 	Error plotting contig000063! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000063
#
# Finished plotting contigs for URI46H! Have a wonderful day :)
# URI48H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/URI48H
# Processing contig000001: homologies:3, syntenies:744
# Finished plotting contig000001
#
# Processing contig000002: homologies:3, syntenies:54
# Finished plotting contig000002
#
# Processing contig000003: homologies:9, syntenies:17
# Finished plotting contig000003
#
# Processing contig000004: homologies:2, syntenies:25
# Finished plotting contig000004
#
# Processing contig000005: homologies:6, syntenies:11
# Finished plotting contig000005
#
# Processing contig000006: homologies:3, syntenies:9
# Finished plotting contig000006
#
# Processing contig000007: homologies:3, syntenies:18
# Finished plotting contig000007
#
# Processing contig000008: homologies:6, syntenies:25
# Finished plotting contig000008
#
# Processing contig000009: homologies:9, syntenies:18
# Finished plotting contig000009
#
# Processing contig000010: homologies:9, syntenies:19
# Finished plotting contig000010
#
# Processing contig000011: homologies:8, syntenies:27
# Finished plotting contig000011
#
# Processing contig000012: homologies:7, syntenies:24
# Finished plotting contig000012
#
# Processing contig000013: homologies:5, syntenies:15
# Finished plotting contig000013
#
# Processing contig000014: homologies:3, syntenies:24
# Finished plotting contig000014
#
# Processing contig000015: homologies:4, syntenies:12
# Finished plotting contig000015
#
# Processing contig000016: homologies:3, syntenies:6
# Finished plotting contig000016
#
# Processing contig000018: homologies:1, syntenies:0
# 	Error plotting contig000018! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000018
#
# Finished plotting contigs for URI48H! Have a wonderful day :)
# URI111H
# True
# True
# /home/mf019/longread_pangenome/synteny/asm_v_b31_subplots/URI111H
# Processing contig000001: homologies:3, syntenies:746
# Finished plotting contig000001
#
# Processing contig000002: homologies:3, syntenies:77
# Finished plotting contig000002
#
# Processing contig000003: homologies:1, syntenies:53
# Finished plotting contig000003
#
# Processing contig000004: homologies:2, syntenies:22
# Finished plotting contig000004
#
# Processing contig000005: homologies:2, syntenies:26
# Finished plotting contig000005
#
# Processing contig000006: homologies:2, syntenies:13
# Finished plotting contig000006
#
# Processing contig000007: homologies:1, syntenies:9
# Finished plotting contig000007
#
# Processing contig000008: homologies:2, syntenies:17
# Finished plotting contig000008
#
# Processing contig000009: homologies:7, syntenies:16
# Finished plotting contig000009
#
# Processing contig000010: homologies:2, syntenies:27
# Finished plotting contig000010
#
# Processing contig000011: homologies:2, syntenies:12
# Finished plotting contig000011
#
# Processing contig000012: homologies:2, syntenies:29
# Finished plotting contig000012
#
# Processing contig000013: homologies:2, syntenies:38
# Finished plotting contig000013
#
# Processing contig000014: homologies:4, syntenies:12
# Finished plotting contig000014
#
# Processing contig000015: homologies:1, syntenies:29
# Finished plotting contig000015
#
# Processing contig000016: homologies:1, syntenies:12
# Finished plotting contig000016
#
# Processing contig000017: homologies:2, syntenies:23
# Finished plotting contig000017
#
# Processing contig000018: homologies:2, syntenies:13
# Finished plotting contig000018
#
# Processing contig000019: homologies:2, syntenies:11
# Finished plotting contig000019
#
# Processing contig000020: homologies:1, syntenies:1
# Finished plotting contig000020
#
# Processing contig000021: homologies:2, syntenies:1
# Finished plotting contig000021
#
# Processing contig000022: homologies:1, syntenies:0
# 	Error plotting contig000022! No syntenies! Attempting to only plot homology!
#
# Finished plotting contig000022
#
# Finished plotting contigs for URI111H! Have a wonderful day :)
