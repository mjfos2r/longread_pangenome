# %%
import os
import glob
from Bio import Entrez
import xml.etree.ElementTree as ET
import time
import pathlib
import pprint

assemblies = 'assemblies'
Entrez.email = "mfoster11@mgh.harvard.edu"

# %%
def printlist(list):
    for item in list:
        print(item)

# %%
def parse_identifiers(text):
    result = {}
    pairs = text.split(';')
    for pair in pairs:
        if ':' in pair:
            key, value = pair.split(':', 1)
            result[key.strip()] = value.strip()
    return result

def parse_xml(element, parent_path=""):
    result = {}
    current_path = f"{parent_path}/{element.tag}" if parent_path else element.tag
    
    # Get attributes
    for key, value in element.attrib.items():
        result[f"{current_path}/@{key}"] = value
    
    # Handle SampleData separately to parse the nested XML
    if element.tag == 'SampleData' and element.text:
        try:
            inner_root = ET.fromstring(element.text.strip())
            inner_results = parse_xml(inner_root, current_path)
            result.update(inner_results)
        except ET.ParseError:
            result[current_path] = element.text.strip()
    elif element.tag == 'Identifiers':
        identifiers = parse_identifiers(element.text)
        for key, value in identifiers.items():
            result[f"{current_path}/{key}"] = value
        
    # Normal element processing
    elif element.text and not element.text.isspace() and not list(element):
        result[current_path] = element.text.strip()
    
    # Process child elements
    for child in element:
        if child.text and child.text.strip() or child.attrib or len(list(child)):
            child_results = parse_xml(child, current_path)
            result.update(child_results)
            
    return result

def get_ncbi_metadata(gcf_id):
    metadata = {}

    # get assembly id
    handle = Entrez.esearch(db="assembly", term=gcf_id)
    record = handle.read().decode()
    handle.close()
    # get asm_id
    asm_id = ET.fromstring(record).find(".//Id").text

    # get assembly summary
    handle = Entrez.esummary(db="assembly", id=asm_id)
    summary = handle.read().decode()
    handle.close()
    
    # parse assembly summary
    root = ET.fromstring(summary)
    asm_description = root.find(".//AssemblyDescription")
    seq_method = root.find(".//AssemblyMethod")
    asm_sum = parse_xml(root)
    metadata['assembly'] = {k.split("/")[-1].replace('@',''): v for k,v in asm_sum.items()}
    
    # get biosample summary
    handle = Entrez.esummary(db="biosample", id=metadata['assembly']['BioSampleId'])
    bs_summary = handle.read().decode()
    handle.close()
    
    # parse biosample summary
    sum_txt = ET.fromstring(bs_summary)
    bs_sum = parse_xml(sum_txt)
    metadata['biosample'] = {k.split("/")[-1].replace('@',''): v for k,v in bs_sum.items()}
    
    return metadata

# %%
genomes = [pathlib.Path(genome).stem for genome in glob.glob('assemblies/complete/*.gff3')]
ids = []
for genome in genomes:
    if genome.startswith(('GCA','GCF')):
        ids.append(genome)
# Out:
# GCF_000172295.2_ASM17229v2_genomic
# GCF_003367295.1_ASM336729v1_genomic
# GCF_000181575.2_ASM18157v2_genomic
# GCF_000008685.2_ASM868v2_genomic
# GCF_000021405.1_ASM2140v1_genomic
# GCF_000181715.2_ASM18171v2_genomic
# GCF_000171735.2_ASM17173v2_genomic
# GCF_000172335.2_ASM17233v2_genomic
# GCF_000166635.1_ASM16663v1_genomic
# GCF_000166655.1_ASM16665v1_genomic
# GCF_002442595.2_ASM244259v2_genomic
# GCF_000181855.2_ASM18185v2_genomic
# GCF_000172315.2_ASM17231v2_genomic
# GCF_000181555.2_ASM18155v2_genomic

# %%
metadata = {}
for asm in ids:
    gcf_id = '_'.join(asm.split('_')[0:2])
    print(gcf_id)
    metadata[asm] = get_ncbi_metadata(gcf_id)
# Out:
# GCF_000172295.2
# None
# GCF_003367295.1
# None
# GCF_000181575.2
# None
# GCF_000008685.2
# None
# GCF_000021405.1
# None
# GCF_000181715.2
# None
# GCF_000171735.2
# None
# GCF_000172335.2
# None
# GCF_000166635.1
# None
# GCF_000166655.1
# None
# GCF_002442595.2
# None
# GCF_000181855.2
# None
# GCF_000172315.2
# None
# GCF_000181555.2
# None

# %%
pprint.pprint(metadata)
# Out:
# {'GCF_000008685.2_ASM868v2_genomic': {'assembly': {'AsmReleaseDate_GenBank': '2012/01/06 '
#                                                                              '00:00',
#                                                    'AsmReleaseDate_RefSeq': '2012/10/16 '
#                                                                             '00:00',
#                                                    'AsmUpdateDate': '2020/03/06 '
#                                                                     '00:00',
#                                                    'AssemblyAccession': 'GCF_000008685.2',
#                                                    'AssemblyName': 'ASM868v2',
#                                                    'AssemblyStatus': 'Complete '
#                                                                      'Genome',
#                                                    'AssemblyStatusSort': '1',
#                                                    'AssemblyType': 'haploid',
#                                                    'BioSampleAccn': 'SAMN02603966',
#                                                    'BioSampleId': '2603966',
#                                                    'BioprojectAccn': 'PRJNA224116',
#                                                    'BioprojectId': '224116',
#                                                    'ChainId': '8685',
#                                                    'ContigN50': '910724',
#                                                    'DbBuild': 'Build241120-0850.1',
#                                                    'FromType': 'assembly from '
#                                                                'type material',
#                                                    'FtpPath_Assembly_rpt': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/008/685/GCF_000008685.2_ASM868v2/GCF_000008685.2_ASM868v2_assembly_report.txt',
#                                                    'FtpPath_GenBank': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/008/685/GCA_000008685.2_ASM868v2',
#                                                    'FtpPath_RefSeq': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/008/685/GCF_000008685.2_ASM868v2',
#                                                    'FtpPath_Stats_rpt': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/008/685/GCF_000008685.2_ASM868v2/GCF_000008685.2_ASM868v2_assembly_stats.txt',
#                                                    'GbUid': '326218',
#                                                    'Genbank': 'GCA_000008685.2',
#                                                    'LastMajorReleaseAccession': 'GCF_000008685.2',
#                                                    'LastUpdateDate': '2020/03/06 '
#                                                                      '00:00',
#                                                    'Meta': '<Stats> <Stat '
#                                                            'category="alt_loci_count" '
#                                                            'sequence_tag="all">0</Stat> '
#                                                            '<Stat '
#                                                            'category="chromosome_count" '
#                                                            'sequence_tag="all">1</Stat> '
#                                                            '<Stat '
#                                                            'category="contig_count" '
#                                                            'sequence_tag="all">22</Stat> '
#                                                            '<Stat '
#                                                            'category="contig_l50" '
#                                                            'sequence_tag="all">1</Stat> '
#                                                            '<Stat '
#                                                            'category="contig_n50" '
#                                                            'sequence_tag="all">910724</Stat> '
#                                                            '<Stat '
#                                                            'category="non_chromosome_replicon_count" '
#                                                            'sequence_tag="all">21</Stat> '
#                                                            '<Stat '
#                                                            'category="replicon_count" '
#                                                            'sequence_tag="all">22</Stat> '
#                                                            '<Stat '
#                                                            'category="scaffold_count" '
#                                                            'sequence_tag="all">22</Stat> '
#                                                            '<Stat '
#                                                            'category="scaffold_count" '
#                                                            'sequence_tag="placed">22</Stat> '
#                                                            '<Stat '
#                                                            'category="scaffold_count" '
#                                                            'sequence_tag="unlocalized">0</Stat> '
#                                                            '<Stat '
#                                                            'category="scaffold_count" '
#                                                            'sequence_tag="unplaced">0</Stat> '
#                                                            '<Stat '
#                                                            'category="scaffold_l50" '
#                                                            'sequence_tag="all">1</Stat> '
#                                                            '<Stat '
#                                                            'category="scaffold_n50" '
#                                                            'sequence_tag="all">910724</Stat> '
#                                                            '<Stat '
#                                                            'category="total_length" '
#                                                            'sequence_tag="all">1521208</Stat> '
#                                                            '<Stat '
#                                                            'category="ungapped_length" '
#                                                            'sequence_tag="all">1521208</Stat> '
#                                                            '</Stats> '
#                                                            '<FtpSites>   '
#                                                            '<FtpPath '
#                                                            'type="Assembly_rpt">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/008/685/GCF_000008685.2_ASM868v2/GCF_000008685.2_ASM868v2_assembly_report.txt</FtpPath>   '
#                                                            '<FtpPath '
#                                                            'type="GenBank">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/008/685/GCA_000008685.2_ASM868v2</FtpPath>   '
#                                                            '<FtpPath '
#                                                            'type="RefSeq">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/008/685/GCF_000008685.2_ASM868v2</FtpPath>   '
#                                                            '<FtpPath '
#                                                            'type="Stats_rpt">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/008/685/GCF_000008685.2_ASM868v2/GCF_000008685.2_ASM868v2_assembly_stats.txt</FtpPath> '
#                                                            '</FtpSites> '
#                                                            '<assembly-level>90</assembly-level> '
#                                                            '<assembly-status>Complete '
#                                                            'Genome</assembly-status> '
#                                                            '<representative-status>na</representative-status> '
#                                                            '<submitter-organization>TIGR</submitter-organization> '
#                                                            '<taxonomy-check-status>OK</taxonomy-check-status>',
#                                                    'Organism': 'Borreliella '
#                                                                'burgdorferi '
#                                                                'B31 (Lyme '
#                                                                'disease '
#                                                                'spirochete)',
#                                                    'PartialGenomeRepresentation': 'false',
#                                                    'Primary': '444928',
#                                                    'RefSeq': 'GCF_000008685.2',
#                                                    'RefSeq_category': 'na',
#                                                    'ReleaseLevel': 'Major',
#                                                    'ReleaseType': 'Major',
#                                                    'RsUid': '444938',
#                                                    'ScaffoldN50': '910724',
#                                                    'SeqReleaseDate': '2011/11/09 '
#                                                                      '00:00',
#                                                    'Similarity': 'identical',
#                                                    'SortOrder': '5C1T82A49990892750000086859797',
#                                                    'SpeciesName': 'Borreliella '
#                                                                   'burgdorferi',
#                                                    'SpeciesTaxid': '139',
#                                                    'Sub_type': 'strain',
#                                                    'Sub_value': 'B31',
#                                                    'SubmissionDate': '2011/11/09 '
#                                                                      '00:00',
#                                                    'SubmitterOrganization': 'TIGR',
#                                                    'Taxid': '224326',
#                                                    'TotalCount': '0',
#                                                    'status': 'OK',
#                                                    'string': 'refseq_has_annotation',
#                                                    'uid': '444938'},
#                                       'biosample': {'Accession': 'SAMN02603966',
#                                                     'Attribute': 'type strain '
#                                                                  'of Borrelia '
#                                                                  'burgdorferi',
#                                                     'BioSample': 'SAMN02603966',
#                                                     'Date': '2014/01/30',
#                                                     'DbBuild': 'Build241121-0746m.1',
#                                                     'Id': 'AE000783',
#                                                     'Infraspecies': 'strain: '
#                                                                     'B31',
#                                                     'Link': '3',
#                                                     'Model': 'Generic',
#                                                     'ModificationDate': '2021/04/04',
#                                                     'Name': 'NCBI',
#                                                     'Organism': 'Borreliella '
#                                                                 'burgdorferi '
#                                                                 'B31',
#                                                     'Organization': 'NCBI',
#                                                     'Package': 'Generic',
#                                                     'PublicationDate': '2014/01/30',
#                                                     'Sample name': 'AE000783',
#                                                     'SortKey': '120210404',
#                                                     'SourceSample': 'BioSample:SAMN02603966',
#                                                     'Taxonomy': '224326',
#                                                     'Title': 'Sample from '
#                                                              'Borreliella '
#                                                              'burgdorferi B31',
#                                                     'access': 'public',
#                                                     'accession': 'SAMN02603966',
#                                                     'attribute_name': 'type-material',
#                                                     'db': 'BioSample',
#                                                     'db_label': 'Sample name',
#                                                     'display_name': 'strain',
#                                                     'harmonized_name': 'strain',
#                                                     'id': '2603966',
#                                                     'is_primary': '1',
#                                                     'label': 'PRJNA3',
#                                                     'last_update': '2021-04-04T02:08:12.317',
#                                                     'publication_date': '2014-01-30T00:00:00.000',
#                                                     'status': 'live',
#                                                     'submission_date': '2014-01-30T14:54:10.403',
#                                                     'target': 'bioproject',
#                                                     'taxonomy_id': '224326',
#                                                     'taxonomy_name': 'Borreliella '
#                                                                      'burgdorferi '
#                                                                      'B31',
#                                                     'type': 'entrez',
#                                                     'uid': '2603966',
#                                                     'version': '1.0',
#                                                     'when': '2014-01-30T14:54:10.403'}},
#  'GCF_000021405.1_ASM2140v1_genomic': {'assembly': {'AsmReleaseDate_GenBank': '2010/05/12 '
#                                                                               '00:00',
#                                                     'AsmReleaseDate_RefSeq': '2010/05/13 '
#                                                                              '00:00',
#                                                     'AsmUpdateDate': '2016/11/29 '
#                                                                      '00:00',
#                                                     'AssemblyAccession': 'GCF_000021405.1',
#                                                     'AssemblyName': 'ASM2140v1',
#                                                     'AssemblyStatus': 'Complete '
#                                                                       'Genome',
#                                                     'AssemblyStatusSort': '1',
#                                                     'AssemblyType': 'haploid',
#                                                     'BioSampleAccn': 'SAMN02603438',
#                                                     'BioSampleId': '2603438',
#                                                     'BioprojectAccn': 'PRJNA224116',
#                                                     'BioprojectId': '224116',
#                                                     'ChainId': '21405',
#                                                     'ContigN50': '906707',
#                                                     'DbBuild': 'Build241120-0850.1',
#                                                     'FtpPath_Assembly_rpt': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/021/405/GCF_000021405.1_ASM2140v1/GCF_000021405.1_ASM2140v1_assembly_report.txt',
#                                                     'FtpPath_GenBank': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/021/405/GCA_000021405.1_ASM2140v1',
#                                                     'FtpPath_RefSeq': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/021/405/GCF_000021405.1_ASM2140v1',
#                                                     'FtpPath_Stats_rpt': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/021/405/GCF_000021405.1_ASM2140v1/GCF_000021405.1_ASM2140v1_assembly_stats.txt',
#                                                     'GbUid': '22208',
#                                                     'Genbank': 'GCA_000021405.1',
#                                                     'LastMajorReleaseAccession': 'GCF_000021405.1',
#                                                     'LastUpdateDate': '2016/11/29 '
#                                                                       '00:00',
#                                                     'Meta': '<Stats> <Stat '
#                                                             'category="alt_loci_count" '
#                                                             'sequence_tag="all">0</Stat> '
#                                                             '<Stat '
#                                                             'category="chromosome_count" '
#                                                             'sequence_tag="all">1</Stat> '
#                                                             '<Stat '
#                                                             'category="contig_count" '
#                                                             'sequence_tag="all">15</Stat> '
#                                                             '<Stat '
#                                                             'category="contig_l50" '
#                                                             'sequence_tag="all">1</Stat> '
#                                                             '<Stat '
#                                                             'category="contig_n50" '
#                                                             'sequence_tag="all">906707</Stat> '
#                                                             '<Stat '
#                                                             'category="non_chromosome_replicon_count" '
#                                                             'sequence_tag="all">14</Stat> '
#                                                             '<Stat '
#                                                             'category="replicon_count" '
#                                                             'sequence_tag="all">15</Stat> '
#                                                             '<Stat '
#                                                             'category="scaffold_count" '
#                                                             'sequence_tag="all">15</Stat> '
#                                                             '<Stat '
#                                                             'category="scaffold_count" '
#                                                             'sequence_tag="placed">15</Stat> '
#                                                             '<Stat '
#                                                             'category="scaffold_count" '
#                                                             'sequence_tag="unlocalized">0</Stat> '
#                                                             '<Stat '
#                                                             'category="scaffold_count" '
#                                                             'sequence_tag="unplaced">0</Stat> '
#                                                             '<Stat '
#                                                             'category="scaffold_l50" '
#                                                             'sequence_tag="all">1</Stat> '
#                                                             '<Stat '
#                                                             'category="scaffold_n50" '
#                                                             'sequence_tag="all">906707</Stat> '
#                                                             '<Stat '
#                                                             'category="total_length" '
#                                                             'sequence_tag="all">1345494</Stat> '
#                                                             '<Stat '
#                                                             'category="ungapped_length" '
#                                                             'sequence_tag="all">1345494</Stat> '
#                                                             '</Stats> '
#                                                             '<FtpSites>   '
#                                                             '<FtpPath '
#                                                             'type="Assembly_rpt">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/021/405/GCF_000021405.1_ASM2140v1/GCF_000021405.1_ASM2140v1_assembly_report.txt</FtpPath>   '
#                                                             '<FtpPath '
#                                                             'type="GenBank">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/021/405/GCA_000021405.1_ASM2140v1</FtpPath>   '
#                                                             '<FtpPath '
#                                                             'type="RefSeq">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/021/405/GCF_000021405.1_ASM2140v1</FtpPath>   '
#                                                             '<FtpPath '
#                                                             'type="Stats_rpt">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/021/405/GCF_000021405.1_ASM2140v1/GCF_000021405.1_ASM2140v1_assembly_stats.txt</FtpPath> '
#                                                             '</FtpSites> '
#                                                             '<assembly-level>90</assembly-level> '
#                                                             '<assembly-status>Complete '
#                                                             'Genome</assembly-status> '
#                                                             '<representative-status>na</representative-status> '
#                                                             '<submitter-organization>J. '
#                                                             'Craig Venter '
#                                                             'Institute</submitter-organization> '
#                                                             '<taxonomy-check-status>OK</taxonomy-check-status>',
#                                                     'Organism': 'Borreliella '
#                                                                 'burgdorferi '
#                                                                 'ZS7 (Lyme '
#                                                                 'disease '
#                                                                 'spirochete)',
#                                                     'PartialGenomeRepresentation': 'false',
#                                                     'Primary': '42418',
#                                                     'RefSeq': 'GCF_000021405.1',
#                                                     'RefSeq_category': 'na',
#                                                     'ReleaseLevel': 'Major',
#                                                     'ReleaseType': 'Major',
#                                                     'RsUid': '42428',
#                                                     'ScaffoldN50': '906707',
#                                                     'SeqReleaseDate': '2008/12/17 '
#                                                                       '00:00',
#                                                     'Similarity': 'identical',
#                                                     'SortOrder': '5C1X82FF9990932920000214059898',
#                                                     'SpeciesName': 'Borreliella '
#                                                                    'burgdorferi',
#                                                     'SpeciesTaxid': '139',
#                                                     'Sub_type': 'strain',
#                                                     'Sub_value': 'ZS7',
#                                                     'SubmissionDate': '2008/12/17 '
#                                                                       '00:00',
#                                                     'SubmitterOrganization': 'J. '
#                                                                              'Craig '
#                                                                              'Venter '
#                                                                              'Institute',
#                                                     'Taxid': '445985',
#                                                     'TotalCount': '0',
#                                                     'status': 'OK',
#                                                     'string': 'refseq_has_annotation',
#                                                     'uid': '42428'},
#                                        'biosample': {'Accession': 'SAMN02603438',
#                                                      'Attribute': 'ZS7',
#                                                      'BioSample': 'SAMN02603438',
#                                                      'Date': '2014/01/30',
#                                                      'DbBuild': 'Build241121-0746m.1',
#                                                      'Id': 'CP001205',
#                                                      'Infraspecies': 'strain: '
#                                                                      'ZS7',
#                                                      'Link': '19839',
#                                                      'Model': 'Generic',
#                                                      'ModificationDate': '2018/06/08',
#                                                      'Name': 'NCBI',
#                                                      'Organism': 'Borreliella '
#                                                                  'burgdorferi '
#                                                                  'ZS7',
#                                                      'Organization': 'NCBI',
#                                                      'Package': 'Generic',
#                                                      'PublicationDate': '2014/01/30',
#                                                      'Sample name': 'CP001205',
#                                                      'SortKey': '120180608',
#                                                      'SourceSample': 'BioSample:SAMN02603438',
#                                                      'Taxonomy': '445985',
#                                                      'Title': 'Sample from '
#                                                               'Borreliella '
#                                                               'burgdorferi ZS7',
#                                                      'access': 'public',
#                                                      'accession': 'SAMN02603438',
#                                                      'attribute_name': 'strain',
#                                                      'db': 'BioSample',
#                                                      'db_label': 'Sample name',
#                                                      'display_name': 'strain',
#                                                      'harmonized_name': 'strain',
#                                                      'id': '2603438',
#                                                      'is_primary': '1',
#                                                      'label': 'PRJNA19839',
#                                                      'last_update': '2018-06-08T21:01:14.008',
#                                                      'publication_date': '2014-01-30T00:00:00.000',
#                                                      'status': 'live',
#                                                      'submission_date': '2014-01-30T14:21:29.893',
#                                                      'target': 'bioproject',
#                                                      'taxonomy_id': '445985',
#                                                      'taxonomy_name': 'Borreliella '
#                                                                       'burgdorferi '
#                                                                       'ZS7',
#                                                      'type': 'entrez',
#                                                      'uid': '2603438',
#                                                      'version': '1.0',
#                                                      'when': '2014-01-30T14:21:29.893'}},
#  'GCF_000166635.1_ASM16663v1_genomic': {'assembly': {'AsmReleaseDate_GenBank': '2011/04/05 '
#                                                                                '00:00',
#                                                      'AsmReleaseDate_RefSeq': '2012/10/16 '
#                                                                               '00:00',
#                                                      'AsmUpdateDate': '2012/10/16 '
#                                                                       '00:00',
#                                                      'AssemblyAccession': 'GCF_000166635.1',
#                                                      'AssemblyName': 'ASM16663v1',
#                                                      'AssemblyStatus': 'Complete '
#                                                                        'Genome',
#                                                      'AssemblyStatusSort': '1',
#                                                      'AssemblyType': 'haploid',
#                                                      'BioSampleAccn': 'SAMN02604202',
#                                                      'BioSampleId': '2604202',
#                                                      'BioprojectAccn': 'PRJNA224116',
#                                                      'BioprojectId': '224116',
#                                                      'ChainId': '166635',
#                                                      'ContigN50': '902191',
#                                                      'DbBuild': 'Build241120-0850.1',
#                                                      'FtpPath_Assembly_rpt': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/166/635/GCF_000166635.1_ASM16663v1/GCF_000166635.1_ASM16663v1_assembly_report.txt',
#                                                      'FtpPath_GenBank': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/166/635/GCA_000166635.2_ASM16663v1',
#                                                      'FtpPath_RefSeq': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/166/635/GCF_000166635.1_ASM16663v1',
#                                                      'FtpPath_Stats_rpt': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/166/635/GCF_000166635.1_ASM16663v1/GCF_000166635.1_ASM16663v1_assembly_stats.txt',
#                                                      'GbUid': '255268',
#                                                      'Genbank': 'GCA_000166635.2',
#                                                      'LastMajorReleaseAccession': 'GCF_000166635.1',
#                                                      'LastUpdateDate': '2012/10/16 '
#                                                                        '00:00',
#                                                      'Meta': '<Stats> <Stat '
#                                                              'category="alt_loci_count" '
#                                                              'sequence_tag="all">0</Stat> '
#                                                              '<Stat '
#                                                              'category="chromosome_count" '
#                                                              'sequence_tag="all">1</Stat> '
#                                                              '<Stat '
#                                                              'category="contig_count" '
#                                                              'sequence_tag="all">17</Stat> '
#                                                              '<Stat '
#                                                              'category="contig_l50" '
#                                                              'sequence_tag="all">1</Stat> '
#                                                              '<Stat '
#                                                              'category="contig_n50" '
#                                                              'sequence_tag="all">902191</Stat> '
#                                                              '<Stat '
#                                                              'category="non_chromosome_replicon_count" '
#                                                              'sequence_tag="all">16</Stat> '
#                                                              '<Stat '
#                                                              'category="replicon_count" '
#                                                              'sequence_tag="all">17</Stat> '
#                                                              '<Stat '
#                                                              'category="scaffold_count" '
#                                                              'sequence_tag="all">17</Stat> '
#                                                              '<Stat '
#                                                              'category="scaffold_count" '
#                                                              'sequence_tag="placed">17</Stat> '
#                                                              '<Stat '
#                                                              'category="scaffold_count" '
#                                                              'sequence_tag="unlocalized">0</Stat> '
#                                                              '<Stat '
#                                                              'category="scaffold_count" '
#                                                              'sequence_tag="unplaced">0</Stat> '
#                                                              '<Stat '
#                                                              'category="scaffold_l50" '
#                                                              'sequence_tag="all">1</Stat> '
#                                                              '<Stat '
#                                                              'category="scaffold_n50" '
#                                                              'sequence_tag="all">902191</Stat> '
#                                                              '<Stat '
#                                                              'category="total_length" '
#                                                              'sequence_tag="all">1339539</Stat> '
#                                                              '<Stat '
#                                                              'category="ungapped_length" '
#                                                              'sequence_tag="all">1339539</Stat> '
#                                                              '</Stats> '
#                                                              '<FtpSites>   '
#                                                              '<FtpPath '
#                                                              'type="Assembly_rpt">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/166/635/GCF_000166635.1_ASM16663v1/GCF_000166635.1_ASM16663v1_assembly_report.txt</FtpPath>   '
#                                                              '<FtpPath '
#                                                              'type="GenBank">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/166/635/GCA_000166635.2_ASM16663v1</FtpPath>   '
#                                                              '<FtpPath '
#                                                              'type="RefSeq">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/166/635/GCF_000166635.1_ASM16663v1</FtpPath>   '
#                                                              '<FtpPath '
#                                                              'type="Stats_rpt">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/166/635/GCF_000166635.1_ASM16663v1/GCF_000166635.1_ASM16663v1_assembly_stats.txt</FtpPath> '
#                                                              '</FtpSites> '
#                                                              '<assembly-level>90</assembly-level> '
#                                                              '<assembly-status>Complete '
#                                                              'Genome</assembly-status> '
#                                                              '<representative-status>na</representative-status> '
#                                                              '<submitter-organization>University '
#                                                              'of Maryland '
#                                                              'School of '
#                                                              'Medicine - '
#                                                              'Institute for '
#                                                              'Genome '
#                                                              'Sciences</submitter-organization> '
#                                                              '<taxonomy-check-status>OK</taxonomy-check-status>',
#                                                      'Organism': 'Borreliella '
#                                                                  'burgdorferi '
#                                                                  'N40 (Lyme '
#                                                                  'disease '
#                                                                  'spirochete)',
#                                                      'PartialGenomeRepresentation': 'false',
#                                                      'Primary': '445188',
#                                                      'RefSeq': 'GCF_000166635.1',
#                                                      'RefSeq_category': 'na',
#                                                      'ReleaseLevel': 'Major',
#                                                      'ReleaseType': 'Major',
#                                                      'RsUid': '445198',
#                                                      'ScaffoldN50': '902191',
#                                                      'SeqReleaseDate': '2010/11/16 '
#                                                                        '00:00',
#                                                      'Similarity': 'identical',
#                                                      'SortOrder': '5C1X82FF9990978080001666359798',
#                                                      'SpeciesName': 'Borreliella '
#                                                                     'burgdorferi',
#                                                      'SpeciesTaxid': '139',
#                                                      'Sub_type': 'strain',
#                                                      'Sub_value': 'N40',
#                                                      'SubmissionDate': '2010/11/16 '
#                                                                        '00:00',
#                                                      'SubmitterOrganization': 'University '
#                                                                               'of '
#                                                                               'Maryland '
#                                                                               'School '
#                                                                               'of '
#                                                                               'Medicine '
#                                                                               '- '
#                                                                               'Institute '
#                                                                               'for '
#                                                                               'Genome '
#                                                                               'Sciences',
#                                                      'Taxid': '521007',
#                                                      'TotalCount': '0',
#                                                      'status': 'OK',
#                                                      'string': 'refseq_has_annotation',
#                                                      'uid': '445198'},
#                                         'biosample': {'Accession': 'SAMN02604202',
#                                                       'Attribute': 'N40',
#                                                       'BioSample': 'SAMN02604202',
#                                                       'Date': '2014/01/30',
#                                                       'DbBuild': 'Build241121-0746m.1',
#                                                       'Id': 'CP002228',
#                                                       'Infraspecies': 'strain: '
#                                                                       'N40',
#                                                       'Link': '29357',
#                                                       'Model': 'Generic',
#                                                       'ModificationDate': '2018/06/08',
#                                                       'Name': 'NCBI',
#                                                       'Organism': 'Borreliella '
#                                                                   'burgdorferi '
#                                                                   'N40',
#                                                       'Organization': 'NCBI',
#                                                       'Package': 'Generic',
#                                                       'PublicationDate': '2014/01/30',
#                                                       'Sample name': 'CP002228',
#                                                       'SortKey': '120180608',
#                                                       'SourceSample': 'BioSample:SAMN02604202',
#                                                       'Taxonomy': '521007',
#                                                       'Title': 'Sample from '
#                                                                'Borreliella '
#                                                                'burgdorferi '
#                                                                'N40',
#                                                       'access': 'public',
#                                                       'accession': 'SAMN02604202',
#                                                       'attribute_name': 'strain',
#                                                       'db': 'BioSample',
#                                                       'db_label': 'Sample name',
#                                                       'display_name': 'strain',
#                                                       'harmonized_name': 'strain',
#                                                       'id': '2604202',
#                                                       'is_primary': '1',
#                                                       'label': 'PRJNA29357',
#                                                       'last_update': '2018-06-08T21:01:17.875',
#                                                       'publication_date': '2014-01-30T00:00:00.000',
#                                                       'status': 'live',
#                                                       'submission_date': '2014-01-30T15:13:18.040',
#                                                       'target': 'bioproject',
#                                                       'taxonomy_id': '521007',
#                                                       'taxonomy_name': 'Borreliella '
#                                                                        'burgdorferi '
#                                                                        'N40',
#                                                       'type': 'entrez',
#                                                       'uid': '2604202',
#                                                       'version': '1.0',
#                                                       'when': '2014-01-30T15:13:18.040'}},
#  'GCF_000166655.1_ASM16665v1_genomic': {'assembly': {'AsmReleaseDate_GenBank': '2010/12/03 '
#                                                                                '00:00',
#                                                      'AsmReleaseDate_RefSeq': '2012/06/18 '
#                                                                               '00:00',
#                                                      'AsmUpdateDate': '2016/11/29 '
#                                                                       '00:00',
#                                                      'AssemblyAccession': 'GCF_000166655.1',
#                                                      'AssemblyName': 'ASM16665v1',
#                                                      'AssemblyStatus': 'Complete '
#                                                                        'Genome',
#                                                      'AssemblyStatusSort': '1',
#                                                      'AssemblyType': 'haploid',
#                                                      'BioSampleAccn': 'SAMN02604203',
#                                                      'BioSampleId': '2604203',
#                                                      'BioprojectAccn': 'PRJNA224116',
#                                                      'BioprojectId': '224116',
#                                                      'ChainId': '166655',
#                                                      'ContigN50': '922801',
#                                                      'DbBuild': 'Build241120-0850.1',
#                                                      'FtpPath_Assembly_rpt': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/166/655/GCF_000166655.1_ASM16665v1/GCF_000166655.1_ASM16665v1_assembly_report.txt',
#                                                      'FtpPath_GenBank': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/166/655/GCA_000166655.2_ASM16665v1',
#                                                      'FtpPath_RefSeq': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/166/655/GCF_000166655.1_ASM16665v1',
# ...
#                                                       'AssemblyName': 'ASM336729v1',
#                                                       'AssemblyStatus': 'Complete '
#                                                                         'Genome',
#                                                       'AssemblyStatusSort': '1',
#                                                       'AssemblyType': 'haploid',
#                                                       'BioSampleAccn': 'SAMN07452586',
#                                                       'BioSampleId': '7452586',
#                                                       'BioprojectAccn': 'PRJNA224116',
#                                                       'BioprojectId': '224116',
#                                                       'ChainId': '3367295',
#                                                       'ContigN50': '908512',
#                                                       'Coverage': '800',
#                                                       'DbBuild': 'Build241120-0850.1',
#                                                       'FtpPath_Assembly_rpt': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/003/367/295/GCF_003367295.1_ASM336729v1/GCF_003367295.1_ASM336729v1_assembly_report.txt',
#                                                       'FtpPath_GenBank': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/003/367/295/GCA_003367295.1_ASM336729v1',
#                                                       'FtpPath_RefSeq': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/003/367/295/GCF_003367295.1_ASM336729v1',
#                                                       'FtpPath_Stats_rpt': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/003/367/295/GCF_003367295.1_ASM336729v1/GCF_003367295.1_ASM336729v1_assembly_stats.txt',
#                                                       'GbUid': '7035338',
#                                                       'Genbank': 'GCA_003367295.1',
#                                                       'LastMajorReleaseAccession': 'GCF_003367295.1',
#                                                       'LastUpdateDate': '2018/08/10 '
#                                                                         '00:00',
#                                                       'Meta': '<Stats> <Stat '
#                                                               'category="alt_loci_count" '
#                                                               'sequence_tag="all">0</Stat> '
#                                                               '<Stat '
#                                                               'category="chromosome_count" '
#                                                               'sequence_tag="all">1</Stat> '
#                                                               '<Stat '
#                                                               'category="contig_count" '
#                                                               'sequence_tag="all">16</Stat> '
#                                                               '<Stat '
#                                                               'category="contig_l50" '
#                                                               'sequence_tag="all">1</Stat> '
#                                                               '<Stat '
#                                                               'category="contig_n50" '
#                                                               'sequence_tag="all">908512</Stat> '
#                                                               '<Stat '
#                                                               'category="non_chromosome_replicon_count" '
#                                                               'sequence_tag="all">15</Stat> '
#                                                               '<Stat '
#                                                               'category="replicon_count" '
#                                                               'sequence_tag="all">16</Stat> '
#                                                               '<Stat '
#                                                               'category="scaffold_count" '
#                                                               'sequence_tag="all">16</Stat> '
#                                                               '<Stat '
#                                                               'category="scaffold_count" '
#                                                               'sequence_tag="placed">16</Stat> '
#                                                               '<Stat '
#                                                               'category="scaffold_count" '
#                                                               'sequence_tag="unlocalized">0</Stat> '
#                                                               '<Stat '
#                                                               'category="scaffold_count" '
#                                                               'sequence_tag="unplaced">0</Stat> '
#                                                               '<Stat '
#                                                               'category="scaffold_l50" '
#                                                               'sequence_tag="all">1</Stat> '
#                                                               '<Stat '
#                                                               'category="scaffold_n50" '
#                                                               'sequence_tag="all">908512</Stat> '
#                                                               '<Stat '
#                                                               'category="total_length" '
#                                                               'sequence_tag="all">1280240</Stat> '
#                                                               '<Stat '
#                                                               'category="ungapped_length" '
#                                                               'sequence_tag="all">1280240</Stat> '
#                                                               '</Stats> '
#                                                               '<FtpSites>   '
#                                                               '<FtpPath '
#                                                               'type="Assembly_rpt">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/003/367/295/GCF_003367295.1_ASM336729v1/GCF_003367295.1_ASM336729v1_assembly_report.txt</FtpPath>   '
#                                                               '<FtpPath '
#                                                               'type="GenBank">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/003/367/295/GCA_003367295.1_ASM336729v1</FtpPath>   '
#                                                               '<FtpPath '
#                                                               'type="RefSeq">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/003/367/295/GCF_003367295.1_ASM336729v1</FtpPath>   '
#                                                               '<FtpPath '
#                                                               'type="Stats_rpt">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/003/367/295/GCF_003367295.1_ASM336729v1/GCF_003367295.1_ASM336729v1_assembly_stats.txt</FtpPath> '
#                                                               '</FtpSites> '
#                                                               '<assembly-level>90</assembly-level> '
#                                                               '<assembly-status>Complete '
#                                                               'Genome</assembly-status> '
#                                                               '<representative-status>na</representative-status> '
#                                                               '<submitter-organization>Institute '
#                                                               'for Systems '
#                                                               'Biology</submitter-organization> '
#                                                               '<taxonomy-check-status>OK</taxonomy-check-status>',
#                                                       'Organism': 'Borreliella '
#                                                                   'burgdorferi '
#                                                                   '(Lyme '
#                                                                   'disease '
#                                                                   'spirochete)',
#                                                       'PartialGenomeRepresentation': 'false',
#                                                       'Primary': '7053338',
#                                                       'RefSeq': 'GCF_003367295.1',
#                                                       'RefSeq_category': 'na',
#                                                       'ReleaseLevel': 'Major',
#                                                       'ReleaseType': 'Major',
#                                                       'RsUid': '7053348',
#                                                       'ScaffoldN50': '908512',
#                                                       'SeqReleaseDate': '2018/08/08 '
#                                                                         '00:00',
#                                                       'Similarity': 'identical',
#                                                       'SortOrder': '5C1X828D9990914870033672959898',
#                                                       'SpeciesName': 'Borreliella '
#                                                                      'burgdorferi',
#                                                       'SpeciesTaxid': '139',
#                                                       'Sub_type': 'strain',
#                                                       'Sub_value': 'MM1',
#                                                       'SubmissionDate': '2018/08/08 '
#                                                                         '00:00',
#                                                       'SubmitterOrganization': 'Institute '
#                                                                                'for '
#                                                                                'Systems '
#                                                                                'Biology',
#                                                       'Taxid': '139',
#                                                       'TotalCount': '0',
#                                                       'status': 'OK',
#                                                       'string': 'refseq_has_annotation',
#                                                       'uid': '1856251'},
#                                          'biosample': {'Accession': 'SAMN07452586',
#                                                        'Attribute': 'NA',
#                                                        'BioSample': 'SAMN07452586',
#                                                        'Date': '2017/08/04',
#                                                        'DbBuild': 'Build241121-0746m.1',
#                                                        'First': 'Christopher',
#                                                        'Id': 'ATCC 51990',
#                                                        'Infraspecies': 'strain: '
#                                                                        'MM1',
#                                                        'Last': 'Lausted',
#                                                        'Link': '397229',
#                                                        'Middle': 'G',
#                                                        'Model': 'Pathogen.cl',
#                                                        'ModificationDate': '2017/08/04',
#                                                        'Name': 'Institute for '
#                                                                'Systems '
#                                                                'Biology',
#                                                        'Organism': 'Borreliella '
#                                                                    'burgdorferi',
#                                                        'OrganismName': 'Borreliella '
#                                                                        'burgdorferi',
#                                                        'Organization': 'Institute '
#                                                                        'for '
#                                                                        'Systems '
#                                                                        'Biology',
#                                                        'Package': 'Pathogen: '
#                                                                   'clinical or '
#                                                                   'host-associated; '
#                                                                   'version 1.0',
#                                                        'PublicationDate': '2017/08/04',
#                                                        'Sample name': 'ATCC '
#                                                                       '51990',
#                                                        'SortKey': '120170804',
#                                                        'SourceSample': 'BioSample:SAMN07452586',
#                                                        'Taxonomy': '139',
#                                                        'Title': 'Borrelia '
#                                                                 'burgdorferi '
#                                                                 'MM1 ATCC '
#                                                                 '51990',
#                                                        'access': 'public',
#                                                        'accession': 'SAMN07452586',
#                                                        'attribute_name': 'subtype',
#                                                        'db': 'BioSample',
#                                                        'db_label': 'Sample '
#                                                                    'name',
#                                                        'display_name': 'subtype',
#                                                        'harmonized_name': 'subtype',
#                                                        'id': '7452586',
#                                                        'is_primary': '1',
#                                                        'label': 'PRJNA397229',
#                                                        'last_update': '2017-08-04T20:01:40.287',
#                                                        'publication_date': '2017-08-04T00:00:00.000',
#                                                        'status': 'live',
#                                                        'submission_date': '2017-08-04T19:37:03.020',
#                                                        'target': 'bioproject',
#                                                        'taxonomy_id': '139',
#                                                        'taxonomy_name': 'Borreliella '
#                                                                         'burgdorferi',
#                                                        'type': 'entrez',
#                                                        'uid': '7452586',
#                                                        'url': 'https://www.systemsbiology.org',
#                                                        'when': '2017-08-04T19:37:03.020'}}}

# %%
from urllib.request import urlopen

for _, asm in metadata.items():
    ftp_path = asm['assembly']['FtpPath_Assembly_rpt']
    print(_, ftp_path)
    with urlopen(ftp_path) as response:
        content = response.read().decode('utf-8')
    for line in content.split('\n'):
        if 'Sequencing Technology' in line:
            print(line)
# Out:
# GCF_000172295.2_ASM17229v2_genomic ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/172/295/GCF_000172295.2_ASM17229v2/GCF_000172295.2_ASM17229v2_assembly_report.txt
# GCF_003367295.1_ASM336729v1_genomic ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/003/367/295/GCF_003367295.1_ASM336729v1/GCF_003367295.1_ASM336729v1_assembly_report.txt
# GCF_000181575.2_ASM18157v2_genomic ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/181/575/GCF_000181575.2_ASM18157v2/GCF_000181575.2_ASM18157v2_assembly_report.txt
# GCF_000008685.2_ASM868v2_genomic ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/008/685/GCF_000008685.2_ASM868v2/GCF_000008685.2_ASM868v2_assembly_report.txt
# GCF_000021405.1_ASM2140v1_genomic ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/021/405/GCF_000021405.1_ASM2140v1/GCF_000021405.1_ASM2140v1_assembly_report.txt
# GCF_000181715.2_ASM18171v2_genomic ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/181/715/GCF_000181715.2_ASM18171v2/GCF_000181715.2_ASM18171v2_assembly_report.txt
# GCF_000171735.2_ASM17173v2_genomic ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/171/735/GCF_000171735.2_ASM17173v2/GCF_000171735.2_ASM17173v2_assembly_report.txt
# GCF_000172335.2_ASM17233v2_genomic ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/172/335/GCF_000172335.2_ASM17233v2/GCF_000172335.2_ASM17233v2_assembly_report.txt
# GCF_000166635.1_ASM16663v1_genomic ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/166/635/GCF_000166635.1_ASM16663v1/GCF_000166635.1_ASM16663v1_assembly_report.txt
# GCF_000166655.1_ASM16665v1_genomic ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/166/655/GCF_000166655.1_ASM16665v1/GCF_000166655.1_ASM16665v1_assembly_report.txt
# GCF_002442595.2_ASM244259v2_genomic ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/442/595/GCF_002442595.2_ASM244259v2/GCF_002442595.2_ASM244259v2_assembly_report.txt
# GCF_000181855.2_ASM18185v2_genomic ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/181/855/GCF_000181855.2_ASM18185v2/GCF_000181855.2_ASM18185v2_assembly_report.txt
# GCF_000172315.2_ASM17231v2_genomic ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/172/315/GCF_000172315.2_ASM17231v2/GCF_000172315.2_ASM17231v2_assembly_report.txt
# GCF_000181555.2_ASM18155v2_genomic ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/181/555/GCF_000181555.2_ASM18155v2/GCF_000181555.2_ASM18155v2_assembly_report.txt

# %%
metadata['GCF_003367295.1_ASM336729v1_genomic']

# GCF_003367295.1_ASM336729v1_genomic == B331 (already in dataset)
# GCF_003367295.1_ASM336729v1_genomic == MM1 (PacBio)
#
# Out:
# {'assembly': {'status': 'OK',
#   'DbBuild': 'Build241120-0850.1',
#   'uid': '1856251',
#   'RsUid': '7053348',
#   'GbUid': '7035338',
#   'AssemblyAccession': 'GCF_003367295.1',
#   'LastMajorReleaseAccession': 'GCF_003367295.1',
#   'ChainId': '3367295',
#   'AssemblyName': 'ASM336729v1',
#   'Taxid': '139',
#   'Organism': 'Borreliella burgdorferi (Lyme disease spirochete)',
#   'SpeciesTaxid': '139',
#   'SpeciesName': 'Borreliella burgdorferi',
#   'AssemblyType': 'haploid',
#   'AssemblyStatus': 'Complete Genome',
#   'AssemblyStatusSort': '1',
#   'BioprojectAccn': 'PRJNA224116',
#   'BioprojectId': '224116',
#   'BioSampleAccn': 'SAMN07452586',
#   'BioSampleId': '7452586',
#   'Sub_type': 'strain',
#   'Sub_value': 'MM1',
#   'Coverage': '800',
#   'PartialGenomeRepresentation': 'false',
#   'Primary': '7053338',
#   'ReleaseLevel': 'Major',
#   'ReleaseType': 'Major',
#   'AsmReleaseDate_GenBank': '2018/08/08 00:00',
#   'AsmReleaseDate_RefSeq': '2018/08/10 00:00',
#   'SeqReleaseDate': '2018/08/08 00:00',
#   'AsmUpdateDate': '2018/08/10 00:00',
#   'SubmissionDate': '2018/08/08 00:00',
#   'LastUpdateDate': '2018/08/10 00:00',
#   'SubmitterOrganization': 'Institute for Systems Biology',
#   'RefSeq_category': 'na',
#   'string': 'refseq_has_annotation',
#   'Genbank': 'GCA_003367295.1',
#   'RefSeq': 'GCF_003367295.1',
#   'Similarity': 'identical',
#   'ContigN50': '908512',
#   'ScaffoldN50': '908512',
#   'FtpPath_GenBank': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/003/367/295/GCA_003367295.1_ASM336729v1',
#   'FtpPath_RefSeq': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/003/367/295/GCF_003367295.1_ASM336729v1',
#   'FtpPath_Assembly_rpt': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/003/367/295/GCF_003367295.1_ASM336729v1/GCF_003367295.1_ASM336729v1_assembly_report.txt',
#   'FtpPath_Stats_rpt': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/003/367/295/GCF_003367295.1_ASM336729v1/GCF_003367295.1_ASM336729v1_assembly_stats.txt',
#   'TotalCount': '0',
#   'SortOrder': '5C1X828D9990914870033672959898',
#   'Meta': '<Stats> <Stat category="alt_loci_count" sequence_tag="all">0</Stat> <Stat category="chromosome_count" sequence_tag="all">1</Stat> <Stat category="contig_count" sequence_tag="all">16</Stat> <Stat category="contig_l50" sequence_tag="all">1</Stat> <Stat category="contig_n50" sequence_tag="all">908512</Stat> <Stat category="non_chromosome_replicon_count" sequence_tag="all">15</Stat> <Stat category="replicon_count" sequence_tag="all">16</Stat> <Stat category="scaffold_count" sequence_tag="all">16</Stat> <Stat category="scaffold_count" sequence_tag="placed">16</Stat> <Stat category="scaffold_count" sequence_tag="unlocalized">0</Stat> <Stat category="scaffold_count" sequence_tag="unplaced">0</Stat> <Stat category="scaffold_l50" sequence_tag="all">1</Stat> <Stat category="scaffold_n50" sequence_tag="all">908512</Stat> <Stat category="total_length" sequence_tag="all">1280240</Stat> <Stat category="ungapped_length" sequence_tag="all">1280240</Stat> </Stats> <FtpSites>   <FtpPath type="Assembly_rpt">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/003/367/295/GCF_003367295.1_ASM336729v1/GCF_003367295.1_ASM336729v1_assembly_report.txt</FtpPath>   <FtpPath type="GenBank">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/003/367/295/GCA_003367295.1_ASM336729v1</FtpPath>   <FtpPath type="RefSeq">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/003/367/295/GCF_003367295.1_ASM336729v1</FtpPath>   <FtpPath type="Stats_rpt">ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/003/367/295/GCF_003367295.1_ASM336729v1/GCF_003367295.1_ASM336729v1_assembly_stats.txt</FtpPath> </FtpSites> <assembly-level>90</assembly-level> <assembly-status>Complete Genome</assembly-status> <representative-status>na</representative-status> <submitter-organization>Institute for Systems Biology</submitter-organization> <taxonomy-check-status>OK</taxonomy-check-status>'},
#  'biosample': {'status': 'live',
#   'DbBuild': 'Build241121-0746m.1',
#   'uid': '7452586',
#   'Title': 'Borrelia burgdorferi MM1 ATCC 51990',
#   'Accession': 'SAMN07452586',
#   'Date': '2017/08/04',
#   'PublicationDate': '2017/08/04',
#   'ModificationDate': '2017/08/04',
#   'Organization': 'Institute for Systems Biology',
#   'Taxonomy': '139',
#   'Organism': 'Borreliella burgdorferi',
#   'SourceSample': 'BioSample:SAMN07452586',
#   'access': 'public',
#   'publication_date': '2017-08-04T00:00:00.000',
#   'last_update': '2017-08-04T20:01:40.287',
#   'submission_date': '2017-08-04T19:37:03.020',
#   'id': '7452586',
#   'accession': 'SAMN07452586',
#   'db': 'BioSample',
#   'is_primary': '1',
#   'Id': 'ATCC 51990',
#   'db_label': 'Sample name',
#   'taxonomy_id': '139',
#   'taxonomy_name': 'Borreliella burgdorferi',
#   'OrganismName': 'Borreliella burgdorferi',
#   'url': 'https://www.systemsbiology.org',
#   'Name': 'Institute for Systems Biology',
#   'First': 'Christopher',
#   'Last': 'Lausted',
#   'Middle': 'G',
#   'Model': 'Pathogen.cl',
#   'display_name': 'subtype',
#   'Package': 'Pathogen: clinical or host-associated; version 1.0',
#   'attribute_name': 'subtype',
#   'harmonized_name': 'subtype',
#   'Attribute': 'NA',
#   'type': 'entrez',
#   'target': 'bioproject',
#   'label': 'PRJNA397229',
#   'Link': '397229',
#   'when': '2017-08-04T19:37:03.020',
#   'BioSample': 'SAMN07452586',
#   'Sample name': 'ATCC 51990',
#   'Infraspecies': 'strain: MM1',
#   'SortKey': '120170804'}}
