# %%
import pandas
import gffutils
import pickle

# %%
negative_correlation_partitions_csv = 'negative_correlation_partitions.csv'
gff_file = '../ref/GCF_000008685.2_ASM868v2_genomic.gff'
db_file = '../ref/B31_gffdb.db'

# %%
id2plasmid = {
    'NC_001318.1':'chromosome',
    'NC_000957.1':'lp5',
    'NC_001904.1':'cp9',
    'NC_001849.2':'lp17',
    'NC_000955.2':'lp21',
    'NC_001850.1':'lp25',
    'NC_001903.1':'cp26',
    'NC_001851.2':'lp28-1',
    'NC_001852.1':'lp28-2',
    'NC_001853.1':'lp28-3',
    'NC_001854.1':'lp28-4',
    'NC_000948.1':'cp32-1',
    'NC_000949.1':'cp32-3',
    'NC_000950.1':'cp32-4',
    'NC_000951.1':'cp32-6',
    'NC_000952.1':'cp32-7',
    'NC_000953.1':'cp32-8',
    'NC_000954.1':'cp32-9',
    'NC_001855.1':'lp36',
    'NC_001856.1':'lp38',
    'NC_001857.2':'lp54',
    'NC_000956.1':'lp56'
}

# %%
gffutils.create_db(gff_file, dbfn=db_file, force=True, keep_order=True, merge_strategy='merge')
db = gffutils.FeatureDB(db_file, keep_order=True)

# %%
# THis is specifically for the negative correlations list of genes that Ben gave me. It is not required for what I am doing below.
neg_corr_df = pandas.read_csv(negative_correlation_partitions_csv)
neg_corr_df['Gene'] = neg_corr_df['Gene'].apply(lambda x: 'gene-' + x)
list_of_genes = neg_corr_df['Gene'].tolist()
neg_corr_df
# Out:
#                 Gene  Partition
# 0    gene-BB_RS05155          9
# 1    gene-BB_RS05160          9
# 2    gene-BB_RS05165          9
# 3    gene-BB_RS05235          9
# 4    gene-BB_RS05170          9
# ..               ...        ...
# 560  gene-BB_RS06060         18
# 561  gene-BB_RS07040         13
# 562  gene-BB_RS03170         11
# 563  gene-BB_RS04390          4
# 564  gene-BB_RS05890         14
#
# [565 rows x 2 columns]

# %%
new_rows = []

for gene in list_of_genes:
    #gene_id = "gene-"+gene
    gene_feature = db[gene]
    children = db.children(gene_feature, level=1)
    for child in children:
        new_row = {
        'Plasmid': id2plasmid[child.seqid],
        'Product': child.attributes.get('product', [''])[0],
        'Protein_ID': child.attributes.get('protein_id', [''])[0],
        'Gene': child.attributes.get('Parent', [''])[0],
        'BB_Name': gene_feature.attributes.get('old_locus_tag', [''])[0],
        }
        new_rows.append(new_row)

df_new_rows = pandas.DataFrame(new_rows)
df_merged = neg_corr_df.merge(df_new_rows, how='left', on='Gene')

# %%
#df_merged = df_merged.sort_values(['Partition','Plasmid']).reset_index(drop=True)

# %%
# don't overwrite this
#df_merged.to_csv('negative_correlation_partitions_annotated_v1.csv', index=False)

# %%
## Okay so now we are going to make a dictionary for gene ID to name/product for ALL proteins and genes.

all_cds = db.features_of_type('CDS')

# %%
for feature in all_cds:
    print(feature)

# %%
# Initialize the dictionary
b31_gene_dict = {}

# Iterate over gene features in the database
for gene in db.features_of_type('CDS'):
    # Assuming 'ID' is the attribute for gene_id in your GFF file
    gene_id = gene.attributes['ID'][0]

    # Extract other required attributes; you might need to adjust these attribute names based on your GFF file
    name = gene.attributes.get('Name', [''])[0]
    replicon = gene.seqid  # Using the seqid field as replicon
    replicon_name = id2plasmid[replicon]
    product = gene.attributes.get('product', [''])[0]
    parent = gene.attributes.get('Parent', [''])[0].replace('gene-', '')
    locus_tag = gene.attributes.get('locus_tag', [''])[0]
    old_locus_tag = gene.attributes.get('old_locus_tag', [''])[0]


    # Store in dictionary
    b31_gene_dict[parent] = {'Protein_ID' : name, 'CDS_id': gene_id, 'replicon': replicon, 'replicon_name' : replicon_name, 'product': product, 'old_locus_tag' : old_locus_tag}

# Optional: print the dictionary to check
print(b31_gene_dict)
b31_ref_pickle = 'b31_gene_dict.pkl'

with open(b31_ref_pickle, 'wb') as outpickle:
    pickle.dump(b31_gene_dict, outpickle)
# Out:
# {'BB_RS00005': {'Protein_ID': 'WP_002658391.1', 'CDS_id': 'cds-WP_002658391.1', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': 'hypothetical protein', 'old_locus_tag': ''}, 'BB_RS00010': {'Protein_ID': 'WP_002658389.1', 'CDS_id': 'cds-WP_002658389.1', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': 'glycoside hydrolase family 3 protein', 'old_locus_tag': ''}, 'BB_RS00015': {'Protein_ID': '', 'CDS_id': 'cds-BB_RS00015', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': 'UTP--glucose-1-phosphate uridylyltransferase', 'old_locus_tag': ''}, 'BB_RS00020': {'Protein_ID': 'WP_020948671.1', 'CDS_id': 'cds-WP_020948671.1', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': 'phosphoglucomutase', 'old_locus_tag': ''}, 'BB_RS00025': {'Protein_ID': 'WP_010889658.1', 'CDS_id': 'cds-WP_010889658.1', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': 'tryptophan--tRNA ligase', 'old_locus_tag': ''}, 'BB_RS00030': {'Protein_ID': 'WP_002658381.1', 'CDS_id': 'cds-WP_002658381.1', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': 'AI-2E family transporter', 'old_locus_tag': ''}, 'BB_RS00035': {'Protein_ID': 'WP_002658378.1', 'CDS_id': 'cds-WP_002658378.1', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': 'HAD family hydrolase', 'old_locus_tag': ''}, 'BB_RS00040': {'Protein_ID': 'WP_002656665.1', 'CDS_id': 'cds-WP_002656665.1', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': 'diadenylate cyclase CdaA', 'old_locus_tag': ''}, 'BB_RS00045': {'Protein_ID': 'WP_010889659.1', 'CDS_id': 'cds-WP_010889659.1', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': 'YbbR-like domain-containing protein', 'old_locus_tag': ''}, 'BB_RS00050': {'Protein_ID': 'WP_002556617.1', 'CDS_id': 'cds-WP_002556617.1', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': "4'-phosphopantetheinyl transferase superfamily protein", 'old_locus_tag': ''}, 'BB_RS00055': {'Protein_ID': 'WP_002556618.1', 'CDS_id': 'cds-WP_002556618.1', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': 'DUF2225 domain-containing protein', 'old_locus_tag': ''}, 'BB_RS00060': {'Protein_ID': 'WP_010889660.1', 'CDS_id': 'cds-WP_010889660.1', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': 'tRNA pseudouridine(38-40) synthase TruA', 'old_locus_tag': ''}, 'BB_RS00065': {'Protein_ID': 'WP_010889661.1', 'CDS_id': 'cds-WP_010889661.1', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': 'hypothetical protein', 'old_locus_tag': ''}, 'BB_RS00070': {'Protein_ID': 'WP_002659035.1', 'CDS_id': 'cds-WP_002659035.1', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': "primosomal protein N'", 'old_locus_tag': ''}, 'BB_RS00075': {'Protein_ID': 'WP_002655979.1', 'CDS_id': 'cds-WP_002655979.1', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': 'uridine kinase', 'old_locus_tag': ''}, 'BB_RS00080': {'Protein_ID': 'WP_002658367.1', 'CDS_id': 'cds-WP_002658367.1', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': 'rhodanese-like domain-containing protein', 'old_locus_tag': ''}, 'BB_RS00085': {'Protein_ID': 'WP_020948674.1', 'CDS_id': 'cds-WP_020948674.1', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': 'YitT family protein', 'old_locus_tag': ''}, 'BB_RS00090': {'Protein_ID': 'WP_002658364.1', 'CDS_id': 'cds-WP_002658364.1', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': 'RluA family pseudouridine synthase', 'old_locus_tag': ''}, 'BB_RS00095': {'Protein_ID': 'WP_002658362.1', 'CDS_id': 'cds-WP_002658362.1', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': 'hypothetical protein', 'old_locus_tag': ''}, 'BB_RS00100': {'Protein_ID': 'WP_002658359.1', 'CDS_id': 'cds-WP_002658359.1', 'replicon': 'NC_001318.1', 'replicon_name': 'chromosome', 'product': 'diphosphate--fructose-6- ...

# %%
sr_gene_presence_absence_file = "/Users/mf019/bioinformatics/longread_pangenome/longread_analysis/v4/shortread_paired_v4/gene_presence_absence.csv"
lr_gene_presence_absence_file = "/Users/mf019/bioinformatics/longread_pangenome/longread_analysis/v4/longread_paired_v4/gene_presence_absence.csv"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 sr_gene_presence_absence_file = "/Users/mf019/bioinformatics/longread_pangenome/longread_analysis/v4/shortread_paired_v4/gene_presence_absence.csv"
#       2 lr_gene_presence_absence_file = "/Users/mf019/bioinformatics/longread_pangenome/longread_analysis/v4/longread_paired_v4/gene_presence_absence.csv"
# ----> 4 lr_gene_pa_df = pandas.read_csv(lr_gene_presence_absence_file, delimiter=',')
#
# NameError: name 'pandas' is not defined

# %%
lr_gene_pa_df = pandas.read_csv(lr_gene_presence_absence_file, delimiter=',')
sr_gene_pa_df = pandas.read_csv(sr_gene_presence_absence_file, delimiter=',')

# %%
# Out:
#                               Gene Non-unique Gene name  \
# 0                Cytosolic protein                  NaN
# 1                             hMG1                  NaN
# 2                       group_1091          Lipoprotein
# 3         BBA07 family lipoprotein                  NaN
# 4  Queuine tRNA-ribosyltransferase                  NaN
#
#                                          Annotation  No. isolates  \
# 0                                 Cytosolic protein            49
# 1  hydroxymethylglutaryl-CoA reductase, degradative            49
# 2                                       Lipoprotein            49
# 3                          BBA07 family lipoprotein            49
# 4                   Queuine tRNA-ribosyltransferase            49
#
#    No. sequences  Avg sequences per isolate  Genome Fragment  \
# 0             49                        1.0               63
# 1             49                        1.0               63
# 2             49                        1.0               63
# 3             49                        1.0               64
# 4             49                        1.0               63
#
#    Order within Fragment  Accessory Fragment  Accessory Order with Fragment  \
# 0                   3286                 NaN                            NaN
# 1                    748                 NaN                            NaN
# 2                    240                 NaN                            NaN
# 3                     47                 NaN                            NaN
# 4                   3270                 NaN                            NaN
#
#    ...         URI86         URI87         URI88         URI89         URI91  \
# 0  ...  GEBMJB_00250  NCOCKI_01290  OHAJAL_00245  CIPKDF_01290  DMHAMM_01290
# 1  ...  GEBMJB_00810  NCOCKI_00730  OHAJAL_00800  CIPKDF_00730  DMHAMM_00730
# 2  ...  GEBMJB_03135  NCOCKI_02510  OHAJAL_03125  CIPKDF_02510  DMHAMM_02510
# 3  ...  GEBMJB_04540  NCOCKI_04550  OHAJAL_05095  CIPKDF_04550  DMHAMM_04550
# 4  ...  GEBMJB_00175  NCOCKI_01365  OHAJAL_00170  CIPKDF_01365  DMHAMM_01365
#
#           URI93        UWI247        UWI248        UWI263        UWI283
# 0  AGFJGC_01290  GGIAGI_01890  AEKFMC_03510  EMEHFM_02570  LGKPKB_03110
# 1  AGFJGC_00730  GGIAGI_03300  AEKFMC_02115  EMEHFM_01720  LGKPKB_03750
# 2  AGFJGC_02510  GGIAGI_02515  AEKFMC_03885  EMEHFM_00655  LGKPKB_04360
# 3  AGFJGC_04550  GGIAGI_05050  AEKFMC_04910  EMEHFM_03965  LGKPKB_05635
# 4  AGFJGC_01365  GGIAGI_03535  AEKFMC_03435  EMEHFM_03260  LGKPKB_03885
#
# [5 rows x 63 columns]

# %%
# Filter rows where the 'Annotation' column contains any of the keywords
keywords = ['partition', 'pf32', 'Pfam32', 'bcsq']
lr_filtered_df = lr_gene_pa_df[lr_gene_pa_df['Annotation'].str.contains('|'.join(keywords), case=False, na=False)]
# Optional: Save the filtered DataFrame to a new CSV file
lr_filtered_df.to_csv('lr_RoaryV4_filtered_output_pf32.csv', index=False)

# Show the first few rows of the filtered DataFrame
print(lr_filtered_df.head())

# Filter rows where the 'Annotation' column contains any of the keywords
keywords = ['partition', 'pf32', 'Pfam32', 'bcsq']
sr_filtered_df = sr_gene_pa_df[sr_gene_pa_df['Annotation'].str.contains('|'.join(keywords), case=False, na=False)]
# Optional: Save the filtered DataFrame to a new CSV file
sr_filtered_df.to_csv('sr_RoaryV4_filtered_output_pf32.csv', index=False)

# Show the first few rows of the filtered DataFrame
print(sr_filtered_df.head())
# Out:
#                                      Gene  \
# 5                              group_1108
# 247                            group_2693
# 336                                  parA
# 569                                  parB
# 619  Borrelia PFam57/62 partition protein
#
#                      Non-unique Gene name  \
# 5    Borrelia PFam57/62 partition protein
# 247  Borrelia PFam57/62 partition protein
# 336                                   NaN
# 569                                   NaN
# 619                                   NaN
#
#                                             Annotation  No. isolates  \
# 5                 Borrelia PFam57/62 partition protein            49
# 247               Borrelia PFam57/62 partition protein            49
# 336  ParA-like ATPase involved in chromosome/plasmi...            49
# 569      putative chromosome-partitioning protein ParB            49
# 619               Borrelia PFam57/62 partition protein            49
#
#      No. sequences  Avg sequences per isolate  Genome Fragment  \
# 5               49                        1.0               37
# 247             49                        1.0               35
# 336             49                        1.0               35
# 569             49                        1.0               35
# 619             49                        1.0               35
#
#      Order within Fragment  Accessory Fragment  Accessory Order with Fragment  \
# 5                       36                 NaN                            NaN
# 247                   3500                 NaN                            NaN
# 336                   3501                 NaN                            NaN
# 569                   3499                 NaN                            NaN
# 619                    216                 NaN                            NaN
#
#      ...        URI86H        URI87H        URI88H        URI89H  \
# 5    ...  IKHOEC_05760  JLNNBJ_07255  FOOKID_07195  JKDFDB_07375
# 247  ...  IKHOEC_02150  JLNNBJ_02160  FOOKID_02150  JKDFDB_02155
# 336  ...  IKHOEC_02145  JLNNBJ_02155  FOOKID_02145  JKDFDB_02150
# 569  ...  IKHOEC_02155  JLNNBJ_02165  FOOKID_02155  JKDFDB_02160
# 619  ...  IKHOEC_01045  JLNNBJ_01050  FOOKID_01045  JKDFDB_01050
#
#            URI91H        URI93H       UWI247P       UWI248P       UWI263P  \
# 5    CFHKPG_07790  EAOOHO_07215  PCFIDF_04325  CEMKAM_04320  FMOGGM_04305
# 247  CFHKPG_02160  EAOOHO_02160  PCFIDF_02150  CEMKAM_02150  FMOGGM_02115
# 336  CFHKPG_02155  EAOOHO_02155  PCFIDF_02145  CEMKAM_02145  FMOGGM_02120
# 569  CFHKPG_02165  EAOOHO_02165  PCFIDF_02155  CEMKAM_02155  FMOGGM_02110
# 619  CFHKPG_01050  EAOOHO_01050  PCFIDF_01045  CEMKAM_01045  FMOGGM_03225
#
#           UWI283P
# 5    JOOONJ_04260
# 247  JOOONJ_02145
# 336  JOOONJ_02140
# 569  JOOONJ_02150
# 619  JOOONJ_01045
#
# [5 rows x 63 columns]
#                                             Gene Non-unique Gene name  \
# 39          Borrelia PFam57/62 partition protein                  NaN
# 289  chromosome replication/partitioning protein                  NaN
# 305                                         parB                  NaN
# 307                                   group_3311                 parA
# 389                                   group_3462                 parA
#
#                                             Annotation  No. isolates  \
# 39                Borrelia PFam57/62 partition protein            49
# 289        chromosome replication/partitioning protein            49
# 305      putative chromosome-partitioning protein ParB            49
# 307  ParA-like ATPase involved in chromosome/plasmi...            49
# 389  ParA-like ATPase involved in chromosome/plasmi...            49
#
#      No. sequences  Avg sequences per isolate  Genome Fragment  \
# 39              49                        1.0               63
# 289             49                        1.0               63
# 305             49                        1.0               63
# 307             49                        1.0               63
# 389             49                        1.0               64
#
#      Order within Fragment  Accessory Fragment  Accessory Order with Fragment  \
# 39                     228                 NaN                            NaN
# 289                   1602                 NaN                            NaN
# 305                    445                 NaN                            NaN
# 307                    443                 NaN                            NaN
# 389                     59                 NaN                            NaN
#
#      ...         URI86         URI87         URI88         URI89  \
# 39   ...  GEBMJB_03200  NCOCKI_02575  OHAJAL_03190  CIPKDF_02575
# 289  ...  GEBMJB_05315  NCOCKI_05445  OHAJAL_04255  CIPKDF_05325
# 305  ...  GEBMJB_02105  NCOCKI_03690  OHAJAL_02095  CIPKDF_03690
# 307  ...  GEBMJB_02115  NCOCKI_03680  OHAJAL_02105  CIPKDF_03680
# 389  ...  GEBMJB_04480  NCOCKI_04490  OHAJAL_05035  CIPKDF_04490
#
#             URI91         URI93        UWI247        UWI248        UWI263  \
# 39   DMHAMM_02575  AGFJGC_02575  GGIAGI_02580  AEKFMC_03950  EMEHFM_00720
# 289  DMHAMM_05425  AGFJGC_05430  GGIAGI_04530  AEKFMC_04255  EMEHFM_04690
# 305  DMHAMM_03690  AGFJGC_03690  GGIAGI_04130  AEKFMC_02935  EMEHFM_01975
# 307  DMHAMM_03680  AGFJGC_03680  GGIAGI_05935  AEKFMC_05060  EMEHFM_05415
# 389  DMHAMM_04490  AGFJGC_04490  GGIAGI_04850  AEKFMC_05020  EMEHFM_03615
#
#            UWI283
# 39   LGKPKB_04425
# 289  LGKPKB_04515
# 305  LGKPKB_01110
# 307  LGKPKB_02065
# 389  LGKPKB_04270
#
# [5 rows x 63 columns]
